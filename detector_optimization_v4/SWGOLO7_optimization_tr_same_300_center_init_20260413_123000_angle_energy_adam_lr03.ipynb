# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_40_300_shower_center_angle_energy"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generate_new_data = True
print("device:", device)
# Out:
# device: cuda

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 300 # 200000
Nvalidation = 300 # 20000
Ntest       = 300 # 3000
Nbatch      = 300 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
use_cache = True
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
            sigma=400
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-2203 m  shift=+5006 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([-1907.7202,  4505.5415, -1643.9329, -1939.2577, -1112.7184,   637.4552,
#         -3818.6675, -4274.4565, -1556.9996, -2235.4377], device='cuda:0')
# Y0: tensor([1422.2808, 5604.9370, 7236.5972,  698.1333,  885.7812, 6356.0146,
#         4484.0601, 3971.6616,  918.8809, 2461.1887], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 7777646.000, energy.max(): 81127968.000
# theta.min():  61.7°, theta.max():  92.6°
# phi.min():    -131.1°, phi.max():    170.7°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# CPU times: user 16.1 ms, sys: 26.4 ms, total: 42.5 ms
# Wall time: 274 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# CPU times: user 22.2 ms, sys: 6.49 ms, total: 28.6 ms
# Wall time: 218 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([300, 90, 5])   labels: torch.Size([300, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0696
# Training 20%  val_loss=0.0694
# Training 30%  val_loss=0.0694
# Training 40%  val_loss=0.0693
# Training 50%  val_loss=0.0692
# Training 60%  val_loss=0.0692
# Training 70%  val_loss=0.0691
# Training 80%  val_loss=0.0691
# CPU times: user 2.76 s, sys: 97.3 ms, total: 2.86 s
# Wall time: 2.92 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
# optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)
optimizer = torch.optim.Adam(                  
      xy_module.parameters(),               
      lr=0.3,              # Adam's effective step ≈ lr, so ~1 m/epoch
      betas=(0.9, 0.999),                                                                                                                                                                                                                                                                          
      eps=1e-8,                           
  )        

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + 1250):

    if epoch < 20:
        Nfinetune = 300 # 3000
    else:
        Nfinetune = 300 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        1e2 * U_angle(preds_th,  th, r_score) +
        1e2 * U_angle(preds_phi, ph, r_score) + 
        1e2 * U_E(preds_e, energy, r_score)   + 0
        # 5e5 * U_PR(r_score)
    ) / 1e3

    U_vals.append(U.item())
    U_th_vals.append( (1e2 * U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( (1e2 * U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   (1e2 * U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  (5e5 * U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=False, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 0  U=4484.968  z_cont=[11.2,12.3]
#   x: grad_norm=21.259342193603516
#   y: grad_norm=70.22843170166016
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1  U=4619.282  z_cont=[11.2,12.3]
#   x: grad_norm=21.66499900817871
#   y: grad_norm=52.86081314086914
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 2  U=4774.008  z_cont=[11.2,12.3]
#   x: grad_norm=21.47216033935547
#   y: grad_norm=42.19428634643555
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 3  U=4897.708  z_cont=[11.2,12.3]
#   x: grad_norm=18.972028732299805
#   y: grad_norm=38.89342498779297
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 4  U=5020.953  z_cont=[11.2,12.3]
#   x: grad_norm=20.944974899291992
#   y: grad_norm=41.64459228515625
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 5  U=5058.980  z_cont=[11.2,12.3]
#   x: grad_norm=25.145723342895508
#   y: grad_norm=42.11993408203125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 6  U=5206.133  z_cont=[11.2,12.3]
#   x: grad_norm=28.534317016601562
#   y: grad_norm=45.62311935424805
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 7  U=5336.214  z_cont=[11.2,12.3]
#   x: grad_norm=22.92450714111328
#   y: grad_norm=41.975303649902344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 8  U=5444.582  z_cont=[11.2,12.3]
#   x: grad_norm=16.60120964050293
#   y: grad_norm=35.133907318115234
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 9  U=5511.756  z_cont=[11.2,12.3]
#   x: grad_norm=10.438241958618164
#   y: grad_norm=18.316591262817383
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 10  U=5500.508  z_cont=[11.2,12.3]
#   x: grad_norm=13.992177963256836
#   y: grad_norm=30.32765769958496
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 11  U=5537.116  z_cont=[11.2,12.3]
#   x: grad_norm=5.510575771331787
#   y: grad_norm=11.254294395446777
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 12  U=5558.939  z_cont=[11.2,12.3]
#   x: grad_norm=32.43738555908203
#   y: grad_norm=293.6557312011719
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 13  U=5549.648  z_cont=[11.2,12.3]
#   x: grad_norm=30.750225067138672
#   y: grad_norm=261.2547302246094
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 14  U=5438.302  z_cont=[11.2,12.3]
#   x: grad_norm=22.37456512451172
#   y: grad_norm=118.56288146972656
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 15  U=5498.233  z_cont=[11.2,12.3]
#   x: grad_norm=12.403529167175293
#   y: grad_norm=34.209228515625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 16  U=5479.939  z_cont=[11.2,12.3]
#   x: grad_norm=25.87457847595215
#   y: grad_norm=225.11618041992188
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 17  U=5488.613  z_cont=[11.3,12.3]
#   x: grad_norm=24.05800437927246
#   y: grad_norm=236.37091064453125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 18  U=5509.286  z_cont=[11.3,12.3]
#   x: grad_norm=22.722856521606445
#   y: grad_norm=213.49957275390625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 19  U=5534.613  z_cont=[11.3,12.3]
#   x: grad_norm=23.13437271118164
#   y: grad_norm=190.599609375
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 20  U=5571.066  z_cont=[11.3,12.3]
#   x: grad_norm=18.443317413330078
#   y: grad_norm=171.89352416992188
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 21  U=5560.963  z_cont=[11.3,12.3]
#   x: grad_norm=22.567350387573242
#   y: grad_norm=235.5182342529297
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 22  U=5560.695  z_cont=[11.3,12.3]
#   x: grad_norm=20.364582061767578
#   y: grad_norm=217.39349365234375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 23  U=5569.306  z_cont=[11.3,12.3]
#   x: grad_norm=18.571149826049805
#   y: grad_norm=179.8901824951172
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 24  U=5581.459  z_cont=[11.3,12.3]
#   x: grad_norm=18.040706634521484
#   y: grad_norm=166.80612182617188
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 25  U=5545.633  z_cont=[11.3,12.3]
#   x: grad_norm=29.288841247558594
#   y: grad_norm=277.73687744140625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 26  U=5560.855  z_cont=[11.3,12.3]
#   x: grad_norm=22.105178833007812
#   y: grad_norm=235.48770141601562
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 27  U=5562.042  z_cont=[11.3,12.4]
#   x: grad_norm=26.186641693115234
#   y: grad_norm=282.3796691894531
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 28  U=5572.217  z_cont=[11.3,12.4]
#   x: grad_norm=27.784502029418945
#   y: grad_norm=296.84002685546875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 29  U=5585.296  z_cont=[11.3,12.4]
#   x: grad_norm=12.762983322143555
#   y: grad_norm=62.41719055175781
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 30  U=5450.387  z_cont=[11.3,12.4]
#   x: grad_norm=32.36609649658203
#   y: grad_norm=275.616455078125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 31  U=5459.089  z_cont=[11.3,12.4]
#   x: grad_norm=29.953031539916992
#   y: grad_norm=245.35528564453125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 32  U=5496.563  z_cont=[11.3,12.4]
#   x: grad_norm=33.56163787841797
#   y: grad_norm=300.88873291015625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 33  U=5556.878  z_cont=[11.3,12.4]
#   x: grad_norm=25.545032501220703
#   y: grad_norm=206.87222290039062
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 34  U=5561.283  z_cont=[11.3,12.4]
#   x: grad_norm=27.118408203125
#   y: grad_norm=293.73822021484375
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 35  U=5501.775  z_cont=[11.3,12.4]
#   x: grad_norm=23.41835594177246
#   y: grad_norm=214.10044860839844
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 36  U=5526.077  z_cont=[11.3,12.4]
#   x: grad_norm=19.950897216796875
#   y: grad_norm=175.30224609375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 37  U=5562.551  z_cont=[11.3,12.4]
#   x: grad_norm=15.027868270874023
#   y: grad_norm=117.05818939208984
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 38  U=5593.115  z_cont=[11.3,12.3]
#   x: grad_norm=16.838520050048828
#   y: grad_norm=116.30795288085938
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 39  U=5612.537  z_cont=[11.3,12.3]
#   x: grad_norm=17.877492904663086
#   y: grad_norm=161.049072265625
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 40  U=5546.672  z_cont=[11.3,12.3]
#   x: grad_norm=23.18206024169922
#   y: grad_norm=199.0877685546875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 41  U=5588.393  z_cont=[11.3,12.3]
#   x: grad_norm=21.5886287689209
#   y: grad_norm=203.54595947265625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 42  U=5612.174  z_cont=[11.3,12.3]
#   x: grad_norm=6.698519229888916
#   y: grad_norm=56.496864318847656
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 43  U=5597.635  z_cont=[11.3,12.3]
#   x: grad_norm=19.86204719543457
#   y: grad_norm=201.09568786621094
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 44  U=5585.326  z_cont=[11.3,12.3]
#   x: grad_norm=24.76416778564453
#   y: grad_norm=251.19593811035156
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 45  U=5604.663  z_cont=[11.3,12.3]
#   x: grad_norm=6.097012042999268
#   y: grad_norm=27.04110336303711
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 46  U=5616.952  z_cont=[11.3,12.3]
#   x: grad_norm=6.13535213470459
#   y: grad_norm=55.121482849121094
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 47  U=5622.213  z_cont=[11.3,12.3]
#   x: grad_norm=5.040387153625488
#   y: grad_norm=31.364837646484375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 48  U=5613.564  z_cont=[11.3,12.3]
#   x: grad_norm=8.311426162719727
#   y: grad_norm=33.99342727661133
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 49  U=5605.699  z_cont=[11.3,12.3]
#   x: grad_norm=9.954275131225586
#   y: grad_norm=44.53295135498047
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 50  U=5607.123  z_cont=[11.3,12.3]
#   x: grad_norm=17.789348602294922
#   y: grad_norm=160.9496612548828
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 51  U=5624.311  z_cont=[11.3,12.3]
#   x: grad_norm=11.08459186553955
#   y: grad_norm=79.85802459716797
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 52  U=5625.518  z_cont=[11.3,12.3]
#   x: grad_norm=13.059122085571289
#   y: grad_norm=149.13104248046875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 53  U=5626.146  z_cont=[11.3,12.3]
#   x: grad_norm=16.864540100097656
#   y: grad_norm=190.23739624023438
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 54  U=5631.079  z_cont=[11.3,12.3]
#   x: grad_norm=9.253114700317383
#   y: grad_norm=88.02760314941406
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 55  U=5560.899  z_cont=[11.3,12.3]
#   x: grad_norm=25.28250503540039
#   y: grad_norm=214.9241943359375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 56  U=5568.237  z_cont=[11.3,12.3]
#   x: grad_norm=23.4400634765625
#   y: grad_norm=203.09536743164062
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 57  U=5590.422  z_cont=[11.3,12.3]
#   x: grad_norm=23.73244285583496
#   y: grad_norm=222.9076690673828
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 58  U=5624.227  z_cont=[11.3,12.3]
#   x: grad_norm=21.174131393432617
#   y: grad_norm=205.94412231445312
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 59  U=5642.829  z_cont=[11.3,12.3]
#   x: grad_norm=13.950237274169922
#   y: grad_norm=137.00643920898438
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 60  U=5622.811  z_cont=[11.3,12.3]
#   x: grad_norm=15.260478973388672
#   y: grad_norm=59.958473205566406
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 61  U=5640.607  z_cont=[11.3,12.3]
#   x: grad_norm=18.83983612060547
#   y: grad_norm=156.78042602539062
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 62  U=5661.112  z_cont=[11.3,12.3]
#   x: grad_norm=20.856521606445312
#   y: grad_norm=171.11929321289062
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 63  U=5683.917  z_cont=[11.3,12.3]
#   x: grad_norm=15.496027946472168
#   y: grad_norm=123.76725769042969
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 64  U=5701.126  z_cont=[11.3,12.3]
#   x: grad_norm=9.67507553100586
#   y: grad_norm=20.325660705566406
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 65  U=5689.175  z_cont=[11.3,12.3]
#   x: grad_norm=20.732004165649414
#   y: grad_norm=154.6979217529297
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 66  U=5690.880  z_cont=[11.3,12.3]
#   x: grad_norm=12.506718635559082
#   y: grad_norm=20.762313842773438
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 67  U=5684.357  z_cont=[11.3,12.3]
#   x: grad_norm=16.396621704101562
#   y: grad_norm=133.59182739257812
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 68  U=5680.799  z_cont=[11.3,12.3]
#   x: grad_norm=18.439441680908203
#   y: grad_norm=152.4434356689453
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 69  U=5684.015  z_cont=[11.3,12.3]
#   x: grad_norm=16.669492721557617
#   y: grad_norm=115.52583312988281
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 70  U=5659.539  z_cont=[11.3,12.3]
#   x: grad_norm=29.906856536865234
#   y: grad_norm=236.4073944091797
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 71  U=5669.598  z_cont=[11.3,12.3]
#   x: grad_norm=29.641599655151367
#   y: grad_norm=239.68017578125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 72  U=5694.898  z_cont=[11.3,12.3]
#   x: grad_norm=23.40382957458496
#   y: grad_norm=187.08277893066406
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 73  U=5712.063  z_cont=[11.3,12.3]
#   x: grad_norm=8.346997261047363
#   y: grad_norm=79.45013427734375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 74  U=5708.982  z_cont=[11.3,12.3]
#   x: grad_norm=16.59751319885254
#   y: grad_norm=148.9508514404297
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 75  U=5657.204  z_cont=[11.3,12.3]
#   x: grad_norm=25.662033081054688
#   y: grad_norm=217.7186737060547
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 76  U=5631.013  z_cont=[11.3,12.3]
#   x: grad_norm=25.127986907958984
#   y: grad_norm=175.67848205566406
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 77  U=5685.536  z_cont=[11.3,12.3]
#   x: grad_norm=18.502403259277344
#   y: grad_norm=134.99444580078125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 78  U=5684.333  z_cont=[11.3,12.3]
#   x: grad_norm=23.112098693847656
#   y: grad_norm=181.19174194335938
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 79  U=5688.001  z_cont=[11.3,12.3]
#   x: grad_norm=16.303550720214844
#   y: grad_norm=79.36930084228516
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 80  U=5655.945  z_cont=[11.3,12.3]
#   x: grad_norm=24.97553253173828
#   y: grad_norm=177.730712890625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 81  U=5669.618  z_cont=[11.3,12.3]
#   x: grad_norm=25.156888961791992
#   y: grad_norm=205.57188415527344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 82  U=5696.144  z_cont=[11.4,12.3]
#   x: grad_norm=18.88020133972168
#   y: grad_norm=156.47079467773438
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 83  U=5714.723  z_cont=[11.4,12.3]
#   x: grad_norm=9.893505096435547
#   y: grad_norm=77.8872299194336
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 84  U=5712.328  z_cont=[11.4,12.3]
#   x: grad_norm=16.52370834350586
#   y: grad_norm=161.53286743164062
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 85  U=5697.491  z_cont=[11.4,12.3]
#   x: grad_norm=14.960814476013184
#   y: grad_norm=46.27235794067383
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 86  U=5704.160  z_cont=[11.4,12.3]
#   x: grad_norm=13.132245063781738
#   y: grad_norm=18.42658042907715
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 87  U=5709.998  z_cont=[11.4,12.3]
#   x: grad_norm=12.671201705932617
#   y: grad_norm=83.43255615234375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 88  U=5671.776  z_cont=[11.4,12.3]
#   x: grad_norm=16.344741821289062
#   y: grad_norm=142.9688720703125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 89  U=5664.880  z_cont=[11.4,12.3]
#   x: grad_norm=23.558889389038086
#   y: grad_norm=195.63687133789062
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 90  U=5620.533  z_cont=[11.4,12.3]
#   x: grad_norm=26.283958435058594
#   y: grad_norm=219.15472412109375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 91  U=5665.737  z_cont=[11.4,12.3]
#   x: grad_norm=24.35803985595703
#   y: grad_norm=192.48297119140625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 92  U=5716.279  z_cont=[11.4,12.3]
#   x: grad_norm=19.97909164428711
#   y: grad_norm=200.4857940673828
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 93  U=5700.735  z_cont=[11.4,12.3]
#   x: grad_norm=26.40119743347168
#   y: grad_norm=236.5648956298828
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 94  U=5700.183  z_cont=[11.4,12.3]
#   x: grad_norm=27.39117431640625
#   y: grad_norm=227.23294067382812
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 95  U=5689.196  z_cont=[11.4,12.3]
#   x: grad_norm=16.0352840423584
#   y: grad_norm=37.59156036376953
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 96  U=5695.508  z_cont=[11.4,12.3]
#   x: grad_norm=22.837522506713867
#   y: grad_norm=193.2857208251953
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 97  U=5706.577  z_cont=[11.4,12.3]
#   x: grad_norm=22.012163162231445
#   y: grad_norm=206.79885864257812
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 98  U=5719.848  z_cont=[11.4,12.3]
#   x: grad_norm=15.833781242370605
#   y: grad_norm=149.373046875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 99  U=5721.884  z_cont=[11.4,12.3]
#   x: grad_norm=10.775260925292969
#   y: grad_norm=89.30794525146484
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 100  U=5671.563  z_cont=[11.4,12.3]
#   x: grad_norm=29.75429344177246
#   y: grad_norm=195.27484130859375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 101  U=5693.536  z_cont=[11.4,12.3]
#   x: grad_norm=16.273189544677734
#   y: grad_norm=33.035850524902344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 102  U=5694.425  z_cont=[11.4,12.3]
#   x: grad_norm=23.586172103881836
#   y: grad_norm=228.9706268310547
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 103  U=5696.999  z_cont=[11.4,12.3]
#   x: grad_norm=28.47593116760254
#   y: grad_norm=286.2842712402344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 104  U=5708.847  z_cont=[11.4,12.3]
#   x: grad_norm=21.485868453979492
#   y: grad_norm=199.3229522705078
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 105  U=5676.251  z_cont=[11.4,12.3]
#   x: grad_norm=31.65192222595215
#   y: grad_norm=294.7372131347656
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 106  U=5674.205  z_cont=[11.4,12.3]
#   x: grad_norm=26.492595672607422
#   y: grad_norm=266.606689453125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 107  U=5690.814  z_cont=[11.4,12.3]
#   x: grad_norm=24.248207092285156
#   y: grad_norm=263.96905517578125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 108  U=5714.167  z_cont=[11.4,12.3]
#   x: grad_norm=10.373549461364746
#   y: grad_norm=72.34200286865234
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 109  U=5698.045  z_cont=[11.4,12.3]
#   x: grad_norm=32.39921569824219
#   y: grad_norm=288.5208740234375
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 110  U=5709.115  z_cont=[11.4,12.3]
#   x: grad_norm=23.083675384521484
#   y: grad_norm=242.28073120117188
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 111  U=5716.553  z_cont=[11.4,12.3]
#   x: grad_norm=17.193233489990234
#   y: grad_norm=183.9803924560547
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 112  U=5716.835  z_cont=[11.4,12.3]
#   x: grad_norm=14.040426254272461
#   y: grad_norm=116.79373931884766
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 113  U=5716.957  z_cont=[11.4,12.3]
#   x: grad_norm=16.629064559936523
#   y: grad_norm=155.90773010253906
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 114  U=5725.262  z_cont=[11.4,12.3]
#   x: grad_norm=4.980220317840576
#   y: grad_norm=23.877681732177734
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 115  U=5697.727  z_cont=[11.4,12.3]
#   x: grad_norm=26.769168853759766
#   y: grad_norm=210.41526794433594
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 116  U=5720.038  z_cont=[11.4,12.3]
#   x: grad_norm=11.496357917785645
#   y: grad_norm=99.16325378417969
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 117  U=5719.786  z_cont=[11.4,12.3]
#   x: grad_norm=18.964101791381836
#   y: grad_norm=188.97410583496094
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 118  U=5719.865  z_cont=[11.4,12.3]
#   x: grad_norm=11.708191871643066
#   y: grad_norm=99.63040161132812
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 119  U=5668.588  z_cont=[11.4,12.3]
#   x: grad_norm=19.996946334838867
#   y: grad_norm=181.8277587890625
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 120  U=5682.265  z_cont=[11.4,12.3]
#   x: grad_norm=31.404705047607422
#   y: grad_norm=256.19818115234375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 121  U=5712.522  z_cont=[11.4,12.3]
#   x: grad_norm=24.69953155517578
#   y: grad_norm=198.95419311523438
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 122  U=5724.399  z_cont=[11.4,12.3]
#   x: grad_norm=15.390090942382812
#   y: grad_norm=160.15045166015625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 123  U=5713.533  z_cont=[11.4,12.3]
#   x: grad_norm=23.65409278869629
#   y: grad_norm=231.2249755859375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 124  U=5715.964  z_cont=[11.4,12.3]
#   x: grad_norm=23.412128448486328
#   y: grad_norm=208.37890625
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 125  U=5686.946  z_cont=[11.4,12.3]
#   x: grad_norm=27.156578063964844
#   y: grad_norm=226.98208618164062
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 126  U=5697.268  z_cont=[11.4,12.3]
#   x: grad_norm=25.552141189575195
#   y: grad_norm=229.84121704101562
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 127  U=5719.672  z_cont=[11.4,12.3]
#   x: grad_norm=18.868288040161133
#   y: grad_norm=179.28704833984375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 128  U=5729.800  z_cont=[11.4,12.3]
#   x: grad_norm=7.6475605964660645
#   y: grad_norm=22.93100929260254
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 129  U=5717.732  z_cont=[11.4,12.3]
#   x: grad_norm=20.306249618530273
#   y: grad_norm=160.72544860839844
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 130  U=5679.381  z_cont=[11.4,12.3]
#   x: grad_norm=12.186494827270508
#   y: grad_norm=52.8236198425293
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 131  U=5698.699  z_cont=[11.4,12.3]
#   x: grad_norm=8.528213500976562
#   y: grad_norm=33.457000732421875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 132  U=5722.013  z_cont=[11.4,12.3]
#   x: grad_norm=6.034915447235107
#   y: grad_norm=30.870986938476562
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 133  U=5730.975  z_cont=[11.4,12.3]
#   x: grad_norm=4.709907531738281
#   y: grad_norm=13.501977920532227
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 134  U=5638.772  z_cont=[11.4,12.3]
#   x: grad_norm=28.250307083129883
#   y: grad_norm=280.6747741699219
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 135  U=5644.083  z_cont=[11.4,12.3]
#   x: grad_norm=23.908409118652344
#   y: grad_norm=242.74107360839844
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 136  U=5640.912  z_cont=[11.4,12.3]
#   x: grad_norm=23.660425186157227
#   y: grad_norm=244.89178466796875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 137  U=5686.057  z_cont=[11.4,12.3]
#   x: grad_norm=13.493253707885742
#   y: grad_norm=125.2668685913086
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 138  U=5645.689  z_cont=[11.4,12.3]
#   x: grad_norm=17.269990921020508
#   y: grad_norm=134.28851318359375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 139  U=5655.011  z_cont=[11.4,12.3]
#   x: grad_norm=15.229649543762207
#   y: grad_norm=118.00918579101562
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 140  U=5607.545  z_cont=[11.4,12.3]
#   x: grad_norm=25.526336669921875
#   y: grad_norm=290.5194396972656
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 141  U=5702.716  z_cont=[11.4,12.3]
#   x: grad_norm=24.620779037475586
#   y: grad_norm=190.48841857910156
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 142  U=5711.310  z_cont=[11.4,12.3]
#   x: grad_norm=14.908852577209473
#   y: grad_norm=129.0098114013672
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 143  U=5708.357  z_cont=[11.4,12.3]
#   x: grad_norm=12.288125038146973
#   y: grad_norm=64.46333312988281
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 144  U=5719.928  z_cont=[11.4,12.3]
#   x: grad_norm=9.554098129272461
#   y: grad_norm=76.02715301513672
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 145  U=5693.726  z_cont=[11.4,12.3]
#   x: grad_norm=18.261754989624023
#   y: grad_norm=125.36004638671875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 146  U=5722.659  z_cont=[11.4,12.3]
#   x: grad_norm=10.96139907836914
#   y: grad_norm=37.19365310668945
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 147  U=5698.723  z_cont=[11.4,12.3]
#   x: grad_norm=31.98589515686035
#   y: grad_norm=220.7796173095703
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 148  U=5699.746  z_cont=[11.4,12.3]
#   x: grad_norm=14.98449420928955
#   y: grad_norm=60.598350524902344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 149  U=5706.965  z_cont=[11.4,12.3]
#   x: grad_norm=10.456398010253906
#   y: grad_norm=42.44197463989258
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 150  U=5671.489  z_cont=[11.4,12.3]
#   x: grad_norm=19.986093521118164
#   y: grad_norm=70.59807586669922
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 151  U=5688.745  z_cont=[11.4,12.3]
#   x: grad_norm=19.63728141784668
#   y: grad_norm=72.04918670654297
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 152  U=5703.782  z_cont=[11.4,12.3]
#   x: grad_norm=12.018763542175293
#   y: grad_norm=37.34370422363281
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 153  U=5681.097  z_cont=[11.4,12.3]
#   x: grad_norm=10.960257530212402
#   y: grad_norm=24.72979736328125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 154  U=5672.652  z_cont=[11.4,12.3]
#   x: grad_norm=12.036772727966309
#   y: grad_norm=33.742740631103516
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 155  U=5630.852  z_cont=[11.4,12.3]
#   x: grad_norm=16.74918556213379
#   y: grad_norm=46.981868743896484
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 156  U=5603.442  z_cont=[11.4,12.3]
#   x: grad_norm=13.881321907043457
#   y: grad_norm=28.214414596557617
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 157  U=5602.920  z_cont=[11.4,12.3]
#   x: grad_norm=13.364628791809082
#   y: grad_norm=28.57921600341797
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 158  U=5609.183  z_cont=[11.4,12.3]
#   x: grad_norm=14.167792320251465
#   y: grad_norm=31.209087371826172
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 159  U=5626.145  z_cont=[11.4,12.3]
#   x: grad_norm=14.851909637451172
#   y: grad_norm=35.16150665283203
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 160  U=5635.389  z_cont=[11.4,12.3]
#   x: grad_norm=10.901267051696777
#   y: grad_norm=32.820796966552734
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 161  U=5659.434  z_cont=[11.4,12.3]
#   x: grad_norm=11.072876930236816
#   y: grad_norm=48.8629264831543
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 162  U=5664.354  z_cont=[11.4,12.3]
#   x: grad_norm=9.562363624572754
#   y: grad_norm=26.955947875976562
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 163  U=5651.696  z_cont=[11.4,12.3]
#   x: grad_norm=12.94771671295166
#   y: grad_norm=70.49189758300781
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 164  U=5653.149  z_cont=[11.4,12.3]
#   x: grad_norm=11.214588165283203
#   y: grad_norm=33.359901428222656
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 165  U=5637.318  z_cont=[11.4,12.3]
#   x: grad_norm=23.40584373474121
#   y: grad_norm=45.850162506103516
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 166  U=5676.990  z_cont=[11.4,12.3]
#   x: grad_norm=14.006393432617188
#   y: grad_norm=29.560625076293945
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 167  U=5710.519  z_cont=[11.4,12.3]
#   x: grad_norm=24.229412078857422
#   y: grad_norm=157.9952850341797
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 168  U=5730.719  z_cont=[11.4,12.3]
#   x: grad_norm=12.418743133544922
#   y: grad_norm=69.90510559082031
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 169  U=5726.140  z_cont=[11.4,12.3]
#   x: grad_norm=10.39711856842041
#   y: grad_norm=59.84189224243164
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 170  U=5671.295  z_cont=[11.4,12.3]
#   x: grad_norm=16.896652221679688
#   y: grad_norm=65.15131378173828
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 171  U=5707.341  z_cont=[11.4,12.3]
#   x: grad_norm=17.882368087768555
#   y: grad_norm=99.84223937988281
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 172  U=5737.888  z_cont=[11.4,12.3]
#   x: grad_norm=3.411458969116211
#   y: grad_norm=14.994876861572266
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 173  U=5713.283  z_cont=[11.4,12.3]
#   x: grad_norm=21.996973037719727
#   y: grad_norm=129.8674774169922
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 174  U=5722.161  z_cont=[11.4,12.3]
#   x: grad_norm=15.489622116088867
#   y: grad_norm=79.1419677734375
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 175  U=5711.424  z_cont=[11.4,12.3]
#   x: grad_norm=13.837080001831055
#   y: grad_norm=56.22225570678711
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 176  U=5718.569  z_cont=[11.4,12.3]
#   x: grad_norm=12.48060417175293
#   y: grad_norm=53.601253509521484
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 177  U=5714.514  z_cont=[11.4,12.3]
#   x: grad_norm=17.769771575927734
#   y: grad_norm=91.15666961669922
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 178  U=5722.149  z_cont=[11.4,12.3]
#   x: grad_norm=17.5893497467041
#   y: grad_norm=76.70209503173828
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 179  U=5717.967  z_cont=[11.4,12.3]
#   x: grad_norm=18.756004333496094
#   y: grad_norm=79.59925079345703
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 180  U=5681.017  z_cont=[11.4,12.3]
#   x: grad_norm=21.75963592529297
#   y: grad_norm=67.42742156982422
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 181  U=5711.766  z_cont=[11.4,12.3]
#   x: grad_norm=17.502056121826172
#   y: grad_norm=84.94816589355469
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 182  U=5673.090  z_cont=[11.4,12.3]
#   x: grad_norm=15.111331939697266
#   y: grad_norm=136.97703552246094
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 183  U=5573.174  z_cont=[11.4,12.3]
#   x: grad_norm=18.874860763549805
#   y: grad_norm=203.89308166503906
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 184  U=5683.192  z_cont=[11.4,12.3]
#   x: grad_norm=25.248714447021484
#   y: grad_norm=193.37582397460938
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 185  U=5685.074  z_cont=[11.4,12.3]
#   x: grad_norm=17.787569046020508
#   y: grad_norm=42.11948776245117
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 186  U=5687.273  z_cont=[11.4,12.3]
#   x: grad_norm=14.226067543029785
#   y: grad_norm=41.98345184326172
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 187  U=5712.651  z_cont=[11.4,12.3]
#   x: grad_norm=9.972509384155273
#   y: grad_norm=26.748214721679688
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 188  U=5716.125  z_cont=[11.4,12.3]
#   x: grad_norm=12.205548286437988
#   y: grad_norm=31.967287063598633
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 189  U=5671.151  z_cont=[11.4,12.3]
#   x: grad_norm=16.249359130859375
#   y: grad_norm=30.884727478027344
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 190  U=5685.211  z_cont=[11.4,12.3]
#   x: grad_norm=11.862500190734863
#   y: grad_norm=57.62211227416992
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 191  U=5693.803  z_cont=[11.4,12.3]
#   x: grad_norm=8.855395317077637
#   y: grad_norm=34.64449691772461
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 192  U=5707.911  z_cont=[11.4,12.3]
#   x: grad_norm=7.137455940246582
#   y: grad_norm=32.81896209716797
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 193  U=5723.344  z_cont=[11.4,12.3]
#   x: grad_norm=6.606457710266113
#   y: grad_norm=17.558597564697266
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 194  U=5676.860  z_cont=[11.4,12.3]
#   x: grad_norm=30.226797103881836
#   y: grad_norm=230.88787841796875
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 195  U=5688.973  z_cont=[11.4,12.3]
#   x: grad_norm=10.500383377075195
#   y: grad_norm=36.0601806640625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 196  U=5689.187  z_cont=[11.4,12.3]
#   x: grad_norm=7.310271739959717
#   y: grad_norm=41.68937301635742
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 197  U=5701.321  z_cont=[11.4,12.3]
#   x: grad_norm=5.397949695587158
#   y: grad_norm=31.564516067504883
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 198  U=5633.875  z_cont=[11.4,12.3]
#   x: grad_norm=10.789999008178711
#   y: grad_norm=64.35780334472656
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 199  U=5717.450  z_cont=[11.4,12.3]
#   x: grad_norm=5.7324395179748535
#   y: grad_norm=15.398407936096191
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 200  U=5638.954  z_cont=[11.4,12.3]
#   x: grad_norm=21.235885620117188
#   y: grad_norm=41.9674186706543
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 201  U=5643.931  z_cont=[11.4,12.3]
#   x: grad_norm=15.099432945251465
#   y: grad_norm=39.499454498291016
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 202  U=5564.930  z_cont=[11.4,12.3]
#   x: grad_norm=43.103878021240234
#   y: grad_norm=365.7169494628906
# ...
# Epoch 1183  U=5555.904  z_cont=[11.4,12.3]
#   x: grad_norm=11.901477813720703
#   y: grad_norm=36.139591217041016
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1184  U=5553.227  z_cont=[11.4,12.3]
#   x: grad_norm=13.915356636047363
#   y: grad_norm=57.83130645751953
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1185  U=5461.765  z_cont=[11.4,12.3]
#   x: grad_norm=53.09270095825195
#   y: grad_norm=474.4941101074219
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1186  U=5471.609  z_cont=[11.4,12.3]
#   x: grad_norm=16.61814308166504
#   y: grad_norm=48.20172882080078
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1187  U=5495.941  z_cont=[11.4,12.3]
#   x: grad_norm=14.968847274780273
#   y: grad_norm=51.97568893432617
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1188  U=5533.300  z_cont=[11.4,12.3]
#   x: grad_norm=12.698298454284668
#   y: grad_norm=52.670875549316406
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1189  U=5558.829  z_cont=[11.4,12.3]
#   x: grad_norm=9.539950370788574
#   y: grad_norm=39.22113800048828
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1190  U=5426.908  z_cont=[11.4,12.3]
#   x: grad_norm=25.19230842590332
#   y: grad_norm=94.4818344116211
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1191  U=5483.095  z_cont=[11.4,12.3]
#   x: grad_norm=19.430526733398438
#   y: grad_norm=85.80962371826172
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1192  U=5555.884  z_cont=[11.4,12.3]
#   x: grad_norm=10.93773078918457
#   y: grad_norm=49.25665283203125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1193  U=5568.027  z_cont=[11.4,12.3]
#   x: grad_norm=13.471546173095703
#   y: grad_norm=61.025306701660156
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1194  U=5548.440  z_cont=[11.4,12.3]
#   x: grad_norm=18.342609405517578
#   y: grad_norm=68.8934326171875
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1195  U=5574.633  z_cont=[11.4,12.3]
#   x: grad_norm=13.450082778930664
#   y: grad_norm=64.3662109375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1196  U=5599.764  z_cont=[11.4,12.3]
#   x: grad_norm=7.0311174392700195
#   y: grad_norm=30.89152717590332
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1197  U=5599.053  z_cont=[11.4,12.3]
#   x: grad_norm=10.39034366607666
#   y: grad_norm=45.543739318847656
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1198  U=5591.781  z_cont=[11.4,12.3]
#   x: grad_norm=13.981115341186523
#   y: grad_norm=60.12244415283203
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1199  U=5605.431  z_cont=[11.4,12.3]
#   x: grad_norm=17.876819610595703
#   y: grad_norm=94.58737182617188
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1200  U=5534.176  z_cont=[11.4,12.3]
#   x: grad_norm=27.912960052490234
#   y: grad_norm=149.99620056152344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1201  U=5613.651  z_cont=[11.4,12.3]
#   x: grad_norm=23.130430221557617
#   y: grad_norm=135.0874786376953
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1202  U=5722.273  z_cont=[11.4,12.3]
#   x: grad_norm=31.879762649536133
#   y: grad_norm=268.933837890625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1203  U=5668.734  z_cont=[11.4,12.3]
#   x: grad_norm=16.846830368041992
#   y: grad_norm=134.13198852539062
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1204  U=5639.046  z_cont=[11.4,12.3]
#   x: grad_norm=15.78235149383545
#   y: grad_norm=100.15499877929688
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1205  U=5625.033  z_cont=[11.4,12.3]
#   x: grad_norm=20.843029022216797
#   y: grad_norm=56.41674041748047
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1206  U=5645.295  z_cont=[11.4,12.3]
#   x: grad_norm=20.264184951782227
#   y: grad_norm=103.37415313720703
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1207  U=5694.058  z_cont=[11.4,12.3]
#   x: grad_norm=15.650053024291992
#   y: grad_norm=74.55181884765625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1208  U=5646.237  z_cont=[11.4,12.3]
#   x: grad_norm=22.189956665039062
#   y: grad_norm=188.92684936523438
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1209  U=5658.884  z_cont=[11.4,12.3]
#   x: grad_norm=14.74540901184082
#   y: grad_norm=28.473379135131836
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1210  U=5590.851  z_cont=[11.4,12.3]
#   x: grad_norm=22.852916717529297
#   y: grad_norm=59.277099609375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1211  U=5621.679  z_cont=[11.4,12.3]
#   x: grad_norm=25.737043380737305
#   y: grad_norm=120.719482421875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1212  U=5603.964  z_cont=[11.4,12.3]
#   x: grad_norm=25.59238624572754
#   y: grad_norm=181.61404418945312
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1213  U=5622.695  z_cont=[11.4,12.3]
#   x: grad_norm=13.114385604858398
#   y: grad_norm=66.36431884765625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1214  U=5637.044  z_cont=[11.4,12.3]
#   x: grad_norm=11.927693367004395
#   y: grad_norm=35.56145477294922
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1215  U=5596.770  z_cont=[11.4,12.3]
#   x: grad_norm=22.84864616394043
#   y: grad_norm=92.7571029663086
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1216  U=5675.086  z_cont=[11.4,12.3]
#   x: grad_norm=555.139892578125
#   y: grad_norm=7319.82080078125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1217  U=5670.079  z_cont=[11.4,12.3]
#   x: grad_norm=33.70954895019531
#   y: grad_norm=195.889404296875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1218  U=5674.868  z_cont=[11.4,12.3]
#   x: grad_norm=30.218889236450195
#   y: grad_norm=139.12342834472656
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1219  U=5713.838  z_cont=[11.4,12.3]
#   x: grad_norm=28.98296356201172
#   y: grad_norm=74.10480499267578
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1220  U=5634.474  z_cont=[11.4,12.3]
#   x: grad_norm=34.981624603271484
#   y: grad_norm=88.06864929199219
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1221  U=5725.090  z_cont=[11.4,12.3]
#   x: grad_norm=30.999948501586914
#   y: grad_norm=185.36180114746094
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1222  U=5623.886  z_cont=[11.4,12.3]
#   x: grad_norm=19.79283905029297
#   y: grad_norm=167.00042724609375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1223  U=5634.203  z_cont=[11.4,12.3]
#   x: grad_norm=26.594802856445312
#   y: grad_norm=217.6884765625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1224  U=5644.683  z_cont=[11.4,12.3]
#   x: grad_norm=36.696922302246094
#   y: grad_norm=331.4002380371094
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1225  U=5592.277  z_cont=[11.4,12.3]
#   x: grad_norm=29.12971305847168
#   y: grad_norm=204.8993682861328
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1226  U=5660.795  z_cont=[11.4,12.3]
#   x: grad_norm=21.281949996948242
#   y: grad_norm=49.98576354980469
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1227  U=5634.132  z_cont=[11.4,12.3]
#   x: grad_norm=36.62095642089844
#   y: grad_norm=262.1869201660156
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1228  U=5677.243  z_cont=[11.4,12.3]
#   x: grad_norm=40.26301956176758
#   y: grad_norm=299.68426513671875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1229  U=5603.723  z_cont=[11.4,12.3]
#   x: grad_norm=59.49252700805664
#   y: grad_norm=409.78497314453125
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1230  U=5637.747  z_cont=[11.4,12.3]
#   x: grad_norm=30.643815994262695
#   y: grad_norm=235.8958282470703
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1231  U=5582.826  z_cont=[11.4,12.3]
#   x: grad_norm=15.722655296325684
#   y: grad_norm=83.40534973144531
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1232  U=5593.859  z_cont=[11.4,12.3]
#   x: grad_norm=12.48719310760498
#   y: grad_norm=53.21963882446289
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1233  U=5603.960  z_cont=[11.4,12.3]
#   x: grad_norm=17.544836044311523
#   y: grad_norm=99.58102416992188
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1234  U=5641.065  z_cont=[11.4,12.3]
#   x: grad_norm=35.477821350097656
#   y: grad_norm=320.82000732421875
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1235  U=5611.060  z_cont=[11.4,12.3]
#   x: grad_norm=43.76611328125
#   y: grad_norm=343.5941467285156
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1236  U=5596.366  z_cont=[11.4,12.3]
#   x: grad_norm=39.66721725463867
#   y: grad_norm=287.595458984375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1237  U=5575.380  z_cont=[11.4,12.3]
#   x: grad_norm=46.83614730834961
#   y: grad_norm=347.3341979980469
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1238  U=5634.195  z_cont=[11.4,12.3]
#   x: grad_norm=29.3143367767334
#   y: grad_norm=206.50875854492188
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1239  U=5625.100  z_cont=[11.4,12.3]
#   x: grad_norm=51.33879089355469
#   y: grad_norm=393.3309326171875
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1240  U=5524.527  z_cont=[11.4,12.3]
#   x: grad_norm=52.49408721923828
#   y: grad_norm=364.9147033691406
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1241  U=5567.250  z_cont=[11.4,12.3]
#   x: grad_norm=51.797935485839844
#   y: grad_norm=343.3881530761719
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1242  U=5588.840  z_cont=[11.4,12.3]
#   x: grad_norm=48.32365036010742
#   y: grad_norm=366.4351806640625
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1243  U=5646.636  z_cont=[11.4,12.3]
#   x: grad_norm=33.90178680419922
#   y: grad_norm=231.83033752441406
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1244  U=5618.919  z_cont=[11.4,12.3]
#   x: grad_norm=47.06889724731445
#   y: grad_norm=385.0106201171875
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1245  U=5507.904  z_cont=[11.4,12.3]
#   x: grad_norm=31.675107955932617
#   y: grad_norm=136.08921813964844
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1246  U=5484.772  z_cont=[11.4,12.3]
#   x: grad_norm=27.889659881591797
#   y: grad_norm=140.00015258789062
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1247  U=5536.600  z_cont=[11.4,12.3]
#   x: grad_norm=21.853275299072266
#   y: grad_norm=147.8348388671875
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1248  U=5628.204  z_cont=[11.4,12.3]
#   x: grad_norm=33.598690032958984
#   y: grad_norm=323.2129821777344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# Epoch 1249  U=5579.500  z_cont=[11.4,12.3]
#   x: grad_norm=23.888338088989258
#   y: grad_norm=117.38165283203125
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt
# CPU times: user 1min 8s, sys: 15.4 s, total: 1min 24s
# Wall time: 6min 46s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='1e2 U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='1e2 U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='1e2 U_E',    lw=1)
# plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
# HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_center_angle_energy/cashed_showers_300.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_lb.detach().cpu().max()], [0, E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
