# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_40_300_shower_mean_U_lr_3"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

#####################
#  Hyperparameters  #
#####################
generate_new_data = True
use_cache = True
training_epochs = 1250
# Out:
# device: cuda

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 300 # 200000
Nvalidation = 300 # 20000
Ntest       = 300 # 3000
Nbatch      = 300 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
            sigma=400
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=873 m  shift=+1930 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([-1139.1880,  4227.9448, -2330.7354, -3994.6155,  -125.5626,  -690.7321,
#          2811.6492,  3772.1150,   480.9774,    83.5631], device='cuda:0')
# Y0: tensor([ 3723.3394,  2490.5283,  4308.3496,   669.1167,  2983.5679,  3904.6221,
#           443.4724, -1440.8091,  2572.3726,  3990.7400], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 110419.125, energy.max(): 88200016.000
# theta.min():  63.8°, theta.max():  98.0°
# phi.min():    -170.3°, phi.max():    126.2°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# CPU times: user 14.6 ms, sys: 21.1 ms, total: 35.6 ms
# Wall time: 271 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# CPU times: user 22.2 ms, sys: 5.84 ms, total: 28.1 ms
# Wall time: 244 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([300, 90, 5])   labels: torch.Size([300, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0668
# Training 20%  val_loss=0.0665
# Training 30%  val_loss=0.0663
# Training 40%  val_loss=0.0661
# Training 50%  val_loss=0.0659
# Training 60%  val_loss=0.0659
# Training 70%  val_loss=0.0657
# Training 80%  val_loss=0.0656
# CPU times: user 3.43 s, sys: 90.5 ms, total: 3.52 s
# Wall time: 3.57 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([E_r.min().cpu(), E_r.max().cpu()], [E_r.min().cpu(), E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()
axes[0].set_xscale("log"); axes[0].set_yscale("log")
axes[0].set_xlim([6e4, 3e8])
axes[0].set_ylim([6e4, 3e8])

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
# optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)
optimizer = torch.optim.Adam(                  
      xy_module.parameters(),               
      lr=3,              
      betas=(0.9, 0.999),                                                                                                                                                                                                                                                                          
      eps=1e-8,                           
  )        

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + training_epochs):

    if epoch < 20:
        Nfinetune = 300 # 3000
    else:
        Nfinetune = 300 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        U_angle(preds_th,  th, r_score) +
        U_angle(preds_phi, ph, r_score) + 
        U_E(preds_e, energy, r_score)   + 0
        # 5e5 * U_PR(r_score)
    )

    U_vals.append(U.item())
    U_th_vals.append(  ( U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( ( U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   ( U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  ( U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=False, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 0  U=181.444  z_cont=[11.2,12.3]
#   x: grad_norm=1.923222303390503
#   y: grad_norm=15.636610984802246
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1  U=181.978  z_cont=[11.2,12.4]
#   x: grad_norm=0.9189713597297668
#   y: grad_norm=1.3760496377944946
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 2  U=178.370  z_cont=[11.2,12.4]
#   x: grad_norm=0.8201016187667847
#   y: grad_norm=1.456175446510315
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 3  U=185.941  z_cont=[11.2,12.4]
#   x: grad_norm=1.1776230335235596
#   y: grad_norm=5.654181480407715
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 4  U=180.259  z_cont=[11.2,12.4]
#   x: grad_norm=0.8942342400550842
#   y: grad_norm=1.437577486038208
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 5  U=184.894  z_cont=[11.2,12.4]
#   x: grad_norm=1.2423653602600098
#   y: grad_norm=1.7105107307434082
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 6  U=180.667  z_cont=[11.2,12.4]
#   x: grad_norm=0.314554363489151
#   y: grad_norm=0.5899625420570374
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 7  U=183.679  z_cont=[11.2,12.4]
#   x: grad_norm=0.6362115740776062
#   y: grad_norm=0.9702962040901184
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 8  U=171.641  z_cont=[11.1,12.4]
#   x: grad_norm=0.5548115968704224
#   y: grad_norm=1.0038760900497437
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 9  U=177.765  z_cont=[11.1,12.5]
#   x: grad_norm=1.3255878686904907
#   y: grad_norm=3.034506320953369
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 10  U=184.857  z_cont=[11.1,12.4]
#   x: grad_norm=1.5903187990188599
#   y: grad_norm=2.318199872970581
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 11  U=191.205  z_cont=[11.1,12.4]
#   x: grad_norm=0.6724326610565186
#   y: grad_norm=1.0729731321334839
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 12  U=187.335  z_cont=[11.1,12.5]
#   x: grad_norm=0.7366519570350647
#   y: grad_norm=1.1756612062454224
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 13  U=193.068  z_cont=[11.0,12.5]
#   x: grad_norm=0.5327495336532593
#   y: grad_norm=0.7782623171806335
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 14  U=189.918  z_cont=[11.0,12.5]
#   x: grad_norm=0.4370114207267761
#   y: grad_norm=0.8660924434661865
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 15  U=190.469  z_cont=[11.0,12.5]
#   x: grad_norm=1.606653094291687
#   y: grad_norm=4.609973430633545
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 16  U=185.960  z_cont=[11.0,12.5]
#   x: grad_norm=1.5948662757873535
#   y: grad_norm=2.4899890422821045
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 17  U=187.989  z_cont=[11.0,12.5]
#   x: grad_norm=0.8410521149635315
#   y: grad_norm=1.266808271408081
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 18  U=189.242  z_cont=[10.9,12.5]
#   x: grad_norm=0.9296416640281677
#   y: grad_norm=1.2958179712295532
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 19  U=183.659  z_cont=[10.9,12.5]
#   x: grad_norm=1.2423508167266846
#   y: grad_norm=1.6194883584976196
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 20  U=194.393  z_cont=[10.9,12.5]
#   x: grad_norm=1.0976150035858154
#   y: grad_norm=2.1508288383483887
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 21  U=184.314  z_cont=[10.8,12.5]
#   x: grad_norm=2.409271717071533
#   y: grad_norm=20.515636444091797
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 22  U=186.870  z_cont=[10.8,12.5]
#   x: grad_norm=0.5478652119636536
#   y: grad_norm=0.810565173625946
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 23  U=193.537  z_cont=[10.8,12.5]
#   x: grad_norm=0.4224283695220947
#   y: grad_norm=1.3065928220748901
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 24  U=191.740  z_cont=[10.8,12.5]
#   x: grad_norm=1.747472882270813
#   y: grad_norm=2.7102084159851074
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 25  U=187.984  z_cont=[10.8,12.5]
#   x: grad_norm=1.0070650577545166
#   y: grad_norm=1.6770586967468262
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 26  U=185.886  z_cont=[10.8,12.6]
#   x: grad_norm=1.270599365234375
#   y: grad_norm=2.1872732639312744
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 27  U=193.662  z_cont=[10.8,12.6]
#   x: grad_norm=1.3604384660720825
#   y: grad_norm=1.8721636533737183
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 28  U=191.954  z_cont=[10.7,12.6]
#   x: grad_norm=0.6624082922935486
#   y: grad_norm=0.9627746343612671
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 29  U=191.319  z_cont=[10.7,12.6]
#   x: grad_norm=1.4782328605651855
#   y: grad_norm=2.1896579265594482
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 30  U=196.488  z_cont=[10.7,12.5]
#   x: grad_norm=0.575003445148468
#   y: grad_norm=0.8659879565238953
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 31  U=199.027  z_cont=[10.7,12.5]
#   x: grad_norm=1.1463980674743652
#   y: grad_norm=1.4785810708999634
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 32  U=194.475  z_cont=[10.7,12.5]
#   x: grad_norm=1.354244351387024
#   y: grad_norm=1.8277652263641357
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 33  U=194.041  z_cont=[10.7,12.5]
#   x: grad_norm=1.4064913988113403
#   y: grad_norm=2.0481150150299072
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 34  U=194.943  z_cont=[10.7,12.5]
#   x: grad_norm=0.2956026494503021
#   y: grad_norm=0.46677300333976746
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 35  U=190.844  z_cont=[10.7,12.5]
#   x: grad_norm=1.194183111190796
#   y: grad_norm=2.678701400756836
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 36  U=191.736  z_cont=[10.7,12.5]
#   x: grad_norm=0.9428881406784058
#   y: grad_norm=1.133880615234375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 37  U=197.333  z_cont=[10.7,12.5]
#   x: grad_norm=0.6663632392883301
#   y: grad_norm=0.9125062823295593
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 38  U=200.425  z_cont=[10.7,12.5]
#   x: grad_norm=0.23311221599578857
#   y: grad_norm=0.47003212571144104
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 39  U=200.760  z_cont=[10.7,12.6]
#   x: grad_norm=0.6949976682662964
#   y: grad_norm=1.6965017318725586
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 40  U=190.294  z_cont=[10.7,12.6]
#   x: grad_norm=1.9120370149612427
#   y: grad_norm=2.7446861267089844
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 41  U=194.300  z_cont=[10.8,12.6]
#   x: grad_norm=0.976826012134552
#   y: grad_norm=1.4440621137619019
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 42  U=192.501  z_cont=[10.8,12.6]
#   x: grad_norm=0.4677625894546509
#   y: grad_norm=0.6685012578964233
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 43  U=193.847  z_cont=[10.8,12.6]
#   x: grad_norm=0.4639865756034851
#   y: grad_norm=0.731162965297699
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 44  U=193.983  z_cont=[10.8,12.6]
#   x: grad_norm=0.9258344173431396
#   y: grad_norm=1.3097916841506958
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 45  U=197.194  z_cont=[10.7,12.6]
#   x: grad_norm=0.49392369389533997
#   y: grad_norm=1.4859176874160767
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 46  U=198.407  z_cont=[10.8,12.6]
#   x: grad_norm=0.2740119993686676
#   y: grad_norm=0.6138485074043274
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 47  U=198.602  z_cont=[10.8,12.6]
#   x: grad_norm=0.2968234419822693
#   y: grad_norm=0.5194591283798218
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 48  U=199.424  z_cont=[10.8,12.6]
#   x: grad_norm=1.0965179204940796
#   y: grad_norm=1.6444200277328491
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 49  U=207.245  z_cont=[10.8,12.6]
#   x: grad_norm=1.273557186126709
#   y: grad_norm=1.4926012754440308
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 50  U=204.091  z_cont=[10.8,12.6]
#   x: grad_norm=2.6575188636779785
#   y: grad_norm=3.932816743850708
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 51  U=194.278  z_cont=[10.8,12.6]
#   x: grad_norm=0.6479164361953735
#   y: grad_norm=0.9657770991325378
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 52  U=189.811  z_cont=[10.8,12.6]
#   x: grad_norm=0.6306993961334229
#   y: grad_norm=0.9561890959739685
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 53  U=198.054  z_cont=[10.8,12.7]
#   x: grad_norm=1.062347650527954
#   y: grad_norm=1.7796902656555176
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 54  U=194.950  z_cont=[10.8,12.7]
#   x: grad_norm=1.9853304624557495
#   y: grad_norm=3.0505425930023193
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 55  U=195.047  z_cont=[10.8,12.7]
#   x: grad_norm=0.8870109915733337
#   y: grad_norm=1.3010690212249756
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 56  U=192.876  z_cont=[10.8,12.7]
#   x: grad_norm=0.6976522207260132
#   y: grad_norm=1.2272727489471436
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 57  U=194.398  z_cont=[10.8,12.7]
#   x: grad_norm=0.335220605134964
#   y: grad_norm=0.5963034629821777
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 58  U=195.035  z_cont=[10.8,12.7]
#   x: grad_norm=0.862139880657196
#   y: grad_norm=1.4345970153808594
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 59  U=196.103  z_cont=[10.8,12.7]
#   x: grad_norm=0.607089638710022
#   y: grad_norm=0.8667686581611633
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 60  U=188.226  z_cont=[10.8,12.7]
#   x: grad_norm=0.3452547788619995
#   y: grad_norm=0.6050049662590027
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 61  U=189.236  z_cont=[10.8,12.7]
#   x: grad_norm=0.335311621427536
#   y: grad_norm=0.618850588798523
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 62  U=190.669  z_cont=[10.8,12.7]
#   x: grad_norm=0.881108820438385
#   y: grad_norm=1.4788191318511963
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 63  U=198.188  z_cont=[10.8,12.7]
#   x: grad_norm=0.6304208040237427
#   y: grad_norm=1.0426987409591675
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 64  U=194.831  z_cont=[10.8,12.7]
#   x: grad_norm=1.0640885829925537
#   y: grad_norm=1.8193684816360474
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 65  U=190.445  z_cont=[10.8,12.7]
#   x: grad_norm=0.7109347581863403
#   y: grad_norm=1.1762763261795044
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 66  U=193.889  z_cont=[10.9,12.7]
#   x: grad_norm=1.4920704364776611
#   y: grad_norm=2.2189581394195557
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 67  U=198.464  z_cont=[10.9,12.7]
#   x: grad_norm=2.814671754837036
#   y: grad_norm=16.701631546020508
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 68  U=195.650  z_cont=[10.9,12.7]
#   x: grad_norm=0.9086927771568298
#   y: grad_norm=1.3574767112731934
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 69  U=199.361  z_cont=[10.8,12.7]
#   x: grad_norm=1.5524539947509766
#   y: grad_norm=2.685767412185669
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 70  U=191.151  z_cont=[10.8,12.7]
#   x: grad_norm=1.0741950273513794
#   y: grad_norm=1.611317753791809
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 71  U=201.110  z_cont=[10.8,12.8]
#   x: grad_norm=1.6007776260375977
#   y: grad_norm=2.2403252124786377
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 72  U=193.916  z_cont=[10.8,12.8]
#   x: grad_norm=1.337343692779541
#   y: grad_norm=2.075205087661743
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 73  U=186.078  z_cont=[10.8,12.8]
#   x: grad_norm=1.3032217025756836
#   y: grad_norm=1.6692323684692383
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 74  U=189.346  z_cont=[10.7,12.8]
#   x: grad_norm=1.6703250408172607
#   y: grad_norm=2.1701459884643555
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 75  U=198.440  z_cont=[10.7,12.8]
#   x: grad_norm=0.4123990535736084
#   y: grad_norm=0.6883640289306641
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 76  U=196.971  z_cont=[10.7,12.8]
#   x: grad_norm=0.49517181515693665
#   y: grad_norm=0.796236515045166
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 77  U=194.927  z_cont=[10.7,12.8]
#   x: grad_norm=0.5268328189849854
#   y: grad_norm=0.718798041343689
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 78  U=195.848  z_cont=[10.6,12.8]
#   x: grad_norm=1.1038591861724854
#   y: grad_norm=1.432845115661621
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 79  U=196.312  z_cont=[10.6,12.8]
#   x: grad_norm=0.5942524671554565
#   y: grad_norm=3.222731113433838
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 80  U=191.408  z_cont=[10.6,12.8]
#   x: grad_norm=0.7529788613319397
#   y: grad_norm=1.1962608098983765
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 81  U=195.878  z_cont=[10.6,12.8]
#   x: grad_norm=0.7917100191116333
#   y: grad_norm=1.5157526731491089
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 82  U=193.493  z_cont=[10.6,12.8]
#   x: grad_norm=0.464437335729599
#   y: grad_norm=0.6753901839256287
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 83  U=192.172  z_cont=[10.6,12.8]
#   x: grad_norm=0.959113359451294
#   y: grad_norm=1.367899775505066
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 84  U=194.727  z_cont=[10.6,12.8]
#   x: grad_norm=0.4078885614871979
#   y: grad_norm=0.6981288194656372
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 85  U=189.942  z_cont=[10.6,12.8]
#   x: grad_norm=1.4533888101577759
#   y: grad_norm=2.128143787384033
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 86  U=195.224  z_cont=[10.6,12.9]
#   x: grad_norm=0.5220881104469299
#   y: grad_norm=0.7444717884063721
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 87  U=196.242  z_cont=[10.6,12.9]
#   x: grad_norm=0.6591508388519287
#   y: grad_norm=0.9291066527366638
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 88  U=196.508  z_cont=[10.5,12.9]
#   x: grad_norm=0.864300549030304
#   y: grad_norm=1.3119747638702393
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 89  U=197.902  z_cont=[10.5,12.9]
#   x: grad_norm=0.7369390726089478
#   y: grad_norm=1.0938323736190796
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 90  U=198.148  z_cont=[10.5,12.9]
#   x: grad_norm=5.630594253540039
#   y: grad_norm=71.62389373779297
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 91  U=201.349  z_cont=[10.5,12.9]
#   x: grad_norm=0.5777744054794312
#   y: grad_norm=0.7564623355865479
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 92  U=204.048  z_cont=[10.5,12.9]
#   x: grad_norm=0.3472321033477783
#   y: grad_norm=0.6884249448776245
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 93  U=203.548  z_cont=[10.5,12.9]
#   x: grad_norm=1.2089945077896118
#   y: grad_norm=1.7049111127853394
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 94  U=205.515  z_cont=[10.5,12.9]
#   x: grad_norm=0.7018241286277771
#   y: grad_norm=0.9232409596443176
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 95  U=194.592  z_cont=[10.5,12.9]
#   x: grad_norm=1.672703504562378
#   y: grad_norm=2.2842345237731934
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 96  U=203.366  z_cont=[10.5,12.9]
#   x: grad_norm=0.7499895095825195
#   y: grad_norm=1.0317716598510742
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 97  U=201.229  z_cont=[10.5,12.9]
#   x: grad_norm=0.8946083784103394
#   y: grad_norm=1.3856734037399292
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 98  U=199.316  z_cont=[10.5,12.9]
#   x: grad_norm=0.7109159231185913
#   y: grad_norm=1.3548856973648071
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 99  U=200.586  z_cont=[10.5,12.9]
#   x: grad_norm=0.6071937084197998
#   y: grad_norm=0.8907800316810608
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 100  U=202.296  z_cont=[10.5,12.9]
#   x: grad_norm=0.8821359872817993
#   y: grad_norm=2.3651981353759766
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 101  U=198.332  z_cont=[10.5,12.9]
#   x: grad_norm=0.9966626763343811
#   y: grad_norm=1.2421191930770874
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 102  U=200.717  z_cont=[10.5,12.9]
#   x: grad_norm=1.228320837020874
#   y: grad_norm=1.3715685606002808
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 103  U=202.558  z_cont=[10.5,12.9]
#   x: grad_norm=0.7811444401741028
#   y: grad_norm=1.0794676542282104
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 104  U=205.408  z_cont=[10.5,12.9]
#   x: grad_norm=1.1944841146469116
#   y: grad_norm=1.8679615259170532
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 105  U=205.225  z_cont=[10.5,12.9]
#   x: grad_norm=1.7460154294967651
#   y: grad_norm=2.9074065685272217
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 106  U=198.149  z_cont=[10.5,12.9]
#   x: grad_norm=1.1158127784729004
#   y: grad_norm=1.3145266771316528
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 107  U=196.626  z_cont=[10.5,12.9]
#   x: grad_norm=0.4254736602306366
#   y: grad_norm=0.5903452634811401
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 108  U=197.282  z_cont=[10.5,12.9]
#   x: grad_norm=0.8595575094223022
#   y: grad_norm=2.03629469871521
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 109  U=198.576  z_cont=[10.5,12.9]
#   x: grad_norm=0.9606097936630249
#   y: grad_norm=1.22405207157135
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 110  U=199.263  z_cont=[10.5,12.9]
#   x: grad_norm=0.8950715661048889
#   y: grad_norm=1.2060052156448364
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 111  U=203.468  z_cont=[10.5,12.9]
#   x: grad_norm=1.7308465242385864
#   y: grad_norm=3.114819288253784
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 112  U=191.699  z_cont=[10.5,12.9]
#   x: grad_norm=1.7872430086135864
#   y: grad_norm=2.0473077297210693
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 113  U=196.064  z_cont=[10.5,12.9]
#   x: grad_norm=1.677972674369812
#   y: grad_norm=1.9639062881469727
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 114  U=202.588  z_cont=[10.5,12.9]
#   x: grad_norm=1.7248252630233765
#   y: grad_norm=2.1415157318115234
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 115  U=195.900  z_cont=[10.5,12.9]
#   x: grad_norm=1.4469853639602661
#   y: grad_norm=2.04256272315979
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 116  U=200.131  z_cont=[10.5,12.9]
#   x: grad_norm=2.485797643661499
#   y: grad_norm=3.14309024810791
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 117  U=204.813  z_cont=[10.5,12.9]
#   x: grad_norm=1.7639329433441162
#   y: grad_norm=3.0416646003723145
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 118  U=202.878  z_cont=[10.5,12.9]
#   x: grad_norm=2.0157816410064697
#   y: grad_norm=2.829780101776123
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 119  U=207.308  z_cont=[10.5,13.0]
#   x: grad_norm=0.8063285946846008
#   y: grad_norm=1.106896162033081
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 120  U=201.740  z_cont=[10.5,13.0]
#   x: grad_norm=0.9901262521743774
#   y: grad_norm=1.2934898138046265
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 121  U=202.978  z_cont=[10.5,13.0]
#   x: grad_norm=1.212131381034851
#   y: grad_norm=1.8842047452926636
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 122  U=203.379  z_cont=[10.5,13.0]
#   x: grad_norm=1.7527658939361572
#   y: grad_norm=2.519440174102783
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 123  U=205.312  z_cont=[10.5,13.0]
#   x: grad_norm=2.0054104328155518
#   y: grad_norm=2.889232873916626
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 124  U=208.177  z_cont=[10.5,13.0]
#   x: grad_norm=1.428086280822754
#   y: grad_norm=2.045999050140381
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 125  U=194.365  z_cont=[10.5,13.0]
#   x: grad_norm=0.38821014761924744
#   y: grad_norm=0.9331905841827393
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 126  U=197.402  z_cont=[10.5,13.0]
#   x: grad_norm=0.7241541147232056
#   y: grad_norm=0.9033219814300537
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 127  U=193.957  z_cont=[10.5,13.0]
#   x: grad_norm=1.3485639095306396
#   y: grad_norm=1.830251932144165
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 128  U=197.805  z_cont=[10.5,13.0]
#   x: grad_norm=0.9396899938583374
#   y: grad_norm=1.4543434381484985
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 129  U=202.856  z_cont=[10.5,13.0]
#   x: grad_norm=2.089975118637085
#   y: grad_norm=2.7130088806152344
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 130  U=201.358  z_cont=[10.5,13.1]
#   x: grad_norm=0.9729047417640686
#   y: grad_norm=1.6243972778320312
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 131  U=201.473  z_cont=[10.5,13.1]
#   x: grad_norm=1.253127932548523
#   y: grad_norm=1.873949408531189
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 132  U=199.451  z_cont=[10.5,13.1]
#   x: grad_norm=1.0586483478546143
#   y: grad_norm=1.5698825120925903
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 133  U=204.852  z_cont=[10.5,13.1]
#   x: grad_norm=1.4501863718032837
#   y: grad_norm=1.8881341218948364
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 134  U=200.205  z_cont=[10.5,13.1]
#   x: grad_norm=0.7833823561668396
#   y: grad_norm=1.487693190574646
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 135  U=204.483  z_cont=[10.5,13.1]
#   x: grad_norm=1.8927463293075562
#   y: grad_norm=2.412447929382324
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 136  U=207.512  z_cont=[10.5,13.1]
#   x: grad_norm=0.8548697829246521
#   y: grad_norm=1.1934784650802612
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 137  U=207.289  z_cont=[10.5,13.0]
#   x: grad_norm=0.9759466052055359
#   y: grad_norm=1.3397934436798096
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 138  U=208.577  z_cont=[10.5,13.0]
#   x: grad_norm=1.2616291046142578
#   y: grad_norm=1.7309365272521973
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 139  U=210.807  z_cont=[10.5,13.0]
#   x: grad_norm=0.5661390423774719
#   y: grad_norm=1.766452670097351
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 140  U=201.698  z_cont=[10.5,13.0]
#   x: grad_norm=1.7323033809661865
#   y: grad_norm=2.5280263423919678
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 141  U=204.534  z_cont=[10.5,13.0]
#   x: grad_norm=1.1326837539672852
#   y: grad_norm=1.671238899230957
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 142  U=208.540  z_cont=[10.5,13.0]
#   x: grad_norm=2.6551642417907715
#   y: grad_norm=3.113247871398926
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 143  U=192.972  z_cont=[10.5,13.0]
#   x: grad_norm=1.8425884246826172
#   y: grad_norm=2.273430824279785
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 144  U=194.046  z_cont=[10.5,13.0]
#   x: grad_norm=1.0175319910049438
#   y: grad_norm=1.269966721534729
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 145  U=195.015  z_cont=[10.5,13.0]
#   x: grad_norm=0.5549339056015015
#   y: grad_norm=0.9177082777023315
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 146  U=193.119  z_cont=[10.5,13.0]
#   x: grad_norm=1.0800212621688843
#   y: grad_norm=1.4808228015899658
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 147  U=196.168  z_cont=[10.5,13.0]
#   x: grad_norm=0.6935157179832458
#   y: grad_norm=1.1140046119689941
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 148  U=196.307  z_cont=[10.5,13.0]
#   x: grad_norm=1.5370968580245972
#   y: grad_norm=1.8695944547653198
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 149  U=197.504  z_cont=[10.5,13.0]
#   x: grad_norm=1.1848474740982056
#   y: grad_norm=1.426588535308838
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 150  U=205.927  z_cont=[10.5,13.0]
#   x: grad_norm=0.47809380292892456
#   y: grad_norm=0.6423981189727783
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 151  U=201.200  z_cont=[10.5,13.0]
#   x: grad_norm=0.5856698751449585
#   y: grad_norm=2.748605966567993
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 152  U=196.370  z_cont=[10.5,13.0]
#   x: grad_norm=0.11314595490694046
#   y: grad_norm=0.19639571011066437
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 153  U=194.848  z_cont=[10.5,13.0]
#   x: grad_norm=1.437362551689148
#   y: grad_norm=1.8414591550827026
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 154  U=203.690  z_cont=[10.5,13.0]
#   x: grad_norm=1.2589157819747925
#   y: grad_norm=1.4101608991622925
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 155  U=200.795  z_cont=[10.5,13.0]
#   x: grad_norm=1.1526203155517578
#   y: grad_norm=1.981431007385254
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 156  U=193.413  z_cont=[10.5,13.0]
#   x: grad_norm=0.6851081848144531
#   y: grad_norm=0.954474151134491
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 157  U=199.574  z_cont=[10.5,13.0]
#   x: grad_norm=1.8267813920974731
#   y: grad_norm=2.6213653087615967
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 158  U=204.710  z_cont=[10.5,13.0]
#   x: grad_norm=0.5391231775283813
#   y: grad_norm=0.6623333096504211
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 159  U=200.357  z_cont=[10.5,13.0]
#   x: grad_norm=0.8697426915168762
#   y: grad_norm=1.125929594039917
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 160  U=202.509  z_cont=[10.5,13.0]
#   x: grad_norm=1.4160840511322021
#   y: grad_norm=1.5233514308929443
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 161  U=206.862  z_cont=[10.5,13.0]
#   x: grad_norm=0.5078732967376709
#   y: grad_norm=0.6213118433952332
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 162  U=200.435  z_cont=[10.5,13.0]
#   x: grad_norm=1.264413595199585
#   y: grad_norm=3.89473032951355
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 163  U=197.079  z_cont=[10.5,13.0]
#   x: grad_norm=1.626137375831604
#   y: grad_norm=1.6863352060317993
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 164  U=200.549  z_cont=[10.5,13.1]
#   x: grad_norm=0.6482939720153809
#   y: grad_norm=0.7763809561729431
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 165  U=206.794  z_cont=[10.5,13.1]
#   x: grad_norm=0.9688398241996765
#   y: grad_norm=1.2652897834777832
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 166  U=208.571  z_cont=[10.5,13.1]
#   x: grad_norm=0.6070231795310974
#   y: grad_norm=0.9962462186813354
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 167  U=208.872  z_cont=[10.5,13.2]
#   x: grad_norm=0.9077298045158386
#   y: grad_norm=1.1630597114562988
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 168  U=211.011  z_cont=[10.5,13.2]
#   x: grad_norm=0.5302684903144836
#   y: grad_norm=0.7221733927726746
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 169  U=210.188  z_cont=[10.5,13.2]
#   x: grad_norm=1.095357060432434
#   y: grad_norm=1.2187641859054565
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 170  U=204.134  z_cont=[10.5,13.2]
#   x: grad_norm=1.1443053483963013
#   y: grad_norm=2.638617515563965
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 171  U=209.778  z_cont=[10.5,13.2]
#   x: grad_norm=0.37012794613838196
#   y: grad_norm=0.7087200284004211
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 172  U=208.607  z_cont=[10.5,13.2]
#   x: grad_norm=0.887334406375885
#   y: grad_norm=1.305906057357788
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 173  U=206.621  z_cont=[10.5,13.3]
#   x: grad_norm=0.4500584304332733
#   y: grad_norm=0.6272830963134766
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 174  U=206.638  z_cont=[10.5,13.3]
#   x: grad_norm=0.47821199893951416
#   y: grad_norm=0.652717113494873
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 175  U=197.337  z_cont=[10.5,13.3]
#   x: grad_norm=1.7530406713485718
#   y: grad_norm=4.423506736755371
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 176  U=203.845  z_cont=[10.5,13.3]
#   x: grad_norm=0.872687816619873
#   y: grad_norm=1.0887495279312134
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 177  U=206.018  z_cont=[10.5,13.3]
#   x: grad_norm=0.7788331508636475
#   y: grad_norm=0.8678694367408752
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 178  U=203.895  z_cont=[10.5,13.3]
#   x: grad_norm=0.24218438565731049
#   y: grad_norm=0.38590529561042786
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 179  U=209.520  z_cont=[10.5,13.3]
#   x: grad_norm=0.6273470520973206
#   y: grad_norm=0.9209835529327393
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 180  U=202.902  z_cont=[10.5,13.3]
#   x: grad_norm=0.7286889553070068
#   y: grad_norm=0.8825433254241943
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 181  U=202.849  z_cont=[10.5,13.3]
#   x: grad_norm=1.8713693618774414
#   y: grad_norm=12.303376197814941
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 182  U=203.832  z_cont=[10.5,13.3]
#   x: grad_norm=0.41561803221702576
#   y: grad_norm=0.5121046900749207
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 183  U=205.808  z_cont=[10.5,13.3]
#   x: grad_norm=1.0345972776412964
#   y: grad_norm=1.0934513807296753
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 184  U=206.293  z_cont=[10.5,13.3]
#   x: grad_norm=0.7211349010467529
#   y: grad_norm=0.9123647809028625
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 185  U=203.695  z_cont=[10.5,13.3]
#   x: grad_norm=0.9608356952667236
#   y: grad_norm=1.4102150201797485
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 186  U=208.127  z_cont=[10.5,13.3]
#   x: grad_norm=0.7211828827857971
#   y: grad_norm=0.9351417422294617
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 187  U=212.356  z_cont=[10.5,13.3]
#   x: grad_norm=0.2799829840660095
#   y: grad_norm=0.5225692391395569
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 188  U=205.359  z_cont=[10.5,13.3]
#   x: grad_norm=0.6394206285476685
#   y: grad_norm=0.8496379852294922
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 189  U=205.134  z_cont=[10.5,13.3]
#   x: grad_norm=0.7797040939331055
#   y: grad_norm=1.1806586980819702
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 190  U=192.389  z_cont=[10.5,13.3]
#   x: grad_norm=0.9935441017150879
#   y: grad_norm=1.3100910186767578
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 191  U=196.292  z_cont=[10.5,13.3]
#   x: grad_norm=1.1886526346206665
#   y: grad_norm=1.702803611755371
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 192  U=202.149  z_cont=[10.5,13.3]
#   x: grad_norm=1.0827374458312988
#   y: grad_norm=1.512413740158081
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 193  U=202.488  z_cont=[10.5,13.3]
#   x: grad_norm=0.6790180206298828
#   y: grad_norm=1.1618658304214478
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 194  U=202.988  z_cont=[10.5,13.3]
#   x: grad_norm=1.251693606376648
#   y: grad_norm=1.747078537940979
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 195  U=190.019  z_cont=[10.4,13.3]
#   x: grad_norm=1.8551304340362549
#   y: grad_norm=2.262211561203003
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 196  U=206.593  z_cont=[10.4,13.3]
#   x: grad_norm=1.0059467554092407
#   y: grad_norm=1.445330023765564
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 197  U=211.325  z_cont=[10.4,13.3]
#   x: grad_norm=0.23760917782783508
#   y: grad_norm=0.3495756685733795
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 198  U=203.611  z_cont=[10.4,13.3]
#   x: grad_norm=1.1215888261795044
#   y: grad_norm=1.5388973951339722
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 199  U=204.987  z_cont=[10.4,13.3]
#   x: grad_norm=0.3924795687198639
#   y: grad_norm=0.7271894216537476
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 200  U=210.058  z_cont=[10.4,13.3]
#   x: grad_norm=10.751705169677734
#   y: grad_norm=72.02932739257812
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 201  U=207.893  z_cont=[10.4,13.3]
#   x: grad_norm=1.6302354335784912
#   y: grad_norm=2.1753740310668945
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 202  U=211.114  z_cont=[10.4,13.3]
#   x: grad_norm=1.0000793933868408
#   y: grad_norm=4.555445194244385
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 203  U=214.309  z_cont=[10.4,13.3]
#   x: grad_norm=0.5351647138595581
#   y: grad_norm=0.7812238931655884
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 204  U=208.394  z_cont=[10.4,13.3]
#   x: grad_norm=1.1822960376739502
#   y: grad_norm=1.5136209726333618
# Fine-tune at epoch 205
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 205  U=196.721  z_cont=[10.3,13.3]
#   x: grad_norm=0.9583551287651062
#   y: grad_norm=1.1656403541564941
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 206  U=201.126  z_cont=[10.3,13.3]
#   x: grad_norm=0.37040603160858154
#   y: grad_norm=0.6843967437744141
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 207  U=203.156  z_cont=[10.3,13.3]
#   x: grad_norm=1.1422630548477173
#   y: grad_norm=1.5618308782577515
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 208  U=209.916  z_cont=[10.3,13.3]
#   x: grad_norm=0.6554366946220398
#   y: grad_norm=1.1201938390731812
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 209  U=207.003  z_cont=[10.3,13.3]
#   x: grad_norm=0.725883960723877
#   y: grad_norm=1.2325454950332642
# Fine-tune at epoch 210
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 210  U=210.566  z_cont=[10.3,13.3]
#   x: grad_norm=0.49163442850112915
#   y: grad_norm=0.7302025556564331
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 211  U=212.451  z_cont=[10.3,13.3]
#   x: grad_norm=0.5313475728034973
#   y: grad_norm=0.7199097275733948
# ...
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1180  U=206.487  z_cont=[9.1,15.0]
#   x: grad_norm=2.0537095069885254
#   y: grad_norm=2.715679168701172
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1181  U=214.971  z_cont=[9.1,15.0]
#   x: grad_norm=1.482185959815979
#   y: grad_norm=2.065793752670288
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1182  U=213.219  z_cont=[9.1,15.0]
#   x: grad_norm=2.6308624744415283
#   y: grad_norm=3.3466758728027344
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1183  U=216.164  z_cont=[9.0,15.0]
#   x: grad_norm=2.2330121994018555
#   y: grad_norm=3.0666890144348145
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1184  U=222.528  z_cont=[9.0,15.0]
#   x: grad_norm=1.9310346841812134
#   y: grad_norm=2.8488898277282715
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1185  U=219.290  z_cont=[9.0,15.0]
#   x: grad_norm=2.064082145690918
#   y: grad_norm=2.9102985858917236
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1186  U=219.257  z_cont=[9.0,15.0]
#   x: grad_norm=4.261785507202148
#   y: grad_norm=5.374444961547852
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1187  U=203.216  z_cont=[9.1,15.1]
#   x: grad_norm=1.4068949222564697
#   y: grad_norm=3.114297389984131
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1188  U=195.647  z_cont=[9.1,15.1]
#   x: grad_norm=0.7571340799331665
#   y: grad_norm=1.7499970197677612
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1189  U=191.011  z_cont=[9.1,15.1]
#   x: grad_norm=0.6904132962226868
#   y: grad_norm=0.8746351599693298
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1190  U=195.456  z_cont=[9.1,15.1]
#   x: grad_norm=1.2777990102767944
#   y: grad_norm=1.4892276525497437
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1191  U=197.185  z_cont=[9.1,15.1]
#   x: grad_norm=1.2008320093154907
#   y: grad_norm=1.4165199995040894
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1192  U=203.506  z_cont=[9.1,15.1]
#   x: grad_norm=0.5327644944190979
#   y: grad_norm=0.7703176736831665
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1193  U=210.300  z_cont=[9.1,15.1]
#   x: grad_norm=2.3413126468658447
#   y: grad_norm=3.0531392097473145
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1194  U=204.256  z_cont=[9.1,15.1]
#   x: grad_norm=1.5480550527572632
#   y: grad_norm=1.9699305295944214
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1195  U=199.294  z_cont=[9.1,15.1]
#   x: grad_norm=0.6441860795021057
#   y: grad_norm=1.8636531829833984
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1196  U=196.225  z_cont=[9.1,15.1]
#   x: grad_norm=1.2743126153945923
#   y: grad_norm=1.7723052501678467
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1197  U=199.238  z_cont=[9.1,15.1]
#   x: grad_norm=1.8472917079925537
#   y: grad_norm=2.3574612140655518
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1198  U=207.748  z_cont=[9.1,15.1]
#   x: grad_norm=0.5534765720367432
#   y: grad_norm=1.4111803770065308
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1199  U=202.159  z_cont=[9.1,15.1]
#   x: grad_norm=0.4526941478252411
#   y: grad_norm=0.9226025938987732
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1200  U=202.152  z_cont=[9.0,15.1]
#   x: grad_norm=0.46417146921157837
#   y: grad_norm=0.8611570596694946
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1201  U=205.452  z_cont=[9.0,15.1]
#   x: grad_norm=1.544264793395996
#   y: grad_norm=1.9320437908172607
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1202  U=204.513  z_cont=[9.0,15.1]
#   x: grad_norm=2.3477210998535156
#   y: grad_norm=2.8020544052124023
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1203  U=199.903  z_cont=[9.0,15.1]
#   x: grad_norm=2.8633790016174316
#   y: grad_norm=3.3527333736419678
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1204  U=210.464  z_cont=[9.0,15.1]
#   x: grad_norm=0.44172048568725586
#   y: grad_norm=0.7686959505081177
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1205  U=203.061  z_cont=[9.0,15.1]
#   x: grad_norm=0.7490405440330505
#   y: grad_norm=0.9970453977584839
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1206  U=203.704  z_cont=[9.0,15.1]
#   x: grad_norm=0.6260637044906616
#   y: grad_norm=0.904887318611145
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1207  U=197.501  z_cont=[9.0,15.1]
#   x: grad_norm=1.569344401359558
#   y: grad_norm=2.124433994293213
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1208  U=199.656  z_cont=[9.0,15.1]
#   x: grad_norm=1.744857668876648
#   y: grad_norm=2.1169650554656982
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1209  U=204.547  z_cont=[9.0,15.1]
#   x: grad_norm=0.7694423794746399
#   y: grad_norm=1.7837891578674316
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1210  U=207.745  z_cont=[9.0,15.1]
#   x: grad_norm=0.7704508900642395
#   y: grad_norm=1.9171323776245117
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1211  U=204.157  z_cont=[9.0,15.1]
#   x: grad_norm=1.5429764986038208
#   y: grad_norm=2.137639284133911
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1212  U=202.042  z_cont=[9.0,15.1]
#   x: grad_norm=0.791558563709259
#   y: grad_norm=1.6390228271484375
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1213  U=206.874  z_cont=[9.0,15.1]
#   x: grad_norm=0.9467158317565918
#   y: grad_norm=1.9869524240493774
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1214  U=212.326  z_cont=[9.0,15.1]
#   x: grad_norm=0.5747794508934021
#   y: grad_norm=1.0942764282226562
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1215  U=210.222  z_cont=[9.0,15.1]
#   x: grad_norm=1.1751307249069214
#   y: grad_norm=1.4868168830871582
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1216  U=208.082  z_cont=[9.0,15.1]
#   x: grad_norm=0.681876003742218
#   y: grad_norm=1.4642276763916016
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1217  U=207.791  z_cont=[9.0,15.1]
#   x: grad_norm=1.277561068534851
#   y: grad_norm=1.7370445728302002
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1218  U=211.246  z_cont=[9.0,15.1]
#   x: grad_norm=0.9315237402915955
#   y: grad_norm=1.7944422960281372
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1219  U=211.896  z_cont=[9.0,15.1]
#   x: grad_norm=0.7650048136711121
#   y: grad_norm=1.3105398416519165
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1220  U=203.633  z_cont=[9.0,15.1]
#   x: grad_norm=0.5921284556388855
#   y: grad_norm=0.8650093078613281
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1221  U=203.655  z_cont=[9.0,15.1]
#   x: grad_norm=0.7016891837120056
#   y: grad_norm=0.9238923788070679
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1222  U=206.338  z_cont=[9.0,15.1]
#   x: grad_norm=1.2504628896713257
#   y: grad_norm=1.5667275190353394
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1223  U=210.935  z_cont=[9.0,15.1]
#   x: grad_norm=0.5676067471504211
#   y: grad_norm=1.0777034759521484
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1224  U=208.233  z_cont=[9.0,15.1]
#   x: grad_norm=1.247162103652954
#   y: grad_norm=1.7001163959503174
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1225  U=211.568  z_cont=[9.0,15.1]
#   x: grad_norm=1.4119679927825928
#   y: grad_norm=1.8573873043060303
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1226  U=214.404  z_cont=[9.0,15.1]
#   x: grad_norm=1.8323208093643188
#   y: grad_norm=2.369647741317749
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1227  U=216.509  z_cont=[9.0,15.1]
#   x: grad_norm=1.275285243988037
#   y: grad_norm=1.567444086074829
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1228  U=213.325  z_cont=[9.0,15.1]
#   x: grad_norm=2.017913341522217
#   y: grad_norm=2.5892419815063477
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1229  U=218.659  z_cont=[9.0,15.1]
#   x: grad_norm=0.4407690763473511
#   y: grad_norm=0.687254011631012
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1230  U=219.409  z_cont=[9.0,15.1]
#   x: grad_norm=0.6003478765487671
#   y: grad_norm=0.9736668467521667
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1231  U=212.576  z_cont=[9.0,15.1]
#   x: grad_norm=3.5490198135375977
#   y: grad_norm=4.501796722412109
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1232  U=210.910  z_cont=[9.0,15.1]
#   x: grad_norm=2.4381957054138184
#   y: grad_norm=3.054020404815674
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1233  U=212.462  z_cont=[9.0,15.1]
#   x: grad_norm=1.7329531908035278
#   y: grad_norm=2.1772522926330566
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1234  U=223.310  z_cont=[9.0,15.1]
#   x: grad_norm=2.3985769748687744
#   y: grad_norm=2.9094154834747314
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1235  U=215.934  z_cont=[9.0,15.1]
#   x: grad_norm=2.2748939990997314
#   y: grad_norm=2.982496976852417
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1236  U=224.210  z_cont=[9.0,15.1]
#   x: grad_norm=2.6905477046966553
#   y: grad_norm=3.2689197063446045
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1237  U=221.098  z_cont=[9.0,15.1]
#   x: grad_norm=2.6267902851104736
#   y: grad_norm=3.3215701580047607
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1238  U=220.020  z_cont=[9.0,15.1]
#   x: grad_norm=3.956393241882324
#   y: grad_norm=4.965271472930908
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1239  U=211.661  z_cont=[9.0,15.1]
#   x: grad_norm=2.8849921226501465
#   y: grad_norm=3.6989657878875732
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1240  U=206.422  z_cont=[9.0,15.1]
#   x: grad_norm=2.585263729095459
#   y: grad_norm=3.225733995437622
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1241  U=220.523  z_cont=[9.0,15.1]
#   x: grad_norm=3.4835236072540283
#   y: grad_norm=4.346774578094482
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1242  U=223.576  z_cont=[9.0,15.1]
#   x: grad_norm=1.0589045286178589
#   y: grad_norm=1.4756609201431274
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1243  U=226.703  z_cont=[9.0,15.1]
#   x: grad_norm=1.0185526609420776
#   y: grad_norm=1.403812289237976
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1244  U=220.569  z_cont=[9.0,15.1]
#   x: grad_norm=4.965198993682861
#   y: grad_norm=6.164865493774414
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1245  U=206.690  z_cont=[9.0,15.1]
#   x: grad_norm=3.0248219966888428
#   y: grad_norm=3.746833086013794
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1246  U=199.962  z_cont=[9.0,15.0]
#   x: grad_norm=2.8411498069763184
#   y: grad_norm=3.4814441204071045
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1247  U=222.590  z_cont=[9.0,15.0]
#   x: grad_norm=1.9390764236450195
#   y: grad_norm=2.4095511436462402
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1248  U=194.946  z_cont=[9.0,15.1]
#   x: grad_norm=1.9511702060699463
#   y: grad_norm=2.3360543251037598
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# Epoch 1249  U=193.282  z_cont=[9.0,15.1]
#   x: grad_norm=0.5034226775169373
#   y: grad_norm=0.7288289666175842
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt
# CPU times: user 1min 19s, sys: 8.56 s, total: 1min 28s
# Wall time: 7min 36s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='U_E',    lw=1)
# plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
# HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_40_300_shower_mean_U_lr_3/cashed_showers_300.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([E_lb.detach().cpu().min(), E_lb.detach().cpu().max()], [E_lb.detach().cpu().min(), E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()
axes[0].set_xscale("log"); axes[0].set_yscale("log")
axes[0].set_xlim([6e4, 3e8])
axes[0].set_ylim([6e4, 3e8])

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
