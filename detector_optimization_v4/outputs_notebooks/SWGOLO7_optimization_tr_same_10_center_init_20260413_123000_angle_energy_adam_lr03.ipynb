# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_39_10_shower_center_angle_energy"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generate_new_data = True
print("device:", device)
# Out:
# device: cpu

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 10 # 200000
Nvalidation = 10 # 20000
Ntest       = 10 # 3000
Nbatch      = 10 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
use_cache = True
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-2203 m  shift=+5006 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([-1907.7203,  4505.5415, -1643.9327, -1939.2573, -1112.7185,   637.4553,
#         -3818.6672, -4274.4561, -1556.9991, -2235.4375])
# Y0: tensor([1422.2808, 5604.9370, 7236.5972,  698.1343,  885.7803, 6356.0146,
#         4484.0601, 3971.6616,  918.8809, 2461.1887])
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 7777646.000, energy.max(): 81127968.000
# theta.min():  61.7°, theta.max():  92.6°
# phi.min():    -131.1°, phi.max():    170.7°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# CPU times: user 38.3 ms, sys: 16.4 ms, total: 54.7 ms
# Wall time: 153 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# CPU times: user 41.4 ms, sys: 1.68 ms, total: 43.1 ms
# Wall time: 90 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([10, 90, 5])   labels: torch.Size([10, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0885
# Training 20%  val_loss=0.0836
# Training 30%  val_loss=0.0836
# Training 40%  val_loss=0.0836
# Training 50%  val_loss=0.0836
# Training 60%  val_loss=0.0836
# Training 70%  val_loss=0.0836
# Training 80%  val_loss=0.0836
# CPU times: user 8.25 s, sys: 30.5 ms, total: 8.28 s
# Wall time: 9.78 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
# optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)
optimizer = torch.optim.Adam(                  
      xy_module.parameters(),               
      lr=0.3,              # Adam's effective step ≈ lr, so ~1 m/epoch
      betas=(0.9, 0.999),                                                                                                                                                                                                                                                                          
      eps=1e-8,                           
  )        

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + 1250):

    if epoch < 20:
        Nfinetune = 10 # 3000
    else:
        Nfinetune = 10 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        1e2 * U_angle(preds_th,  th, r_score) +
        1e2 * U_angle(preds_phi, ph, r_score) + 
        1e2 * U_E(preds_e, energy, r_score)   + 0
        # 5e5 * U_PR(r_score)
    ) / 1e3

    U_vals.append(U.item())
    U_th_vals.append( (1e2 * U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( (1e2 * U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   (1e2 * U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  (5e5 * U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=False, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 0  U=91.520  z_cont=[11.2,12.3]
#   x: grad_norm=0.7759487628936768
#   y: grad_norm=1.3233299255371094
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1  U=97.270  z_cont=[11.2,12.3]
#   x: grad_norm=1.071773648262024
#   y: grad_norm=1.8074995279312134
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 2  U=104.905  z_cont=[11.1,12.3]
#   x: grad_norm=1.3996092081069946
#   y: grad_norm=2.3682918548583984
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 3  U=114.288  z_cont=[11.1,12.3]
#   x: grad_norm=1.6953023672103882
#   y: grad_norm=2.909329414367676
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 4  U=125.083  z_cont=[11.1,12.3]
#   x: grad_norm=1.8867018222808838
#   y: grad_norm=3.317410469055176
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 5  U=136.137  z_cont=[11.1,12.3]
#   x: grad_norm=1.9904221296310425
#   y: grad_norm=3.4980058670043945
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 6  U=148.071  z_cont=[11.1,12.4]
#   x: grad_norm=1.8585988283157349
#   y: grad_norm=3.222576141357422
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 7  U=158.151  z_cont=[11.1,12.4]
#   x: grad_norm=1.3652013540267944
#   y: grad_norm=2.370051383972168
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 8  U=164.193  z_cont=[11.1,12.4]
#   x: grad_norm=0.6085361242294312
#   y: grad_norm=1.0263725519180298
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 9  U=165.371  z_cont=[11.1,12.4]
#   x: grad_norm=0.1675463765859604
#   y: grad_norm=0.3168748617172241
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 10  U=163.687  z_cont=[11.1,12.4]
#   x: grad_norm=0.5934416055679321
#   y: grad_norm=1.0604101419448853
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 11  U=160.739  z_cont=[11.1,12.4]
#   x: grad_norm=0.8316304683685303
#   y: grad_norm=1.475053071975708
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 12  U=158.118  z_cont=[11.1,12.4]
#   x: grad_norm=0.8960531949996948
#   y: grad_norm=1.586111307144165
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 13  U=156.322  z_cont=[11.1,12.4]
#   x: grad_norm=0.8928195834159851
#   y: grad_norm=1.5811785459518433
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 14  U=155.294  z_cont=[11.1,12.4]
#   x: grad_norm=0.8753634095191956
#   y: grad_norm=1.5490508079528809
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 15  U=155.565  z_cont=[11.1,12.4]
#   x: grad_norm=0.8767139315605164
#   y: grad_norm=1.5504696369171143
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 16  U=155.720  z_cont=[11.1,12.4]
#   x: grad_norm=0.8761874437332153
#   y: grad_norm=1.5538909435272217
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 17  U=156.355  z_cont=[11.1,12.4]
#   x: grad_norm=0.884361982345581
#   y: grad_norm=1.5672141313552856
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 18  U=157.428  z_cont=[11.1,12.4]
#   x: grad_norm=0.8912901878356934
#   y: grad_norm=1.5787878036499023
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 19  U=158.886  z_cont=[11.1,12.4]
#   x: grad_norm=0.8829647898674011
#   y: grad_norm=1.5648341178894043
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 20  U=161.254  z_cont=[11.1,12.4]
#   x: grad_norm=0.8184449076652527
#   y: grad_norm=1.4501811265945435
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 21  U=163.046  z_cont=[11.1,12.4]
#   x: grad_norm=0.7114695310592651
#   y: grad_norm=1.2626985311508179
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 22  U=164.659  z_cont=[11.1,12.4]
#   x: grad_norm=0.5371254086494446
#   y: grad_norm=0.9581286907196045
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 23  U=165.801  z_cont=[11.1,12.4]
#   x: grad_norm=0.29727742075920105
#   y: grad_norm=0.5393507480621338
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 24  U=166.258  z_cont=[11.1,12.4]
#   x: grad_norm=0.05545688420534134
#   y: grad_norm=0.08832167088985443
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 25  U=165.817  z_cont=[11.1,12.4]
#   x: grad_norm=0.37589114904403687
#   y: grad_norm=0.6286848187446594
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 26  U=164.969  z_cont=[11.1,12.4]
#   x: grad_norm=0.6204849481582642
#   y: grad_norm=1.055629849433899
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 27  U=164.122  z_cont=[11.1,12.4]
#   x: grad_norm=0.7904497981071472
#   y: grad_norm=1.3519902229309082
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 28  U=163.614  z_cont=[11.1,12.4]
#   x: grad_norm=0.8773708343505859
#   y: grad_norm=1.5033345222473145
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 29  U=163.606  z_cont=[11.1,12.4]
#   x: grad_norm=0.8883139491081238
#   y: grad_norm=1.521109700202942
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 30  U=163.482  z_cont=[11.1,12.4]
#   x: grad_norm=0.9111812114715576
#   y: grad_norm=1.5606110095977783
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 31  U=164.359  z_cont=[11.1,12.4]
#   x: grad_norm=0.779589056968689
#   y: grad_norm=1.3317457437515259
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 32  U=165.333  z_cont=[11.1,12.4]
#   x: grad_norm=0.5944370031356812
#   y: grad_norm=1.0096702575683594
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 33  U=166.136  z_cont=[11.1,12.4]
#   x: grad_norm=0.3775634467601776
#   y: grad_norm=0.6321415305137634
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 34  U=166.600  z_cont=[11.1,12.4]
#   x: grad_norm=0.15873156487941742
#   y: grad_norm=0.2502675950527191
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 35  U=166.719  z_cont=[11.1,12.4]
#   x: grad_norm=0.05876174941658974
#   y: grad_norm=0.08016937226057053
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 36  U=166.647  z_cont=[11.1,12.4]
#   x: grad_norm=0.15615102648735046
#   y: grad_norm=0.2900948226451874
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 37  U=166.393  z_cont=[11.1,12.4]
#   x: grad_norm=0.2902449071407318
#   y: grad_norm=0.5259671807289124
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 38  U=166.099  z_cont=[11.1,12.4]
#   x: grad_norm=0.38455331325531006
#   y: grad_norm=0.6908354759216309
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 39  U=165.883  z_cont=[11.1,12.4]
#   x: grad_norm=0.44016769528388977
#   y: grad_norm=0.7877840399742126
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 40  U=166.120  z_cont=[11.1,12.4]
#   x: grad_norm=0.39695101976394653
#   y: grad_norm=0.7153863310813904
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 41  U=166.186  z_cont=[11.1,12.4]
#   x: grad_norm=0.3902519941329956
#   y: grad_norm=0.7035422921180725
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 42  U=166.355  z_cont=[11.1,12.4]
#   x: grad_norm=0.35763081908226013
#   y: grad_norm=0.6462089419364929
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 43  U=166.586  z_cont=[11.1,12.4]
#   x: grad_norm=0.304004967212677
#   y: grad_norm=0.5512952208518982
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 44  U=166.829  z_cont=[11.1,12.4]
#   x: grad_norm=0.22598876059055328
#   y: grad_norm=0.4202479422092438
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 45  U=167.097  z_cont=[11.1,12.4]
#   x: grad_norm=0.06600294262170792
#   y: grad_norm=0.12251035869121552
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 46  U=167.140  z_cont=[11.1,12.4]
#   x: grad_norm=0.07538963854312897
#   y: grad_norm=0.10778823494911194
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 47  U=167.114  z_cont=[11.1,12.4]
#   x: grad_norm=0.1539543867111206
#   y: grad_norm=0.24870386719703674
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 48  U=167.059  z_cont=[11.1,12.4]
#   x: grad_norm=0.2210443764925003
#   y: grad_norm=0.3689623177051544
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 49  U=167.021  z_cont=[11.1,12.4]
#   x: grad_norm=0.26393309235572815
#   y: grad_norm=0.4456658363342285
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 50  U=166.836  z_cont=[11.1,12.4]
#   x: grad_norm=0.3610210716724396
#   y: grad_norm=0.6188877820968628
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 51  U=166.933  z_cont=[11.1,12.4]
#   x: grad_norm=0.33939507603645325
#   y: grad_norm=0.5801610350608826
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 52  U=167.097  z_cont=[11.1,12.4]
#   x: grad_norm=0.2873559892177582
#   y: grad_norm=0.4872658848762512
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 53  U=167.278  z_cont=[11.1,12.4]
#   x: grad_norm=0.2136543095111847
#   y: grad_norm=0.35499313473701477
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 54  U=167.429  z_cont=[11.1,12.4]
#   x: grad_norm=0.12926605343818665
#   y: grad_norm=0.20185725390911102
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 55  U=167.472  z_cont=[11.1,12.4]
#   x: grad_norm=0.12577210366725922
#   y: grad_norm=0.1952994018793106
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 56  U=167.558  z_cont=[11.1,12.4]
#   x: grad_norm=0.058310218155384064
#   y: grad_norm=0.07787694036960602
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 57  U=167.582  z_cont=[11.1,12.4]
#   x: grad_norm=0.07987555861473083
#   y: grad_norm=0.14848288893699646
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 58  U=167.570  z_cont=[11.1,12.4]
#   x: grad_norm=0.13355916738510132
#   y: grad_norm=0.25083521008491516
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 59  U=167.554  z_cont=[11.1,12.4]
#   x: grad_norm=0.17439505457878113
#   y: grad_norm=0.32493820786476135
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 60  U=167.666  z_cont=[11.1,12.4]
#   x: grad_norm=0.12525798380374908
#   y: grad_norm=0.23577503859996796
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 61  U=167.702  z_cont=[11.1,12.4]
#   x: grad_norm=0.13464978337287903
#   y: grad_norm=0.25317612290382385
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 62  U=167.756  z_cont=[11.1,12.4]
#   x: grad_norm=0.13148190081119537
#   y: grad_norm=0.2473321110010147
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 63  U=167.823  z_cont=[11.1,12.4]
#   x: grad_norm=0.11731031537055969
#   y: grad_norm=0.22087521851062775
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 64  U=167.897  z_cont=[11.1,12.4]
#   x: grad_norm=0.09527463465929031
#   y: grad_norm=0.1788286566734314
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 65  U=167.966  z_cont=[11.1,12.4]
#   x: grad_norm=0.06392016261816025
#   y: grad_norm=0.08795040100812912
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 66  U=168.009  z_cont=[11.1,12.4]
#   x: grad_norm=0.08183092623949051
#   y: grad_norm=0.11732300370931625
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 67  U=168.052  z_cont=[11.1,12.4]
#   x: grad_norm=0.09802085161209106
#   y: grad_norm=0.14620155096054077
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 68  U=168.098  z_cont=[11.1,12.4]
#   x: grad_norm=0.10700951516628265
#   y: grad_norm=0.16231511533260345
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 69  U=168.151  z_cont=[11.1,12.4]
#   x: grad_norm=0.10728088021278381
#   y: grad_norm=0.1630324274301529
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 70  U=168.129  z_cont=[11.1,12.4]
#   x: grad_norm=0.16894665360450745
#   y: grad_norm=0.27394816279411316
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 71  U=168.209  z_cont=[11.1,12.4]
#   x: grad_norm=0.14552393555641174
#   y: grad_norm=0.23210406303405762
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 72  U=168.293  z_cont=[11.1,12.4]
#   x: grad_norm=0.11167638003826141
#   y: grad_norm=0.17159448564052582
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 73  U=168.368  z_cont=[11.1,12.4]
#   x: grad_norm=0.07600326836109161
#   y: grad_norm=0.11012295633554459
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 74  U=168.427  z_cont=[11.1,12.4]
#   x: grad_norm=0.05239678919315338
#   y: grad_norm=0.0751398578286171
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 75  U=168.457  z_cont=[11.1,12.4]
#   x: grad_norm=0.07187114655971527
#   y: grad_norm=0.10347007215023041
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 76  U=168.513  z_cont=[11.1,12.4]
#   x: grad_norm=0.05027596279978752
#   y: grad_norm=0.07265650480985641
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 77  U=168.557  z_cont=[11.1,12.4]
#   x: grad_norm=0.05479395389556885
#   y: grad_norm=0.09836335480213165
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 78  U=168.592  z_cont=[11.1,12.4]
#   x: grad_norm=0.07069430500268936
#   y: grad_norm=0.13544045388698578
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 79  U=168.627  z_cont=[11.1,12.4]
#   x: grad_norm=0.07721704989671707
#   y: grad_norm=0.14871762692928314
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 80  U=168.666  z_cont=[11.1,12.4]
#   x: grad_norm=0.04515241086483002
#   y: grad_norm=0.06536661088466644
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 81  U=168.705  z_cont=[11.1,12.4]
#   x: grad_norm=0.044344693422317505
#   y: grad_norm=0.06377674639225006
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 82  U=168.743  z_cont=[11.1,12.4]
#   x: grad_norm=0.04336191713809967
#   y: grad_norm=0.06214355677366257
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 83  U=168.779  z_cont=[11.1,12.4]
#   x: grad_norm=0.04223914444446564
#   y: grad_norm=0.06040412560105324
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 84  U=168.814  z_cont=[11.1,12.4]
#   x: grad_norm=0.040892817080020905
#   y: grad_norm=0.05871904268860817
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 85  U=168.806  z_cont=[11.1,12.4]
#   x: grad_norm=0.09532705694437027
#   y: grad_norm=0.1521395891904831
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 86  U=168.844  z_cont=[11.1,12.4]
#   x: grad_norm=0.08645398169755936
#   y: grad_norm=0.13421329855918884
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 87  U=168.884  z_cont=[11.1,12.4]
#   x: grad_norm=0.07033143937587738
#   y: grad_norm=0.10525383800268173
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 88  U=168.921  z_cont=[11.1,12.4]
#   x: grad_norm=0.0513283871114254
#   y: grad_norm=0.07158809900283813
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 89  U=168.954  z_cont=[11.1,12.4]
#   x: grad_norm=0.03685719147324562
#   y: grad_norm=0.04992722347378731
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 90  U=168.952  z_cont=[11.1,12.4]
#   x: grad_norm=0.07260790467262268
#   y: grad_norm=0.10932869464159012
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 91  U=168.987  z_cont=[11.1,12.4]
#   x: grad_norm=0.04857141897082329
#   y: grad_norm=0.06751229614019394
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 92  U=169.016  z_cont=[11.1,12.4]
#   x: grad_norm=0.032404251396656036
#   y: grad_norm=0.045775651931762695
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 93  U=169.036  z_cont=[11.1,12.4]
#   x: grad_norm=0.03669404238462448
#   y: grad_norm=0.06592149287462234
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 94  U=169.054  z_cont=[11.1,12.4]
#   x: grad_norm=0.04920950159430504
#   y: grad_norm=0.09274850785732269
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 95  U=169.067  z_cont=[11.1,12.4]
#   x: grad_norm=0.032315514981746674
#   y: grad_norm=0.043722596019506454
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 96  U=169.088  z_cont=[11.1,12.4]
#   x: grad_norm=0.02850630134344101
#   y: grad_norm=0.04165170341730118
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 97  U=169.108  z_cont=[11.1,12.4]
#   x: grad_norm=0.027950266376137733
#   y: grad_norm=0.04553869366645813
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 98  U=169.126  z_cont=[11.1,12.4]
#   x: grad_norm=0.028913913294672966
#   y: grad_norm=0.050370797514915466
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 99  U=169.144  z_cont=[11.1,12.4]
#   x: grad_norm=0.0291683841496706
#   y: grad_norm=0.05198231711983681
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 100  U=169.133  z_cont=[11.1,12.4]
#   x: grad_norm=0.06394951045513153
#   y: grad_norm=0.0990743488073349
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 101  U=169.153  z_cont=[11.1,12.4]
#   x: grad_norm=0.0569942332804203
#   y: grad_norm=0.08726302534341812
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 102  U=169.174  z_cont=[11.1,12.4]
#   x: grad_norm=0.04442857950925827
#   y: grad_norm=0.06517764925956726
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 103  U=169.194  z_cont=[11.1,12.4]
#   x: grad_norm=0.030529005452990532
#   y: grad_norm=0.04296259954571724
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 104  U=169.210  z_cont=[11.1,12.4]
#   x: grad_norm=0.02524588815867901
#   y: grad_norm=0.041484981775283813
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 105  U=169.204  z_cont=[11.1,12.4]
#   x: grad_norm=0.04948056861758232
#   y: grad_norm=0.07562705874443054
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 106  U=169.225  z_cont=[11.1,12.4]
#   x: grad_norm=0.03296251595020294
#   y: grad_norm=0.04780743643641472
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 107  U=169.242  z_cont=[11.1,12.4]
#   x: grad_norm=0.02432779222726822
#   y: grad_norm=0.03926483914256096
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 108  U=169.255  z_cont=[11.1,12.4]
#   x: grad_norm=0.029777508229017258
#   y: grad_norm=0.05597597360610962
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 109  U=169.268  z_cont=[11.1,12.4]
#   x: grad_norm=0.03843502700328827
#   y: grad_norm=0.07378798723220825
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 110  U=169.269  z_cont=[11.1,12.4]
#   x: grad_norm=0.035104911774396896
#   y: grad_norm=0.05145096778869629
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 111  U=169.285  z_cont=[11.1,12.4]
#   x: grad_norm=0.0292701106518507
#   y: grad_norm=0.04237200692296028
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 112  U=169.301  z_cont=[11.1,12.4]
#   x: grad_norm=0.024932224303483963
#   y: grad_norm=0.03770972788333893
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 113  U=169.316  z_cont=[11.1,12.4]
#   x: grad_norm=0.023876549676060677
#   y: grad_norm=0.04041329026222229
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 114  U=169.330  z_cont=[11.1,12.4]
#   x: grad_norm=0.02616005949676037
#   y: grad_norm=0.04757329821586609
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 115  U=169.318  z_cont=[11.1,12.4]
#   x: grad_norm=0.07164575904607773
#   y: grad_norm=0.11542772501707077
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 116  U=169.338  z_cont=[11.1,12.4]
#   x: grad_norm=0.06037114933133125
#   y: grad_norm=0.09515699744224548
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 117  U=169.360  z_cont=[11.1,12.4]
#   x: grad_norm=0.04335254058241844
#   y: grad_norm=0.06627270579338074
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 118  U=169.380  z_cont=[11.1,12.4]
#   x: grad_norm=0.029504815116524696
#   y: grad_norm=0.04246389865875244
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 119  U=169.396  z_cont=[11.1,12.4]
#   x: grad_norm=0.028486598283052444
#   y: grad_norm=0.04978621006011963
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 120  U=169.392  z_cont=[11.1,12.4]
#   x: grad_norm=0.04822288081049919
#   y: grad_norm=0.07619231194257736
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 121  U=169.415  z_cont=[11.1,12.4]
#   x: grad_norm=0.03257675841450691
#   y: grad_norm=0.04906656593084335
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 122  U=169.433  z_cont=[11.1,12.4]
#   x: grad_norm=0.028235772624611855
#   y: grad_norm=0.04734203591942787
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 123  U=169.449  z_cont=[11.1,12.4]
#   x: grad_norm=0.03665805980563164
#   y: grad_norm=0.06820321083068848
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 124  U=169.466  z_cont=[11.1,12.4]
#   x: grad_norm=0.044805858284235
#   y: grad_norm=0.08518341183662415
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 125  U=169.471  z_cont=[11.1,12.4]
#   x: grad_norm=0.04870956018567085
#   y: grad_norm=0.07336632162332535
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 126  U=169.495  z_cont=[11.1,12.4]
#   x: grad_norm=0.0439356230199337
#   y: grad_norm=0.06378190964460373
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 127  U=169.520  z_cont=[11.1,12.4]
#   x: grad_norm=0.03703983128070831
#   y: grad_norm=0.05555582791566849
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 128  U=169.545  z_cont=[11.1,12.4]
#   x: grad_norm=0.034672848880290985
#   y: grad_norm=0.05321282148361206
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 129  U=169.571  z_cont=[11.1,12.4]
#   x: grad_norm=0.03628244251012802
#   y: grad_norm=0.05956638604402542
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 130  U=169.566  z_cont=[11.1,12.4]
#   x: grad_norm=0.056577157229185104
#   y: grad_norm=0.08922270685434341
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 131  U=169.600  z_cont=[11.1,12.4]
#   x: grad_norm=0.04866664484143257
#   y: grad_norm=0.07363571226596832
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 132  U=169.636  z_cont=[11.1,12.4]
#   x: grad_norm=0.04297683760523796
#   y: grad_norm=0.06434287875890732
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 133  U=169.673  z_cont=[11.1,12.4]
#   x: grad_norm=0.04437870532274246
#   y: grad_norm=0.07257623225450516
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 134  U=169.711  z_cont=[11.1,12.4]
#   x: grad_norm=0.05102057009935379
#   y: grad_norm=0.08444656431674957
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 135  U=169.706  z_cont=[11.2,12.4]
#   x: grad_norm=0.05910539627075195
#   y: grad_norm=0.0841674655675888
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 136  U=169.754  z_cont=[11.2,12.4]
#   x: grad_norm=0.05877690762281418
#   y: grad_norm=0.07800997048616409
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 137  U=169.806  z_cont=[11.2,12.4]
#   x: grad_norm=0.05874450132250786
#   y: grad_norm=0.08040980249643326
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 138  U=169.863  z_cont=[11.2,12.4]
#   x: grad_norm=0.061352115124464035
#   y: grad_norm=0.08912546187639236
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 139  U=169.927  z_cont=[11.2,12.4]
#   x: grad_norm=0.06611723452806473
#   y: grad_norm=0.1006145030260086
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 140  U=169.934  z_cont=[11.2,12.4]
#   x: grad_norm=0.07612932473421097
#   y: grad_norm=0.10703423619270325
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 141  U=170.014  z_cont=[11.2,12.4]
#   x: grad_norm=0.07636558264493942
#   y: grad_norm=0.10709474235773087
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 142  U=170.105  z_cont=[11.2,12.4]
#   x: grad_norm=0.07801849395036697
#   y: grad_norm=0.1122896820306778
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 143  U=170.209  z_cont=[11.2,12.4]
#   x: grad_norm=0.08250847458839417
#   y: grad_norm=0.12249855697154999
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 144  U=170.328  z_cont=[11.2,12.4]
#   x: grad_norm=0.08978502452373505
#   y: grad_norm=0.1369941532611847
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 145  U=170.377  z_cont=[11.2,12.4]
#   x: grad_norm=0.09612476825714111
#   y: grad_norm=0.13603736460208893
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 146  U=170.531  z_cont=[11.2,12.4]
#   x: grad_norm=0.10230015218257904
#   y: grad_norm=0.14699222147464752
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 147  U=170.705  z_cont=[11.2,12.4]
#   x: grad_norm=0.11453134566545486
#   y: grad_norm=0.16040031611919403
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 148  U=170.895  z_cont=[11.2,12.4]
#   x: grad_norm=0.1197269931435585
#   y: grad_norm=0.1715315580368042
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 149  U=171.114  z_cont=[11.2,12.4]
#   x: grad_norm=0.1277470886707306
#   y: grad_norm=0.18261480331420898
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 150  U=171.226  z_cont=[11.2,12.4]
#   x: grad_norm=0.14178360998630524
#   y: grad_norm=0.20330369472503662
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 151  U=171.459  z_cont=[11.2,12.4]
#   x: grad_norm=0.13801337778568268
#   y: grad_norm=0.21679198741912842
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 152  U=171.702  z_cont=[11.2,12.4]
#   x: grad_norm=0.1340675801038742
#   y: grad_norm=0.21921777725219727
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 153  U=171.969  z_cont=[11.2,12.4]
#   x: grad_norm=0.1279895305633545
#   y: grad_norm=0.20548342168331146
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 154  U=172.248  z_cont=[11.2,12.4]
#   x: grad_norm=0.12441662698984146
#   y: grad_norm=0.20440684258937836
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 155  U=172.392  z_cont=[11.2,12.4]
#   x: grad_norm=0.1344081461429596
#   y: grad_norm=0.22209694981575012
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 156  U=172.710  z_cont=[11.2,12.4]
#   x: grad_norm=0.12656179070472717
#   y: grad_norm=0.21113187074661255
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 157  U=173.042  z_cont=[11.2,12.4]
#   x: grad_norm=0.12403880059719086
#   y: grad_norm=0.20769543945789337
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 158  U=173.390  z_cont=[11.2,12.4]
#   x: grad_norm=0.12396508455276489
#   y: grad_norm=0.21388030052185059
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 159  U=173.766  z_cont=[11.2,12.4]
#   x: grad_norm=0.13326184451580048
#   y: grad_norm=0.22411248087882996
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 160  U=173.948  z_cont=[11.2,12.4]
#   x: grad_norm=0.1386217325925827
#   y: grad_norm=0.22723393142223358
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 161  U=174.332  z_cont=[11.2,12.4]
#   x: grad_norm=0.15869423747062683
#   y: grad_norm=0.24506255984306335
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 162  U=174.776  z_cont=[11.2,12.4]
#   x: grad_norm=0.19087687134742737
#   y: grad_norm=0.28713279962539673
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 163  U=175.358  z_cont=[11.2,12.4]
#   x: grad_norm=0.24945518374443054
#   y: grad_norm=0.367692768573761
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 164  U=176.219  z_cont=[11.2,12.4]
#   x: grad_norm=0.33870673179626465
#   y: grad_norm=0.5080916285514832
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 165  U=177.217  z_cont=[11.2,12.4]
#   x: grad_norm=0.4629738926887512
#   y: grad_norm=0.7144604921340942
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 166  U=179.515  z_cont=[11.2,12.4]
#   x: grad_norm=0.8295434713363647
#   y: grad_norm=1.2068685293197632
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 167  U=184.789  z_cont=[11.2,12.4]
#   x: grad_norm=1.6891133785247803
#   y: grad_norm=2.5120272636413574
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 168  U=202.863  z_cont=[11.2,12.4]
#   x: grad_norm=5.594983100891113
#   y: grad_norm=8.06899356842041
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 169  U=266.003  z_cont=[11.2,12.4]
#   x: grad_norm=2.4965052604675293
#   y: grad_norm=3.21960711479187
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 170  U=208.596  z_cont=[11.2,12.4]
#   x: grad_norm=8.840338706970215
#   y: grad_norm=13.923080444335938
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 171  U=221.448  z_cont=[11.2,12.4]
#   x: grad_norm=10.262090682983398
#   y: grad_norm=15.786458015441895
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 172  U=268.086  z_cont=[11.2,12.4]
#   x: grad_norm=0.8396605253219604
#   y: grad_norm=1.4833574295043945
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 173  U=229.701  z_cont=[11.2,12.4]
#   x: grad_norm=9.896871566772461
#   y: grad_norm=14.506793975830078
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 174  U=230.068  z_cont=[11.2,12.4]
#   x: grad_norm=9.763749122619629
#   y: grad_norm=14.486824035644531
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 175  U=251.696  z_cont=[11.2,12.4]
#   x: grad_norm=10.364322662353516
#   y: grad_norm=15.401456832885742
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 176  U=250.504  z_cont=[11.2,12.4]
#   x: grad_norm=10.48066520690918
#   y: grad_norm=15.838494300842285
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 177  U=232.752  z_cont=[11.2,12.4]
#   x: grad_norm=10.236681938171387
#   y: grad_norm=14.919248580932617
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 178  U=245.032  z_cont=[11.2,12.4]
#   x: grad_norm=10.777108192443848
#   y: grad_norm=15.618456840515137
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 179  U=269.333  z_cont=[11.2,12.4]
#   x: grad_norm=0.7558382749557495
#   y: grad_norm=1.2156704664230347
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 180  U=235.376  z_cont=[11.2,12.4]
#   x: grad_norm=10.500636100769043
#   y: grad_norm=16.21889877319336
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 181  U=235.022  z_cont=[11.2,12.4]
#   x: grad_norm=10.531928062438965
#   y: grad_norm=15.411693572998047
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 182  U=257.394  z_cont=[11.2,12.4]
#   x: grad_norm=9.604641914367676
#   y: grad_norm=14.0197172164917
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 183  U=264.061  z_cont=[11.2,12.4]
#   x: grad_norm=7.287761211395264
#   y: grad_norm=10.566564559936523
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 184  U=246.788  z_cont=[11.2,12.4]
#   x: grad_norm=10.685644149780273
#   y: grad_norm=15.589426040649414
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 185  U=263.701  z_cont=[11.2,12.4]
#   x: grad_norm=7.679752349853516
#   y: grad_norm=11.234867095947266
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 186  U=270.278  z_cont=[11.2,12.4]
#   x: grad_norm=1.5974528789520264
#   y: grad_norm=2.2926974296569824
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 187  U=263.139  z_cont=[11.2,12.4]
#   x: grad_norm=7.98773717880249
#   y: grad_norm=11.609551429748535
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 188  U=265.025  z_cont=[11.2,12.4]
#   x: grad_norm=7.141396522521973
#   y: grad_norm=10.344501495361328
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 189  U=270.617  z_cont=[11.2,12.4]
#   x: grad_norm=0.3489626348018646
#   y: grad_norm=0.5941476821899414
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 190  U=270.521  z_cont=[11.2,12.4]
#   x: grad_norm=0.7480204105377197
#   y: grad_norm=1.2318222522735596
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 191  U=266.690  z_cont=[11.2,12.4]
#   x: grad_norm=6.0571722984313965
#   y: grad_norm=9.393165588378906
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 192  U=268.189  z_cont=[11.2,12.4]
#   x: grad_norm=4.939418315887451
#   y: grad_norm=7.383965015411377
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 193  U=270.645  z_cont=[11.2,12.4]
#   x: grad_norm=1.0345100164413452
#   y: grad_norm=1.3675408363342285
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 194  U=268.052  z_cont=[11.2,12.4]
#   x: grad_norm=5.288465976715088
#   y: grad_norm=7.602120399475098
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 195  U=261.181  z_cont=[11.2,12.4]
#   x: grad_norm=8.788734436035156
#   y: grad_norm=12.727520942687988
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 196  U=270.798  z_cont=[11.2,12.4]
#   x: grad_norm=1.2647714614868164
#   y: grad_norm=1.7202788591384888
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 197  U=264.573  z_cont=[11.2,12.4]
#   x: grad_norm=7.574033260345459
#   y: grad_norm=11.206425666809082
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 198  U=262.762  z_cont=[11.2,12.4]
#   x: grad_norm=8.369799613952637
#   y: grad_norm=12.34826946258545
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 199  U=270.369  z_cont=[11.2,12.4]
#   x: grad_norm=2.941044330596924
#   y: grad_norm=4.360755443572998
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 200  U=258.657  z_cont=[11.2,12.4]
#   x: grad_norm=9.566513061523438
#   y: grad_norm=13.962953567504883
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 201  U=260.366  z_cont=[11.2,12.4]
#   x: grad_norm=9.1727294921875
#   y: grad_norm=13.404278755187988
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 202  U=270.867  z_cont=[11.2,12.4]
#   x: grad_norm=2.2305567264556885
#   y: grad_norm=3.2397139072418213
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 203  U=265.518  z_cont=[11.2,12.4]
#   x: grad_norm=7.265694618225098
#   y: grad_norm=10.673008918762207
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# ...
# Epoch 1182  U=271.145  z_cont=[11.0,12.7]
#   x: grad_norm=0.3712109625339508
#   y: grad_norm=0.5772156119346619
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1183  U=269.800  z_cont=[11.0,12.7]
#   x: grad_norm=3.5787558555603027
#   y: grad_norm=6.798652172088623
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1184  U=269.568  z_cont=[11.0,12.7]
#   x: grad_norm=3.6518702507019043
#   y: grad_norm=6.910065650939941
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1185  U=269.471  z_cont=[11.0,12.7]
#   x: grad_norm=3.6591994762420654
#   y: grad_norm=6.743597984313965
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1186  U=269.883  z_cont=[11.0,12.7]
#   x: grad_norm=3.2306742668151855
#   y: grad_norm=5.9509100914001465
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1187  U=271.117  z_cont=[11.0,12.7]
#   x: grad_norm=0.6289722919464111
#   y: grad_norm=1.1379753351211548
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1188  U=270.620  z_cont=[11.0,12.7]
#   x: grad_norm=2.186880350112915
#   y: grad_norm=4.132401943206787
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1189  U=270.062  z_cont=[11.0,12.7]
#   x: grad_norm=3.0859920978546143
#   y: grad_norm=5.824951171875
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1190  U=269.373  z_cont=[11.0,12.7]
#   x: grad_norm=4.101474761962891
#   y: grad_norm=7.803032875061035
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1191  U=270.575  z_cont=[11.0,12.7]
#   x: grad_norm=2.1784708499908447
#   y: grad_norm=4.002584934234619
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1192  U=271.084  z_cont=[11.0,12.7]
#   x: grad_norm=0.7792500853538513
#   y: grad_norm=1.4631272554397583
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1193  U=270.327  z_cont=[11.0,12.7]
#   x: grad_norm=2.795522689819336
#   y: grad_norm=4.821484565734863
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1194  U=270.528  z_cont=[11.0,12.7]
#   x: grad_norm=2.5271167755126953
#   y: grad_norm=4.357977867126465
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1195  U=268.384  z_cont=[11.0,12.7]
#   x: grad_norm=4.879988670349121
#   y: grad_norm=8.426793098449707
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1196  U=269.933  z_cont=[11.0,12.7]
#   x: grad_norm=3.2781519889831543
#   y: grad_norm=5.53706169128418
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1197  U=271.080  z_cont=[11.0,12.7]
#   x: grad_norm=0.8150391578674316
#   y: grad_norm=1.4635413885116577
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1198  U=269.579  z_cont=[11.0,12.7]
#   x: grad_norm=3.8370163440704346
#   y: grad_norm=6.6811652183532715
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1199  U=269.770  z_cont=[11.0,12.7]
#   x: grad_norm=3.6566097736358643
#   y: grad_norm=6.363495349884033
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1200  U=268.986  z_cont=[11.0,12.7]
#   x: grad_norm=4.49796724319458
#   y: grad_norm=7.804819583892822
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1201  U=269.623  z_cont=[11.0,12.7]
#   x: grad_norm=3.652226448059082
#   y: grad_norm=6.182747840881348
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1202  U=271.112  z_cont=[11.0,12.7]
#   x: grad_norm=0.6220484972000122
#   y: grad_norm=0.9889538884162903
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1203  U=270.332  z_cont=[11.0,12.7]
#   x: grad_norm=2.9572641849517822
#   y: grad_norm=5.157598495483398
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1204  U=269.897  z_cont=[11.0,12.7]
#   x: grad_norm=3.6528422832489014
#   y: grad_norm=6.360508441925049
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1205  U=268.847  z_cont=[11.0,12.7]
#   x: grad_norm=4.3770952224731445
#   y: grad_norm=7.473031520843506
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1206  U=269.997  z_cont=[11.0,12.7]
#   x: grad_norm=3.1579012870788574
#   y: grad_norm=5.340203762054443
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1207  U=271.132  z_cont=[11.0,12.7]
#   x: grad_norm=0.33040687441825867
#   y: grad_norm=0.5779299139976501
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1208  U=270.194  z_cont=[11.0,12.7]
#   x: grad_norm=3.0223801136016846
#   y: grad_norm=5.396988868713379
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1209  U=270.259  z_cont=[11.0,12.7]
#   x: grad_norm=2.944655179977417
#   y: grad_norm=5.2648539543151855
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1210  U=268.164  z_cont=[11.0,12.7]
#   x: grad_norm=5.052788734436035
#   y: grad_norm=8.792871475219727
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1211  U=269.760  z_cont=[11.0,12.7]
#   x: grad_norm=3.4705498218536377
#   y: grad_norm=6.0051116943359375
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1212  U=270.987  z_cont=[11.0,12.7]
#   x: grad_norm=0.8350372910499573
#   y: grad_norm=1.5414819717407227
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1213  U=269.425  z_cont=[11.0,12.7]
#   x: grad_norm=3.9400906562805176
#   y: grad_norm=7.038422584533691
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1214  U=269.648  z_cont=[11.0,12.7]
#   x: grad_norm=3.7378294467926025
#   y: grad_norm=6.672457695007324
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1215  U=268.197  z_cont=[11.0,12.7]
#   x: grad_norm=5.048063278198242
#   y: grad_norm=8.794901847839355
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1216  U=269.294  z_cont=[11.0,12.7]
#   x: grad_norm=4.082680702209473
#   y: grad_norm=7.101004123687744
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1217  U=271.125  z_cont=[11.0,12.7]
#   x: grad_norm=0.2230677306652069
#   y: grad_norm=0.3027580678462982
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1218  U=269.646  z_cont=[11.0,12.7]
#   x: grad_norm=4.1881232261657715
#   y: grad_norm=7.355407238006592
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1219  U=269.670  z_cont=[11.0,12.7]
#   x: grad_norm=3.911546230316162
#   y: grad_norm=6.89529275894165
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1220  U=268.224  z_cont=[11.0,12.7]
#   x: grad_norm=5.155679702758789
#   y: grad_norm=8.9133882522583
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1221  U=269.444  z_cont=[11.0,12.7]
#   x: grad_norm=4.016696453094482
#   y: grad_norm=6.936946392059326
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1222  U=271.149  z_cont=[11.0,12.7]
#   x: grad_norm=0.2610870599746704
#   y: grad_norm=0.4535667598247528
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1223  U=269.678  z_cont=[11.0,12.7]
#   x: grad_norm=3.7501072883605957
#   y: grad_norm=6.693975448608398
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1224  U=269.538  z_cont=[11.0,12.7]
#   x: grad_norm=3.9494497776031494
#   y: grad_norm=7.039522647857666
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1225  U=269.137  z_cont=[11.0,12.7]
#   x: grad_norm=4.258695125579834
#   y: grad_norm=7.459863185882568
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1226  U=269.650  z_cont=[11.0,12.7]
#   x: grad_norm=4.168815612792969
#   y: grad_norm=7.373964309692383
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1227  U=271.140  z_cont=[11.0,12.7]
#   x: grad_norm=0.48685595393180847
#   y: grad_norm=0.7814037799835205
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1228  U=270.525  z_cont=[11.0,12.7]
#   x: grad_norm=2.4884912967681885
#   y: grad_norm=4.434647560119629
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1229  U=270.282  z_cont=[11.0,12.8]
#   x: grad_norm=2.9276466369628906
#   y: grad_norm=5.197261810302734
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1230  U=268.697  z_cont=[11.0,12.8]
#   x: grad_norm=4.633725643157959
#   y: grad_norm=8.029864311218262
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1231  U=270.202  z_cont=[11.0,12.8]
#   x: grad_norm=2.867293357849121
#   y: grad_norm=4.929687976837158
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1232  U=270.932  z_cont=[11.0,12.8]
#   x: grad_norm=1.1639289855957031
#   y: grad_norm=2.1112685203552246
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1233  U=269.607  z_cont=[11.0,12.8]
#   x: grad_norm=3.74623966217041
#   y: grad_norm=6.646651744842529
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1234  U=270.090  z_cont=[11.0,12.8]
#   x: grad_norm=3.161327838897705
#   y: grad_norm=5.612922668457031
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1235  U=266.806  z_cont=[10.9,12.8]
#   x: grad_norm=6.638393878936768
#   y: grad_norm=11.482001304626465
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1236  U=269.364  z_cont=[10.9,12.8]
#   x: grad_norm=3.9987995624542236
#   y: grad_norm=6.909939765930176
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1237  U=271.014  z_cont=[10.9,12.8]
#   x: grad_norm=0.9153494834899902
#   y: grad_norm=1.5324602127075195
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1238  U=269.147  z_cont=[10.9,12.8]
#   x: grad_norm=4.927732467651367
#   y: grad_norm=8.290385246276855
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1239  U=270.311  z_cont=[10.9,12.8]
#   x: grad_norm=3.267817258834839
#   y: grad_norm=5.526200294494629
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1240  U=265.439  z_cont=[10.9,12.8]
#   x: grad_norm=7.403895378112793
#   y: grad_norm=12.091775894165039
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1241  U=268.744  z_cont=[10.9,12.8]
#   x: grad_norm=5.0286784172058105
#   y: grad_norm=8.18931770324707
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1242  U=270.648  z_cont=[10.9,12.8]
#   x: grad_norm=2.3054513931274414
#   y: grad_norm=3.971970319747925
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1243  U=267.334  z_cont=[10.9,12.8]
#   x: grad_norm=6.544370651245117
#   y: grad_norm=11.084080696105957
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1244  U=269.716  z_cont=[10.9,12.8]
#   x: grad_norm=4.0188679695129395
#   y: grad_norm=6.800329208374023
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1245  U=265.745  z_cont=[10.9,12.8]
#   x: grad_norm=7.140878200531006
#   y: grad_norm=11.851692199707031
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1246  U=267.631  z_cont=[10.9,12.8]
#   x: grad_norm=5.93543004989624
#   y: grad_norm=9.839404106140137
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1247  U=271.071  z_cont=[10.9,12.8]
#   x: grad_norm=0.3875015377998352
#   y: grad_norm=0.6605654954910278
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1248  U=268.551  z_cont=[10.9,12.8]
#   x: grad_norm=5.147464275360107
#   y: grad_norm=8.945357322692871
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# Epoch 1249  U=268.895  z_cont=[10.9,12.8]
#   x: grad_norm=5.272594928741455
#   y: grad_norm=9.012471199035645
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt
# CPU times: user 1min 49s, sys: 13.5 s, total: 2min 3s
# Wall time: 4min

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='1e2 U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='1e2 U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='1e8 U_E',    lw=1)
# plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_39_10_shower_center_angle_energy/cashed_showers_10.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_lb.detach().cpu().max()], [0, E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
