# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_38_10_shower_center_init_angle_error"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generate_new_data = True
print("device:", device)
# Out:
# device: cpu

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 10 # 200000
Nvalidation = 10 # 20000
Ntest       = 10 # 3000
Nbatch      = 10 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
use_cache = True
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-2203 m  shift=+5006 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([-1907.7203,  4505.5415, -1643.9327, -1939.2573, -1112.7185,   637.4553,
#         -3818.6672, -4274.4561, -1556.9991, -2235.4375])
# Y0: tensor([1422.2808, 5604.9370, 7236.5972,  698.1343,  885.7803, 6356.0146,
#         4484.0601, 3971.6616,  918.8809, 2461.1887])
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 7777646.000, energy.max(): 81127968.000
# theta.min():  61.7°, theta.max():  92.6°
# phi.min():    -131.1°, phi.max():    170.7°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# CPU times: user 42.2 ms, sys: 12.5 ms, total: 54.7 ms
# Wall time: 66 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# CPU times: user 42.8 ms, sys: 8.87 ms, total: 51.6 ms
# Wall time: 60.4 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([10, 90, 5])   labels: torch.Size([10, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0849
# Training 20%  val_loss=0.0836
# Training 30%  val_loss=0.0836
# Training 40%  val_loss=0.0836
# Training 50%  val_loss=0.0836
# Training 60%  val_loss=0.0836
# Training 70%  val_loss=0.0836
# Training 80%  val_loss=0.0836
# CPU times: user 8.17 s, sys: 76.1 ms, total: 8.25 s
# Wall time: 9.24 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
# optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)
optimizer = torch.optim.Adam(                  
      xy_module.parameters(),               
      lr=0.3,              # Adam's effective step ≈ lr, so ~1 m/epoch
      betas=(0.9, 0.999),                                                                                                                                                                                                                                                                          
      eps=1e-8,                           
  )        

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + 1250):

    if epoch < 20:
        Nfinetune = 10 # 3000
    else:
        Nfinetune = 10 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        1e2 * U_angle(preds_th,  th, r_score) +
        1e2 * U_angle(preds_phi, ph, r_score) + 0
        # 1e8 * U_E(preds_e, energy, r_score)   +
        # 5e5 * U_PR(r_score)
    ) / 1e3

    U_vals.append(U.item())
    U_th_vals.append( (1e2 * U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( (1e2 * U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   (1e8 * U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  (5e5 * U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=False, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 0  U=67.804  z_cont=[11.2,12.3]
#   x: grad_norm=0.7552874684333801
#   y: grad_norm=1.3264131546020508
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1  U=73.479  z_cont=[11.2,12.3]
#   x: grad_norm=0.9990224242210388
#   y: grad_norm=1.7771743535995483
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 2  U=80.752  z_cont=[11.1,12.3]
#   x: grad_norm=1.2597947120666504
#   y: grad_norm=2.2482147216796875
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 3  U=89.788  z_cont=[11.1,12.3]
#   x: grad_norm=1.534433364868164
#   y: grad_norm=2.7384660243988037
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 4  U=100.550  z_cont=[11.1,12.3]
#   x: grad_norm=1.7753117084503174
#   y: grad_norm=3.166166067123413
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 5  U=111.605  z_cont=[11.1,12.3]
#   x: grad_norm=1.894935965538025
#   y: grad_norm=3.38423490524292
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 6  U=123.856  z_cont=[11.1,12.4]
#   x: grad_norm=1.8304362297058105
#   y: grad_norm=3.2195358276367188
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 7  U=134.640  z_cont=[11.1,12.4]
#   x: grad_norm=1.4436675310134888
#   y: grad_norm=2.5285167694091797
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 8  U=141.864  z_cont=[11.1,12.4]
#   x: grad_norm=0.7678411602973938
#   y: grad_norm=1.3442556858062744
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 9  U=144.347  z_cont=[11.1,12.4]
#   x: grad_norm=0.04765672609210014
#   y: grad_norm=0.08022244274616241
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 10  U=143.390  z_cont=[11.1,12.4]
#   x: grad_norm=0.4150746464729309
#   y: grad_norm=0.7206791639328003
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 11  U=140.786  z_cont=[11.1,12.4]
#   x: grad_norm=0.6854370832443237
#   y: grad_norm=1.1890698671340942
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 12  U=138.134  z_cont=[11.1,12.4]
#   x: grad_norm=0.7685207724571228
#   y: grad_norm=1.3331537246704102
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 13  U=136.079  z_cont=[11.1,12.4]
#   x: grad_norm=0.7680394053459167
#   y: grad_norm=1.3332735300064087
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 14  U=134.700  z_cont=[11.1,12.4]
#   x: grad_norm=0.7351238131523132
#   y: grad_norm=1.2761914730072021
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 15  U=134.428  z_cont=[11.1,12.4]
#   x: grad_norm=0.7220704555511475
#   y: grad_norm=1.2467827796936035
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 16  U=134.043  z_cont=[11.1,12.4]
#   x: grad_norm=0.7072504162788391
#   y: grad_norm=1.221225380897522
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 17  U=134.036  z_cont=[11.1,12.4]
#   x: grad_norm=0.7058554887771606
#   y: grad_norm=1.2199207544326782
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 18  U=134.366  z_cont=[11.1,12.4]
#   x: grad_norm=0.7185713052749634
#   y: grad_norm=1.2418570518493652
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 19  U=135.015  z_cont=[11.1,12.4]
#   x: grad_norm=0.7441449761390686
#   y: grad_norm=1.2714563608169556
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 20  U=136.556  z_cont=[11.1,12.4]
#   x: grad_norm=0.7724742293357849
#   y: grad_norm=1.3193827867507935
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 21  U=137.844  z_cont=[11.1,12.4]
#   x: grad_norm=0.7744616270065308
#   y: grad_norm=1.322758436203003
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 22  U=139.372  z_cont=[11.1,12.4]
#   x: grad_norm=0.7479485273361206
#   y: grad_norm=1.2775802612304688
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 23  U=141.012  z_cont=[11.1,12.4]
#   x: grad_norm=0.6750681400299072
#   y: grad_norm=1.1563323736190796
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 24  U=142.555  z_cont=[11.1,12.4]
#   x: grad_norm=0.542117178440094
#   y: grad_norm=0.9284514784812927
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 25  U=143.965  z_cont=[11.1,12.4]
#   x: grad_norm=0.2771701514720917
#   y: grad_norm=0.4777393639087677
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 26  U=144.361  z_cont=[11.1,12.4]
#   x: grad_norm=0.021657979115843773
#   y: grad_norm=0.03834521397948265
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 27  U=144.107  z_cont=[11.1,12.4]
#   x: grad_norm=0.24451030790805817
#   y: grad_norm=0.4169830083847046
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 28  U=143.402  z_cont=[11.1,12.4]
#   x: grad_norm=0.47844409942626953
#   y: grad_norm=0.8181536793708801
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 29  U=142.584  z_cont=[11.1,12.4]
#   x: grad_norm=0.6536334753036499
#   y: grad_norm=1.1177030801773071
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 30  U=141.468  z_cont=[11.1,12.4]
#   x: grad_norm=0.8320618271827698
#   y: grad_norm=1.4231138229370117
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 31  U=141.307  z_cont=[11.1,12.4]
#   x: grad_norm=0.8546991944313049
#   y: grad_norm=1.4618911743164062
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 32  U=141.654  z_cont=[11.1,12.4]
#   x: grad_norm=0.8054881691932678
#   y: grad_norm=1.3775900602340698
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 33  U=142.354  z_cont=[11.1,12.4]
#   x: grad_norm=0.6943174004554749
#   y: grad_norm=1.1880123615264893
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 34  U=143.168  z_cont=[11.1,12.4]
#   x: grad_norm=0.5363909006118774
#   y: grad_norm=0.9129925966262817
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 35  U=143.600  z_cont=[11.1,12.4]
#   x: grad_norm=0.4296095073223114
#   y: grad_norm=0.7235956192016602
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 36  U=144.151  z_cont=[11.1,12.4]
#   x: grad_norm=0.22722306847572327
#   y: grad_norm=0.3815370202064514
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 37  U=144.368  z_cont=[11.1,12.4]
#   x: grad_norm=0.03420170024037361
#   y: grad_norm=0.055242788046598434
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 38  U=144.287  z_cont=[11.1,12.4]
#   x: grad_norm=0.13385620713233948
#   y: grad_norm=0.2276097536087036
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 39  U=144.023  z_cont=[11.1,12.4]
#   x: grad_norm=0.26321735978126526
#   y: grad_norm=0.44599953293800354
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 40  U=143.942  z_cont=[11.1,12.4]
#   x: grad_norm=0.2887687385082245
#   y: grad_norm=0.4889579117298126
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 41  U=143.715  z_cont=[11.1,12.4]
#   x: grad_norm=0.3514012396335602
#   y: grad_norm=0.5946394205093384
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 42  U=143.573  z_cont=[11.1,12.4]
#   x: grad_norm=0.3839249014854431
#   y: grad_norm=0.6495210528373718
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 43  U=143.548  z_cont=[11.1,12.4]
#   x: grad_norm=0.3895409107208252
#   y: grad_norm=0.6590061187744141
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 44  U=143.636  z_cont=[11.1,12.4]
#   x: grad_norm=0.3706700801849365
#   y: grad_norm=0.6271786093711853
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 45  U=144.012  z_cont=[11.1,12.4]
#   x: grad_norm=0.2662558853626251
#   y: grad_norm=0.4508698880672455
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 46  U=144.165  z_cont=[11.1,12.4]
#   x: grad_norm=0.20548316836357117
#   y: grad_norm=0.34835970401763916
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 47  U=144.292  z_cont=[11.1,12.4]
#   x: grad_norm=0.13189563155174255
#   y: grad_norm=0.2242112010717392
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 48  U=144.365  z_cont=[11.1,12.4]
#   x: grad_norm=0.05157679691910744
#   y: grad_norm=0.08849336951971054
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 49  U=144.375  z_cont=[11.1,12.4]
#   x: grad_norm=0.031114740297198296
#   y: grad_norm=0.0499480664730072
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 50  U=144.235  z_cont=[11.1,12.4]
#   x: grad_norm=0.1812722533941269
#   y: grad_norm=0.3035307824611664
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 51  U=144.143  z_cont=[11.1,12.4]
#   x: grad_norm=0.23387663066387177
#   y: grad_norm=0.39216122031211853
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 52  U=144.089  z_cont=[11.1,12.4]
#   x: grad_norm=0.2610779106616974
#   y: grad_norm=0.4355565309524536
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 53  U=144.092  z_cont=[11.1,12.4]
#   x: grad_norm=0.2605520188808441
#   y: grad_norm=0.43466827273368835
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 54  U=144.146  z_cont=[11.1,12.4]
#   x: grad_norm=0.2352735996246338
#   y: grad_norm=0.39234045147895813
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 55  U=144.065  z_cont=[11.1,12.4]
#   x: grad_norm=0.27106210589408875
#   y: grad_norm=0.45477092266082764
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 56  U=144.201  z_cont=[11.1,12.4]
#   x: grad_norm=0.20421573519706726
#   y: grad_norm=0.3420916795730591
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 57  U=144.315  z_cont=[11.1,12.4]
#   x: grad_norm=0.12541575729846954
#   y: grad_norm=0.20923194289207458
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 58  U=144.377  z_cont=[11.1,12.4]
#   x: grad_norm=0.04451460763812065
#   y: grad_norm=0.07261164486408234
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 59  U=144.381  z_cont=[11.1,12.4]
#   x: grad_norm=0.03321365639567375
#   y: grad_norm=0.057266708463430405
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 60  U=144.381  z_cont=[11.1,12.4]
#   x: grad_norm=0.024193797260522842
#   y: grad_norm=0.0417703278362751
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 61  U=144.355  z_cont=[11.1,12.4]
#   x: grad_norm=0.0783248245716095
#   y: grad_norm=0.13461871445178986
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 62  U=144.316  z_cont=[11.1,12.4]
#   x: grad_norm=0.1197296604514122
#   y: grad_norm=0.20520883798599243
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 63  U=144.282  z_cont=[11.1,12.4]
#   x: grad_norm=0.14597932994365692
#   y: grad_norm=0.24993667006492615
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 64  U=144.267  z_cont=[11.1,12.4]
#   x: grad_norm=0.1566120833158493
#   y: grad_norm=0.26812878251075745
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 65  U=144.355  z_cont=[11.1,12.4]
#   x: grad_norm=0.08100386708974838
#   y: grad_norm=0.13919471204280853
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 66  U=144.365  z_cont=[11.1,12.4]
#   x: grad_norm=0.06942237913608551
#   y: grad_norm=0.11943694949150085
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 67  U=144.377  z_cont=[11.1,12.4]
#   x: grad_norm=0.05232402682304382
#   y: grad_norm=0.09022653847932816
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 68  U=144.387  z_cont=[11.1,12.4]
#   x: grad_norm=0.031941961497068405
#   y: grad_norm=0.05524664372205734
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 69  U=144.392  z_cont=[11.1,12.4]
#   x: grad_norm=0.01222431194037199
#   y: grad_norm=0.020237406715750694
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 70  U=144.352  z_cont=[11.1,12.4]
#   x: grad_norm=0.09299513697624207
#   y: grad_norm=0.15652091801166534
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 71  U=144.345  z_cont=[11.1,12.4]
#   x: grad_norm=0.10340525954961777
#   y: grad_norm=0.1742529273033142
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 72  U=144.347  z_cont=[11.1,12.4]
#   x: grad_norm=0.10220904648303986
#   y: grad_norm=0.17220540344715118
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 73  U=144.359  z_cont=[11.1,12.4]
#   x: grad_norm=0.088592030107975
#   y: grad_norm=0.1543024778366089
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 74  U=144.374  z_cont=[11.1,12.4]
#   x: grad_norm=0.06993087381124496
#   y: grad_norm=0.12141045928001404
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 75  U=144.324  z_cont=[11.1,12.4]
#   x: grad_norm=0.12250683456659317
#   y: grad_norm=0.21394726634025574
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 76  U=144.360  z_cont=[11.1,12.4]
#   x: grad_norm=0.08716531097888947
#   y: grad_norm=0.1517474353313446
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 77  U=144.388  z_cont=[11.1,12.4]
#   x: grad_norm=0.04656374454498291
#   y: grad_norm=0.08010667562484741
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 78  U=144.399  z_cont=[11.1,12.4]
#   x: grad_norm=0.0100448252633214
#   y: grad_norm=0.013749849982559681
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 79  U=144.395  z_cont=[11.1,12.4]
#   x: grad_norm=0.03404127061367035
#   y: grad_norm=0.05995134264230728
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 80  U=144.397  z_cont=[11.1,12.4]
#   x: grad_norm=0.012805815786123276
#   y: grad_norm=0.01915135607123375
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 81  U=144.397  z_cont=[11.1,12.4]
#   x: grad_norm=0.021073894575238228
#   y: grad_norm=0.03655305877327919
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 82  U=144.392  z_cont=[11.1,12.4]
#   x: grad_norm=0.043028563261032104
#   y: grad_norm=0.07592938095331192
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 83  U=144.385  z_cont=[11.1,12.4]
#   x: grad_norm=0.05884454771876335
#   y: grad_norm=0.1039128303527832
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 84  U=144.382  z_cont=[11.1,12.4]
#   x: grad_norm=0.06693675369024277
#   y: grad_norm=0.11818687617778778
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 85  U=144.401  z_cont=[11.1,12.4]
#   x: grad_norm=0.01335072796791792
#   y: grad_norm=0.020146211609244347
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 86  U=144.403  z_cont=[11.1,12.4]
#   x: grad_norm=0.012614267878234386
#   y: grad_norm=0.018705936148762703
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 87  U=144.405  z_cont=[11.1,12.4]
#   x: grad_norm=0.011459391564130783
#   y: grad_norm=0.01643376611173153
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 88  U=144.407  z_cont=[11.1,12.4]
#   x: grad_norm=0.010297714732587337
#   y: grad_norm=0.014121731743216515
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 89  U=144.408  z_cont=[11.1,12.4]
#   x: grad_norm=0.009547424502670765
#   y: grad_norm=0.012699420563876629
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 90  U=144.380  z_cont=[11.1,12.4]
#   x: grad_norm=0.07371190935373306
#   y: grad_norm=0.12731772661209106
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 91  U=144.389  z_cont=[11.1,12.4]
#   x: grad_norm=0.0631595030426979
#   y: grad_norm=0.10881190001964569
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 92  U=144.400  z_cont=[11.1,12.4]
#   x: grad_norm=0.046620145440101624
#   y: grad_norm=0.07974603027105331
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 93  U=144.408  z_cont=[11.1,12.4]
#   x: grad_norm=0.027042947709560394
#   y: grad_norm=0.04506024718284607
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 94  U=144.413  z_cont=[11.1,12.4]
#   x: grad_norm=0.010336228646337986
#   y: grad_norm=0.014180222526192665
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 95  U=144.392  z_cont=[11.1,12.4]
#   x: grad_norm=0.06294315308332443
#   y: grad_norm=0.10838480293750763
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 96  U=144.406  z_cont=[11.1,12.4]
#   x: grad_norm=0.03825168311595917
#   y: grad_norm=0.06505469977855682
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 97  U=144.414  z_cont=[11.1,12.4]
#   x: grad_norm=0.013986057601869106
#   y: grad_norm=0.021265532821416855
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 98  U=144.415  z_cont=[11.1,12.4]
#   x: grad_norm=0.01755526475608349
#   y: grad_norm=0.029498334974050522
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 99  U=144.411  z_cont=[11.1,12.4]
#   x: grad_norm=0.036647289991378784
#   y: grad_norm=0.06390053778886795
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 100  U=144.412  z_cont=[11.1,12.4]
#   x: grad_norm=0.027156835421919823
#   y: grad_norm=0.045319683849811554
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 101  U=144.417  z_cont=[11.1,12.4]
#   x: grad_norm=0.013389195315539837
#   y: grad_norm=0.019845275208353996
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 102  U=144.419  z_cont=[11.1,12.4]
#   x: grad_norm=0.011392918415367603
#   y: grad_norm=0.017063938081264496
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 103  U=144.419  z_cont=[11.1,12.4]
#   x: grad_norm=0.021268026903271675
#   y: grad_norm=0.03632155805826187
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 104  U=144.419  z_cont=[11.1,12.4]
#   x: grad_norm=0.029795661568641663
#   y: grad_norm=0.05177285522222519
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 105  U=144.412  z_cont=[11.1,12.4]
#   x: grad_norm=0.04349165037274361
#   y: grad_norm=0.07425322383642197
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 106  U=144.418  z_cont=[11.1,12.4]
#   x: grad_norm=0.03415164723992348
#   y: grad_norm=0.05768318101763725
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 107  U=144.423  z_cont=[11.1,12.4]
#   x: grad_norm=0.02237718738615513
#   y: grad_norm=0.03651850298047066
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 108  U=144.427  z_cont=[11.1,12.4]
#   x: grad_norm=0.011764835566282272
#   y: grad_norm=0.016459977254271507
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 109  U=144.429  z_cont=[11.1,12.4]
#   x: grad_norm=0.012015829794108868
#   y: grad_norm=0.018217263743281364
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 110  U=144.411  z_cont=[11.1,12.4]
#   x: grad_norm=0.05933375656604767
#   y: grad_norm=0.10012077540159225
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 111  U=144.421  z_cont=[11.1,12.4]
#   x: grad_norm=0.0425368994474411
#   y: grad_norm=0.07108697295188904
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 112  U=144.429  z_cont=[11.1,12.4]
#   x: grad_norm=0.02307177521288395
#   y: grad_norm=0.03702821582555771
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 113  U=144.434  z_cont=[11.1,12.4]
#   x: grad_norm=0.010070236399769783
#   y: grad_norm=0.013249254785478115
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 114  U=144.434  z_cont=[11.1,12.4]
#   x: grad_norm=0.021405493840575218
#   y: grad_norm=0.03585025668144226
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 115  U=144.424  z_cont=[11.1,12.4]
#   x: grad_norm=0.04499451443552971
#   y: grad_norm=0.07527142763137817
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 116  U=144.432  z_cont=[11.1,12.4]
#   x: grad_norm=0.027099905535578728
#   y: grad_norm=0.04408414661884308
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 117  U=144.437  z_cont=[11.1,12.4]
#   x: grad_norm=0.011442574672400951
#   y: grad_norm=0.015500089153647423
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 118  U=144.439  z_cont=[11.1,12.4]
#   x: grad_norm=0.016643334180116653
#   y: grad_norm=0.027044661343097687
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 119  U=144.438  z_cont=[11.1,12.4]
#   x: grad_norm=0.02957134135067463
#   y: grad_norm=0.050344813615083694
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 120  U=144.432  z_cont=[11.1,12.4]
#   x: grad_norm=0.041848983615636826
#   y: grad_norm=0.07066135108470917
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 121  U=144.439  z_cont=[11.1,12.4]
#   x: grad_norm=0.028247198089957237
#   y: grad_norm=0.04677685350179672
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 122  U=144.444  z_cont=[11.1,12.4]
#   x: grad_norm=0.014380340464413166
#   y: grad_norm=0.021611979231238365
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 123  U=144.447  z_cont=[11.1,12.4]
#   x: grad_norm=0.011865499429404736
#   y: grad_norm=0.01756344921886921
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 124  U=144.448  z_cont=[11.1,12.4]
#   x: grad_norm=0.021701810881495476
#   y: grad_norm=0.036378633230924606
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 125  U=144.437  z_cont=[11.1,12.4]
#   x: grad_norm=0.04493480175733566
#   y: grad_norm=0.07603719830513
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 126  U=144.444  z_cont=[11.1,12.4]
#   x: grad_norm=0.03104292042553425
#   y: grad_norm=0.051678940653800964
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 127  U=144.450  z_cont=[11.1,12.4]
#   x: grad_norm=0.01617782935500145
#   y: grad_norm=0.024901777505874634
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 128  U=144.453  z_cont=[11.1,12.4]
#   x: grad_norm=0.011434399522840977
#   y: grad_norm=0.01645844615995884
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 129  U=144.454  z_cont=[11.1,12.4]
#   x: grad_norm=0.021482281386852264
#   y: grad_norm=0.03594126179814339
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 130  U=144.442  z_cont=[11.1,12.4]
#   x: grad_norm=0.05103302001953125
#   y: grad_norm=0.08658884465694427
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 131  U=144.451  z_cont=[11.1,12.4]
#   x: grad_norm=0.03529128059744835
#   y: grad_norm=0.059074826538562775
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 132  U=144.458  z_cont=[11.1,12.4]
#   x: grad_norm=0.017935296520590782
#   y: grad_norm=0.028042886406183243
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 133  U=144.462  z_cont=[11.1,12.4]
#   x: grad_norm=0.011784352362155914
#   y: grad_norm=0.017041388899087906
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 134  U=144.463  z_cont=[11.1,12.4]
#   x: grad_norm=0.023697491735219955
#   y: grad_norm=0.03988829627633095
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 135  U=144.453  z_cont=[11.1,12.4]
#   x: grad_norm=0.04800794646143913
#   y: grad_norm=0.07795237004756927
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 136  U=144.461  z_cont=[11.1,12.4]
#   x: grad_norm=0.03142048791050911
#   y: grad_norm=0.04988887533545494
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 137  U=144.468  z_cont=[11.1,12.4]
#   x: grad_norm=0.014511470682919025
#   y: grad_norm=0.021110747009515762
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 138  U=144.471  z_cont=[11.1,12.4]
#   x: grad_norm=0.014184131287038326
#   y: grad_norm=0.021749572828412056
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 139  U=144.471  z_cont=[11.1,12.4]
#   x: grad_norm=0.026220275089144707
#   y: grad_norm=0.04432160407304764
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 140  U=144.463  z_cont=[11.1,12.4]
#   x: grad_norm=0.04482530802488327
#   y: grad_norm=0.07535669207572937
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 141  U=144.471  z_cont=[11.1,12.4]
#   x: grad_norm=0.03007972240447998
#   y: grad_norm=0.04948337748646736
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 142  U=144.478  z_cont=[11.1,12.4]
#   x: grad_norm=0.015101847238838673
#   y: grad_norm=0.022284705191850662
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 143  U=144.481  z_cont=[11.1,12.4]
#   x: grad_norm=0.013136711902916431
#   y: grad_norm=0.01995135471224785
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 144  U=144.482  z_cont=[11.1,12.4]
#   x: grad_norm=0.023435669019818306
#   y: grad_norm=0.03947006165981293
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 145  U=144.471  z_cont=[11.1,12.4]
#   x: grad_norm=0.04775015264749527
#   y: grad_norm=0.07922263443470001
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 146  U=144.480  z_cont=[11.1,12.4]
#   x: grad_norm=0.03335360810160637
#   y: grad_norm=0.054327644407749176
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 147  U=144.487  z_cont=[11.1,12.4]
#   x: grad_norm=0.01749928668141365
#   y: grad_norm=0.02630692534148693
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 148  U=144.491  z_cont=[11.1,12.4]
#   x: grad_norm=0.012213166803121567
#   y: grad_norm=0.0178753100335598
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 149  U=144.492  z_cont=[11.1,12.4]
#   x: grad_norm=0.023711591958999634
#   y: grad_norm=0.03940550237894058
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 150  U=144.483  z_cont=[11.1,12.4]
#   x: grad_norm=0.04529215767979622
#   y: grad_norm=0.07645992934703827
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 151  U=144.493  z_cont=[11.1,12.4]
#   x: grad_norm=0.029879219830036163
#   y: grad_norm=0.04950788989663124
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 152  U=144.500  z_cont=[11.1,12.4]
#   x: grad_norm=0.0152214290574193
#   y: grad_norm=0.0229729562997818
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 153  U=144.504  z_cont=[11.1,12.4]
#   x: grad_norm=0.015997592359781265
#   y: grad_norm=0.02472502365708351
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 154  U=144.506  z_cont=[11.1,12.4]
#   x: grad_norm=0.02709936909377575
#   y: grad_norm=0.04525379091501236
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 155  U=144.499  z_cont=[11.1,12.4]
#   x: grad_norm=0.04442519694566727
#   y: grad_norm=0.07467848807573318
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 156  U=144.509  z_cont=[11.1,12.4]
#   x: grad_norm=0.030499080196022987
#   y: grad_norm=0.05027790740132332
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 157  U=144.516  z_cont=[11.1,12.4]
#   x: grad_norm=0.01677706651389599
#   y: grad_norm=0.025088945403695107
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 158  U=144.521  z_cont=[11.1,12.4]
#   x: grad_norm=0.015541085042059422
#   y: grad_norm=0.022849764674901962
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 159  U=144.524  z_cont=[11.1,12.4]
#   x: grad_norm=0.02544800005853176
#   y: grad_norm=0.04150089994072914
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 160  U=144.515  z_cont=[11.1,12.4]
#   x: grad_norm=0.04929526895284653
#   y: grad_norm=0.08304248005151749
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 161  U=144.526  z_cont=[11.1,12.4]
#   x: grad_norm=0.034438882023096085
#   y: grad_norm=0.057032566517591476
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 162  U=144.536  z_cont=[11.1,12.4]
#   x: grad_norm=0.018929386511445045
#   y: grad_norm=0.02888355776667595
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 163  U=144.542  z_cont=[11.1,12.4]
#   x: grad_norm=0.015623439103364944
#   y: grad_norm=0.02261204645037651
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 164  U=144.545  z_cont=[11.1,12.4]
#   x: grad_norm=0.026211261749267578
#   y: grad_norm=0.04271027445793152
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 165  U=144.535  z_cont=[11.1,12.4]
#   x: grad_norm=0.048941995948553085
#   y: grad_norm=0.08228439092636108
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 166  U=144.548  z_cont=[11.1,12.4]
#   x: grad_norm=0.033131275326013565
#   y: grad_norm=0.05450449883937836
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 167  U=144.557  z_cont=[11.1,12.4]
#   x: grad_norm=0.017842205241322517
#   y: grad_norm=0.026400895789265633
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 168  U=144.564  z_cont=[11.1,12.4]
#   x: grad_norm=0.017702432349324226
#   y: grad_norm=0.026393236592411995
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 169  U=144.567  z_cont=[11.1,12.4]
#   x: grad_norm=0.02921208366751671
#   y: grad_norm=0.04788742959499359
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 170  U=144.561  z_cont=[11.1,12.4]
#   x: grad_norm=0.045362841337919235
#   y: grad_norm=0.0758603885769844
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 171  U=144.573  z_cont=[11.1,12.4]
#   x: grad_norm=0.03096027486026287
#   y: grad_norm=0.05037360638380051
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 172  U=144.583  z_cont=[11.1,12.4]
#   x: grad_norm=0.017880478873848915
#   y: grad_norm=0.026017598807811737
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 173  U=144.590  z_cont=[11.1,12.4]
#   x: grad_norm=0.01834735833108425
#   y: grad_norm=0.027240844443440437
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 174  U=144.595  z_cont=[11.1,12.4]
#   x: grad_norm=0.028338739648461342
#   y: grad_norm=0.046037908643484116
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 175  U=144.590  z_cont=[11.1,12.4]
#   x: grad_norm=0.045489612966775894
#   y: grad_norm=0.07666055858135223
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 176  U=144.602  z_cont=[11.1,12.4]
#   x: grad_norm=0.03218509256839752
#   y: grad_norm=0.05308997258543968
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 177  U=144.613  z_cont=[11.1,12.4]
#   x: grad_norm=0.019465990364551544
#   y: grad_norm=0.029488058760762215
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 178  U=144.621  z_cont=[11.1,12.4]
#   x: grad_norm=0.018754640594124794
#   y: grad_norm=0.027541855350136757
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 179  U=144.628  z_cont=[11.1,12.4]
#   x: grad_norm=0.028247106820344925
#   y: grad_norm=0.045006733387708664
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 180  U=144.620  z_cont=[11.1,12.4]
#   x: grad_norm=0.05016222596168518
#   y: grad_norm=0.0837835744023323
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 181  U=144.636  z_cont=[11.1,12.4]
#   x: grad_norm=0.03477911278605461
#   y: grad_norm=0.05714486166834831
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 182  U=144.650  z_cont=[11.1,12.4]
#   x: grad_norm=0.021232593804597855
#   y: grad_norm=0.0322919562458992
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 183  U=144.660  z_cont=[11.1,12.4]
#   x: grad_norm=0.021695220842957497
#   y: grad_norm=0.033224135637283325
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 184  U=144.669  z_cont=[11.1,12.4]
#   x: grad_norm=0.032412394881248474
#   y: grad_norm=0.052568044513463974
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 185  U=144.664  z_cont=[11.1,12.4]
#   x: grad_norm=0.04770318418741226
#   y: grad_norm=0.07860690355300903
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 186  U=144.682  z_cont=[11.1,12.4]
#   x: grad_norm=0.03375692665576935
#   y: grad_norm=0.054136935621500015
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 187  U=144.698  z_cont=[11.1,12.4]
#   x: grad_norm=0.022703107446432114
#   y: grad_norm=0.032619837671518326
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 188  U=144.711  z_cont=[11.1,12.4]
#   x: grad_norm=0.022829176858067513
#   y: grad_norm=0.033865172415971756
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 189  U=144.723  z_cont=[11.1,12.4]
#   x: grad_norm=0.031052567064762115
#   y: grad_norm=0.05001934990286827
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 190  U=144.717  z_cont=[11.1,12.4]
#   x: grad_norm=0.05330974981188774
#   y: grad_norm=0.08928895741701126
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 191  U=144.738  z_cont=[11.1,12.4]
#   x: grad_norm=0.0393553264439106
#   y: grad_norm=0.06452625244855881
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 192  U=144.757  z_cont=[11.1,12.4]
#   x: grad_norm=0.02580040879547596
#   y: grad_norm=0.03937416151165962
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 193  U=144.773  z_cont=[11.1,12.4]
#   x: grad_norm=0.023961573839187622
#   y: grad_norm=0.03558531031012535
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 194  U=144.787  z_cont=[11.1,12.4]
#   x: grad_norm=0.03304582089185715
#   y: grad_norm=0.05266059562563896
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 195  U=144.785  z_cont=[11.1,12.4]
#   x: grad_norm=0.05012388899922371
#   y: grad_norm=0.08317447453737259
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 196  U=144.808  z_cont=[11.1,12.4]
#   x: grad_norm=0.03547670319676399
#   y: grad_norm=0.05737816542387009
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 197  U=144.830  z_cont=[11.1,12.4]
#   x: grad_norm=0.026038208976387978
#   y: grad_norm=0.038077738136053085
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 198  U=144.849  z_cont=[11.1,12.4]
#   x: grad_norm=0.028544696047902107
#   y: grad_norm=0.04212174564599991
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 199  U=144.867  z_cont=[11.1,12.4]
# ...
# Epoch 1184  U=242.450  z_cont=[10.8,12.5]
#   x: grad_norm=2.555776357650757
#   y: grad_norm=4.157705307006836
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1185  U=242.559  z_cont=[10.8,12.5]
#   x: grad_norm=2.4427969455718994
#   y: grad_norm=3.8212790489196777
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1186  U=243.130  z_cont=[10.8,12.5]
#   x: grad_norm=1.8900591135025024
#   y: grad_norm=2.9576680660247803
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1187  U=243.930  z_cont=[10.8,12.5]
#   x: grad_norm=0.12161768227815628
#   y: grad_norm=0.18383139371871948
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1188  U=243.397  z_cont=[10.8,12.5]
#   x: grad_norm=1.5657193660736084
#   y: grad_norm=2.464127540588379
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1189  U=243.037  z_cont=[10.8,12.5]
#   x: grad_norm=2.0125372409820557
#   y: grad_norm=3.1620945930480957
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1190  U=242.083  z_cont=[10.8,12.5]
#   x: grad_norm=2.83880615234375
#   y: grad_norm=4.454293727874756
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1191  U=243.180  z_cont=[10.8,12.5]
#   x: grad_norm=1.8488513231277466
#   y: grad_norm=2.9020330905914307
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1192  U=243.918  z_cont=[10.8,12.5]
#   x: grad_norm=0.33184322714805603
#   y: grad_norm=0.5224335193634033
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1193  U=242.994  z_cont=[10.8,12.5]
#   x: grad_norm=2.0567309856414795
#   y: grad_norm=3.2308523654937744
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1194  U=242.806  z_cont=[10.8,12.5]
#   x: grad_norm=2.243475914001465
#   y: grad_norm=3.521855592727661
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1195  U=241.875  z_cont=[10.8,12.5]
#   x: grad_norm=3.196254253387451
#   y: grad_norm=4.610617637634277
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1196  U=242.800  z_cont=[10.8,12.5]
#   x: grad_norm=2.2234292030334473
#   y: grad_norm=3.5338821411132812
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1197  U=243.934  z_cont=[10.8,12.5]
#   x: grad_norm=0.18291723728179932
#   y: grad_norm=0.2887086570262909
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1198  U=243.175  z_cont=[10.8,12.5]
#   x: grad_norm=2.009401321411133
#   y: grad_norm=3.2335398197174072
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1199  U=242.748  z_cont=[10.8,12.5]
#   x: grad_norm=2.270799398422241
#   y: grad_norm=3.613147020339966
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1200  U=241.767  z_cont=[10.8,12.5]
#   x: grad_norm=3.2897493839263916
#   y: grad_norm=5.5329060554504395
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1201  U=243.313  z_cont=[10.8,12.5]
#   x: grad_norm=1.6428297758102417
#   y: grad_norm=2.602325439453125
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1202  U=243.884  z_cont=[10.7,12.5]
#   x: grad_norm=0.432100772857666
#   y: grad_norm=0.6989212036132812
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1203  U=243.035  z_cont=[10.7,12.5]
#   x: grad_norm=2.133467197418213
#   y: grad_norm=3.642183303833008
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1204  U=243.379  z_cont=[10.7,12.5]
#   x: grad_norm=1.5831815004348755
#   y: grad_norm=2.572807788848877
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1205  U=240.643  z_cont=[10.7,12.5]
#   x: grad_norm=3.6810829639434814
#   y: grad_norm=5.953989505767822
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1206  U=242.550  z_cont=[10.7,12.5]
#   x: grad_norm=2.4513256549835205
#   y: grad_norm=3.9610092639923096
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1207  U=243.851  z_cont=[10.7,12.5]
#   x: grad_norm=0.575931966304779
#   y: grad_norm=0.8729502558708191
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1208  U=242.300  z_cont=[10.7,12.5]
#   x: grad_norm=2.795292854309082
#   y: grad_norm=4.160567760467529
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1209  U=242.316  z_cont=[10.7,12.5]
#   x: grad_norm=2.752917766571045
#   y: grad_norm=4.203100681304932
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1210  U=241.297  z_cont=[10.7,12.5]
#   x: grad_norm=3.4775407314300537
#   y: grad_norm=5.241950511932373
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1211  U=242.231  z_cont=[10.7,12.5]
#   x: grad_norm=2.7971251010894775
#   y: grad_norm=4.243009090423584
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1212  U=243.893  z_cont=[10.7,12.5]
#   x: grad_norm=0.22538234293460846
#   y: grad_norm=0.33854934573173523
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1213  U=242.751  z_cont=[10.7,12.5]
#   x: grad_norm=2.446955919265747
#   y: grad_norm=3.9444050788879395
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1214  U=242.434  z_cont=[10.7,12.5]
#   x: grad_norm=2.658280372619629
#   y: grad_norm=4.112125873565674
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1215  U=241.794  z_cont=[10.7,12.5]
#   x: grad_norm=3.1308860778808594
#   y: grad_norm=4.827208995819092
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1216  U=242.791  z_cont=[10.7,12.5]
#   x: grad_norm=2.3246090412139893
#   y: grad_norm=3.5841310024261475
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1217  U=243.921  z_cont=[10.7,12.5]
#   x: grad_norm=0.20909518003463745
#   y: grad_norm=0.32490235567092896
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1218  U=242.855  z_cont=[10.7,12.6]
#   x: grad_norm=2.3081958293914795
#   y: grad_norm=3.5574796199798584
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1219  U=242.776  z_cont=[10.7,12.6]
#   x: grad_norm=2.393815279006958
#   y: grad_norm=3.6887454986572266
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1220  U=240.854  z_cont=[10.7,12.5]
#   x: grad_norm=3.9022035598754883
#   y: grad_norm=6.083985805511475
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1221  U=242.667  z_cont=[10.7,12.6]
#   x: grad_norm=2.489790916442871
#   y: grad_norm=3.8357484340667725
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1222  U=243.845  z_cont=[10.7,12.6]
#   x: grad_norm=0.6705158352851868
#   y: grad_norm=1.0348089933395386
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1223  U=242.154  z_cont=[10.7,12.6]
#   x: grad_norm=2.930973529815674
#   y: grad_norm=4.518860816955566
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1224  U=242.378  z_cont=[10.7,12.6]
#   x: grad_norm=2.7535455226898193
#   y: grad_norm=4.245230197906494
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1225  U=240.717  z_cont=[10.7,12.6]
#   x: grad_norm=3.845424175262451
#   y: grad_norm=5.926131248474121
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1226  U=241.969  z_cont=[10.7,12.6]
#   x: grad_norm=3.064549684524536
#   y: grad_norm=4.72247838973999
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1227  U=243.929  z_cont=[10.7,12.6]
#   x: grad_norm=0.10468103736639023
#   y: grad_norm=0.16666215658187866
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1228  U=242.713  z_cont=[10.7,12.6]
#   x: grad_norm=2.4990148544311523
#   y: grad_norm=3.814831495285034
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1229  U=242.334  z_cont=[10.7,12.6]
#   x: grad_norm=2.847871780395508
#   y: grad_norm=4.346396446228027
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1230  U=242.086  z_cont=[10.7,12.6]
#   x: grad_norm=3.0201220512390137
#   y: grad_norm=4.600256443023682
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1231  U=242.768  z_cont=[10.7,12.6]
#   x: grad_norm=2.4157679080963135
#   y: grad_norm=3.6789469718933105
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1232  U=243.904  z_cont=[10.7,12.6]
#   x: grad_norm=0.07294009625911713
#   y: grad_norm=0.12127465009689331
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1233  U=242.965  z_cont=[10.7,12.6]
#   x: grad_norm=2.3530659675598145
#   y: grad_norm=3.6674561500549316
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1234  U=242.828  z_cont=[10.7,12.6]
#   x: grad_norm=2.369645357131958
#   y: grad_norm=3.6191976070404053
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1235  U=240.909  z_cont=[10.7,12.6]
#   x: grad_norm=3.793159246444702
#   y: grad_norm=5.779951095581055
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1236  U=242.637  z_cont=[10.7,12.6]
#   x: grad_norm=2.5247907638549805
#   y: grad_norm=3.8455352783203125
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1237  U=243.789  z_cont=[10.7,12.6]
#   x: grad_norm=0.7494812607765198
#   y: grad_norm=1.174156665802002
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1238  U=242.099  z_cont=[10.7,12.6]
#   x: grad_norm=3.146353244781494
#   y: grad_norm=4.8906941413879395
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1239  U=242.696  z_cont=[10.7,12.6]
#   x: grad_norm=2.601080894470215
#   y: grad_norm=3.9240970611572266
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1240  U=239.944  z_cont=[10.7,12.6]
#   x: grad_norm=4.380743980407715
#   y: grad_norm=6.64250373840332
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1241  U=241.741  z_cont=[10.7,12.6]
#   x: grad_norm=3.3313543796539307
#   y: grad_norm=5.050440788269043
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1242  U=243.888  z_cont=[10.7,12.6]
#   x: grad_norm=0.3020198345184326
#   y: grad_norm=0.46377211809158325
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1243  U=241.780  z_cont=[10.7,12.6]
#   x: grad_norm=3.379929780960083
#   y: grad_norm=5.029991626739502
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1244  U=241.614  z_cont=[10.7,12.6]
#   x: grad_norm=3.4405460357666016
#   y: grad_norm=5.152911186218262
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1245  U=241.072  z_cont=[10.7,12.6]
#   x: grad_norm=3.8038508892059326
#   y: grad_norm=5.6190385818481445
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1246  U=241.917  z_cont=[10.7,12.6]
#   x: grad_norm=3.2367801666259766
#   y: grad_norm=4.781498432159424
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1247  U=243.900  z_cont=[10.7,12.6]
#   x: grad_norm=0.2812267541885376
#   y: grad_norm=0.42322850227355957
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1248  U=242.628  z_cont=[10.7,12.6]
#   x: grad_norm=2.6138970851898193
#   y: grad_norm=3.915721893310547
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1249  U=241.987  z_cont=[10.7,12.6]
#   x: grad_norm=3.171685218811035
#   y: grad_norm=4.751279354095459
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# CPU times: user 1min 56s, sys: 4.65 s, total: 2min
# Wall time: 2min 31s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='1e2 U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='1e2 U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='1e8 U_E',    lw=1)
plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_lb.detach().cpu().max()], [0, E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
