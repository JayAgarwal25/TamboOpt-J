# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_40_10_shower_mean_U_lr_3"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

#####################
#  Hyperparameters  #
#####################
generate_new_data = True
use_cache = True
training_epochs = 1250
# Out:
# device: cuda

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 10 # 200000
Nvalidation = 10 # 20000
Ntest       = 10 # 3000
Nbatch      = 10 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
            sigma=400
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
#   Loading PointCountFM from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/num_of_point_clouds_dequantize_compiled.pt ...
#   Loaded in 666.4 ms
#   Running inference on 10 samples ...
#   Inference done in 0.70 s
#   Mean total hits predicted per shower: 2000.1
#   Loading AllShowers generator from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/all_showers ...
#   Loaded in 0.07 s
#   Time mode: ON (x,y,e,t)
#   Generating 10 showers (16 ODE steps, solver=midpoint, device=cuda) ...
# [     0s]: start batch   0
# [    14s]: generation done
#   Generation done in 14.61 s
# samples shape: torch.Size([10, 2048, 5])
#   Saved 10 showers → ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-56 m  shift=+2860 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([ 1209.3162,  -185.9382, -4770.9209, -3740.6626, -2724.5300,  6926.7793,
#         -1610.1606,   491.2737,  3148.9158, -4356.9370], device='cuda:0')
# Y0: tensor([ 5521.8242,  5838.6670,  1888.6909,  1871.6783,   482.1055,   954.0850,
#          4315.3809,  3780.6860, -1127.4365,  2013.8997], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 255442.672, energy.max(): 76481400.000
# theta.min():  65.2°, theta.max():  98.9°
# phi.min():    -138.1°, phi.max():    178.4°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# CPU times: user 4.74 ms, sys: 2.03 ms, total: 6.78 ms
# Wall time: 58.2 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# CPU times: user 5.12 ms, sys: 0 ns, total: 5.12 ms
# Wall time: 59.7 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([10, 90, 5])   labels: torch.Size([10, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0715
# Training 20%  val_loss=0.0707
# Training 30%  val_loss=0.0708
# Training 40%  val_loss=0.0707
# Training 50%  val_loss=0.0707
# Training 60%  val_loss=0.0707
# Training 70%  val_loss=0.0707
# Training 80%  val_loss=0.0707
# CPU times: user 1.44 s, sys: 57.4 ms, total: 1.5 s
# Wall time: 1.55 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([E_r.min().cpu(), E_r.max().cpu()], [E_r.min().cpu(), E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()
axes[0].set_xscale("log"); axes[0].set_yscale("log")
axes[0].set_xlim([6e4, 3e8])
axes[0].set_ylim([6e4, 3e8])

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
# optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)
optimizer = torch.optim.Adam(                  
      xy_module.parameters(),               
      lr=3,              
      betas=(0.9, 0.999),                                                                                                                                                                                                                                                                          
      eps=1e-8,                           
  )        

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + training_epochs):

    if epoch < 20:
        Nfinetune = 10 # 3000
    else:
        Nfinetune = 10 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        U_angle(preds_th,  th, r_score) +
        U_angle(preds_phi, ph, r_score) + 
        U_E(preds_e, energy, r_score)   + 0
        # 5e5 * U_PR(r_score)
    )

    U_vals.append(U.item())
    U_th_vals.append(  ( U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( ( U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   ( U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  ( U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=False, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 0  U=227.625  z_cont=[11.2,12.3]
#   x: grad_norm=5.567366123199463
#   y: grad_norm=12.596938133239746
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1  U=197.033  z_cont=[11.2,12.4]
#   x: grad_norm=2.078003168106079
#   y: grad_norm=3.543071746826172
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 2  U=272.643  z_cont=[11.3,12.4]
#   x: grad_norm=3.88569974899292
#   y: grad_norm=6.103917598724365
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 3  U=367.919  z_cont=[11.3,12.4]
#   x: grad_norm=15.600085258483887
#   y: grad_norm=22.26654052734375
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 4  U=371.668  z_cont=[11.3,12.4]
#   x: grad_norm=1.8900461196899414
#   y: grad_norm=3.9468955993652344
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 5  U=337.039  z_cont=[11.3,12.4]
#   x: grad_norm=4.765697956085205
#   y: grad_norm=7.044083595275879
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 6  U=358.083  z_cont=[11.3,12.4]
#   x: grad_norm=11.975808143615723
#   y: grad_norm=18.74664306640625
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 7  U=433.690  z_cont=[11.3,12.4]
#   x: grad_norm=13.801460266113281
#   y: grad_norm=21.06406021118164
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 8  U=382.787  z_cont=[11.3,12.4]
#   x: grad_norm=2.6248793601989746
#   y: grad_norm=4.939411640167236
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 9  U=364.922  z_cont=[11.3,12.4]
#   x: grad_norm=3.3637611865997314
#   y: grad_norm=4.316061496734619
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 10  U=348.987  z_cont=[11.3,12.4]
#   x: grad_norm=3.5230236053466797
#   y: grad_norm=5.307746410369873
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 11  U=353.853  z_cont=[11.3,12.4]
#   x: grad_norm=3.095576763153076
#   y: grad_norm=5.4231462478637695
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 12  U=367.394  z_cont=[11.3,12.4]
#   x: grad_norm=1.4157503843307495
#   y: grad_norm=3.81394100189209
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 13  U=372.331  z_cont=[11.3,12.4]
#   x: grad_norm=1.2120286226272583
#   y: grad_norm=1.8168028593063354
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 14  U=362.776  z_cont=[11.3,12.4]
#   x: grad_norm=2.3833203315734863
#   y: grad_norm=4.347873687744141
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 15  U=359.781  z_cont=[11.3,12.5]
#   x: grad_norm=2.1379172801971436
#   y: grad_norm=5.0716657638549805
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 16  U=365.986  z_cont=[11.3,12.5]
#   x: grad_norm=1.5345860719680786
#   y: grad_norm=4.133039951324463
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 17  U=373.186  z_cont=[11.3,12.5]
#   x: grad_norm=0.31738829612731934
#   y: grad_norm=0.6850566864013672
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 18  U=370.085  z_cont=[11.3,12.5]
#   x: grad_norm=0.8704760074615479
#   y: grad_norm=2.4491991996765137
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 19  U=365.899  z_cont=[11.3,12.5]
#   x: grad_norm=1.4597100019454956
#   y: grad_norm=3.4523770809173584
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 20  U=365.605  z_cont=[11.3,12.5]
#   x: grad_norm=1.80500066280365
#   y: grad_norm=3.3378918170928955
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 21  U=370.722  z_cont=[11.3,12.5]
#   x: grad_norm=1.1623756885528564
#   y: grad_norm=1.9076380729675293
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 22  U=373.034  z_cont=[11.3,12.5]
#   x: grad_norm=0.14925269782543182
#   y: grad_norm=0.4195149540901184
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 23  U=370.252  z_cont=[11.2,12.5]
#   x: grad_norm=1.1416410207748413
#   y: grad_norm=2.2187137603759766
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 24  U=368.147  z_cont=[11.2,12.5]
#   x: grad_norm=1.5549393892288208
#   y: grad_norm=2.9026341438293457
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 25  U=370.881  z_cont=[11.2,12.5]
#   x: grad_norm=0.8695492744445801
#   y: grad_norm=2.1454598903656006
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 26  U=373.157  z_cont=[11.2,12.5]
#   x: grad_norm=0.23839271068572998
#   y: grad_norm=0.6889541745185852
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 27  U=372.890  z_cont=[11.2,12.5]
#   x: grad_norm=0.4437330961227417
#   y: grad_norm=1.0108658075332642
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 28  U=371.296  z_cont=[11.2,12.5]
#   x: grad_norm=0.8372445702552795
#   y: grad_norm=2.0284688472747803
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 29  U=371.288  z_cont=[11.2,12.5]
#   x: grad_norm=0.8626658916473389
#   y: grad_norm=2.0204360485076904
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 30  U=372.359  z_cont=[11.2,12.5]
#   x: grad_norm=0.912800133228302
#   y: grad_norm=1.3771802186965942
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 31  U=373.675  z_cont=[11.2,12.5]
#   x: grad_norm=0.23763355612754822
#   y: grad_norm=0.37760528922080994
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 32  U=372.901  z_cont=[11.2,12.5]
#   x: grad_norm=0.6402372717857361
#   y: grad_norm=1.237276315689087
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 33  U=371.852  z_cont=[11.2,12.5]
#   x: grad_norm=1.0477293729782104
#   y: grad_norm=1.776001214981079
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 34  U=372.538  z_cont=[11.2,12.5]
#   x: grad_norm=0.8657110333442688
#   y: grad_norm=1.4907190799713135
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 35  U=373.783  z_cont=[11.2,12.5]
#   x: grad_norm=0.332523912191391
#   y: grad_norm=0.8131060600280762
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 36  U=373.680  z_cont=[11.2,12.5]
#   x: grad_norm=0.596057653427124
#   y: grad_norm=0.7903515696525574
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 37  U=373.253  z_cont=[11.2,12.5]
#   x: grad_norm=0.6137245297431946
#   y: grad_norm=1.2882206439971924
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 38  U=373.425  z_cont=[11.2,12.5]
#   x: grad_norm=0.461108922958374
#   y: grad_norm=1.4175584316253662
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 39  U=374.253  z_cont=[11.2,12.5]
#   x: grad_norm=0.2815144658088684
#   y: grad_norm=0.9039047360420227
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 40  U=374.689  z_cont=[11.2,12.5]
#   x: grad_norm=0.3118244409561157
#   y: grad_norm=0.4397357702255249
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 41  U=374.651  z_cont=[11.2,12.5]
#   x: grad_norm=0.3181304335594177
#   y: grad_norm=1.000378131866455
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 42  U=374.733  z_cont=[11.2,12.5]
#   x: grad_norm=0.5065337419509888
#   y: grad_norm=1.1744976043701172
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 43  U=375.462  z_cont=[11.2,12.5]
#   x: grad_norm=0.5717592239379883
#   y: grad_norm=0.962165892124176
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 44  U=376.599  z_cont=[11.2,12.5]
#   x: grad_norm=0.4391663074493408
#   y: grad_norm=0.6506621837615967
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 45  U=377.276  z_cont=[11.2,12.5]
#   x: grad_norm=0.8517017960548401
#   y: grad_norm=1.0974669456481934
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 46  U=379.627  z_cont=[11.2,12.5]
#   x: grad_norm=1.1770159006118774
#   y: grad_norm=1.5484062433242798
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 47  U=386.969  z_cont=[11.2,12.5]
#   x: grad_norm=1.9761792421340942
#   y: grad_norm=2.8996174335479736
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 48  U=424.875  z_cont=[11.2,12.5]
#   x: grad_norm=9.795730590820312
#   y: grad_norm=14.523131370544434
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 49  U=371.497  z_cont=[11.2,12.5]
#   x: grad_norm=3.3465676307678223
#   y: grad_norm=5.185360908508301
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 50  U=360.612  z_cont=[11.2,12.5]
#   x: grad_norm=3.0984842777252197
#   y: grad_norm=4.568930149078369
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 51  U=369.530  z_cont=[11.1,12.5]
#   x: grad_norm=2.1524484157562256
#   y: grad_norm=2.943650007247925
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 52  U=378.955  z_cont=[11.1,12.6]
#   x: grad_norm=0.9835463762283325
#   y: grad_norm=2.1658926010131836
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 53  U=389.274  z_cont=[11.1,12.6]
#   x: grad_norm=2.4101381301879883
#   y: grad_norm=4.0447564125061035
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 54  U=446.034  z_cont=[11.1,12.6]
#   x: grad_norm=13.249629974365234
#   y: grad_norm=19.74759864807129
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 55  U=355.825  z_cont=[11.1,12.6]
#   x: grad_norm=3.5178120136260986
#   y: grad_norm=6.562939643859863
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 56  U=340.867  z_cont=[11.0,12.6]
#   x: grad_norm=3.6025660037994385
#   y: grad_norm=6.483599662780762
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 57  U=352.497  z_cont=[11.0,12.6]
#   x: grad_norm=3.361894130706787
#   y: grad_norm=4.874242782592773
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 58  U=369.074  z_cont=[11.0,12.6]
#   x: grad_norm=1.7044137716293335
#   y: grad_norm=2.6432206630706787
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 59  U=367.214  z_cont=[11.0,12.6]
#   x: grad_norm=1.9379925727844238
#   y: grad_norm=4.263307094573975
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 60  U=366.185  z_cont=[11.0,12.6]
#   x: grad_norm=2.3494558334350586
#   y: grad_norm=3.7659192085266113
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 61  U=368.209  z_cont=[11.0,12.6]
#   x: grad_norm=1.7464500665664673
#   y: grad_norm=2.756620168685913
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 62  U=369.325  z_cont=[11.0,12.6]
#   x: grad_norm=1.0697455406188965
#   y: grad_norm=3.049589157104492
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 63  U=370.391  z_cont=[11.0,12.6]
#   x: grad_norm=1.2208280563354492
#   y: grad_norm=3.163520574569702
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 64  U=372.355  z_cont=[11.0,12.6]
#   x: grad_norm=1.2912276983261108
#   y: grad_norm=2.074780225753784
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 65  U=370.922  z_cont=[11.0,12.6]
#   x: grad_norm=1.2815443277359009
#   y: grad_norm=2.35168719291687
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 66  U=369.779  z_cont=[11.0,12.6]
#   x: grad_norm=1.1072547435760498
#   y: grad_norm=3.1233201026916504
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 67  U=372.657  z_cont=[11.0,12.6]
#   x: grad_norm=0.9507116675376892
#   y: grad_norm=2.826662540435791
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 68  U=375.668  z_cont=[11.0,12.6]
#   x: grad_norm=0.6826490163803101
#   y: grad_norm=1.1635262966156006
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 69  U=374.174  z_cont=[11.0,12.6]
#   x: grad_norm=0.8885452151298523
#   y: grad_norm=2.3663463592529297
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 70  U=373.615  z_cont=[11.0,12.6]
#   x: grad_norm=0.8854041695594788
#   y: grad_norm=3.0071821212768555
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 71  U=376.817  z_cont=[11.0,12.6]
#   x: grad_norm=0.49767112731933594
#   y: grad_norm=1.6658952236175537
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 72  U=378.390  z_cont=[10.9,12.5]
#   x: grad_norm=0.5215674638748169
#   y: grad_norm=1.0852501392364502
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 73  U=377.779  z_cont=[10.9,12.5]
#   x: grad_norm=1.0397732257843018
#   y: grad_norm=2.5992817878723145
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 74  U=382.260  z_cont=[10.9,12.5]
#   x: grad_norm=1.379048466682434
#   y: grad_norm=2.590568780899048
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 75  U=393.452  z_cont=[10.9,12.6]
#   x: grad_norm=2.931551456451416
#   y: grad_norm=4.520922660827637
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 76  U=464.842  z_cont=[10.9,12.6]
#   x: grad_norm=5.851818561553955
#   y: grad_norm=9.190546035766602
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 77  U=472.091  z_cont=[10.9,12.5]
#   x: grad_norm=2.2525813579559326
#   y: grad_norm=3.5986249446868896
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 78  U=445.030  z_cont=[10.9,12.5]
#   x: grad_norm=11.201953887939453
#   y: grad_norm=17.602182388305664
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 79  U=353.371  z_cont=[10.9,12.5]
#   x: grad_norm=5.181375980377197
#   y: grad_norm=8.607555389404297
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 80  U=347.656  z_cont=[10.9,12.5]
#   x: grad_norm=4.202174663543701
#   y: grad_norm=7.218906402587891
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 81  U=371.244  z_cont=[10.9,12.5]
#   x: grad_norm=2.3717100620269775
#   y: grad_norm=3.7549779415130615
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 82  U=373.917  z_cont=[10.9,12.5]
#   x: grad_norm=1.582977056503296
#   y: grad_norm=3.347407817840576
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 83  U=359.307  z_cont=[10.9,12.5]
#   x: grad_norm=3.1431214809417725
#   y: grad_norm=5.976400375366211
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 84  U=370.656  z_cont=[10.9,12.5]
#   x: grad_norm=3.719902515411377
#   y: grad_norm=8.764195442199707
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 85  U=403.226  z_cont=[10.8,12.5]
#   x: grad_norm=7.352455139160156
#   y: grad_norm=23.59889793395996
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 86  U=375.669  z_cont=[10.9,12.5]
#   x: grad_norm=1.5286893844604492
#   y: grad_norm=4.926634788513184
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 87  U=364.521  z_cont=[10.9,12.5]
#   x: grad_norm=2.5605764389038086
#   y: grad_norm=5.287269592285156
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 88  U=364.978  z_cont=[10.9,12.5]
#   x: grad_norm=2.485288619995117
#   y: grad_norm=3.895968198776245
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 89  U=363.664  z_cont=[10.8,12.5]
#   x: grad_norm=1.7078903913497925
#   y: grad_norm=5.157424449920654
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 90  U=363.546  z_cont=[10.8,12.5]
#   x: grad_norm=1.536723256111145
#   y: grad_norm=5.741759777069092
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 91  U=368.451  z_cont=[10.8,12.5]
#   x: grad_norm=1.737929105758667
#   y: grad_norm=4.432852745056152
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 92  U=371.833  z_cont=[10.8,12.5]
#   x: grad_norm=1.0909960269927979
#   y: grad_norm=2.2013351917266846
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 93  U=367.003  z_cont=[10.7,12.5]
#   x: grad_norm=1.2194385528564453
#   y: grad_norm=4.624131202697754
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 94  U=369.342  z_cont=[10.7,12.6]
#   x: grad_norm=1.0879781246185303
#   y: grad_norm=4.126313209533691
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 95  U=374.566  z_cont=[10.7,12.6]
#   x: grad_norm=0.462485134601593
#   y: grad_norm=0.8086033463478088
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 96  U=370.816  z_cont=[10.7,12.6]
#   x: grad_norm=0.9666703343391418
#   y: grad_norm=3.3964931964874268
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 97  U=369.075  z_cont=[10.7,12.6]
#   x: grad_norm=1.1139037609100342
#   y: grad_norm=4.098264217376709
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 98  U=373.571  z_cont=[10.7,12.6]
#   x: grad_norm=0.6078938245773315
#   y: grad_norm=2.2099416255950928
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 99  U=374.434  z_cont=[10.7,12.6]
#   x: grad_norm=0.4234141707420349
#   y: grad_norm=1.4802089929580688
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 100  U=370.887  z_cont=[10.7,12.6]
#   x: grad_norm=1.0355174541473389
#   y: grad_norm=3.4505882263183594
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 101  U=372.396  z_cont=[10.7,12.6]
#   x: grad_norm=0.8191960453987122
#   y: grad_norm=3.0413296222686768
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 102  U=375.259  z_cont=[10.7,12.6]
#   x: grad_norm=0.19501391053199768
#   y: grad_norm=0.4966990053653717
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 103  U=373.982  z_cont=[10.7,12.6]
#   x: grad_norm=0.680394172668457
#   y: grad_norm=1.9511090517044067
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 104  U=372.832  z_cont=[10.7,12.6]
#   x: grad_norm=0.8804118633270264
#   y: grad_norm=2.7131845951080322
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 105  U=375.209  z_cont=[10.7,12.6]
#   x: grad_norm=0.6199769377708435
#   y: grad_norm=1.816390872001648
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 106  U=376.619  z_cont=[10.7,12.6]
#   x: grad_norm=0.33824676275253296
#   y: grad_norm=0.8065688014030457
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 107  U=375.799  z_cont=[10.7,12.6]
#   x: grad_norm=0.6666978597640991
#   y: grad_norm=2.337604284286499
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 108  U=377.461  z_cont=[10.7,12.6]
#   x: grad_norm=0.7535386681556702
#   y: grad_norm=2.2778029441833496
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 109  U=382.195  z_cont=[10.7,12.6]
#   x: grad_norm=1.1407064199447632
#   y: grad_norm=1.8953818082809448
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 110  U=397.395  z_cont=[10.7,12.6]
#   x: grad_norm=4.93455696105957
#   y: grad_norm=7.90623664855957
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 111  U=401.122  z_cont=[10.7,12.6]
#   x: grad_norm=6.117643356323242
#   y: grad_norm=9.37942886352539
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 112  U=396.710  z_cont=[10.7,12.6]
#   x: grad_norm=4.678704261779785
#   y: grad_norm=7.167861461639404
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 113  U=471.574  z_cont=[10.7,12.6]
#   x: grad_norm=1.6020594835281372
#   y: grad_norm=2.867396831512451
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 114  U=417.979  z_cont=[10.6,12.6]
#   x: grad_norm=10.759377479553223
#   y: grad_norm=15.874618530273438
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 115  U=387.748  z_cont=[10.7,12.6]
#   x: grad_norm=3.199324369430542
#   y: grad_norm=5.445229530334473
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 116  U=374.805  z_cont=[10.7,12.6]
#   x: grad_norm=2.0210161209106445
#   y: grad_norm=4.061064720153809
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 117  U=377.050  z_cont=[10.7,12.6]
#   x: grad_norm=1.010308861732483
#   y: grad_norm=1.6738238334655762
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 118  U=375.635  z_cont=[10.7,12.6]
#   x: grad_norm=0.7956657409667969
#   y: grad_norm=2.3798940181732178
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 119  U=373.121  z_cont=[10.7,12.6]
#   x: grad_norm=1.4828306436538696
#   y: grad_norm=3.519428014755249
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 120  U=375.551  z_cont=[10.7,12.6]
#   x: grad_norm=1.3925095796585083
#   y: grad_norm=2.4185426235198975
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 121  U=378.113  z_cont=[10.7,12.6]
#   x: grad_norm=0.6029700636863708
#   y: grad_norm=1.7136300802230835
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 122  U=376.774  z_cont=[10.7,12.6]
#   x: grad_norm=1.7010935544967651
#   y: grad_norm=3.6816582679748535
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 123  U=386.075  z_cont=[10.7,12.6]
#   x: grad_norm=2.5705149173736572
#   y: grad_norm=3.842367172241211
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 124  U=443.388  z_cont=[10.7,12.6]
#   x: grad_norm=14.635388374328613
#   y: grad_norm=20.02275848388672
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 125  U=376.220  z_cont=[10.7,12.6]
#   x: grad_norm=0.2848551869392395
#   y: grad_norm=0.57506263256073
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 126  U=372.711  z_cont=[10.7,12.5]
#   x: grad_norm=0.8594436645507812
#   y: grad_norm=1.6771413087844849
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 127  U=372.935  z_cont=[10.8,12.5]
#   x: grad_norm=0.6199894547462463
#   y: grad_norm=1.7174657583236694
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 128  U=374.349  z_cont=[10.8,12.5]
#   x: grad_norm=0.284320205450058
#   y: grad_norm=0.9176042079925537
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 129  U=375.482  z_cont=[10.8,12.5]
#   x: grad_norm=0.7807908654212952
#   y: grad_norm=1.9786261320114136
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 130  U=379.390  z_cont=[10.8,12.5]
#   x: grad_norm=1.7919496297836304
#   y: grad_norm=5.247745037078857
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 131  U=468.553  z_cont=[10.8,12.5]
#   x: grad_norm=6.228491306304932
#   y: grad_norm=18.725269317626953
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 132  U=373.532  z_cont=[10.8,12.5]
#   x: grad_norm=2.716823101043701
#   y: grad_norm=6.8726019859313965
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 133  U=370.568  z_cont=[10.8,12.5]
#   x: grad_norm=2.427231788635254
#   y: grad_norm=5.6384406089782715
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 134  U=380.107  z_cont=[10.8,12.5]
#   x: grad_norm=0.9354544281959534
#   y: grad_norm=2.6919445991516113
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 135  U=382.050  z_cont=[10.9,12.5]
#   x: grad_norm=3.1898815631866455
#   y: grad_norm=9.029000282287598
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 136  U=425.498  z_cont=[10.8,12.5]
#   x: grad_norm=11.440693855285645
#   y: grad_norm=33.32368469238281
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 137  U=377.655  z_cont=[10.8,12.5]
#   x: grad_norm=0.6503311395645142
#   y: grad_norm=1.885109782218933
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 138  U=370.059  z_cont=[10.9,12.5]
#   x: grad_norm=1.366612195968628
#   y: grad_norm=3.2955994606018066
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 139  U=368.018  z_cont=[10.8,12.5]
#   x: grad_norm=1.5082674026489258
#   y: grad_norm=3.877840757369995
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 140  U=372.438  z_cont=[10.8,12.6]
#   x: grad_norm=0.17393898963928223
#   y: grad_norm=0.26580309867858887
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 141  U=366.305  z_cont=[10.8,12.6]
#   x: grad_norm=1.6467912197113037
#   y: grad_norm=4.908934593200684
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 142  U=365.718  z_cont=[10.8,12.6]
#   x: grad_norm=1.5761022567749023
#   y: grad_norm=5.081105709075928
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 143  U=371.352  z_cont=[10.8,12.6]
#   x: grad_norm=0.5809342861175537
#   y: grad_norm=1.4991651773452759
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 144  U=368.649  z_cont=[10.8,12.6]
#   x: grad_norm=1.549292802810669
#   y: grad_norm=3.6917436122894287
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 145  U=368.225  z_cont=[10.8,12.7]
#   x: grad_norm=1.1376926898956299
#   y: grad_norm=3.6834075450897217
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 146  U=370.933  z_cont=[10.8,12.7]
#   x: grad_norm=0.7009379863739014
#   y: grad_norm=1.9739702939987183
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 147  U=370.070  z_cont=[10.8,12.7]
#   x: grad_norm=1.2491761445999146
#   y: grad_norm=2.564532995223999
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 148  U=369.899  z_cont=[10.8,12.7]
#   x: grad_norm=1.0914891958236694
#   y: grad_norm=3.1433823108673096
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 149  U=371.513  z_cont=[10.7,12.7]
#   x: grad_norm=0.5716162919998169
#   y: grad_norm=1.134690523147583
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 150  U=370.933  z_cont=[10.7,12.7]
#   x: grad_norm=0.9471896290779114
#   y: grad_norm=1.8632522821426392
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 151  U=370.734  z_cont=[10.7,12.7]
#   x: grad_norm=0.9218568205833435
#   y: grad_norm=2.186689615249634
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 152  U=372.026  z_cont=[10.7,12.7]
#   x: grad_norm=0.17365707457065582
#   y: grad_norm=0.5917810201644897
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 153  U=371.167  z_cont=[10.7,12.7]
#   x: grad_norm=0.8517975211143494
#   y: grad_norm=1.639359951019287
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 154  U=370.942  z_cont=[10.7,12.7]
#   x: grad_norm=0.8804388046264648
#   y: grad_norm=1.9602837562561035
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 155  U=371.928  z_cont=[10.7,12.7]
#   x: grad_norm=0.4718441367149353
#   y: grad_norm=0.8194953203201294
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 156  U=371.662  z_cont=[10.7,12.7]
#   x: grad_norm=0.6307327151298523
#   y: grad_norm=1.3172868490219116
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 157  U=370.864  z_cont=[10.7,12.7]
#   x: grad_norm=1.0298117399215698
#   y: grad_norm=1.9033857583999634
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 158  U=371.877  z_cont=[10.7,12.7]
#   x: grad_norm=8.132233619689941
#   y: grad_norm=47.07662582397461
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 159  U=370.044  z_cont=[10.7,12.7]
#   x: grad_norm=1.245939016342163
#   y: grad_norm=3.480642080307007
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 160  U=366.942  z_cont=[10.7,12.7]
#   x: grad_norm=1.8842706680297852
#   y: grad_norm=4.068386554718018
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 161  U=371.970  z_cont=[10.7,12.7]
#   x: grad_norm=0.7325390577316284
#   y: grad_norm=1.1032497882843018
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 162  U=369.760  z_cont=[10.7,12.7]
#   x: grad_norm=1.1466190814971924
#   y: grad_norm=3.181086301803589
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 163  U=367.891  z_cont=[10.7,12.7]
#   x: grad_norm=1.685786485671997
#   y: grad_norm=3.8763442039489746
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 164  U=371.984  z_cont=[10.7,12.7]
#   x: grad_norm=0.7226593494415283
#   y: grad_norm=1.257143497467041
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 165  U=370.083  z_cont=[10.6,12.7]
#   x: grad_norm=1.1611921787261963
#   y: grad_norm=2.9061787128448486
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 166  U=369.104  z_cont=[10.6,12.7]
#   x: grad_norm=1.3729876279830933
#   y: grad_norm=3.366584539413452
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 167  U=372.386  z_cont=[10.6,12.7]
#   x: grad_norm=0.34115666151046753
#   y: grad_norm=0.8257978558540344
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 168  U=371.154  z_cont=[10.5,12.7]
#   x: grad_norm=0.9293162822723389
#   y: grad_norm=2.146439552307129
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 169  U=370.145  z_cont=[10.5,12.7]
#   x: grad_norm=1.2097994089126587
#   y: grad_norm=2.7784242630004883
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 170  U=372.513  z_cont=[10.5,12.7]
#   x: grad_norm=0.220437690615654
#   y: grad_norm=0.5753135085105896
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 171  U=371.762  z_cont=[10.5,12.7]
#   x: grad_norm=0.7735616564750671
#   y: grad_norm=1.6792569160461426
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 172  U=371.624  z_cont=[10.5,12.7]
#   x: grad_norm=0.738341212272644
#   y: grad_norm=1.9510626792907715
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 173  U=372.664  z_cont=[10.5,12.7]
#   x: grad_norm=0.19301752746105194
#   y: grad_norm=0.6581896543502808
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 174  U=372.214  z_cont=[10.4,12.7]
#   x: grad_norm=0.7068557143211365
#   y: grad_norm=1.2891836166381836
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 175  U=372.401  z_cont=[10.4,12.7]
#   x: grad_norm=0.39316216111183167
#   y: grad_norm=1.2832221984863281
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 176  U=372.778  z_cont=[10.4,12.7]
#   x: grad_norm=0.21556657552719116
#   y: grad_norm=0.6729958653450012
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 177  U=372.864  z_cont=[10.4,12.7]
#   x: grad_norm=0.29774612188339233
#   y: grad_norm=0.5931522250175476
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 178  U=372.731  z_cont=[10.4,12.7]
#   x: grad_norm=0.3264283239841461
#   y: grad_norm=1.0337430238723755
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 179  U=372.912  z_cont=[10.4,12.7]
#   x: grad_norm=0.1988615095615387
#   y: grad_norm=0.6809549331665039
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 180  U=373.074  z_cont=[10.4,12.7]
#   x: grad_norm=0.10379309952259064
#   y: grad_norm=0.1686631739139557
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 181  U=372.912  z_cont=[10.4,12.7]
#   x: grad_norm=0.30033794045448303
#   y: grad_norm=0.8644198775291443
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 182  U=372.957  z_cont=[10.4,12.7]
#   x: grad_norm=0.32118234038352966
#   y: grad_norm=0.809129536151886
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 183  U=373.159  z_cont=[10.4,12.7]
#   x: grad_norm=0.059446781873703
#   y: grad_norm=0.11031194776296616
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 184  U=373.022  z_cont=[10.4,12.7]
#   x: grad_norm=0.2518385946750641
#   y: grad_norm=0.7742104530334473
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 185  U=372.679  z_cont=[10.4,12.7]
#   x: grad_norm=0.6366301774978638
#   y: grad_norm=1.1412900686264038
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 186  U=373.198  z_cont=[10.4,12.7]
#   x: grad_norm=0.0935167744755745
#   y: grad_norm=0.18067395687103271
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 187  U=372.862  z_cont=[10.4,12.7]
#   x: grad_norm=0.5146915316581726
#   y: grad_norm=1.0307142734527588
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 188  U=372.880  z_cont=[10.4,12.7]
#   x: grad_norm=0.5470964312553406
#   y: grad_norm=0.9406282901763916
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 189  U=373.222  z_cont=[10.3,12.7]
#   x: grad_norm=0.12408211082220078
#   y: grad_norm=0.3050740659236908
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 190  U=372.493  z_cont=[10.3,12.7]
#   x: grad_norm=0.7867969274520874
#   y: grad_norm=1.3786897659301758
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 191  U=372.999  z_cont=[10.3,12.7]
#   x: grad_norm=0.4907686710357666
#   y: grad_norm=0.8039748072624207
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 192  U=373.218  z_cont=[10.3,12.7]
#   x: grad_norm=0.24034027755260468
#   y: grad_norm=0.5419474244117737
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 193  U=372.783  z_cont=[10.3,12.7]
#   x: grad_norm=0.6627896428108215
#   y: grad_norm=1.1635724306106567
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 194  U=373.136  z_cont=[10.3,12.7]
#   x: grad_norm=0.45071348547935486
#   y: grad_norm=0.6695117354393005
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 195  U=372.990  z_cont=[10.3,12.7]
#   x: grad_norm=0.5590660572052002
#   y: grad_norm=0.9964419007301331
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 196  U=373.004  z_cont=[10.3,12.7]
#   x: grad_norm=0.560355007648468
#   y: grad_norm=0.9966721534729004
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 197  U=373.415  z_cont=[10.3,12.7]
#   x: grad_norm=0.06387477368116379
#   y: grad_norm=0.11495348066091537
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 198  U=373.146  z_cont=[10.3,12.7]
#   x: grad_norm=0.469937264919281
#   y: grad_norm=0.8917794823646545
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 199  U=373.179  z_cont=[10.3,12.7]
#   x: grad_norm=0.47888636589050293
#   y: grad_norm=0.8106303811073303
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 200  U=373.242  z_cont=[10.3,12.7]
#   x: grad_norm=0.4128124415874481
#   y: grad_norm=0.763597309589386
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 201  U=373.250  z_cont=[10.3,12.7]
#   x: grad_norm=0.41600343585014343
#   y: grad_norm=0.8054931163787842
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 202  U=373.502  z_cont=[10.3,12.7]
#   x: grad_norm=0.03352535516023636
#   y: grad_norm=0.05345209687948227
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 203  U=373.339  z_cont=[10.3,12.7]
#   x: grad_norm=0.37411630153656006
#   y: grad_norm=0.7024900317192078
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 204  U=373.388  z_cont=[10.3,12.7]
#   x: grad_norm=0.35084274411201477
#   y: grad_norm=0.625523567199707
# Fine-tune at epoch 205
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 205  U=373.318  z_cont=[10.3,12.7]
#   x: grad_norm=0.4438529312610626
#   y: grad_norm=0.6799975037574768
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 206  U=373.415  z_cont=[10.3,12.7]
#   x: grad_norm=0.35485759377479553
#   y: grad_norm=0.6361134648323059
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 207  U=373.580  z_cont=[10.3,12.7]
#   x: grad_norm=0.0913577526807785
#   y: grad_norm=0.1671285331249237
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 208  U=373.424  z_cont=[10.3,12.7]
#   x: grad_norm=0.4063047468662262
#   y: grad_norm=0.6182278394699097
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 209  U=373.514  z_cont=[10.3,12.7]
#   x: grad_norm=0.3204082250595093
#   y: grad_norm=0.5056962370872498
# Fine-tune at epoch 210
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 210  U=373.347  z_cont=[10.3,12.7]
#   x: grad_norm=0.49244385957717896
#   y: grad_norm=0.7334290742874146
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 211  U=373.489  z_cont=[10.3,12.7]
#   x: grad_norm=0.3769385516643524
#   y: grad_norm=0.5724982619285583
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 212  U=373.669  z_cont=[10.3,12.7]
#   x: grad_norm=0.09179630875587463
#   y: grad_norm=0.1392117589712143
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 213  U=373.496  z_cont=[10.3,12.7]
#   x: grad_norm=0.42535200715065
#   y: grad_norm=0.6328885555267334
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# ...
#   y: grad_norm=3.9260449409484863
# Fine-tune at epoch 1180
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1180  U=266.823  z_cont=[9.7,13.5]
#   x: grad_norm=1.954471230506897
#   y: grad_norm=3.002307415008545
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1181  U=274.620  z_cont=[9.7,13.5]
#   x: grad_norm=0.2876359224319458
#   y: grad_norm=0.35957497358322144
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1182  U=269.307  z_cont=[9.7,13.5]
#   x: grad_norm=1.721550464630127
#   y: grad_norm=2.6811134815216064
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1183  U=268.975  z_cont=[9.7,13.5]
#   x: grad_norm=1.8287557363510132
#   y: grad_norm=2.844437837600708
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1184  U=275.809  z_cont=[9.7,13.5]
#   x: grad_norm=0.5303280353546143
#   y: grad_norm=0.8771074414253235
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1185  U=275.844  z_cont=[9.7,13.5]
#   x: grad_norm=0.7129980325698853
#   y: grad_norm=1.0869876146316528
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1186  U=272.092  z_cont=[9.7,13.5]
#   x: grad_norm=1.63517427444458
#   y: grad_norm=2.5645079612731934
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1187  U=275.040  z_cont=[9.7,13.5]
#   x: grad_norm=1.0859018564224243
#   y: grad_norm=1.6846404075622559
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1188  U=276.848  z_cont=[9.7,13.5]
#   x: grad_norm=0.4603627622127533
#   y: grad_norm=0.7492020130157471
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1189  U=274.253  z_cont=[9.6,13.5]
#   x: grad_norm=1.256756067276001
#   y: grad_norm=2.039757251739502
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1190  U=271.463  z_cont=[9.6,13.5]
#   x: grad_norm=1.9494704008102417
#   y: grad_norm=3.068061590194702
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1191  U=277.976  z_cont=[9.6,13.5]
#   x: grad_norm=0.19318096339702606
#   y: grad_norm=0.2869643270969391
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1192  U=272.001  z_cont=[9.6,13.5]
#   x: grad_norm=1.836400032043457
#   y: grad_norm=2.9546706676483154
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1193  U=273.387  z_cont=[9.6,13.5]
#   x: grad_norm=1.655551791191101
#   y: grad_norm=2.665412425994873
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1194  U=278.691  z_cont=[9.6,13.5]
#   x: grad_norm=0.2088891863822937
#   y: grad_norm=0.3333794176578522
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1195  U=270.979  z_cont=[9.6,13.5]
#   x: grad_norm=1.995887041091919
#   y: grad_norm=3.0230541229248047
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1196  U=273.099  z_cont=[9.6,13.5]
#   x: grad_norm=1.7182807922363281
#   y: grad_norm=2.501055955886841
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1197  U=278.286  z_cont=[9.6,13.5]
#   x: grad_norm=0.4754345715045929
#   y: grad_norm=0.6773113012313843
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1198  U=274.436  z_cont=[9.6,13.5]
#   x: grad_norm=1.6798949241638184
#   y: grad_norm=2.524646282196045
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1199  U=272.984  z_cont=[9.6,13.5]
#   x: grad_norm=1.8395994901657104
#   y: grad_norm=2.8298583030700684
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1200  U=278.788  z_cont=[9.6,13.5]
#   x: grad_norm=0.36286985874176025
#   y: grad_norm=0.5193153023719788
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1201  U=276.388  z_cont=[9.6,13.5]
#   x: grad_norm=1.250425100326538
#   y: grad_norm=1.835763692855835
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1202  U=277.514  z_cont=[9.6,13.5]
#   x: grad_norm=1.0201114416122437
#   y: grad_norm=1.49665367603302
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1203  U=279.393  z_cont=[9.6,13.5]
#   x: grad_norm=0.14902961254119873
#   y: grad_norm=0.2385072559118271
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1204  U=277.790  z_cont=[9.6,13.5]
#   x: grad_norm=1.0097037553787231
#   y: grad_norm=1.5491127967834473
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1205  U=279.493  z_cont=[9.6,13.5]
#   x: grad_norm=0.21628493070602417
#   y: grad_norm=0.33330172300338745
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1206  U=279.659  z_cont=[9.6,13.5]
#   x: grad_norm=0.08865860849618912
#   y: grad_norm=0.141262948513031
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1207  U=279.650  z_cont=[9.6,13.5]
#   x: grad_norm=0.2519446909427643
#   y: grad_norm=0.39132359623908997
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1208  U=279.786  z_cont=[9.6,13.5]
#   x: grad_norm=0.21463517844676971
#   y: grad_norm=0.3344361186027527
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1209  U=279.975  z_cont=[9.6,13.5]
#   x: grad_norm=0.06297024339437485
#   y: grad_norm=0.10541248321533203
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1210  U=279.647  z_cont=[9.6,13.5]
#   x: grad_norm=0.3955121338367462
#   y: grad_norm=0.6624616384506226
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1211  U=280.050  z_cont=[9.6,13.5]
#   x: grad_norm=0.13035863637924194
#   y: grad_norm=0.2001558095216751
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1212  U=279.786  z_cont=[9.6,13.5]
#   x: grad_norm=0.4868234097957611
#   y: grad_norm=0.7414218187332153
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1213  U=280.024  z_cont=[9.6,13.5]
#   x: grad_norm=0.4201907217502594
#   y: grad_norm=0.6391699910163879
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1214  U=280.455  z_cont=[9.6,13.5]
#   x: grad_norm=0.07909001410007477
#   y: grad_norm=0.11935535073280334
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1215  U=278.911  z_cont=[9.6,13.5]
#   x: grad_norm=0.893596887588501
#   y: grad_norm=1.4255015850067139
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1216  U=280.189  z_cont=[9.6,13.5]
#   x: grad_norm=0.497940331697464
#   y: grad_norm=0.7733916640281677
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1217  U=280.747  z_cont=[9.6,13.5]
#   x: grad_norm=0.28889089822769165
#   y: grad_norm=0.43234896659851074
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1218  U=279.979  z_cont=[9.6,13.5]
#   x: grad_norm=0.7950176000595093
#   y: grad_norm=1.208351969718933
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1219  U=280.674  z_cont=[9.6,13.5]
#   x: grad_norm=0.6078110933303833
#   y: grad_norm=0.9182151556015015
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1220  U=280.582  z_cont=[9.6,13.5]
#   x: grad_norm=0.7340578436851501
#   y: grad_norm=1.105556845664978
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1221  U=280.961  z_cont=[9.6,13.5]
#   x: grad_norm=0.7226717472076416
#   y: grad_norm=1.0899603366851807
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1222  U=282.289  z_cont=[9.6,13.5]
#   x: grad_norm=0.21695557236671448
#   y: grad_norm=0.32227054238319397
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1223  U=282.352  z_cont=[9.6,13.5]
#   x: grad_norm=0.6262390613555908
#   y: grad_norm=0.9176362156867981
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1224  U=282.971  z_cont=[9.6,13.5]
#   x: grad_norm=0.7795925736427307
#   y: grad_norm=1.1362600326538086
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1225  U=285.020  z_cont=[9.6,13.5]
#   x: grad_norm=0.6231634616851807
#   y: grad_norm=0.9508073329925537
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1226  U=288.454  z_cont=[9.6,13.5]
#   x: grad_norm=1.0748460292816162
#   y: grad_norm=1.5923534631729126
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1227  U=302.680  z_cont=[9.6,13.5]
#   x: grad_norm=3.8172380924224854
#   y: grad_norm=5.362936973571777
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1228  U=318.663  z_cont=[9.6,13.5]
#   x: grad_norm=8.89050006866455
#   y: grad_norm=12.358054161071777
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1229  U=354.050  z_cont=[9.6,13.5]
#   x: grad_norm=13.581720352172852
#   y: grad_norm=18.836017608642578
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1230  U=279.168  z_cont=[9.6,13.5]
#   x: grad_norm=1.9623085260391235
#   y: grad_norm=2.855780601501465
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1231  U=268.010  z_cont=[9.6,13.5]
#   x: grad_norm=2.358264923095703
#   y: grad_norm=4.095557689666748
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1232  U=278.194  z_cont=[9.6,13.5]
#   x: grad_norm=1.8882389068603516
#   y: grad_norm=2.8163599967956543
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1233  U=346.091  z_cont=[9.6,13.5]
#   x: grad_norm=12.393330574035645
#   y: grad_norm=17.543743133544922
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1234  U=279.906  z_cont=[9.6,13.5]
#   x: grad_norm=1.3725295066833496
#   y: grad_norm=2.0031542778015137
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1235  U=279.085  z_cont=[9.6,13.5]
#   x: grad_norm=0.6339349746704102
#   y: grad_norm=0.9378304481506348
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1236  U=292.359  z_cont=[9.6,13.5]
#   x: grad_norm=1.9666413068771362
#   y: grad_norm=2.9890058040618896
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1237  U=283.644  z_cont=[9.6,13.6]
#   x: grad_norm=2.3479628562927246
#   y: grad_norm=3.401048183441162
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1238  U=281.096  z_cont=[9.6,13.6]
#   x: grad_norm=0.8501636385917664
#   y: grad_norm=1.2243363857269287
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1239  U=280.917  z_cont=[9.6,13.6]
#   x: grad_norm=0.6788763403892517
#   y: grad_norm=1.0124757289886475
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1240  U=280.592  z_cont=[9.6,13.6]
#   x: grad_norm=1.030254602432251
#   y: grad_norm=1.503420352935791
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1241  U=282.880  z_cont=[9.6,13.6]
#   x: grad_norm=1.0627610683441162
#   y: grad_norm=1.5135496854782104
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1242  U=291.453  z_cont=[9.6,13.6]
#   x: grad_norm=1.042728066444397
#   y: grad_norm=1.3425393104553223
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1243  U=363.162  z_cont=[9.6,13.6]
#   x: grad_norm=13.77432632446289
#   y: grad_norm=18.100515365600586
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1244  U=255.876  z_cont=[9.6,13.6]
#   x: grad_norm=3.1842734813690186
#   y: grad_norm=4.930737495422363
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1245  U=226.906  z_cont=[9.6,13.6]
#   x: grad_norm=0.973853349685669
#   y: grad_norm=1.543298602104187
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1246  U=221.938  z_cont=[9.6,13.6]
#   x: grad_norm=0.8134596347808838
#   y: grad_norm=1.1422698497772217
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1247  U=229.261  z_cont=[9.6,13.6]
#   x: grad_norm=1.8518269062042236
#   y: grad_norm=2.483560562133789
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1248  U=256.075  z_cont=[9.6,13.6]
#   x: grad_norm=2.842210292816162
#   y: grad_norm=3.7527267932891846
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# Epoch 1249  U=287.115  z_cont=[9.6,13.6]
#   x: grad_norm=0.1980554759502411
#   y: grad_norm=0.289617657661438
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt
# CPU times: user 30.1 s, sys: 1.28 s, total: 31.3 s
# Wall time: 2min 36s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='U_E',    lw=1)
# plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
# HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_40_10_shower_mean_U_lr_3/cashed_showers_10.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([E_lb.detach().cpu().min(), E_lb.detach().cpu().max()], [E_lb.detach().cpu().min(), E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()
axes[0].set_xscale("log"); axes[0].set_yscale("log")
axes[0].set_xlim([6e4, 3e8])
axes[0].set_ylim([6e4, 3e8])

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
