# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_38_10_shower_center_init_angle_error"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generate_new_data = True
print("device:", device)
# Out:
# device: cuda

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 10 # 200000
Nvalidation = 10 # 20000
Ntest       = 10 # 3000
Nbatch      = 10 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
use_cache = True
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
#   Loading PointCountFM from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/num_of_point_clouds_dequantize_compiled.pt ...
#   Loaded in 817.0 ms
#   Running inference on 10 samples ...
#   Inference done in 0.82 s
#   Mean total hits predicted per shower: 2000.8
#   Loading AllShowers generator from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/all_showers ...
#   Loaded in 0.04 s
#   Time mode: ON (x,y,e,t)
#   Generating 10 showers (16 ODE steps, solver=midpoint, device=cuda) ...
# [   948s]: start batch   0
# [   949s]: generation done
#   Generation done in 0.16 s
# samples shape: torch.Size([10, 2048, 5])
#   Saved 10 showers → ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-187 m  shift=+2991 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([-2427.6921,  2127.4688,  3277.8638, -1773.2681, -2959.6562, -2441.5601,
#         -2486.8843,  1728.2251,    85.7385, -1234.6127], device='cuda:0')
# Y0: tensor([1779.3727, 4825.5308,  443.4099, 4590.9414, 2613.5698, 4455.9580,
#          219.8330, 4085.4504, 6595.0190,  167.5557], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 141291.750, energy.max(): 91978288.000
# theta.min():  61.6°, theta.max():  97.0°
# phi.min():    -155.4°, phi.max():    175.3°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# CPU times: user 8.9 ms, sys: 3 ms, total: 11.9 ms
# Wall time: 59.9 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# CPU times: user 10.9 ms, sys: 1.05 ms, total: 12 ms
# Wall time: 56.7 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([10, 90, 5])   labels: torch.Size([10, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0914
# Training 20%  val_loss=0.0751
# Training 30%  val_loss=0.0751
# Training 40%  val_loss=0.0751
# Training 50%  val_loss=0.0750
# Training 60%  val_loss=0.0751
# Training 70%  val_loss=0.0750
# Training 80%  val_loss=0.0751
# CPU times: user 2.91 s, sys: 60.4 ms, total: 2.98 s
# Wall time: 3.42 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
# optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)
optimizer = torch.optim.Adam(                  
      xy_module.parameters(),               
      lr=1.0,              # Adam's effective step ≈ lr, so ~1 m/epoch
      betas=(0.9, 0.999),                                                                                                                                                                                                                                                                          
      eps=1e-8,                           
  )        

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + 1250):

    if epoch < 20:
        Nfinetune = 10 # 3000
    else:
        Nfinetune = 10 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        1e2 * U_angle(preds_th,  th, r_score) +
        1e2 * U_angle(preds_phi, ph, r_score) + 0
        # 1e8 * U_E(preds_e, energy, r_score)   +
        # 5e5 * U_PR(r_score)
    ) / 1e3

    U_vals.append(U.item())
    U_th_vals.append( (1e2 * U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( (1e2 * U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   (1e8 * U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  (5e5 * U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=False, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 0  U=275.901  z_cont=[11.2,12.3]
#   x: grad_norm=5.705080986022949
#   y: grad_norm=25.518789291381836
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1  U=195.194  z_cont=[11.1,12.3]
#   x: grad_norm=2.8316922187805176
#   y: grad_norm=5.582553386688232
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 2  U=230.191  z_cont=[11.1,12.4]
#   x: grad_norm=2.4408562183380127
#   y: grad_norm=3.826472282409668
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 3  U=248.078  z_cont=[11.1,12.4]
#   x: grad_norm=1.1542856693267822
#   y: grad_norm=3.2178871631622314
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 4  U=240.703  z_cont=[11.1,12.4]
#   x: grad_norm=1.5521873235702515
#   y: grad_norm=4.005334377288818
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 5  U=239.199  z_cont=[11.1,12.4]
#   x: grad_norm=1.401060700416565
#   y: grad_norm=3.66939115524292
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 6  U=242.972  z_cont=[11.0,12.4]
#   x: grad_norm=0.8881832361221313
#   y: grad_norm=2.9284369945526123
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 7  U=246.974  z_cont=[11.0,12.4]
#   x: grad_norm=0.48313578963279724
#   y: grad_norm=1.6863479614257812
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 8  U=249.943  z_cont=[11.0,12.4]
#   x: grad_norm=0.4118800163269043
#   y: grad_norm=0.6916549801826477
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 9  U=251.692  z_cont=[11.0,12.4]
#   x: grad_norm=0.8053603768348694
#   y: grad_norm=5.592214107513428
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 10  U=253.202  z_cont=[11.0,12.4]
#   x: grad_norm=0.5770313143730164
#   y: grad_norm=1.340340256690979
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 11  U=256.671  z_cont=[11.0,12.4]
#   x: grad_norm=0.5471650958061218
#   y: grad_norm=0.925366222858429
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 12  U=259.222  z_cont=[11.0,12.4]
#   x: grad_norm=0.36594530940055847
#   y: grad_norm=0.5758430361747742
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 13  U=260.090  z_cont=[10.9,12.4]
#   x: grad_norm=0.03546066954731941
#   y: grad_norm=0.08043117076158524
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 14  U=258.999  z_cont=[10.9,12.5]
#   x: grad_norm=0.4314931333065033
#   y: grad_norm=0.6438283324241638
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 15  U=257.490  z_cont=[10.9,12.5]
#   x: grad_norm=0.5950267910957336
#   y: grad_norm=0.9727134704589844
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 16  U=253.668  z_cont=[10.9,12.5]
#   x: grad_norm=6.40261697769165
#   y: grad_norm=46.57048034667969
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 17  U=254.806  z_cont=[10.9,12.5]
#   x: grad_norm=0.8547773361206055
#   y: grad_norm=1.3278201818466187
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 18  U=255.018  z_cont=[10.9,12.5]
#   x: grad_norm=0.8413370847702026
#   y: grad_norm=1.3030287027359009
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 19  U=256.156  z_cont=[10.9,12.5]
#   x: grad_norm=0.6958155035972595
#   y: grad_norm=1.1393413543701172
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 20  U=258.006  z_cont=[10.9,12.5]
#   x: grad_norm=0.4266034960746765
#   y: grad_norm=1.0100749731063843
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 21  U=258.925  z_cont=[10.9,12.5]
#   x: grad_norm=0.3244189918041229
#   y: grad_norm=1.021144986152649
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 22  U=259.499  z_cont=[10.9,12.5]
#   x: grad_norm=0.29850977659225464
#   y: grad_norm=0.8983350396156311
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 23  U=259.759  z_cont=[10.9,12.4]
#   x: grad_norm=0.23331430554389954
#   y: grad_norm=0.5400915741920471
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 24  U=259.592  z_cont=[10.9,12.4]
#   x: grad_norm=0.18354719877243042
#   y: grad_norm=0.32652464509010315
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 25  U=259.159  z_cont=[10.9,12.4]
#   x: grad_norm=0.3586532473564148
#   y: grad_norm=2.2940564155578613
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 26  U=259.115  z_cont=[10.9,12.4]
#   x: grad_norm=0.48575863242149353
#   y: grad_norm=0.8862133622169495
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 27  U=259.324  z_cont=[10.9,12.4]
#   x: grad_norm=0.2856668531894684
#   y: grad_norm=0.46625861525535583
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 28  U=259.157  z_cont=[11.0,12.4]
#   x: grad_norm=0.28061410784721375
#   y: grad_norm=0.8898442983627319
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 29  U=258.947  z_cont=[11.0,12.4]
#   x: grad_norm=0.3921809196472168
#   y: grad_norm=1.2682178020477295
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 30  U=259.273  z_cont=[10.9,12.4]
#   x: grad_norm=0.2871297597885132
#   y: grad_norm=0.9252040982246399
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 31  U=259.663  z_cont=[10.9,12.4]
#   x: grad_norm=0.18459424376487732
#   y: grad_norm=0.5620642900466919
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 32  U=259.914  z_cont=[10.9,12.4]
#   x: grad_norm=0.13703837990760803
#   y: grad_norm=0.2233690619468689
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 33  U=259.953  z_cont=[10.9,12.4]
#   x: grad_norm=0.19668978452682495
#   y: grad_norm=0.43505486845970154
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 34  U=259.923  z_cont=[10.9,12.4]
#   x: grad_norm=0.2068001627922058
#   y: grad_norm=0.5626768469810486
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 35  U=259.958  z_cont=[10.9,12.4]
#   x: grad_norm=0.19782789051532745
#   y: grad_norm=0.549423336982727
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 36  U=259.992  z_cont=[10.9,12.5]
#   x: grad_norm=0.10814037173986435
#   y: grad_norm=0.2569064795970917
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 37  U=259.868  z_cont=[10.9,12.5]
#   x: grad_norm=0.2241399884223938
#   y: grad_norm=0.3420306146144867
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 38  U=259.740  z_cont=[10.9,12.5]
#   x: grad_norm=0.3114788234233856
#   y: grad_norm=0.5186961889266968
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 39  U=259.785  z_cont=[10.9,12.5]
#   x: grad_norm=0.28883832693099976
#   y: grad_norm=0.4669056236743927
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 40  U=260.087  z_cont=[10.9,12.5]
#   x: grad_norm=0.10050883889198303
#   y: grad_norm=0.245469331741333
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 41  U=260.106  z_cont=[10.9,12.5]
#   x: grad_norm=0.13379234075546265
#   y: grad_norm=0.39163270592689514
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 42  U=260.145  z_cont=[10.9,12.5]
#   x: grad_norm=0.14492203295230865
#   y: grad_norm=0.39467471837997437
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 43  U=260.214  z_cont=[10.9,12.5]
#   x: grad_norm=0.09246581047773361
#   y: grad_norm=0.22769896686077118
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 44  U=260.247  z_cont=[10.9,12.5]
#   x: grad_norm=0.038982097059488297
#   y: grad_norm=0.12552642822265625
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 45  U=260.238  z_cont=[10.9,12.5]
#   x: grad_norm=0.09778512269258499
#   y: grad_norm=0.20628254115581512
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 46  U=260.238  z_cont=[10.9,12.5]
#   x: grad_norm=0.10214044898748398
#   y: grad_norm=0.31808632612228394
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 47  U=260.259  z_cont=[10.9,12.5]
#   x: grad_norm=0.11726631224155426
#   y: grad_norm=0.38680240511894226
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 48  U=260.328  z_cont=[10.9,12.5]
#   x: grad_norm=0.10224805772304535
#   y: grad_norm=0.3341429829597473
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 49  U=260.420  z_cont=[10.9,12.5]
#   x: grad_norm=0.06939183920621872
#   y: grad_norm=0.2155054807662964
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 50  U=260.432  z_cont=[10.9,12.5]
#   x: grad_norm=0.22072653472423553
#   y: grad_norm=0.4423239231109619
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 51  U=260.561  z_cont=[10.9,12.5]
#   x: grad_norm=0.17119503021240234
#   y: grad_norm=0.36754724383354187
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 52  U=260.699  z_cont=[10.9,12.5]
#   x: grad_norm=0.06869278848171234
#   y: grad_norm=0.18214866518974304
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 53  U=260.751  z_cont=[10.9,12.5]
#   x: grad_norm=0.12078926712274551
#   y: grad_norm=0.2721262574195862
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 54  U=260.782  z_cont=[10.9,12.5]
#   x: grad_norm=0.19272394478321075
#   y: grad_norm=0.40453529357910156
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 55  U=261.074  z_cont=[10.9,12.5]
#   x: grad_norm=0.09741584956645966
#   y: grad_norm=0.24657462537288666
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 56  U=261.219  z_cont=[10.9,12.5]
#   x: grad_norm=0.1129801794886589
#   y: grad_norm=0.28819093108177185
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 57  U=261.415  z_cont=[10.9,12.5]
#   x: grad_norm=0.12748630344867706
#   y: grad_norm=0.3297228515148163
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 58  U=261.682  z_cont=[10.9,12.5]
#   x: grad_norm=0.14421337842941284
#   y: grad_norm=0.3756067752838135
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 59  U=262.047  z_cont=[10.9,12.5]
#   x: grad_norm=0.17024599015712738
#   y: grad_norm=0.45146244764328003
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 60  U=262.745  z_cont=[10.9,12.5]
#   x: grad_norm=0.2285577952861786
#   y: grad_norm=0.6420314311981201
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 61  U=263.660  z_cont=[10.9,12.5]
#   x: grad_norm=0.31591811776161194
#   y: grad_norm=0.9111052751541138
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 62  U=265.442  z_cont=[10.9,12.5]
#   x: grad_norm=0.5112463235855103
#   y: grad_norm=1.5974992513656616
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 63  U=270.100  z_cont=[10.9,12.5]
#   x: grad_norm=1.123923420906067
#   y: grad_norm=3.5552725791931152
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 64  U=296.384  z_cont=[10.9,12.5]
#   x: grad_norm=5.325469970703125
#   y: grad_norm=16.218406677246094
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 65  U=290.142  z_cont=[10.9,12.5]
#   x: grad_norm=4.025507926940918
#   y: grad_norm=12.43948745727539
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 66  U=276.150  z_cont=[10.9,12.5]
#   x: grad_norm=1.8370693922042847
#   y: grad_norm=5.530783653259277
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 67  U=275.774  z_cont=[10.9,12.5]
#   x: grad_norm=1.6709911823272705
#   y: grad_norm=4.909295558929443
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 68  U=282.631  z_cont=[10.9,12.5]
#   x: grad_norm=2.691798210144043
#   y: grad_norm=7.861659049987793
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 69  U=330.192  z_cont=[11.0,12.5]
#   x: grad_norm=8.72325611114502
#   y: grad_norm=25.82403564453125
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 70  U=276.344  z_cont=[11.0,12.5]
#   x: grad_norm=2.4682793617248535
#   y: grad_norm=7.438192844390869
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 71  U=262.625  z_cont=[11.0,12.5]
#   x: grad_norm=0.9286490082740784
#   y: grad_norm=2.653519630432129
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 72  U=260.969  z_cont=[11.0,12.5]
#   x: grad_norm=0.5569629073143005
#   y: grad_norm=1.6538678407669067
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 73  U=260.784  z_cont=[11.0,12.5]
#   x: grad_norm=0.22978369891643524
#   y: grad_norm=0.6306126117706299
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 74  U=260.015  z_cont=[11.0,12.5]
#   x: grad_norm=0.3909716308116913
#   y: grad_norm=0.7768880128860474
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 75  U=258.651  z_cont=[11.0,12.5]
#   x: grad_norm=0.6995075345039368
#   y: grad_norm=1.5770008563995361
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 76  U=248.623  z_cont=[11.0,12.5]
#   x: grad_norm=1.6856293678283691
#   y: grad_norm=4.5475921630859375
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 77  U=251.243  z_cont=[11.0,12.5]
#   x: grad_norm=4.817694664001465
#   y: grad_norm=43.99563980102539
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 78  U=258.819  z_cont=[11.0,12.5]
#   x: grad_norm=0.4475345313549042
#   y: grad_norm=1.427446722984314
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 79  U=256.156  z_cont=[11.0,12.5]
#   x: grad_norm=1.2434391975402832
#   y: grad_norm=2.8946022987365723
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 80  U=252.543  z_cont=[11.0,12.5]
#   x: grad_norm=1.6516872644424438
#   y: grad_norm=4.068953990936279
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 81  U=253.916  z_cont=[11.0,12.5]
#   x: grad_norm=1.4538613557815552
#   y: grad_norm=3.5644659996032715
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 82  U=256.666  z_cont=[11.0,12.4]
#   x: grad_norm=2.436171293258667
#   y: grad_norm=22.05098533630371
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 83  U=259.366  z_cont=[11.0,12.4]
#   x: grad_norm=0.3472607433795929
#   y: grad_norm=0.825477123260498
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 84  U=256.401  z_cont=[11.0,12.4]
#   x: grad_norm=1.0244660377502441
#   y: grad_norm=2.61922550201416
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 85  U=254.342  z_cont=[11.0,12.4]
#   x: grad_norm=1.261973261833191
#   y: grad_norm=3.1725175380706787
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 86  U=256.248  z_cont=[11.0,12.4]
#   x: grad_norm=0.9776480197906494
#   y: grad_norm=2.333503007888794
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 87  U=258.699  z_cont=[11.0,12.4]
#   x: grad_norm=0.4865155816078186
#   y: grad_norm=0.960114061832428
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 88  U=259.076  z_cont=[11.0,12.4]
#   x: grad_norm=0.2703390121459961
#   y: grad_norm=0.8296296000480652
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 89  U=257.647  z_cont=[11.0,12.4]
#   x: grad_norm=0.680095374584198
#   y: grad_norm=1.924301266670227
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 90  U=257.230  z_cont=[11.0,12.4]
#   x: grad_norm=0.7589408159255981
#   y: grad_norm=2.1196296215057373
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 91  U=257.886  z_cont=[11.0,12.4]
#   x: grad_norm=0.6749421954154968
#   y: grad_norm=1.8355993032455444
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 92  U=259.185  z_cont=[11.0,12.4]
#   x: grad_norm=0.3543378412723541
#   y: grad_norm=0.952473521232605
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 93  U=259.579  z_cont=[11.0,12.4]
#   x: grad_norm=0.08732970058917999
#   y: grad_norm=0.26222455501556396
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 94  U=258.868  z_cont=[11.0,12.4]
#   x: grad_norm=0.42992928624153137
#   y: grad_norm=1.210377812385559
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 95  U=257.953  z_cont=[11.0,12.4]
#   x: grad_norm=0.6652127504348755
#   y: grad_norm=1.7742514610290527
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 96  U=258.327  z_cont=[11.0,12.4]
#   x: grad_norm=0.572361171245575
#   y: grad_norm=1.5652458667755127
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 97  U=259.197  z_cont=[11.0,12.4]
#   x: grad_norm=0.2949444353580475
#   y: grad_norm=0.8642266988754272
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 98  U=259.496  z_cont=[11.0,12.4]
#   x: grad_norm=0.15180355310440063
#   y: grad_norm=0.232300266623497
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 99  U=259.031  z_cont=[11.0,12.4]
#   x: grad_norm=0.42882800102233887
#   y: grad_norm=0.952927827835083
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 100  U=259.039  z_cont=[11.0,12.4]
#   x: grad_norm=0.4374373257160187
#   y: grad_norm=1.0592596530914307
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 101  U=259.121  z_cont=[11.0,12.4]
#   x: grad_norm=0.3990359306335449
#   y: grad_norm=1.001956820487976
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 102  U=259.457  z_cont=[11.0,12.4]
#   x: grad_norm=0.209450364112854
#   y: grad_norm=0.5687313675880432
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 103  U=259.602  z_cont=[11.0,12.4]
#   x: grad_norm=0.05451648309826851
#   y: grad_norm=0.08841978013515472
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 104  U=259.440  z_cont=[11.0,12.4]
#   x: grad_norm=0.23469679057598114
#   y: grad_norm=0.5068175792694092
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 105  U=258.932  z_cont=[11.0,12.4]
#   x: grad_norm=0.45411184430122375
#   y: grad_norm=1.006445050239563
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 106  U=259.097  z_cont=[11.0,12.4]
#   x: grad_norm=0.3978651762008667
#   y: grad_norm=0.8749188184738159
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 107  U=259.465  z_cont=[11.0,12.4]
#   x: grad_norm=0.2175091803073883
#   y: grad_norm=0.44081079959869385
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 108  U=259.602  z_cont=[11.0,12.4]
#   x: grad_norm=0.05853964388370514
#   y: grad_norm=0.17140287160873413
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 109  U=259.428  z_cont=[11.0,12.4]
#   x: grad_norm=0.23868156969547272
#   y: grad_norm=0.6184988617897034
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 110  U=259.483  z_cont=[11.0,12.4]
#   x: grad_norm=0.20293302834033966
#   y: grad_norm=0.5501652359962463
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 111  U=259.494  z_cont=[11.0,12.4]
#   x: grad_norm=0.20801228284835815
#   y: grad_norm=0.5209022760391235
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 112  U=259.575  z_cont=[11.0,12.4]
#   x: grad_norm=0.14005346596240997
#   y: grad_norm=0.3065579831600189
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 113  U=259.615  z_cont=[11.0,12.4]
#   x: grad_norm=0.05622194707393646
#   y: grad_norm=0.0993022471666336
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 114  U=259.566  z_cont=[11.0,12.4]
#   x: grad_norm=0.10652641952037811
#   y: grad_norm=0.3299034833908081
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 115  U=259.413  z_cont=[11.0,12.4]
#   x: grad_norm=0.2574872374534607
#   y: grad_norm=0.6758170127868652
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 116  U=259.485  z_cont=[11.0,12.4]
#   x: grad_norm=0.21403203904628754
#   y: grad_norm=0.5651336908340454
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 117  U=259.615  z_cont=[11.0,12.4]
#   x: grad_norm=0.09287543594837189
#   y: grad_norm=0.25409162044525146
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 118  U=259.638  z_cont=[11.0,12.4]
#   x: grad_norm=0.0559796541929245
#   y: grad_norm=0.12694795429706573
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 119  U=259.556  z_cont=[11.0,12.4]
#   x: grad_norm=0.16749262809753418
#   y: grad_norm=0.416029155254364
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 120  U=259.619  z_cont=[11.0,12.4]
#   x: grad_norm=0.08356364071369171
#   y: grad_norm=0.25123462080955505
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 121  U=259.619  z_cont=[11.0,12.4]
#   x: grad_norm=0.08504600822925568
#   y: grad_norm=0.25481343269348145
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 122  U=259.639  z_cont=[11.0,12.4]
#   x: grad_norm=0.05611617863178253
#   y: grad_norm=0.1704956740140915
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 123  U=259.655  z_cont=[11.0,12.4]
#   x: grad_norm=0.023968270048499107
#   y: grad_norm=0.051438622176647186
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 124  U=259.653  z_cont=[11.0,12.4]
#   x: grad_norm=0.0478430800139904
#   y: grad_norm=0.10665684193372726
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 125  U=259.548  z_cont=[11.0,12.4]
#   x: grad_norm=0.1929933726787567
#   y: grad_norm=0.4326099455356598
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 126  U=259.607  z_cont=[11.0,12.4]
#   x: grad_norm=0.140645831823349
#   y: grad_norm=0.3235674202442169
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 127  U=259.666  z_cont=[11.0,12.4]
#   x: grad_norm=0.04082973673939705
#   y: grad_norm=0.09662511199712753
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 128  U=259.658  z_cont=[11.0,12.4]
#   x: grad_norm=0.06680245697498322
#   y: grad_norm=0.1512090414762497
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 129  U=259.612  z_cont=[11.0,12.4]
#   x: grad_norm=0.13850954174995422
#   y: grad_norm=0.31260862946510315
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 130  U=259.683  z_cont=[11.0,12.4]
#   x: grad_norm=0.01634317822754383
#   y: grad_norm=0.047429390251636505
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 131  U=259.684  z_cont=[11.0,12.4]
#   x: grad_norm=0.016889842227101326
#   y: grad_norm=0.04151984304189682
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 132  U=259.685  z_cont=[11.0,12.4]
#   x: grad_norm=0.016486769542098045
#   y: grad_norm=0.030470363795757294
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 133  U=259.685  z_cont=[11.0,12.4]
#   x: grad_norm=0.0168148223310709
#   y: grad_norm=0.0342840738594532
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 134  U=259.685  z_cont=[11.0,12.4]
#   x: grad_norm=0.01912662386894226
#   y: grad_norm=0.05069069564342499
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 135  U=259.642  z_cont=[11.0,12.4]
#   x: grad_norm=0.13115741312503815
#   y: grad_norm=0.29222097992897034
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 136  U=259.675  z_cont=[11.0,12.4]
#   x: grad_norm=0.08631853014230728
#   y: grad_norm=0.18335875868797302
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 137  U=259.698  z_cont=[11.0,12.4]
#   x: grad_norm=0.021671926602721214
#   y: grad_norm=0.038255639374256134
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 138  U=259.688  z_cont=[11.0,12.4]
#   x: grad_norm=0.060133714228868484
#   y: grad_norm=0.16268695890903473
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 139  U=259.672  z_cont=[11.0,12.4]
#   x: grad_norm=0.096041239798069
#   y: grad_norm=0.2413681298494339
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 140  U=259.699  z_cont=[11.0,12.4]
#   x: grad_norm=0.043420154601335526
#   y: grad_norm=0.07799259573221207
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 141  U=259.708  z_cont=[11.0,12.5]
#   x: grad_norm=0.033474139869213104
#   y: grad_norm=0.054127126932144165
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 142  U=259.714  z_cont=[11.0,12.5]
#   x: grad_norm=0.020966198295354843
#   y: grad_norm=0.04031455144286156
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 143  U=259.717  z_cont=[11.0,12.5]
#   x: grad_norm=0.012206372804939747
#   y: grad_norm=0.03873811662197113
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 144  U=259.716  z_cont=[11.0,12.5]
#   x: grad_norm=0.02014392986893654
#   y: grad_norm=0.04637843742966652
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 145  U=259.703  z_cont=[11.0,12.5]
#   x: grad_norm=0.09222806990146637
#   y: grad_norm=0.19993917644023895
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 146  U=259.725  z_cont=[11.0,12.5]
#   x: grad_norm=0.04671116918325424
#   y: grad_norm=0.1018432229757309
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 147  U=259.733  z_cont=[11.0,12.5]
#   x: grad_norm=0.016112687066197395
#   y: grad_norm=0.04061707481741905
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 148  U=259.723  z_cont=[11.0,12.5]
#   x: grad_norm=0.06451535224914551
#   y: grad_norm=0.14495019614696503
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 149  U=259.716  z_cont=[11.0,12.5]
#   x: grad_norm=0.08268789201974869
#   y: grad_norm=0.17777739465236664
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 150  U=259.737  z_cont=[11.0,12.5]
#   x: grad_norm=0.06631647050380707
#   y: grad_norm=0.1401345282793045
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 151  U=259.743  z_cont=[11.0,12.5]
#   x: grad_norm=0.05582817271351814
#   y: grad_norm=0.12472400814294815
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 152  U=259.753  z_cont=[11.0,12.5]
#   x: grad_norm=0.024579502642154694
#   y: grad_norm=0.058424871414899826
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 153  U=259.756  z_cont=[11.0,12.5]
#   x: grad_norm=0.017869245260953903
#   y: grad_norm=0.041056275367736816
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 154  U=259.753  z_cont=[11.0,12.5]
#   x: grad_norm=0.04442165419459343
#   y: grad_norm=0.09740651398897171
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 155  U=259.752  z_cont=[11.0,12.5]
#   x: grad_norm=0.07171211391687393
#   y: grad_norm=0.12911398708820343
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 156  U=259.766  z_cont=[11.0,12.5]
#   x: grad_norm=0.046700041741132736
#   y: grad_norm=0.10703201591968536
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 157  U=259.775  z_cont=[11.0,12.5]
#   x: grad_norm=0.019988583400845528
#   y: grad_norm=0.09264152497053146
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 158  U=259.776  z_cont=[11.0,12.5]
#   x: grad_norm=0.031622085720300674
#   y: grad_norm=0.12029669433832169
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 159  U=259.763  z_cont=[11.0,12.5]
#   x: grad_norm=0.09940490871667862
#   y: grad_norm=0.9027659296989441
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 160  U=259.752  z_cont=[11.0,12.5]
#   x: grad_norm=0.12653641402721405
#   y: grad_norm=0.28905943036079407
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 161  U=259.772  z_cont=[11.0,12.5]
#   x: grad_norm=0.1011953130364418
#   y: grad_norm=0.24406173825263977
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 162  U=259.800  z_cont=[11.0,12.5]
#   x: grad_norm=0.03229682892560959
#   y: grad_norm=0.08913073688745499
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 163  U=259.797  z_cont=[11.0,12.5]
#   x: grad_norm=0.053570352494716644
#   y: grad_norm=0.11038468778133392
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 164  U=259.778  z_cont=[11.0,12.5]
#   x: grad_norm=0.10227937251329422
#   y: grad_norm=0.22221334278583527
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 165  U=259.816  z_cont=[11.0,12.5]
#   x: grad_norm=0.03350193053483963
#   y: grad_norm=0.06430131942033768
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 166  U=259.823  z_cont=[11.0,12.5]
#   x: grad_norm=0.02779410406947136
#   y: grad_norm=0.05170002952218056
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 167  U=259.829  z_cont=[11.0,12.5]
#   x: grad_norm=0.019774500280618668
#   y: grad_norm=0.04045423865318298
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 168  U=259.834  z_cont=[11.0,12.5]
#   x: grad_norm=0.01266290619969368
#   y: grad_norm=0.03465954586863518
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 169  U=259.837  z_cont=[11.0,12.5]
#   x: grad_norm=0.013921497389674187
#   y: grad_norm=0.03672022372484207
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 170  U=259.801  z_cont=[11.0,12.5]
#   x: grad_norm=0.14029009640216827
#   y: grad_norm=0.3161129057407379
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 171  U=259.848  z_cont=[11.0,12.5]
#   x: grad_norm=0.06827714294195175
#   y: grad_norm=0.15095165371894836
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 172  U=259.861  z_cont=[11.0,12.5]
#   x: grad_norm=0.03550705313682556
#   y: grad_norm=0.09079200774431229
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 173  U=259.839  z_cont=[11.0,12.5]
#   x: grad_norm=0.10456547141075134
#   y: grad_norm=0.24747270345687866
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 174  U=259.836  z_cont=[11.0,12.5]
#   x: grad_norm=0.11645393818616867
#   y: grad_norm=0.26451730728149414
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 175  U=259.875  z_cont=[11.0,12.5]
#   x: grad_norm=0.08460350334644318
#   y: grad_norm=0.18223093450069427
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 176  U=259.881  z_cont=[11.0,12.5]
#   x: grad_norm=0.08490811288356781
#   y: grad_norm=0.19347842037677765
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 177  U=259.901  z_cont=[11.0,12.5]
#   x: grad_norm=0.046020615845918655
#   y: grad_norm=0.11031871289014816
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 178  U=259.912  z_cont=[11.0,12.5]
#   x: grad_norm=0.01986786536872387
#   y: grad_norm=0.05022071674466133
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 179  U=259.908  z_cont=[11.0,12.5]
#   x: grad_norm=0.0606684572994709
#   y: grad_norm=0.13507097959518433
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 180  U=259.922  z_cont=[11.0,12.5]
#   x: grad_norm=0.09075511991977692
#   y: grad_norm=0.1913519948720932
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 181  U=259.948  z_cont=[11.0,12.5]
#   x: grad_norm=0.04321965202689171
#   y: grad_norm=0.08767790347337723
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 182  U=259.958  z_cont=[11.0,12.5]
#   x: grad_norm=0.03480206057429314
#   y: grad_norm=0.08760082721710205
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 183  U=259.955  z_cont=[11.0,12.5]
#   x: grad_norm=0.07104125618934631
#   y: grad_norm=0.16562682390213013
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 184  U=259.961  z_cont=[11.0,12.5]
#   x: grad_norm=0.07364262640476227
#   y: grad_norm=0.16202080249786377
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 185  U=259.947  z_cont=[11.0,12.5]
#   x: grad_norm=0.13908524811267853
#   y: grad_norm=0.3306148648262024
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 186  U=259.986  z_cont=[11.0,12.5]
#   x: grad_norm=0.09805845469236374
#   y: grad_norm=0.23843906819820404
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 187  U=260.023  z_cont=[11.0,12.5]
#   x: grad_norm=0.021722178906202316
#   y: grad_norm=0.06324893981218338
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 188  U=260.017  z_cont=[11.0,12.5]
#   x: grad_norm=0.07469156384468079
#   y: grad_norm=0.17132647335529327
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 189  U=260.005  z_cont=[11.0,12.5]
#   x: grad_norm=0.11387386918067932
#   y: grad_norm=0.2606569230556488
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 190  U=260.064  z_cont=[11.0,12.5]
#   x: grad_norm=0.053894441574811935
#   y: grad_norm=0.09381682425737381
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 191  U=260.079  z_cont=[11.0,12.5]
#   x: grad_norm=0.052157897502183914
#   y: grad_norm=0.09862542152404785
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 192  U=260.097  z_cont=[11.0,12.5]
#   x: grad_norm=0.039805326610803604
#   y: grad_norm=0.08635629713535309
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 193  U=260.114  z_cont=[11.0,12.5]
#   x: grad_norm=0.024095330387353897
#   y: grad_norm=0.06666282564401627
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 194  U=260.126  z_cont=[11.0,12.5]
#   x: grad_norm=0.02701563946902752
#   y: grad_norm=0.06879320740699768
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 195  U=260.127  z_cont=[11.0,12.5]
#   x: grad_norm=0.12514960765838623
#   y: grad_norm=0.29318174719810486
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 196  U=260.181  z_cont=[11.0,12.5]
#   x: grad_norm=0.05163539573550224
#   y: grad_norm=0.12413295358419418
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 197  U=260.196  z_cont=[11.0,12.5]
#   x: grad_norm=0.05537301301956177
#   y: grad_norm=0.13306178152561188
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 198  U=260.188  z_cont=[11.0,12.5]
#   x: grad_norm=0.10927417129278183
#   y: grad_norm=0.25410720705986023
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 199  U=260.209  z_cont=[11.0,12.5]
#   x: grad_norm=0.10554022341966629
#   y: grad_norm=0.23632189631462097
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# ...
#   x: grad_norm=0.11649058014154434
#   y: grad_norm=0.2148391753435135
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1185  U=260.367  z_cont=[10.3,12.8]
#   x: grad_norm=0.05379104241728783
#   y: grad_norm=0.08823725581169128
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1186  U=260.351  z_cont=[10.3,12.8]
#   x: grad_norm=0.10048020631074905
#   y: grad_norm=0.19927051663398743
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1187  U=260.341  z_cont=[10.3,12.8]
#   x: grad_norm=0.12807847559452057
#   y: grad_norm=0.2570347785949707
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1188  U=260.362  z_cont=[10.3,12.8]
#   x: grad_norm=0.11572109162807465
#   y: grad_norm=0.2305629998445511
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1189  U=260.398  z_cont=[10.3,12.8]
#   x: grad_norm=0.07317354530096054
#   y: grad_norm=0.13854648172855377
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1190  U=260.215  z_cont=[10.3,12.8]
#   x: grad_norm=0.2577606737613678
#   y: grad_norm=0.4759804606437683
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1191  U=260.266  z_cont=[10.3,12.8]
#   x: grad_norm=0.2362377792596817
#   y: grad_norm=0.4372405707836151
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1192  U=260.379  z_cont=[10.3,12.8]
#   x: grad_norm=0.14943556487560272
#   y: grad_norm=0.2666679620742798
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1193  U=260.451  z_cont=[10.3,12.8]
#   x: grad_norm=0.057396046817302704
#   y: grad_norm=0.08239968121051788
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1194  U=260.442  z_cont=[10.3,12.8]
#   x: grad_norm=0.11429164558649063
#   y: grad_norm=0.22440838813781738
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1195  U=260.452  z_cont=[10.3,12.8]
#   x: grad_norm=0.16483619809150696
#   y: grad_norm=0.30533307790756226
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1196  U=260.536  z_cont=[10.3,12.8]
#   x: grad_norm=0.06761524081230164
#   y: grad_norm=0.10854163765907288
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1197  U=260.547  z_cont=[10.3,12.8]
#   x: grad_norm=0.0842885673046112
#   y: grad_norm=0.16474272310733795
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1198  U=260.518  z_cont=[10.3,12.8]
#   x: grad_norm=0.1554829180240631
#   y: grad_norm=0.31104475259780884
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1199  U=260.518  z_cont=[10.3,12.8]
#   x: grad_norm=0.17308758199214935
#   y: grad_norm=0.3411434292793274
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1200  U=260.542  z_cont=[10.3,12.8]
#   x: grad_norm=0.19428494572639465
#   y: grad_norm=0.38484111428260803
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1201  U=260.586  z_cont=[10.3,12.8]
#   x: grad_norm=0.16782578825950623
#   y: grad_norm=0.33664220571517944
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1202  U=260.657  z_cont=[10.3,12.8]
#   x: grad_norm=0.09376061707735062
#   y: grad_norm=0.18966081738471985
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1203  U=260.693  z_cont=[10.3,12.8]
#   x: grad_norm=0.0523390993475914
#   y: grad_norm=0.08399100601673126
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1204  U=260.673  z_cont=[10.3,12.8]
#   x: grad_norm=0.1422165483236313
#   y: grad_norm=0.2762301564216614
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1205  U=260.790  z_cont=[10.3,12.8]
#   x: grad_norm=0.0991019532084465
#   y: grad_norm=0.17325106263160706
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1206  U=260.828  z_cont=[10.3,12.8]
#   x: grad_norm=0.05906058847904205
#   y: grad_norm=0.08637552708387375
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1207  U=260.849  z_cont=[10.3,12.8]
#   x: grad_norm=0.07595331966876984
#   y: grad_norm=0.14092618227005005
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1208  U=260.868  z_cont=[10.3,12.8]
#   x: grad_norm=0.10114647448062897
#   y: grad_norm=0.1977684050798416
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1209  U=260.901  z_cont=[10.3,12.8]
#   x: grad_norm=0.09442408382892609
#   y: grad_norm=0.17975567281246185
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1210  U=260.907  z_cont=[10.3,12.8]
#   x: grad_norm=0.1765008121728897
#   y: grad_norm=0.31118419766426086
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1211  U=260.965  z_cont=[10.3,12.8]
#   x: grad_norm=0.15346403419971466
#   y: grad_norm=0.2660369575023651
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1212  U=261.038  z_cont=[10.3,12.8]
#   x: grad_norm=0.09748012572526932
#   y: grad_norm=0.14971855282783508
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1213  U=261.089  z_cont=[10.3,12.8]
#   x: grad_norm=0.0851474478840828
#   y: grad_norm=0.13805469870567322
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1214  U=261.121  z_cont=[10.3,12.8]
#   x: grad_norm=0.12214336544275284
#   y: grad_norm=0.22592148184776306
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1215  U=261.192  z_cont=[10.3,12.8]
#   x: grad_norm=0.16581423580646515
#   y: grad_norm=0.27806562185287476
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1216  U=261.288  z_cont=[10.3,12.8]
#   x: grad_norm=0.12167511880397797
#   y: grad_norm=0.1871662586927414
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1217  U=261.370  z_cont=[10.3,12.8]
#   x: grad_norm=0.10028336942195892
#   y: grad_norm=0.1560819298028946
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1218  U=261.433  z_cont=[10.3,12.8]
#   x: grad_norm=0.1259189248085022
#   y: grad_norm=0.23032614588737488
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1219  U=261.507  z_cont=[10.3,12.8]
#   x: grad_norm=0.13946902751922607
#   y: grad_norm=0.2572953999042511
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1220  U=261.564  z_cont=[10.3,12.8]
#   x: grad_norm=0.13966107368469238
#   y: grad_norm=0.20976516604423523
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1221  U=261.679  z_cont=[10.3,12.8]
#   x: grad_norm=0.14296184480190277
#   y: grad_norm=0.21900588274002075
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1222  U=261.808  z_cont=[10.3,12.8]
#   x: grad_norm=0.1385672688484192
#   y: grad_norm=0.21108902990818024
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1223  U=261.947  z_cont=[10.3,12.8]
#   x: grad_norm=0.13686202466487885
#   y: grad_norm=0.21073311567306519
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1224  U=262.097  z_cont=[10.3,12.8]
#   x: grad_norm=0.14515548944473267
#   y: grad_norm=0.2277533859014511
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1225  U=262.048  z_cont=[10.3,12.8]
#   x: grad_norm=0.42472702264785767
#   y: grad_norm=0.7948777079582214
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1226  U=262.489  z_cont=[10.3,12.8]
#   x: grad_norm=0.2836785912513733
#   y: grad_norm=0.5089580416679382
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1227  U=262.833  z_cont=[10.3,12.8]
#   x: grad_norm=0.20658083260059357
#   y: grad_norm=0.3244668245315552
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1228  U=263.010  z_cont=[10.3,12.8]
#   x: grad_norm=0.3327128291130066
#   y: grad_norm=0.6126561760902405
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1229  U=263.220  z_cont=[10.3,12.8]
#   x: grad_norm=0.459727942943573
#   y: grad_norm=0.9059432744979858
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1230  U=263.859  z_cont=[10.3,12.8]
#   x: grad_norm=0.34407198429107666
#   y: grad_norm=0.5583392977714539
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1231  U=264.473  z_cont=[10.3,12.8]
#   x: grad_norm=0.40262389183044434
#   y: grad_norm=0.6599004864692688
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1232  U=265.381  z_cont=[10.3,12.8]
#   x: grad_norm=0.46434664726257324
#   y: grad_norm=0.7476142644882202
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1233  U=266.720  z_cont=[10.3,12.8]
#   x: grad_norm=0.6058654189109802
#   y: grad_norm=0.9882486462593079
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1234  U=268.949  z_cont=[10.3,12.8]
#   x: grad_norm=0.9048599600791931
#   y: grad_norm=1.4562602043151855
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1235  U=272.795  z_cont=[10.3,12.8]
#   x: grad_norm=1.50840163230896
#   y: grad_norm=2.5117437839508057
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1236  U=285.944  z_cont=[10.3,12.8]
#   x: grad_norm=3.883262872695923
#   y: grad_norm=6.302704334259033
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1237  U=358.040  z_cont=[10.3,12.8]
#   x: grad_norm=1.1590564250946045
#   y: grad_norm=2.119192361831665
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1238  U=285.448  z_cont=[10.3,12.8]
#   x: grad_norm=4.776278018951416
#   y: grad_norm=7.936485290527344
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1239  U=279.123  z_cont=[10.3,12.8]
#   x: grad_norm=2.9144339561462402
#   y: grad_norm=5.018657207489014
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1240  U=287.213  z_cont=[10.3,12.8]
#   x: grad_norm=4.579333782196045
#   y: grad_norm=8.062599182128906
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1241  U=338.570  z_cont=[10.3,12.8]
#   x: grad_norm=9.60583209991455
#   y: grad_norm=15.29250431060791
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1242  U=263.889  z_cont=[10.3,12.8]
#   x: grad_norm=2.928464651107788
#   y: grad_norm=4.984643459320068
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1243  U=255.407  z_cont=[10.3,12.8]
#   x: grad_norm=1.7912338972091675
#   y: grad_norm=3.2815470695495605
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1244  U=257.956  z_cont=[10.3,12.8]
#   x: grad_norm=1.0620876550674438
#   y: grad_norm=1.9377998113632202
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1245  U=257.361  z_cont=[10.3,12.8]
#   x: grad_norm=0.43797624111175537
#   y: grad_norm=0.9142320156097412
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1246  U=252.531  z_cont=[10.3,12.8]
#   x: grad_norm=1.341740608215332
#   y: grad_norm=3.1147894859313965
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1247  U=249.977  z_cont=[10.3,12.8]
#   x: grad_norm=1.5688408613204956
#   y: grad_norm=3.674457550048828
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1248  U=252.403  z_cont=[10.3,12.8]
#   x: grad_norm=1.2659357786178589
#   y: grad_norm=3.0023880004882812
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# Epoch 1249  U=255.862  z_cont=[10.3,12.8]
#   x: grad_norm=0.4749048948287964
#   y: grad_norm=1.074097752571106
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt
# CPU times: user 1min 22s, sys: 4.27 s, total: 1min 27s
# Wall time: 3min 25s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='1e2 U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='1e2 U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='1e8 U_E',    lw=1)
plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_38_10_shower_center_init_angle_error/cashed_showers_10.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_lb.detach().cpu().max()], [0, E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
