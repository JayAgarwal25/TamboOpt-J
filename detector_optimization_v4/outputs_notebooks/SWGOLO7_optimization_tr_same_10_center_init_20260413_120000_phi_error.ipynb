# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_37_10_shower_center_init_phi_error"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generate_new_data = True
print("device:", device)
# Out:
# device: cuda

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 10 # 200000
Nvalidation = 10 # 20000
Ntest       = 10 # 3000
Nbatch      = 10 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
use_cache = True
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
#   Loading PointCountFM from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/num_of_point_clouds_dequantize_compiled.pt ...
#   Loaded in 846.2 ms
#   Running inference on 10 samples ...
#   Inference done in 0.84 s
#   Mean total hits predicted per shower: 1983.9
#   Loading AllShowers generator from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/all_showers ...
#   Loaded in 0.07 s
#   Time mode: ON (x,y,e,t)
#   Generating 10 showers (16 ODE steps, solver=midpoint, device=cuda) ...
# [     0s]: start batch   0
# [    15s]: generation done
#   Generation done in 15.34 s
# samples shape: torch.Size([10, 2048, 5])
#   Saved 10 showers → ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-1621 m  shift=+4425 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([ -978.1579,  4576.3403,  3862.4006, -3024.3110, -1464.8605,  2581.8643,
#           434.1276,  3895.6003,  3708.8110, -3681.9866], device='cuda:0')
# Y0: tensor([5468.6533, 2282.5295, 2545.8750, 4652.3403, 5684.4482,  605.5437,
#          636.1125, 2032.6968,  369.2310, 3069.4556], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 101786.438, energy.max(): 34634256.000
# theta.min():  61.0°, theta.max():  97.4°
# phi.min():    -162.9°, phi.max():    150.9°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# CPU times: user 13.2 ms, sys: 6.99 ms, total: 20.2 ms
# Wall time: 69.2 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# CPU times: user 19.1 ms, sys: 464 μs, total: 19.6 ms
# Wall time: 66.4 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([10, 90, 5])   labels: torch.Size([10, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0811
# Training 20%  val_loss=0.0692
# Training 30%  val_loss=0.0658
# Training 40%  val_loss=0.0657
# Training 50%  val_loss=0.0657
# Training 60%  val_loss=0.0657
# Training 70%  val_loss=0.0657
# Training 80%  val_loss=0.0657
# CPU times: user 2.97 s, sys: 96 ms, total: 3.06 s
# Wall time: 3.21 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + 1250):

    if epoch < 20:
        Nfinetune = 10 # 3000
    else:
        Nfinetune = 10 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        # 1e2 * U_angle(preds_th,  th, r_score) + 0
        1e2 * U_angle(preds_phi, ph, r_score) + 0
        # 1e8 * U_E(preds_e, energy, r_score)   +
        # 5e5 * U_PR(r_score)
    ) / 1e3

    U_vals.append(U.item())
    U_th_vals.append( (1e2 * U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( (1e2 * U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   (1e8 * U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  (5e5 * U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=True, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 0  U=38.520  z_cont=[10.5,12.7]
#   x: grad_norm=3.013292074203491
#   y: grad_norm=4.155348300933838
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1  U=28.060  z_cont=[10.4,12.8]
#   x: grad_norm=0.7174076437950134
#   y: grad_norm=0.9777076840400696
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 2  U=101.701  z_cont=[10.4,12.8]
#   x: grad_norm=3.6029105186462402
#   y: grad_norm=4.909067153930664
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 3  U=53.587  z_cont=[10.4,12.8]
#   x: grad_norm=4.393744945526123
#   y: grad_norm=5.918238162994385
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 4  U=33.843  z_cont=[10.5,12.7]
#   x: grad_norm=2.1529486179351807
#   y: grad_norm=3.035825729370117
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 5  U=67.459  z_cont=[10.6,12.6]
#   x: grad_norm=4.734643936157227
#   y: grad_norm=6.942694664001465
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 6  U=21.237  z_cont=[10.5,12.7]
#   x: grad_norm=0.7225686311721802
#   y: grad_norm=0.9952723979949951
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 7  U=18.032  z_cont=[10.5,12.7]
#   x: grad_norm=0.37890902161598206
#   y: grad_norm=0.53826904296875
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 8  U=19.801  z_cont=[10.5,12.7]
#   x: grad_norm=0.55973219871521
#   y: grad_norm=0.7806318402290344
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 9  U=28.329  z_cont=[10.5,12.7]
#   x: grad_norm=1.3729394674301147
#   y: grad_norm=1.9674466848373413
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 10  U=129.368  z_cont=[10.6,12.7]
#   x: grad_norm=4.069552898406982
#   y: grad_norm=5.867977619171143
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 11  U=108.298  z_cont=[10.7,12.6]
#   x: grad_norm=1.4424751996994019
#   y: grad_norm=2.3542795181274414
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 12  U=83.463  z_cont=[10.7,12.6]
#   x: grad_norm=4.696572780609131
#   y: grad_norm=7.695662498474121
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 13  U=6.618  z_cont=[10.7,12.7]
#   x: grad_norm=0.21241232752799988
#   y: grad_norm=0.3218573033809662
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 14  U=5.421  z_cont=[10.7,12.7]
#   x: grad_norm=0.20688128471374512
#   y: grad_norm=0.29014649987220764
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 15  U=5.811  z_cont=[10.7,12.7]
#   x: grad_norm=0.2318280041217804
#   y: grad_norm=0.3283175826072693
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 16  U=6.889  z_cont=[10.7,12.7]
#   x: grad_norm=0.30920669436454773
#   y: grad_norm=0.4371843636035919
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 17  U=9.164  z_cont=[10.7,12.7]
#   x: grad_norm=0.49200281500816345
#   y: grad_norm=0.7007935643196106
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 18  U=16.263  z_cont=[10.7,12.7]
#   x: grad_norm=1.2010444402694702
#   y: grad_norm=1.6986509561538696
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 19  U=108.791  z_cont=[10.7,12.7]
#   x: grad_norm=1.226599097251892
#   y: grad_norm=1.8503267765045166
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 20  U=63.627  z_cont=[10.7,12.7]
#   x: grad_norm=5.335267543792725
#   y: grad_norm=7.793810844421387
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 21  U=106.519  z_cont=[10.7,12.6]
#   x: grad_norm=0.8107581734657288
#   y: grad_norm=1.2170547246932983
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 22  U=84.398  z_cont=[10.6,12.6]
#   x: grad_norm=8.250171661376953
#   y: grad_norm=12.2842435836792
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 23  U=67.854  z_cont=[10.6,12.7]
#   x: grad_norm=8.646228790283203
#   y: grad_norm=11.608534812927246
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 24  U=0.972  z_cont=[10.5,12.9]
#   x: grad_norm=0.010052376426756382
#   y: grad_norm=0.013125259429216385
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 25  U=0.765  z_cont=[10.5,12.9]
#   x: grad_norm=0.004484520759433508
#   y: grad_norm=0.0067584216594696045
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 26  U=0.730  z_cont=[10.4,12.9]
#   x: grad_norm=0.0036525249015539885
#   y: grad_norm=0.005626574158668518
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 27  U=0.722  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034221007954329252
#   y: grad_norm=0.00527085131034255
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 28  U=0.719  z_cont=[10.4,13.0]
#   x: grad_norm=0.003359782276675105
#   y: grad_norm=0.00517481192946434
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 29  U=0.719  z_cont=[10.4,13.0]
#   x: grad_norm=0.003346340963616967
#   y: grad_norm=0.005154096521437168
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 30  U=0.719  z_cont=[10.4,13.0]
#   x: grad_norm=0.0033474110532552004
#   y: grad_norm=0.00515574449673295
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 31  U=0.719  z_cont=[10.4,13.0]
#   x: grad_norm=0.0033528313506394625
#   y: grad_norm=0.005164098925888538
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 32  U=0.719  z_cont=[10.4,13.0]
#   x: grad_norm=0.0033595548011362553
#   y: grad_norm=0.005174458958208561
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 33  U=0.719  z_cont=[10.4,13.0]
#   x: grad_norm=0.003366743680089712
#   y: grad_norm=0.005185538437217474
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 34  U=0.720  z_cont=[10.4,13.0]
#   x: grad_norm=0.0033740606158971786
#   y: grad_norm=0.005196813493967056
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 35  U=0.720  z_cont=[10.4,13.0]
#   x: grad_norm=0.0033814506605267525
#   y: grad_norm=0.005208202637732029
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 36  U=0.720  z_cont=[10.4,13.0]
#   x: grad_norm=0.003388860961422324
#   y: grad_norm=0.005219623912125826
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 37  U=0.721  z_cont=[10.4,13.0]
#   x: grad_norm=0.003396296640858054
#   y: grad_norm=0.005231081508100033
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 38  U=0.721  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034037476871162653
#   y: grad_norm=0.005242564715445042
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 39  U=0.721  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034112422727048397
#   y: grad_norm=0.005254114046692848
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 40  U=0.721  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034187454730272293
#   y: grad_norm=0.005265676416456699
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 41  U=0.722  z_cont=[10.4,13.0]
#   x: grad_norm=0.003426280105486512
#   y: grad_norm=0.0052772886119782925
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 42  U=0.722  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034338494297116995
#   y: grad_norm=0.005288953892886639
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 43  U=0.722  z_cont=[10.4,13.0]
#   x: grad_norm=0.003441444132477045
#   y: grad_norm=0.0053006564266979694
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 44  U=0.723  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034490416292101145
#   y: grad_norm=0.005312366411089897
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 45  U=0.723  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034566838294267654
#   y: grad_norm=0.0053241439163684845
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 46  U=0.723  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034643348772078753
#   y: grad_norm=0.0053359344601631165
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 47  U=0.723  z_cont=[10.4,13.0]
#   x: grad_norm=0.003472025040537119
#   y: grad_norm=0.005347786005586386
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 48  U=0.724  z_cont=[10.4,13.0]
#   x: grad_norm=0.003479724284261465
#   y: grad_norm=0.0053596505895257
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 49  U=0.724  z_cont=[10.4,13.0]
#   x: grad_norm=0.003487463342025876
#   y: grad_norm=0.005371578503400087
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 50  U=0.724  z_cont=[10.4,13.0]
#   x: grad_norm=0.0034952161367982626
#   y: grad_norm=0.005383526440709829
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 51  U=0.725  z_cont=[10.4,13.0]
#   x: grad_norm=0.003503004088997841
#   y: grad_norm=0.005395526997745037
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 52  U=0.725  z_cont=[10.4,13.0]
#   x: grad_norm=0.003510811598971486
#   y: grad_norm=0.005407560151070356
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 53  U=0.725  z_cont=[10.4,13.0]
#   x: grad_norm=0.0035186605527997017
#   y: grad_norm=0.005419655237346888
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 54  U=0.725  z_cont=[10.4,13.0]
#   x: grad_norm=0.003526517888531089
#   y: grad_norm=0.005431764759123325
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 55  U=0.726  z_cont=[10.4,13.0]
#   x: grad_norm=0.0035344157367944717
#   y: grad_norm=0.005443936679512262
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 56  U=0.726  z_cont=[10.4,13.0]
#   x: grad_norm=0.00354233430698514
#   y: grad_norm=0.005456140730530024
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 57  U=0.726  z_cont=[10.4,13.0]
#   x: grad_norm=0.00355028104968369
#   y: grad_norm=0.005468386225402355
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 58  U=0.727  z_cont=[10.4,13.0]
#   x: grad_norm=0.0035582559648901224
#   y: grad_norm=0.005480678752064705
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 59  U=0.727  z_cont=[10.4,13.0]
#   x: grad_norm=0.0035662774462252855
#   y: grad_norm=0.005493040196597576
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 60  U=0.727  z_cont=[10.4,13.0]
#   x: grad_norm=0.003574321512132883
#   y: grad_norm=0.005505437031388283
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 61  U=0.728  z_cont=[10.4,13.0]
#   x: grad_norm=0.0035823811776936054
#   y: grad_norm=0.005517857149243355
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 62  U=0.728  z_cont=[10.4,13.0]
#   x: grad_norm=0.003590475069358945
#   y: grad_norm=0.005530332215130329
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 63  U=0.728  z_cont=[10.4,13.0]
#   x: grad_norm=0.0035985801368951797
#   y: grad_norm=0.005542822647839785
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 64  U=0.729  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036067680921405554
#   y: grad_norm=0.00555544113740325
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 65  U=0.729  z_cont=[10.4,13.0]
#   x: grad_norm=0.003614948596805334
#   y: grad_norm=0.005568049382418394
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 66  U=0.729  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036231516860425472
#   y: grad_norm=0.005580690689384937
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 67  U=0.729  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036314025055617094
#   y: grad_norm=0.005593406967818737
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 68  U=0.730  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036396700888872147
#   y: grad_norm=0.005606148857623339
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 69  U=0.730  z_cont=[10.4,13.0]
#   x: grad_norm=0.003647967241704464
#   y: grad_norm=0.005618935450911522
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 70  U=0.730  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036562858149409294
#   y: grad_norm=0.005631756968796253
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 71  U=0.731  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036646469961851835
#   y: grad_norm=0.005644641816616058
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 72  U=0.731  z_cont=[10.4,13.0]
#   x: grad_norm=0.003673038212582469
#   y: grad_norm=0.005657576024532318
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 73  U=0.731  z_cont=[10.4,13.0]
#   x: grad_norm=0.003681426402181387
#   y: grad_norm=0.005670501384884119
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 74  U=0.732  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036898767575621605
#   y: grad_norm=0.0056835259310901165
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 75  U=0.732  z_cont=[10.4,13.0]
#   x: grad_norm=0.0036981471348553896
#   y: grad_norm=0.005686619784682989
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 76  U=0.732  z_cont=[10.4,13.0]
#   x: grad_norm=0.0037066566292196512
#   y: grad_norm=0.005699713248759508
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 77  U=0.733  z_cont=[10.4,13.0]
#   x: grad_norm=0.0037151770666241646
#   y: grad_norm=0.005712823010981083
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 78  U=0.733  z_cont=[10.4,13.0]
#   x: grad_norm=0.0037237396463751793
#   y: grad_norm=0.005725998431444168
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 79  U=0.733  z_cont=[10.4,13.0]
#   x: grad_norm=0.0037323273718357086
#   y: grad_norm=0.005739210639148951
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 80  U=0.734  z_cont=[10.4,13.0]
#   x: grad_norm=0.003740931861102581
#   y: grad_norm=0.005752450320869684
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 81  U=0.734  z_cont=[10.4,13.0]
#   x: grad_norm=0.0037495805881917477
#   y: grad_norm=0.005765756592154503
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 82  U=0.734  z_cont=[10.4,13.0]
#   x: grad_norm=0.003758240258321166
#   y: grad_norm=0.005779080558568239
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 83  U=0.735  z_cont=[10.4,13.0]
#   x: grad_norm=0.0037669241428375244
#   y: grad_norm=0.0057924422435462475
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 84  U=0.735  z_cont=[10.4,13.0]
#   x: grad_norm=0.0037756836973130703
#   y: grad_norm=0.0058059184812009335
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 85  U=0.735  z_cont=[10.4,13.0]
#   x: grad_norm=0.00378445559181273
#   y: grad_norm=0.005819415207952261
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 86  U=0.736  z_cont=[10.4,13.0]
#   x: grad_norm=0.003793289652094245
#   y: grad_norm=0.005833006929606199
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 87  U=0.736  z_cont=[10.4,13.0]
#   x: grad_norm=0.0038021490909159184
#   y: grad_norm=0.005846640095114708
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 88  U=0.736  z_cont=[10.4,13.0]
#   x: grad_norm=0.003811014350503683
#   y: grad_norm=0.005860279779881239
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 89  U=0.737  z_cont=[10.4,13.0]
#   x: grad_norm=0.0038199236150830984
#   y: grad_norm=0.005873987451195717
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 90  U=0.737  z_cont=[10.4,13.0]
#   x: grad_norm=0.003828858258202672
#   y: grad_norm=0.005887734238058329
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 91  U=0.738  z_cont=[10.4,13.0]
#   x: grad_norm=0.0038377982564270496
#   y: grad_norm=0.005901490803807974
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 92  U=0.738  z_cont=[10.4,13.0]
#   x: grad_norm=0.0038468034472316504
#   y: grad_norm=0.005915347021073103
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 93  U=0.738  z_cont=[10.4,13.0]
#   x: grad_norm=0.0038558533415198326
#   y: grad_norm=0.005929270759224892
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 94  U=0.739  z_cont=[10.4,13.0]
#   x: grad_norm=0.003864915808662772
#   y: grad_norm=0.005943214520812035
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 95  U=0.739  z_cont=[10.4,13.0]
#   x: grad_norm=0.003874067682772875
#   y: grad_norm=0.005957296118140221
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 96  U=0.739  z_cont=[10.4,12.9]
#   x: grad_norm=0.0038832600694149733
#   y: grad_norm=0.005971439648419619
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 97  U=0.740  z_cont=[10.4,12.9]
#   x: grad_norm=0.0038924645632505417
#   y: grad_norm=0.0059856027364730835
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 98  U=0.740  z_cont=[10.4,12.9]
#   x: grad_norm=0.0039017272647470236
#   y: grad_norm=0.005999854765832424
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 99  U=0.740  z_cont=[10.4,12.9]
#   x: grad_norm=0.003910966217517853
#   y: grad_norm=0.006014072801917791
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 100  U=0.741  z_cont=[10.4,12.9]
#   x: grad_norm=0.003920269664376974
#   y: grad_norm=0.006028387229889631
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 101  U=0.741  z_cont=[10.4,12.9]
#   x: grad_norm=0.003929580561816692
#   y: grad_norm=0.006042712368071079
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 102  U=0.742  z_cont=[10.4,12.9]
#   x: grad_norm=0.0039389305748045444
#   y: grad_norm=0.006057101301848888
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 103  U=0.742  z_cont=[10.4,12.9]
#   x: grad_norm=0.003948315046727657
#   y: grad_norm=0.006071539595723152
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 104  U=0.742  z_cont=[10.4,12.9]
#   x: grad_norm=0.003957738634198904
#   y: grad_norm=0.006086038425564766
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 105  U=0.743  z_cont=[10.4,12.9]
#   x: grad_norm=0.0039672162383794785
#   y: grad_norm=0.006100622937083244
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 106  U=0.743  z_cont=[10.4,12.9]
#   x: grad_norm=0.003976754378527403
#   y: grad_norm=0.006115295924246311
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 107  U=0.743  z_cont=[10.4,12.9]
#   x: grad_norm=0.003986279480159283
#   y: grad_norm=0.00612995307892561
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 108  U=0.744  z_cont=[10.4,12.9]
#   x: grad_norm=0.003995839972048998
#   y: grad_norm=0.006144664250314236
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 109  U=0.744  z_cont=[10.4,12.9]
#   x: grad_norm=0.0040054344572126865
#   y: grad_norm=0.00615942757576704
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 110  U=0.745  z_cont=[10.4,12.9]
#   x: grad_norm=0.004015082959085703
#   y: grad_norm=0.006174273323267698
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 111  U=0.745  z_cont=[10.4,12.9]
#   x: grad_norm=0.004024791996926069
#   y: grad_norm=0.006189212668687105
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 112  U=0.745  z_cont=[10.4,12.9]
#   x: grad_norm=0.004034528974443674
#   y: grad_norm=0.006204194389283657
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 113  U=0.746  z_cont=[10.4,12.9]
#   x: grad_norm=0.004044302273541689
#   y: grad_norm=0.006219233851879835
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 114  U=0.746  z_cont=[10.4,12.9]
#   x: grad_norm=0.004054136574268341
#   y: grad_norm=0.006234365981072187
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 115  U=0.747  z_cont=[10.4,12.9]
#   x: grad_norm=0.004063998814672232
#   y: grad_norm=0.006249539088457823
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 116  U=0.747  z_cont=[10.4,12.9]
#   x: grad_norm=0.0040739174000918865
#   y: grad_norm=0.006264801602810621
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 117  U=0.747  z_cont=[10.4,12.9]
#   x: grad_norm=0.0040838513523340225
#   y: grad_norm=0.006280088797211647
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 118  U=0.748  z_cont=[10.4,12.9]
#   x: grad_norm=0.004093827214092016
#   y: grad_norm=0.006295438855886459
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 119  U=0.748  z_cont=[10.4,12.9]
#   x: grad_norm=0.004103853367269039
#   y: grad_norm=0.006310867145657539
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 120  U=0.749  z_cont=[10.4,12.9]
#   x: grad_norm=0.00411390233784914
#   y: grad_norm=0.006326329428702593
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 121  U=0.749  z_cont=[10.4,12.9]
#   x: grad_norm=0.004124014172703028
#   y: grad_norm=0.006341888103634119
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 122  U=0.749  z_cont=[10.4,12.9]
#   x: grad_norm=0.004134161863476038
#   y: grad_norm=0.006357502657920122
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 123  U=0.750  z_cont=[10.4,12.9]
#   x: grad_norm=0.0041443402878940105
#   y: grad_norm=0.006373164709657431
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 124  U=0.750  z_cont=[10.4,12.9]
#   x: grad_norm=0.004154568538069725
#   y: grad_norm=0.0063889045268297195
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 125  U=0.751  z_cont=[10.4,12.9]
#   x: grad_norm=0.004164834041148424
#   y: grad_norm=0.006404699292033911
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 126  U=0.751  z_cont=[10.4,12.9]
#   x: grad_norm=0.004175164736807346
#   y: grad_norm=0.006420594174414873
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 127  U=0.751  z_cont=[10.4,12.9]
#   x: grad_norm=0.0041854847222566605
#   y: grad_norm=0.006436476018279791
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 128  U=0.752  z_cont=[10.4,12.9]
#   x: grad_norm=0.004195882938802242
#   y: grad_norm=0.00645247520878911
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 129  U=0.752  z_cont=[10.4,12.9]
#   x: grad_norm=0.004206305369734764
#   y: grad_norm=0.006468512583523989
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 130  U=0.753  z_cont=[10.4,12.9]
#   x: grad_norm=0.004216786008328199
#   y: grad_norm=0.006484639830887318
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 131  U=0.753  z_cont=[10.4,12.9]
#   x: grad_norm=0.004227339290082455
#   y: grad_norm=0.006500878371298313
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 132  U=0.754  z_cont=[10.4,12.9]
#   x: grad_norm=0.004237949848175049
#   y: grad_norm=0.006517206318676472
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 133  U=0.754  z_cont=[10.4,12.9]
#   x: grad_norm=0.004248586483299732
#   y: grad_norm=0.006533573381602764
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 134  U=0.754  z_cont=[10.4,12.9]
#   x: grad_norm=0.0042592622339725494
#   y: grad_norm=0.006550000514835119
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 135  U=0.755  z_cont=[10.4,12.9]
#   x: grad_norm=0.0042699831537902355
#   y: grad_norm=0.006566498428583145
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 136  U=0.755  z_cont=[10.4,12.9]
#   x: grad_norm=0.004277520813047886
#   y: grad_norm=0.006583055946975946
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 137  U=0.756  z_cont=[10.4,12.9]
#   x: grad_norm=0.004288319032639265
#   y: grad_norm=0.0065996842458844185
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 138  U=0.756  z_cont=[10.4,12.9]
#   x: grad_norm=0.004299151245504618
#   y: grad_norm=0.006616364233195782
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 139  U=0.757  z_cont=[10.4,12.9]
#   x: grad_norm=0.0043100351467728615
#   y: grad_norm=0.0066331252455711365
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 140  U=0.757  z_cont=[10.4,12.9]
#   x: grad_norm=0.004320946056395769
#   y: grad_norm=0.006649928167462349
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 141  U=0.757  z_cont=[10.4,12.9]
#   x: grad_norm=0.004331896547228098
#   y: grad_norm=0.006666791625320911
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 142  U=0.758  z_cont=[10.4,12.9]
#   x: grad_norm=0.0043429299257695675
#   y: grad_norm=0.0066837831400334835
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 143  U=0.758  z_cont=[10.4,12.9]
#   x: grad_norm=0.004353953525424004
#   y: grad_norm=0.006700760219246149
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 144  U=0.759  z_cont=[10.4,12.9]
#   x: grad_norm=0.004365095403045416
#   y: grad_norm=0.006717916578054428
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 145  U=0.759  z_cont=[10.4,12.9]
#   x: grad_norm=0.004376263823360205
#   y: grad_norm=0.0067351157777011395
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 146  U=0.760  z_cont=[10.4,12.9]
#   x: grad_norm=0.0043874941766262054
#   y: grad_norm=0.006752411834895611
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 147  U=0.760  z_cont=[10.4,12.9]
#   x: grad_norm=0.004398781340569258
#   y: grad_norm=0.0067697931081056595
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 148  U=0.761  z_cont=[10.4,12.9]
#   x: grad_norm=0.0044101024977862835
#   y: grad_norm=0.006787226069718599
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 149  U=0.761  z_cont=[10.4,12.9]
#   x: grad_norm=0.0044214725494384766
#   y: grad_norm=0.006804736331105232
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 150  U=0.762  z_cont=[10.4,12.9]
#   x: grad_norm=0.004432862624526024
#   y: grad_norm=0.006822278723120689
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 151  U=0.762  z_cont=[10.4,12.9]
#   x: grad_norm=0.004444317426532507
#   y: grad_norm=0.0068399193696677685
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 152  U=0.763  z_cont=[10.4,12.9]
#   x: grad_norm=0.004455814138054848
#   y: grad_norm=0.006857622880488634
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 153  U=0.763  z_cont=[10.4,12.9]
#   x: grad_norm=0.00446740398183465
#   y: grad_norm=0.006875470746308565
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 154  U=0.764  z_cont=[10.4,12.9]
#   x: grad_norm=0.0044790287502110004
#   y: grad_norm=0.006893374025821686
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 155  U=0.764  z_cont=[10.4,12.9]
#   x: grad_norm=0.004490719176828861
#   y: grad_norm=0.006911377422511578
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 156  U=0.765  z_cont=[10.4,12.9]
#   x: grad_norm=0.004502473399043083
#   y: grad_norm=0.006929478142410517
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 157  U=0.765  z_cont=[10.4,12.9]
#   x: grad_norm=0.004514272324740887
#   y: grad_norm=0.006947650108486414
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 158  U=0.765  z_cont=[10.4,12.9]
#   x: grad_norm=0.004526100587099791
#   y: grad_norm=0.006965863984078169
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 159  U=0.766  z_cont=[10.4,12.9]
#   x: grad_norm=0.004537974018603563
#   y: grad_norm=0.006984150968492031
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 160  U=0.766  z_cont=[10.4,12.9]
#   x: grad_norm=0.004549948498606682
#   y: grad_norm=0.007002591155469418
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 161  U=0.767  z_cont=[10.4,12.9]
#   x: grad_norm=0.004561960697174072
#   y: grad_norm=0.007021088618785143
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 162  U=0.767  z_cont=[10.4,12.9]
#   x: grad_norm=0.004574044141918421
#   y: grad_norm=0.007039697840809822
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 163  U=0.768  z_cont=[10.4,12.9]
#   x: grad_norm=0.00458618625998497
#   y: grad_norm=0.007058397866785526
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 164  U=0.768  z_cont=[10.4,12.9]
#   x: grad_norm=0.00459838705137372
#   y: grad_norm=0.007077186834067106
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 165  U=0.769  z_cont=[10.4,12.9]
#   x: grad_norm=0.004610603675246239
#   y: grad_norm=0.0070960004813969135
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 166  U=0.770  z_cont=[10.4,12.9]
#   x: grad_norm=0.004622890613973141
#   y: grad_norm=0.007114921696484089
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 167  U=0.770  z_cont=[10.4,12.9]
#   x: grad_norm=0.004635229706764221
#   y: grad_norm=0.007133925799280405
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 168  U=0.771  z_cont=[10.4,12.9]
#   x: grad_norm=0.004647625610232353
#   y: grad_norm=0.007153016049414873
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 169  U=0.771  z_cont=[10.4,12.9]
#   x: grad_norm=0.004660078324377537
#   y: grad_norm=0.0071721915155649185
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 170  U=0.772  z_cont=[10.4,12.9]
#   x: grad_norm=0.00467258645221591
#   y: grad_norm=0.00719145592302084
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 171  U=0.772  z_cont=[10.4,12.9]
#   x: grad_norm=0.004685159306973219
#   y: grad_norm=0.007210819516330957
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 172  U=0.773  z_cont=[10.4,12.9]
#   x: grad_norm=0.004697829019278288
#   y: grad_norm=0.007230331189930439
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 173  U=0.773  z_cont=[10.4,12.9]
#   x: grad_norm=0.004710540175437927
#   y: grad_norm=0.007249908521771431
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 174  U=0.774  z_cont=[10.4,12.9]
#   x: grad_norm=0.004723309073597193
#   y: grad_norm=0.0072695729322731495
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 175  U=0.774  z_cont=[10.4,12.9]
#   x: grad_norm=0.004736142233014107
#   y: grad_norm=0.007289336994290352
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 176  U=0.775  z_cont=[10.4,12.9]
#   x: grad_norm=0.004749059211462736
#   y: grad_norm=0.007309230510145426
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 177  U=0.775  z_cont=[10.4,12.9]
#   x: grad_norm=0.0047620246186852455
#   y: grad_norm=0.007329197600483894
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 178  U=0.776  z_cont=[10.4,12.9]
#   x: grad_norm=0.004775028210133314
#   y: grad_norm=0.007349722553044558
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 179  U=0.776  z_cont=[10.4,12.9]
#   x: grad_norm=0.004788123536854982
#   y: grad_norm=0.007369892671704292
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 180  U=0.777  z_cont=[10.4,12.9]
#   x: grad_norm=0.004801287315785885
#   y: grad_norm=0.007390167098492384
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 181  U=0.778  z_cont=[10.4,12.9]
#   x: grad_norm=0.00481448695063591
#   y: grad_norm=0.00741049787029624
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 182  U=0.778  z_cont=[10.4,12.9]
#   x: grad_norm=0.00482775317505002
#   y: grad_norm=0.007430931553244591
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 183  U=0.779  z_cont=[10.4,12.9]
#   x: grad_norm=0.004841180052608252
#   y: grad_norm=0.007455579005181789
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 184  U=0.779  z_cont=[10.4,12.9]
#   x: grad_norm=0.004854594822973013
#   y: grad_norm=0.007476251572370529
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 185  U=0.780  z_cont=[10.4,12.9]
#   x: grad_norm=0.0048681022599339485
#   y: grad_norm=0.007497068960219622
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 186  U=0.780  z_cont=[10.4,12.9]
#   x: grad_norm=0.004881666507571936
#   y: grad_norm=0.007517971098423004
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 187  U=0.781  z_cont=[10.4,12.9]
#   x: grad_norm=0.004895306192338467
#   y: grad_norm=0.007538989651948214
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 188  U=0.781  z_cont=[10.4,12.9]
#   x: grad_norm=0.004909006878733635
#   y: grad_norm=0.0075601027347147465
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 189  U=0.782  z_cont=[10.4,12.9]
#   x: grad_norm=0.004922764375805855
#   y: grad_norm=0.0075813038274645805
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 190  U=0.783  z_cont=[10.4,12.9]
#   x: grad_norm=0.004936616867780685
#   y: grad_norm=0.007602652534842491
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 191  U=0.783  z_cont=[10.4,12.9]
#   x: grad_norm=0.00495052570477128
#   y: grad_norm=0.007624085061252117
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 192  U=0.784  z_cont=[10.4,12.9]
#   x: grad_norm=0.004964492749422789
#   y: grad_norm=0.007645609322935343
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 193  U=0.784  z_cont=[10.4,12.9]
#   x: grad_norm=0.004978536162525415
#   y: grad_norm=0.007667251862585545
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 194  U=0.785  z_cont=[10.4,12.9]
#   x: grad_norm=0.004992674570530653
#   y: grad_norm=0.007689040619879961
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 195  U=0.786  z_cont=[10.4,12.9]
#   x: grad_norm=0.005006847903132439
#   y: grad_norm=0.007710882928222418
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 196  U=0.786  z_cont=[10.4,12.9]
#   x: grad_norm=0.005021086428314447
#   y: grad_norm=0.0077328248880803585
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 197  U=0.787  z_cont=[10.4,12.9]
#   x: grad_norm=0.005035435780882835
#   y: grad_norm=0.007754938211292028
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 198  U=0.787  z_cont=[10.4,12.9]
#   x: grad_norm=0.005049828439950943
#   y: grad_norm=0.007777119521051645
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 199  U=0.788  z_cont=[10.4,12.9]
#   x: grad_norm=0.005064322613179684
#   y: grad_norm=0.007799456361681223
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 200  U=0.789  z_cont=[10.4,12.9]
#   x: grad_norm=0.005078890360891819
#   y: grad_norm=0.007821906358003616
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# ...
# Epoch 1183  U=137.135  z_cont=[10.0,12.9]
#   x: grad_norm=0.07601361721754074
#   y: grad_norm=0.09704796969890594
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1184  U=121.868  z_cont=[10.0,12.9]
#   x: grad_norm=3.647489547729492
#   y: grad_norm=4.65703010559082
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1185  U=90.123  z_cont=[10.0,12.9]
#   x: grad_norm=4.239353656768799
#   y: grad_norm=5.4583210945129395
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1186  U=132.116  z_cont=[10.0,12.9]
#   x: grad_norm=2.266989231109619
#   y: grad_norm=2.894746780395508
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1187  U=128.761  z_cont=[10.0,12.9]
#   x: grad_norm=0.22718055546283722
#   y: grad_norm=0.2902243137359619
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1188  U=135.080  z_cont=[10.0,12.9]
#   x: grad_norm=0.6187595725059509
#   y: grad_norm=0.7904298305511475
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1189  U=117.525  z_cont=[10.0,12.9]
#   x: grad_norm=3.928199529647827
#   y: grad_norm=5.020354747772217
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1190  U=84.480  z_cont=[10.0,12.9]
#   x: grad_norm=3.672438144683838
#   y: grad_norm=4.698365688323975
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1191  U=131.338  z_cont=[10.0,12.9]
#   x: grad_norm=0.9521062970161438
#   y: grad_norm=1.2162673473358154
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1192  U=83.646  z_cont=[10.0,12.9]
#   x: grad_norm=4.039710998535156
#   y: grad_norm=5.167152404785156
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1193  U=124.752  z_cont=[10.0,12.9]
#   x: grad_norm=3.3820717334747314
#   y: grad_norm=4.319153308868408
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1194  U=135.544  z_cont=[10.0,12.9]
#   x: grad_norm=0.36788210272789
#   y: grad_norm=0.46991071105003357
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1195  U=129.241  z_cont=[10.0,12.9]
#   x: grad_norm=2.564171314239502
#   y: grad_norm=3.2758069038391113
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1196  U=131.863  z_cont=[10.0,12.9]
#   x: grad_norm=2.3209517002105713
#   y: grad_norm=2.9640257358551025
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1197  U=130.918  z_cont=[10.0,12.9]
#   x: grad_norm=0.9088591933250427
#   y: grad_norm=1.1610438823699951
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1198  U=104.791  z_cont=[10.0,12.9]
#   x: grad_norm=4.383507251739502
#   y: grad_norm=5.602699279785156
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1199  U=82.202  z_cont=[10.0,12.9]
#   x: grad_norm=3.5437071323394775
#   y: grad_norm=4.588860034942627
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1200  U=129.187  z_cont=[10.0,12.9]
#   x: grad_norm=0.4986553192138672
#   y: grad_norm=0.644213080406189
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1201  U=122.907  z_cont=[10.0,12.9]
#   x: grad_norm=3.452737808227539
#   y: grad_norm=4.4628214836120605
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1202  U=108.949  z_cont=[10.0,12.9]
#   x: grad_norm=4.183139801025391
#   y: grad_norm=5.400793552398682
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1203  U=114.579  z_cont=[10.0,12.9]
#   x: grad_norm=4.07941198348999
#   y: grad_norm=5.402444362640381
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1204  U=114.496  z_cont=[10.0,12.9]
#   x: grad_norm=4.047823905944824
#   y: grad_norm=5.227776050567627
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1205  U=117.397  z_cont=[10.0,12.9]
#   x: grad_norm=3.9187943935394287
#   y: grad_norm=5.0654120445251465
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1206  U=120.298  z_cont=[10.0,12.9]
#   x: grad_norm=3.7474477291107178
#   y: grad_norm=4.841084003448486
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1207  U=124.168  z_cont=[10.0,12.9]
#   x: grad_norm=3.3116157054901123
#   y: grad_norm=4.278406620025635
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1208  U=134.807  z_cont=[10.0,12.9]
#   x: grad_norm=1.5350028276443481
#   y: grad_norm=1.982820749282837
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1209  U=130.822  z_cont=[10.0,12.9]
#   x: grad_norm=0.9411697387695312
#   y: grad_norm=1.2160059213638306
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1210  U=136.349  z_cont=[10.0,12.9]
#   x: grad_norm=0.8746965527534485
#   y: grad_norm=1.1298787593841553
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1211  U=131.314  z_cont=[10.0,12.9]
#   x: grad_norm=1.0092440843582153
#   y: grad_norm=1.3039411306381226
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1212  U=133.669  z_cont=[10.0,12.9]
#   x: grad_norm=1.878987431526184
#   y: grad_norm=2.427159309387207
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1213  U=132.655  z_cont=[10.0,12.9]
#   x: grad_norm=0.9925366640090942
#   y: grad_norm=1.2823193073272705
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1214  U=90.420  z_cont=[10.0,12.9]
#   x: grad_norm=4.22980260848999
#   y: grad_norm=5.478427410125732
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1215  U=102.458  z_cont=[10.0,12.9]
#   x: grad_norm=4.1887054443359375
#   y: grad_norm=5.416562557220459
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1216  U=129.069  z_cont=[10.0,12.9]
#   x: grad_norm=2.583148956298828
#   y: grad_norm=3.340294361114502
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1217  U=132.681  z_cont=[10.0,12.9]
#   x: grad_norm=1.1114498376846313
#   y: grad_norm=1.437342882156372
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1218  U=90.159  z_cont=[10.0,12.9]
#   x: grad_norm=3.893620252609253
#   y: grad_norm=5.035032749176025
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1219  U=123.853  z_cont=[10.0,12.9]
#   x: grad_norm=3.346018075942993
#   y: grad_norm=4.326700210571289
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1220  U=136.774  z_cont=[10.0,12.9]
#   x: grad_norm=0.5855509638786316
#   y: grad_norm=0.757268488407135
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1221  U=135.351  z_cont=[10.0,12.9]
#   x: grad_norm=1.3369805812835693
#   y: grad_norm=1.7290738821029663
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1222  U=129.659  z_cont=[10.0,12.9]
#   x: grad_norm=0.6638027429580688
#   y: grad_norm=0.8584306240081787
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1223  U=127.025  z_cont=[10.0,12.9]
#   x: grad_norm=2.9254822731018066
#   y: grad_norm=3.7839317321777344
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1224  U=128.045  z_cont=[10.0,12.9]
#   x: grad_norm=2.9660627841949463
#   y: grad_norm=3.8350067138671875
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1225  U=135.676  z_cont=[10.0,12.9]
#   x: grad_norm=0.13332891464233398
#   y: grad_norm=0.17247262597084045
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1226  U=122.969  z_cont=[10.0,12.9]
#   x: grad_norm=3.442686080932617
#   y: grad_norm=4.452932834625244
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1227  U=97.836  z_cont=[10.0,12.9]
#   x: grad_norm=4.12005615234375
#   y: grad_norm=5.327508926391602
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1228  U=129.149  z_cont=[10.0,12.9]
#   x: grad_norm=2.5673210620880127
#   y: grad_norm=3.3207767009735107
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1229  U=132.129  z_cont=[10.0,12.9]
#   x: grad_norm=1.0837445259094238
#   y: grad_norm=1.4015724658966064
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1230  U=94.254  z_cont=[10.0,12.9]
#   x: grad_norm=4.030238628387451
#   y: grad_norm=5.211913108825684
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1231  U=112.346  z_cont=[10.0,12.9]
#   x: grad_norm=4.1782636642456055
#   y: grad_norm=5.407015800476074
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1232  U=118.758  z_cont=[10.0,12.9]
#   x: grad_norm=3.8425509929656982
#   y: grad_norm=4.968416213989258
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1233  U=122.869  z_cont=[10.0,12.9]
#   x: grad_norm=3.4529659748077393
#   y: grad_norm=4.4663825035095215
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1234  U=132.402  z_cont=[10.0,12.9]
#   x: grad_norm=2.190871477127075
#   y: grad_norm=2.8334755897521973
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1235  U=129.556  z_cont=[10.0,12.9]
#   x: grad_norm=0.6329893469810486
#   y: grad_norm=0.8186247944831848
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1236  U=127.372  z_cont=[10.0,12.9]
#   x: grad_norm=2.8715786933898926
#   y: grad_norm=3.71443510055542
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1237  U=129.790  z_cont=[10.0,12.9]
#   x: grad_norm=2.6975059509277344
#   y: grad_norm=3.4887492656707764
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1238  U=134.703  z_cont=[10.0,12.9]
#   x: grad_norm=0.742597222328186
#   y: grad_norm=0.9604593515396118
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1239  U=89.760  z_cont=[10.0,12.9]
#   x: grad_norm=4.297735691070557
#   y: grad_norm=5.5211639404296875
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1240  U=99.285  z_cont=[10.0,12.9]
#   x: grad_norm=4.246983051300049
#   y: grad_norm=5.51167631149292
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1241  U=130.583  z_cont=[10.0,12.9]
#   x: grad_norm=2.279043197631836
#   y: grad_norm=2.946531295776367
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1242  U=129.484  z_cont=[10.0,12.9]
#   x: grad_norm=0.6265396475791931
#   y: grad_norm=0.8093046545982361
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1243  U=131.971  z_cont=[10.0,12.9]
#   x: grad_norm=2.289644956588745
#   y: grad_norm=2.9559638500213623
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1244  U=135.537  z_cont=[10.0,12.9]
#   x: grad_norm=0.338332861661911
#   y: grad_norm=0.43739616870880127
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1245  U=106.000  z_cont=[10.0,12.9]
#   x: grad_norm=4.3502116203308105
#   y: grad_norm=5.62562370300293
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1246  U=74.877  z_cont=[10.1,12.9]
#   x: grad_norm=3.142995834350586
#   y: grad_norm=4.0181145668029785
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1247  U=133.230  z_cont=[10.0,12.9]
#   x: grad_norm=1.126784324645996
#   y: grad_norm=1.4425140619277954
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1248  U=136.131  z_cont=[10.0,12.9]
#   x: grad_norm=0.997745156288147
#   y: grad_norm=1.2773512601852417
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# Epoch 1249  U=129.654  z_cont=[10.0,12.9]
#   x: grad_norm=0.685384213924408
#   y: grad_norm=0.8774421811103821
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt
# CPU times: user 1min 20s, sys: 4.63 s, total: 1min 24s
# Wall time: 3min 21s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='1e2 U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='1e2 U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='1e8 U_E',    lw=1)
plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_37_10_shower_center_init_phi_error/cashed_showers_10.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_lb.detach().cpu().max()], [0, E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
