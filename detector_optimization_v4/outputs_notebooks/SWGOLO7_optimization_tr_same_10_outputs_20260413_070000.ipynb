# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_35_10_shower"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generate_new_data = True
print("device:", device)
# Out:
# device: cuda

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 10 # 200000
Nvalidation = 10 # 20000
Ntest       = 10 # 3000
Nbatch      = 10 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="grid")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
use_cache = True
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=3.19  max=19.97  mean=10.93

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
#   Loading PointCountFM from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/num_of_point_clouds_dequantize_compiled.pt ...
#   Loaded in 847.1 ms
#   Running inference on 10 samples ...
#   Inference done in 0.83 s
#   Mean total hits predicted per shower: 1994.9
#   Loading AllShowers generator from /n/home05/zdimitrov/tambo/TAMBO-opt/allshowers/checkpoints/all_showers ...
#   Loaded in 0.09 s
#   Time mode: ON (x,y,e,t)
#   Generating 10 showers (16 ODE steps, solver=midpoint, device=cuda) ...
# [     0s]: start batch   0
# [    15s]: generation done
#   Generation done in 14.93 s
# samples shape: torch.Size([10, 2048, 5])
#   Saved 10 showers → ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-413 m  shift=+3217 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([ -398.7780, -2160.6218,  5279.1108,  1926.2769,  4902.3086, -3752.8149,
#          2401.2869,   960.8806, -4381.3589, -2374.9990], device='cuda:0')
# Y0: tensor([ 4586.1670,  4952.5322,   459.1760, -1293.0955, -2440.6335,  2062.0537,
#          4049.7305,  5647.6025,  2776.4353,  4311.6387], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 209611.703, energy.max(): 62013936.000
# theta.min():  70.1°, theta.max():  92.9°
# phi.min():    -178.2°, phi.max():    162.4°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# CPU times: user 12.4 ms, sys: 7.72 ms, total: 20.1 ms
# Wall time: 67.1 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# CPU times: user 6.96 ms, sys: 2.8 ms, total: 9.76 ms
# Wall time: 53.6 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([10, 90, 5])   labels: torch.Size([10, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0775
# Training 20%  val_loss=0.0413
# Training 30%  val_loss=0.0295
# Training 40%  val_loss=0.0231
# Training 50%  val_loss=0.0194
# Training 60%  val_loss=0.0169
# Training 70%  val_loss=0.0147
# Training 80%  val_loss=0.0130
# CPU times: user 3.92 s, sys: 89 ms, total: 4.01 s
# Wall time: 4.19 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
optimizer = torch.optim.SGD(xy_module.parameters(), lr=0.5, momentum=.3)

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + 1000):

    if epoch < 20:
        Nfinetune = 10 # 3000
    else:
        Nfinetune = 10 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        1e2 * U_angle(preds_th,  th, r_score) +
        1e2 * U_angle(preds_phi, ph, r_score) +
        1e8 * U_E(preds_e, energy, r_score)   +
        5e5 * U_PR(r_score)
    ) / 1e3

    U_vals.append(U.item())
    U_th_vals.append( (1e2 * U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( (1e2 * U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   (1e8 * U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  (5e5 * U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=True, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 0  U=2409.693  z_cont=[3.2,20.0]
#   x: grad_norm=44.292755126953125
#   y: grad_norm=84.53333282470703
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 1  U=2138.583  z_cont=[3.2,19.8]
#   x: grad_norm=8.651129722595215
#   y: grad_norm=25.516254425048828
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 2  U=2129.512  z_cont=[3.2,19.5]
#   x: grad_norm=8.007885932922363
#   y: grad_norm=18.648191452026367
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 3  U=2209.704  z_cont=[3.2,19.4]
#   x: grad_norm=4.9983439445495605
#   y: grad_norm=24.335744857788086
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 4  U=2101.352  z_cont=[3.2,19.2]
#   x: grad_norm=3.8028948307037354
#   y: grad_norm=13.197030067443848
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 5  U=2126.341  z_cont=[3.2,19.1]
#   x: grad_norm=3.9116833209991455
#   y: grad_norm=13.554612159729004
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 6  U=2100.613  z_cont=[3.2,18.9]
#   x: grad_norm=3.6214306354522705
#   y: grad_norm=12.0000581741333
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 7  U=2147.094  z_cont=[3.2,18.7]
#   x: grad_norm=2.287440061569214
#   y: grad_norm=6.838354110717773
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 8  U=2147.414  z_cont=[3.2,18.4]
#   x: grad_norm=3.2978546619415283
#   y: grad_norm=11.45450496673584
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 9  U=2117.025  z_cont=[3.2,18.4]
#   x: grad_norm=3.9883944988250732
#   y: grad_norm=13.643887519836426
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 10  U=2159.988  z_cont=[3.2,18.4]
#   x: grad_norm=3.511385440826416
#   y: grad_norm=12.121699333190918
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 11  U=2141.372  z_cont=[3.2,18.4]
#   x: grad_norm=4.526106834411621
#   y: grad_norm=14.97018051147461
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 12  U=2146.900  z_cont=[3.2,18.4]
#   x: grad_norm=3.945246696472168
#   y: grad_norm=13.379711151123047
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 13  U=2173.485  z_cont=[3.2,18.4]
#   x: grad_norm=4.233564376831055
#   y: grad_norm=13.723167419433594
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 14  U=2147.158  z_cont=[3.2,18.4]
#   x: grad_norm=3.545004367828369
#   y: grad_norm=12.0118989944458
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 15  U=2191.651  z_cont=[3.2,18.4]
#   x: grad_norm=2.0520927906036377
#   y: grad_norm=6.002551555633545
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 16  U=2190.317  z_cont=[3.2,18.4]
#   x: grad_norm=2.836127758026123
#   y: grad_norm=9.694902420043945
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 17  U=2158.549  z_cont=[3.2,18.4]
#   x: grad_norm=4.143768787384033
#   y: grad_norm=13.9785737991333
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 18  U=2175.163  z_cont=[3.2,18.4]
#   x: grad_norm=4.143848419189453
#   y: grad_norm=14.123533248901367
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 19  U=2167.371  z_cont=[3.2,18.4]
#   x: grad_norm=4.145809173583984
#   y: grad_norm=14.644965171813965
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 20  U=2173.138  z_cont=[3.2,18.4]
#   x: grad_norm=4.108246803283691
#   y: grad_norm=13.896937370300293
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 21  U=2177.820  z_cont=[3.2,18.4]
#   x: grad_norm=4.299899578094482
#   y: grad_norm=15.43165111541748
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 22  U=2163.402  z_cont=[3.2,18.4]
#   x: grad_norm=3.4484524726867676
#   y: grad_norm=12.833642959594727
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 23  U=2202.431  z_cont=[3.2,18.4]
#   x: grad_norm=2.523486614227295
#   y: grad_norm=8.397369384765625
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 24  U=2190.765  z_cont=[3.2,18.4]
#   x: grad_norm=3.9974730014801025
#   y: grad_norm=13.549084663391113
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 25  U=2159.996  z_cont=[3.2,18.4]
#   x: grad_norm=3.14208722114563
#   y: grad_norm=11.977306365966797
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 26  U=2209.698  z_cont=[3.2,18.4]
#   x: grad_norm=0.6711274981498718
#   y: grad_norm=1.8446637392044067
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 27  U=2208.524  z_cont=[3.2,18.4]
#   x: grad_norm=1.8279203176498413
#   y: grad_norm=6.522034168243408
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 28  U=2187.406  z_cont=[3.2,18.4]
#   x: grad_norm=3.993048906326294
#   y: grad_norm=14.883284568786621
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 29  U=2164.705  z_cont=[3.2,18.4]
#   x: grad_norm=3.3263320922851562
#   y: grad_norm=11.421106338500977
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 30  U=2257.211  z_cont=[3.2,18.4]
#   x: grad_norm=4.324489593505859
#   y: grad_norm=7.283125400543213
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 31  U=2249.401  z_cont=[3.2,18.4]
#   x: grad_norm=7.773527145385742
#   y: grad_norm=26.433452606201172
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 32  U=2159.758  z_cont=[3.2,18.4]
#   x: grad_norm=3.395949602127075
#   y: grad_norm=11.683531761169434
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 33  U=2204.156  z_cont=[3.2,18.4]
#   x: grad_norm=0.6028885841369629
#   y: grad_norm=1.8374239206314087
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 34  U=2191.427  z_cont=[3.2,18.4]
#   x: grad_norm=3.654573440551758
#   y: grad_norm=13.097147941589355
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 35  U=2155.292  z_cont=[3.2,18.4]
#   x: grad_norm=2.992441415786743
#   y: grad_norm=11.487907409667969
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 36  U=2205.775  z_cont=[3.2,18.4]
#   x: grad_norm=1.1125009059906006
#   y: grad_norm=4.191888809204102
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 37  U=2177.927  z_cont=[3.2,18.4]
#   x: grad_norm=3.959970474243164
#   y: grad_norm=14.743370056152344
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 38  U=2167.130  z_cont=[3.2,18.4]
#   x: grad_norm=3.667778491973877
#   y: grad_norm=12.613070487976074
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 39  U=2206.764  z_cont=[3.2,18.4]
#   x: grad_norm=2.0367789268493652
#   y: grad_norm=7.00355339050293
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 40  U=2201.024  z_cont=[3.2,18.4]
#   x: grad_norm=3.0334177017211914
#   y: grad_norm=11.406715393066406
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 41  U=2168.817  z_cont=[3.2,18.4]
#   x: grad_norm=3.472604274749756
#   y: grad_norm=13.137295722961426
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 42  U=2202.511  z_cont=[3.2,18.4]
#   x: grad_norm=3.054865837097168
#   y: grad_norm=11.43233585357666
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 43  U=2183.106  z_cont=[3.2,18.4]
#   x: grad_norm=3.9425268173217773
#   y: grad_norm=14.67031478881836
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 44  U=2176.811  z_cont=[3.2,18.4]
#   x: grad_norm=3.7069289684295654
#   y: grad_norm=13.308587074279785
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 45  U=2203.024  z_cont=[3.2,18.4]
#   x: grad_norm=3.4351606369018555
#   y: grad_norm=12.345537185668945
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 46  U=2179.587  z_cont=[3.2,18.4]
#   x: grad_norm=3.538830518722534
#   y: grad_norm=13.488189697265625
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 47  U=2195.759  z_cont=[3.2,18.4]
#   x: grad_norm=3.9135468006134033
#   y: grad_norm=14.449997901916504
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 48  U=2175.942  z_cont=[3.2,18.4]
#   x: grad_norm=3.597440242767334
#   y: grad_norm=12.843875885009766
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 49  U=2208.722  z_cont=[3.2,18.4]
#   x: grad_norm=2.8770828247070312
#   y: grad_norm=10.284561157226562
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 50  U=2191.676  z_cont=[3.2,18.4]
#   x: grad_norm=3.69189453125
#   y: grad_norm=14.187236785888672
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 51  U=2176.642  z_cont=[3.2,18.4]
#   x: grad_norm=3.591402292251587
#   y: grad_norm=13.493910789489746
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 52  U=2206.217  z_cont=[3.2,18.4]
#   x: grad_norm=3.3085684776306152
#   y: grad_norm=11.557825088500977
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 53  U=2186.784  z_cont=[3.2,18.4]
#   x: grad_norm=3.9142043590545654
#   y: grad_norm=14.596060752868652
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 54  U=2182.350  z_cont=[3.2,18.4]
#   x: grad_norm=3.540736675262451
#   y: grad_norm=13.459029197692871
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 55  U=2203.785  z_cont=[3.2,18.4]
#   x: grad_norm=3.6105268001556396
#   y: grad_norm=13.076375961303711
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 56  U=2180.359  z_cont=[3.2,18.4]
#   x: grad_norm=3.689436435699463
#   y: grad_norm=13.187826156616211
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 57  U=2203.877  z_cont=[3.2,18.4]
#   x: grad_norm=3.614983081817627
#   y: grad_norm=13.10184097290039
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 58  U=2181.301  z_cont=[3.2,18.4]
#   x: grad_norm=3.7075350284576416
#   y: grad_norm=13.28107738494873
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 59  U=2202.531  z_cont=[3.2,18.4]
#   x: grad_norm=3.7077739238739014
#   y: grad_norm=13.451069831848145
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 60  U=2180.856  z_cont=[3.2,18.4]
#   x: grad_norm=3.6868274211883545
#   y: grad_norm=13.182498931884766
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 61  U=2204.747  z_cont=[3.2,18.4]
#   x: grad_norm=3.5762553215026855
#   y: grad_norm=12.923307418823242
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 62  U=2182.353  z_cont=[3.2,18.4]
#   x: grad_norm=3.507841110229492
#   y: grad_norm=13.327247619628906
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 63  U=2202.013  z_cont=[3.2,18.4]
#   x: grad_norm=3.748476028442383
#   y: grad_norm=13.61931037902832
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 64  U=2181.023  z_cont=[3.2,18.4]
#   x: grad_norm=3.68109393119812
#   y: grad_norm=13.157044410705566
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 65  U=2205.829  z_cont=[3.2,18.4]
#   x: grad_norm=3.3976380825042725
#   y: grad_norm=12.309948921203613
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 66  U=2186.310  z_cont=[3.2,18.4]
#   x: grad_norm=3.8546276092529297
#   y: grad_norm=13.761883735656738
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 67  U=2193.505  z_cont=[3.2,18.4]
#   x: grad_norm=3.963890790939331
#   y: grad_norm=14.696735382080078
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 68  U=2183.633  z_cont=[3.2,18.4]
#   x: grad_norm=3.5449318885803223
#   y: grad_norm=13.408260345458984
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 69  U=2204.565  z_cont=[3.2,18.4]
#   x: grad_norm=3.6297004222869873
#   y: grad_norm=13.137578964233398
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 70  U=2182.400  z_cont=[3.2,18.4]
#   x: grad_norm=3.7159926891326904
#   y: grad_norm=13.255118370056152
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 71  U=2204.352  z_cont=[3.2,18.4]
#   x: grad_norm=3.657059907913208
#   y: grad_norm=13.241856575012207
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 72  U=2183.061  z_cont=[3.2,18.4]
#   x: grad_norm=3.7320563793182373
#   y: grad_norm=13.299774169921875
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 73  U=2204.067  z_cont=[3.2,18.4]
#   x: grad_norm=3.902966260910034
#   y: grad_norm=13.147028923034668
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 74  U=2184.481  z_cont=[3.2,18.4]
#   x: grad_norm=3.7640655040740967
#   y: grad_norm=13.43968391418457
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 75  U=2202.950  z_cont=[3.2,18.4]
#   x: grad_norm=3.786444664001465
#   y: grad_norm=13.813105583190918
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 76  U=2180.558  z_cont=[3.2,18.4]
#   x: grad_norm=3.716628313064575
#   y: grad_norm=13.183216094970703
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 77  U=2204.753  z_cont=[3.2,18.4]
#   x: grad_norm=3.5675318241119385
#   y: grad_norm=12.12895393371582
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 78  U=2186.774  z_cont=[3.2,18.4]
#   x: grad_norm=3.8817834854125977
#   y: grad_norm=13.855903625488281
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 79  U=2190.471  z_cont=[3.2,18.4]
#   x: grad_norm=3.947190523147583
#   y: grad_norm=14.695456504821777
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 80  U=2185.380  z_cont=[3.2,18.4]
#   x: grad_norm=3.8484890460968018
#   y: grad_norm=13.704163551330566
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 81  U=2198.490  z_cont=[3.2,18.4]
#   x: grad_norm=4.083024501800537
#   y: grad_norm=13.797553062438965
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 82  U=2182.238  z_cont=[3.2,18.4]
#   x: grad_norm=3.7595787048339844
#   y: grad_norm=13.336697578430176
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 83  U=2203.406  z_cont=[3.2,18.4]
#   x: grad_norm=3.8508622646331787
#   y: grad_norm=12.980414390563965
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 84  U=2183.191  z_cont=[3.2,18.4]
#   x: grad_norm=3.979595184326172
#   y: grad_norm=13.48470687866211
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 85  U=2199.752  z_cont=[3.2,18.4]
#   x: grad_norm=4.043649196624756
#   y: grad_norm=13.688335418701172
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 86  U=2182.959  z_cont=[3.2,18.4]
#   x: grad_norm=3.960233211517334
#   y: grad_norm=13.431656837463379
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 87  U=2201.941  z_cont=[3.2,18.4]
#   x: grad_norm=3.952054500579834
#   y: grad_norm=13.339576721191406
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 88  U=2183.125  z_cont=[3.2,18.4]
#   x: grad_norm=3.7674005031585693
#   y: grad_norm=13.389460563659668
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 89  U=2202.132  z_cont=[3.2,18.4]
#   x: grad_norm=3.9471075534820557
#   y: grad_norm=13.341791152954102
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 90  U=2183.200  z_cont=[3.2,18.4]
#   x: grad_norm=4.199743270874023
#   y: grad_norm=12.82246208190918
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 91  U=2205.321  z_cont=[3.2,18.4]
#   x: grad_norm=3.6007320880889893
#   y: grad_norm=12.202253341674805
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 92  U=2187.306  z_cont=[3.2,18.4]
#   x: grad_norm=3.651057720184326
#   y: grad_norm=13.734090805053711
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 93  U=2193.794  z_cont=[3.2,18.4]
#   x: grad_norm=4.180923938751221
#   y: grad_norm=14.39919376373291
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 94  U=2185.490  z_cont=[3.2,18.4]
#   x: grad_norm=3.8286995887756348
#   y: grad_norm=13.594758987426758
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 95  U=2201.024  z_cont=[3.2,18.4]
#   x: grad_norm=4.017295837402344
#   y: grad_norm=13.584957122802734
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 96  U=2183.309  z_cont=[3.2,18.4]
#   x: grad_norm=3.951444387435913
#   y: grad_norm=13.37207317352295
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 97  U=2203.424  z_cont=[3.2,18.4]
#   x: grad_norm=3.7481436729431152
#   y: grad_norm=12.786954879760742
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 98  U=2187.031  z_cont=[3.2,18.4]
#   x: grad_norm=4.110441207885742
#   y: grad_norm=13.07902717590332
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 99  U=2199.884  z_cont=[3.2,18.4]
#   x: grad_norm=4.073233127593994
#   y: grad_norm=13.728984832763672
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 100  U=2183.764  z_cont=[3.2,18.4]
#   x: grad_norm=3.5401175022125244
#   y: grad_norm=13.295554161071777
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 101  U=2205.637  z_cont=[3.2,18.4]
#   x: grad_norm=4.89866828918457
#   y: grad_norm=65.03041076660156
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 102  U=2225.940  z_cont=[3.2,18.4]
#   x: grad_norm=4.130720138549805
#   y: grad_norm=13.97551441192627
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 103  U=2161.953  z_cont=[3.2,18.4]
#   x: grad_norm=3.9431965351104736
#   y: grad_norm=14.530999183654785
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 104  U=2170.242  z_cont=[3.2,18.3]
#   x: grad_norm=4.451969623565674
#   y: grad_norm=14.045838356018066
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 105  U=2170.690  z_cont=[3.2,18.3]
#   x: grad_norm=3.8569705486297607
#   y: grad_norm=14.136011123657227
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 106  U=2182.759  z_cont=[3.2,18.3]
#   x: grad_norm=4.07016134262085
#   y: grad_norm=15.007424354553223
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 107  U=2174.696  z_cont=[3.2,18.3]
#   x: grad_norm=3.7703866958618164
#   y: grad_norm=13.885467529296875
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 108  U=2198.905  z_cont=[3.2,18.3]
#   x: grad_norm=3.9098846912384033
#   y: grad_norm=13.107173919677734
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 109  U=2183.410  z_cont=[3.2,18.3]
#   x: grad_norm=3.8163607120513916
#   y: grad_norm=13.048633575439453
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 110  U=2203.000  z_cont=[3.2,18.3]
#   x: grad_norm=4.005495548248291
#   y: grad_norm=13.049799919128418
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 111  U=2185.156  z_cont=[3.2,18.3]
#   x: grad_norm=3.8037192821502686
#   y: grad_norm=12.938844680786133
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 112  U=2205.296  z_cont=[3.2,18.3]
#   x: grad_norm=3.8942182064056396
#   y: grad_norm=12.762109756469727
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 113  U=2186.273  z_cont=[3.2,18.3]
#   x: grad_norm=3.8435781002044678
#   y: grad_norm=12.94826889038086
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 114  U=2204.047  z_cont=[3.2,18.3]
#   x: grad_norm=3.40242338180542
#   y: grad_norm=13.55107307434082
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 115  U=2184.059  z_cont=[3.2,18.3]
#   x: grad_norm=3.9717323780059814
#   y: grad_norm=12.800928115844727
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 116  U=2208.518  z_cont=[3.2,18.3]
#   x: grad_norm=3.6996243000030518
#   y: grad_norm=12.37082290649414
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 117  U=2186.339  z_cont=[3.2,18.3]
#   x: grad_norm=4.044369697570801
#   y: grad_norm=13.065672874450684
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 118  U=2202.919  z_cont=[3.2,18.3]
#   x: grad_norm=4.024994850158691
#   y: grad_norm=13.288141250610352
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 119  U=2186.851  z_cont=[3.2,18.3]
#   x: grad_norm=4.055779457092285
#   y: grad_norm=13.10696029663086
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 120  U=2204.110  z_cont=[3.2,18.3]
#   x: grad_norm=3.9806318283081055
#   y: grad_norm=13.150274276733398
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 121  U=2186.570  z_cont=[3.2,18.3]
#   x: grad_norm=4.041247844696045
#   y: grad_norm=13.063774108886719
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 122  U=2204.848  z_cont=[3.2,18.3]
#   x: grad_norm=3.952059030532837
#   y: grad_norm=13.05783462524414
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 123  U=2186.773  z_cont=[3.2,18.3]
#   x: grad_norm=4.042827606201172
#   y: grad_norm=13.069600105285645
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 124  U=2204.731  z_cont=[3.2,18.3]
#   x: grad_norm=3.9650912284851074
#   y: grad_norm=13.093326568603516
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 125  U=2187.009  z_cont=[3.2,18.3]
#   x: grad_norm=4.045495986938477
#   y: grad_norm=13.079452514648438
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 126  U=2204.793  z_cont=[3.2,18.3]
#   x: grad_norm=3.969114065170288
#   y: grad_norm=13.10050106048584
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 127  U=2187.206  z_cont=[3.2,18.3]
#   x: grad_norm=4.04703950881958
#   y: grad_norm=13.08359146118164
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 128  U=2204.890  z_cont=[3.2,18.3]
#   x: grad_norm=3.9714486598968506
#   y: grad_norm=13.102048873901367
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 129  U=2187.408  z_cont=[3.2,18.3]
#   x: grad_norm=4.0488481521606445
#   y: grad_norm=13.088980674743652
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 130  U=2204.958  z_cont=[3.2,18.3]
#   x: grad_norm=3.975069522857666
#   y: grad_norm=13.107246398925781
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 131  U=2187.610  z_cont=[3.2,18.3]
#   x: grad_norm=4.050607204437256
#   y: grad_norm=13.09471607208252
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 132  U=2205.027  z_cont=[3.2,18.3]
#   x: grad_norm=3.97861909866333
#   y: grad_norm=13.111808776855469
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 133  U=2187.819  z_cont=[3.2,18.3]
#   x: grad_norm=4.052807331085205
#   y: grad_norm=13.099632263183594
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 134  U=2205.093  z_cont=[3.2,18.3]
#   x: grad_norm=3.98224139213562
#   y: grad_norm=13.116433143615723
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 135  U=2188.028  z_cont=[3.2,18.3]
#   x: grad_norm=4.054943561553955
#   y: grad_norm=13.105591773986816
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 136  U=2205.154  z_cont=[3.2,18.3]
#   x: grad_norm=3.9860546588897705
#   y: grad_norm=13.121261596679688
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 137  U=2188.241  z_cont=[3.2,18.3]
#   x: grad_norm=4.057382106781006
#   y: grad_norm=13.111141204833984
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 138  U=2205.207  z_cont=[3.2,18.3]
#   x: grad_norm=3.990182399749756
#   y: grad_norm=13.12671947479248
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 139  U=2188.453  z_cont=[3.2,18.3]
#   x: grad_norm=4.059791564941406
#   y: grad_norm=13.115897178649902
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 140  U=2205.267  z_cont=[3.2,18.3]
#   x: grad_norm=3.9939005374908447
#   y: grad_norm=13.130687713623047
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 141  U=2188.664  z_cont=[3.2,18.3]
#   x: grad_norm=4.06221342086792
#   y: grad_norm=13.121190071105957
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 142  U=2205.325  z_cont=[3.2,18.3]
#   x: grad_norm=3.965224504470825
#   y: grad_norm=13.151137351989746
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 143  U=2188.855  z_cont=[3.2,18.3]
#   x: grad_norm=4.273821830749512
#   y: grad_norm=13.157550811767578
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 144  U=2204.854  z_cont=[3.2,18.3]
#   x: grad_norm=3.9896931648254395
#   y: grad_norm=13.248988151550293
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 145  U=2189.275  z_cont=[3.2,18.3]
#   x: grad_norm=4.276255130767822
#   y: grad_norm=13.213248252868652
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 146  U=2204.670  z_cont=[3.2,18.3]
#   x: grad_norm=4.000725269317627
#   y: grad_norm=13.314066886901855
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 147  U=2189.529  z_cont=[3.2,18.4]
#   x: grad_norm=4.272596836090088
#   y: grad_norm=13.2548828125
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 148  U=2204.724  z_cont=[3.2,18.3]
#   x: grad_norm=4.0025858879089355
#   y: grad_norm=13.350874900817871
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 149  U=2189.723  z_cont=[3.2,18.4]
#   x: grad_norm=4.2676496505737305
#   y: grad_norm=13.291027069091797
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 150  U=2204.605  z_cont=[3.2,18.3]
#   x: grad_norm=4.257675647735596
#   y: grad_norm=12.782488822937012
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 151  U=2194.470  z_cont=[3.2,18.4]
#   x: grad_norm=4.798342227935791
#   y: grad_norm=25.153295516967773
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 152  U=2178.141  z_cont=[3.2,18.4]
#   x: grad_norm=3.2837629318237305
#   y: grad_norm=12.038298606872559
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 153  U=2212.864  z_cont=[3.2,18.4]
#   x: grad_norm=3.5476531982421875
#   y: grad_norm=12.040548324584961
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 154  U=2174.091  z_cont=[3.2,18.4]
#   x: grad_norm=3.0426318645477295
#   y: grad_norm=11.190340995788574
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 155  U=2221.008  z_cont=[3.2,18.4]
#   x: grad_norm=1.6259253025054932
#   y: grad_norm=5.861569404602051
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 156  U=2214.439  z_cont=[3.2,18.4]
#   x: grad_norm=2.896489143371582
#   y: grad_norm=10.705248832702637
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 157  U=2165.390  z_cont=[3.2,18.4]
#   x: grad_norm=3.843965768814087
#   y: grad_norm=11.962207794189453
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 158  U=2218.401  z_cont=[3.2,18.4]
#   x: grad_norm=1.871507167816162
#   y: grad_norm=7.109551429748535
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 159  U=2204.652  z_cont=[3.2,18.4]
#   x: grad_norm=4.48682165145874
#   y: grad_norm=15.806659698486328
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 160  U=2158.210  z_cont=[3.2,18.4]
#   x: grad_norm=1.5379984378814697
#   y: grad_norm=7.046084403991699
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 161  U=2170.062  z_cont=[3.2,18.4]
#   x: grad_norm=2.120321750640869
#   y: grad_norm=9.7603120803833
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 162  U=2217.995  z_cont=[3.2,18.5]
#   x: grad_norm=2.645101308822632
#   y: grad_norm=9.170856475830078
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 163  U=2199.002  z_cont=[3.2,18.4]
#   x: grad_norm=2.855245590209961
#   y: grad_norm=13.449952125549316
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 164  U=2177.093  z_cont=[3.2,18.5]
#   x: grad_norm=3.8923041820526123
#   y: grad_norm=14.216958999633789
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 165  U=2205.746  z_cont=[3.2,18.4]
#   x: grad_norm=2.730358362197876
#   y: grad_norm=13.055834770202637
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 166  U=2187.814  z_cont=[3.2,18.5]
#   x: grad_norm=3.4738423824310303
#   y: grad_norm=15.42823600769043
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 167  U=2187.706  z_cont=[3.2,18.4]
#   x: grad_norm=2.723402500152588
#   y: grad_norm=12.843120574951172
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 168  U=2215.720  z_cont=[3.2,18.5]
#   x: grad_norm=2.2635371685028076
#   y: grad_norm=10.283455848693848
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 169  U=2198.705  z_cont=[3.2,18.5]
#   x: grad_norm=2.8560233116149902
#   y: grad_norm=13.622715950012207
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 170  U=2186.863  z_cont=[3.2,18.5]
#   x: grad_norm=3.401397705078125
#   y: grad_norm=15.321824073791504
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 171  U=2195.122  z_cont=[3.2,18.5]
#   x: grad_norm=2.8382651805877686
#   y: grad_norm=13.531158447265625
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 172  U=2204.644  z_cont=[3.2,18.5]
#   x: grad_norm=2.919092893600464
#   y: grad_norm=13.786589622497559
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 173  U=2189.550  z_cont=[3.2,18.5]
#   x: grad_norm=2.744415760040283
#   y: grad_norm=13.034008026123047
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 174  U=2211.866  z_cont=[3.2,18.5]
#   x: grad_norm=2.6306533813476562
#   y: grad_norm=12.327810287475586
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 175  U=2192.604  z_cont=[3.2,18.5]
#   x: grad_norm=2.532517671585083
#   y: grad_norm=13.884135246276855
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 176  U=2200.581  z_cont=[3.2,18.6]
#   x: grad_norm=2.303609609603882
#   y: grad_norm=14.98083209991455
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 177  U=2189.149  z_cont=[3.2,18.5]
#   x: grad_norm=2.7276854515075684
#   y: grad_norm=12.97524356842041
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 178  U=2214.735  z_cont=[3.2,18.6]
#   x: grad_norm=2.445568323135376
#   y: grad_norm=11.370538711547852
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 179  U=2196.442  z_cont=[3.2,18.6]
#   x: grad_norm=2.837646245956421
#   y: grad_norm=13.592378616333008
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 180  U=2197.412  z_cont=[3.2,18.7]
#   x: grad_norm=2.999850273132324
#   y: grad_norm=14.498191833496094
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 181  U=2195.693  z_cont=[3.2,18.6]
#   x: grad_norm=2.825620412826538
#   y: grad_norm=13.54086685180664
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 182  U=2205.208  z_cont=[3.2,18.7]
#   x: grad_norm=2.9191629886627197
#   y: grad_norm=13.857175827026367
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 183  U=2191.655  z_cont=[3.2,18.7]
#   x: grad_norm=2.7650206089019775
#   y: grad_norm=13.187726974487305
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 184  U=2211.505  z_cont=[3.2,18.7]
#   x: grad_norm=2.697833299636841
#   y: grad_norm=12.72679615020752
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 185  U=2193.099  z_cont=[3.2,18.7]
#   x: grad_norm=2.9802842140197754
#   y: grad_norm=12.442681312561035
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 186  U=2212.728  z_cont=[3.2,18.8]
#   x: grad_norm=2.7512035369873047
#   y: grad_norm=13.401754379272461
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 187  U=2193.902  z_cont=[3.2,18.7]
#   x: grad_norm=2.8055717945098877
#   y: grad_norm=13.362316131591797
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 188  U=2206.153  z_cont=[3.2,18.8]
#   x: grad_norm=2.9267232418060303
#   y: grad_norm=14.082672119140625
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 189  U=2191.312  z_cont=[3.2,18.8]
#   x: grad_norm=2.7526021003723145
#   y: grad_norm=13.08463191986084
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 190  U=2214.039  z_cont=[3.2,18.9]
#   x: grad_norm=2.5630879402160645
#   y: grad_norm=12.04057788848877
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 191  U=2196.196  z_cont=[3.2,18.8]
#   x: grad_norm=3.022146701812744
#   y: grad_norm=12.620744705200195
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 192  U=2208.644  z_cont=[3.2,18.9]
#   x: grad_norm=2.8419973850250244
#   y: grad_norm=13.433271408081055
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 193  U=2193.119  z_cont=[3.2,18.9]
#   x: grad_norm=2.781222105026245
#   y: grad_norm=13.214153289794922
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 194  U=2211.499  z_cont=[3.2,18.9]
#   x: grad_norm=2.730503559112549
#   y: grad_norm=12.856493949890137
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 195  U=2195.062  z_cont=[3.2,18.9]
#   x: grad_norm=2.8105103969573975
#   y: grad_norm=13.376222610473633
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 196  U=2207.731  z_cont=[3.2,19.0]
#   x: grad_norm=2.8989057540893555
#   y: grad_norm=13.94284439086914
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 197  U=2192.695  z_cont=[3.2,18.9]
#   x: grad_norm=2.7664363384246826
#   y: grad_norm=13.138219833374023
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 198  U=2214.237  z_cont=[3.2,19.0]
#   x: grad_norm=2.5885467529296875
#   y: grad_norm=12.18631362915039
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 199  U=2197.191  z_cont=[3.2,19.0]
#   x: grad_norm=3.0274670124053955
#   y: grad_norm=12.619254112243652
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 200  U=2209.895  z_cont=[3.2,19.0]
#   x: grad_norm=2.8151185512542725
#   y: grad_norm=13.31069564819336
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 201  U=2194.800  z_cont=[3.2,19.0]
#   x: grad_norm=2.8013341426849365
#   y: grad_norm=13.284771919250488
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 202  U=2211.276  z_cont=[3.2,19.1]
#   x: grad_norm=2.7646965980529785
#   y: grad_norm=13.05272102355957
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 203  U=2196.212  z_cont=[3.2,19.0]
#   x: grad_norm=3.014075517654419
#   y: grad_norm=12.506059646606445
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 204  U=2214.369  z_cont=[3.2,19.1]
#   x: grad_norm=2.860081911087036
#   y: grad_norm=11.773558616638184
# Fine-tune at epoch 205
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 205  U=2200.469  z_cont=[3.2,19.1]
#   x: grad_norm=3.054219961166382
#   y: grad_norm=12.689858436584473
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 206  U=2207.084  z_cont=[3.2,19.1]
#   x: grad_norm=2.9343197345733643
#   y: grad_norm=14.067087173461914
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 207  U=2193.977  z_cont=[3.2,19.1]
#   x: grad_norm=2.7817180156707764
#   y: grad_norm=13.130480766296387
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 208  U=2215.399  z_cont=[3.2,19.2]
#   x: grad_norm=2.804612636566162
#   y: grad_norm=11.526546478271484
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 209  U=2202.160  z_cont=[3.2,19.1]
#   x: grad_norm=3.0558855533599854
#   y: grad_norm=12.703977584838867
# Fine-tune at epoch 210
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 210  U=2205.297  z_cont=[3.2,19.2]
#   x: grad_norm=2.9656126499176025
#   y: grad_norm=14.2718505859375
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 211  U=2195.377  z_cont=[3.2,19.2]
#   x: grad_norm=2.8018646240234375
#   y: grad_norm=13.22876262664795
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 212  U=2214.652  z_cont=[3.2,19.3]
#   x: grad_norm=2.8776631355285645
#   y: grad_norm=11.870183944702148
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 213  U=2201.523  z_cont=[3.2,19.2]
#   x: grad_norm=3.0562796592712402
#   y: grad_norm=12.691961288452148
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 214  U=2207.682  z_cont=[3.2,19.3]
#   x: grad_norm=3.181978225708008
#   y: grad_norm=13.280190467834473
# Fine-tune at epoch 215
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 215  U=2199.873  z_cont=[3.2,19.2]
#   x: grad_norm=3.0496063232421875
#   y: grad_norm=12.645366668701172
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 216  U=2212.725  z_cont=[3.2,19.3]
#   x: grad_norm=3.0028157234191895
#   y: grad_norm=12.467874526977539
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 217  U=2199.805  z_cont=[3.2,19.3]
#   x: grad_norm=3.050510883331299
#   y: grad_norm=12.633944511413574
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 218  U=2211.852  z_cont=[3.2,19.3]
#   x: grad_norm=3.050043821334839
#   y: grad_norm=12.681256294250488
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 219  U=2199.992  z_cont=[3.2,19.3]
#   x: grad_norm=3.049708604812622
#   y: grad_norm=12.63159465789795
# Fine-tune at epoch 220
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 220  U=2212.336  z_cont=[3.2,19.4]
#   x: grad_norm=3.0338003635406494
#   y: grad_norm=12.607948303222656
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 221  U=2200.235  z_cont=[3.2,19.3]
#   x: grad_norm=3.0511200428009033
#   y: grad_norm=12.631230354309082
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 222  U=2212.309  z_cont=[3.2,19.4]
#   x: grad_norm=3.0412278175354004
#   y: grad_norm=12.637908935546875
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 223  U=2200.432  z_cont=[3.2,19.3]
#   x: grad_norm=3.0509066581726074
#   y: grad_norm=12.629622459411621
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 224  U=2212.516  z_cont=[3.2,19.4]
#   x: grad_norm=3.0369138717651367
#   y: grad_norm=12.616842269897461
# Fine-tune at epoch 225
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 225  U=2200.658  z_cont=[3.2,19.4]
#   x: grad_norm=3.053609848022461
#   y: grad_norm=12.627859115600586
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 226  U=2212.575  z_cont=[3.2,19.4]
#   x: grad_norm=3.0394811630249023
#   y: grad_norm=12.628216743469238
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 227  U=2200.876  z_cont=[3.2,19.4]
#   x: grad_norm=3.0531647205352783
#   y: grad_norm=12.626180648803711
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 228  U=2212.736  z_cont=[3.2,19.4]
#   x: grad_norm=3.0376694202423096
#   y: grad_norm=12.619897842407227
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 229  U=2201.056  z_cont=[3.2,19.4]
# ...
# Epoch 924  U=2244.349  z_cont=[3.2,21.0]
#   x: grad_norm=1.8213088512420654
#   y: grad_norm=8.545736312866211
# Fine-tune at epoch 925
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 925  U=2242.289  z_cont=[3.2,21.0]
#   x: grad_norm=1.8222743272781372
#   y: grad_norm=9.713237762451172
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 926  U=2239.427  z_cont=[3.2,21.0]
#   x: grad_norm=2.191950798034668
#   y: grad_norm=10.320253372192383
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 927  U=2240.387  z_cont=[3.2,21.0]
#   x: grad_norm=1.9231071472167969
#   y: grad_norm=10.402030944824219
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 928  U=2239.572  z_cont=[3.2,21.0]
#   x: grad_norm=1.6758888959884644
#   y: grad_norm=10.071999549865723
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 929  U=2242.335  z_cont=[3.2,21.0]
#   x: grad_norm=1.838443398475647
#   y: grad_norm=9.751541137695312
# Fine-tune at epoch 930
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 930  U=2240.892  z_cont=[3.2,21.0]
#   x: grad_norm=2.094937801361084
#   y: grad_norm=9.894826889038086
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 931  U=2241.121  z_cont=[3.2,21.0]
#   x: grad_norm=1.8934340476989746
#   y: grad_norm=10.165509223937988
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 932  U=2240.018  z_cont=[3.2,21.0]
#   x: grad_norm=1.5898704528808594
#   y: grad_norm=10.065481185913086
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 933  U=2242.256  z_cont=[3.2,21.0]
#   x: grad_norm=1.6468459367752075
#   y: grad_norm=8.96539306640625
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 934  U=2244.803  z_cont=[3.2,21.0]
#   x: grad_norm=1.7726930379867554
#   y: grad_norm=8.398417472839355
# Fine-tune at epoch 935
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 935  U=2243.449  z_cont=[3.2,21.0]
#   x: grad_norm=1.5643415451049805
#   y: grad_norm=8.371203422546387
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 936  U=2244.601  z_cont=[3.2,21.0]
#   x: grad_norm=1.3252264261245728
#   y: grad_norm=8.414329528808594
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 937  U=2243.628  z_cont=[3.2,21.0]
#   x: grad_norm=1.5562360286712646
#   y: grad_norm=8.328258514404297
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 938  U=2244.909  z_cont=[3.2,21.0]
#   x: grad_norm=1.3132274150848389
#   y: grad_norm=8.31175422668457
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 939  U=2243.967  z_cont=[3.2,21.0]
#   x: grad_norm=1.5395159721374512
#   y: grad_norm=8.260580062866211
# Fine-tune at epoch 940
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 940  U=2244.844  z_cont=[3.2,21.0]
#   x: grad_norm=1.794456124305725
#   y: grad_norm=8.452546119689941
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 941  U=2242.832  z_cont=[3.2,21.0]
#   x: grad_norm=1.7978085279464722
#   y: grad_norm=9.669812202453613
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 942  U=2239.623  z_cont=[3.2,21.0]
#   x: grad_norm=2.1856637001037598
#   y: grad_norm=10.320713996887207
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 943  U=2241.061  z_cont=[3.2,21.0]
#   x: grad_norm=1.7977555990219116
#   y: grad_norm=9.256739616394043
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 944  U=2245.039  z_cont=[3.2,21.0]
#   x: grad_norm=1.2954686880111694
#   y: grad_norm=8.267877578735352
# Fine-tune at epoch 945
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 945  U=2244.663  z_cont=[3.2,21.0]
#   x: grad_norm=1.4878052473068237
#   y: grad_norm=7.97627592086792
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 946  U=2245.380  z_cont=[3.2,21.0]
#   x: grad_norm=1.278720498085022
#   y: grad_norm=8.143083572387695
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 947  U=2244.194  z_cont=[3.2,21.0]
#   x: grad_norm=1.5358740091323853
#   y: grad_norm=8.38318157196045
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 948  U=2244.355  z_cont=[3.2,21.0]
#   x: grad_norm=1.8485252857208252
#   y: grad_norm=8.746957778930664
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 949  U=2242.649  z_cont=[3.2,21.0]
#   x: grad_norm=1.8175582885742188
#   y: grad_norm=9.786470413208008
# Fine-tune at epoch 950
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 950  U=2239.918  z_cont=[3.2,21.0]
#   x: grad_norm=1.6013365983963013
#   y: grad_norm=10.189498901367188
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 951  U=2242.509  z_cont=[3.2,21.0]
#   x: grad_norm=1.8330819606781006
#   y: grad_norm=9.864034652709961
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 952  U=2241.116  z_cont=[3.2,21.0]
#   x: grad_norm=2.112725257873535
#   y: grad_norm=9.980257034301758
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 953  U=2241.219  z_cont=[3.2,21.0]
#   x: grad_norm=1.7964894771575928
#   y: grad_norm=9.298087120056152
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 954  U=2245.167  z_cont=[3.2,21.0]
#   x: grad_norm=1.7696751356124878
#   y: grad_norm=8.43603515625
# Fine-tune at epoch 955
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 955  U=2244.296  z_cont=[3.2,21.0]
#   x: grad_norm=1.7013248205184937
#   y: grad_norm=9.21324634552002
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 956  U=2240.699  z_cont=[3.2,21.0]
#   x: grad_norm=1.5618679523468018
#   y: grad_norm=9.996253967285156
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 957  U=2242.256  z_cont=[3.2,21.0]
#   x: grad_norm=1.8745994567871094
#   y: grad_norm=9.978546142578125
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 958  U=2241.138  z_cont=[3.2,21.0]
#   x: grad_norm=2.108285665512085
#   y: grad_norm=9.973382949829102
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 959  U=2242.004  z_cont=[3.2,21.0]
#   x: grad_norm=1.6320083141326904
#   y: grad_norm=8.293848037719727
# Fine-tune at epoch 960
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 960  U=2248.621  z_cont=[3.2,21.0]
#   x: grad_norm=0.9629906415939331
#   y: grad_norm=6.2613525390625
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 961  U=2248.371  z_cont=[3.2,21.0]
#   x: grad_norm=1.163068413734436
#   y: grad_norm=6.1800665855407715
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 962  U=2247.267  z_cont=[3.2,21.0]
#   x: grad_norm=1.1313762664794922
#   y: grad_norm=7.276607036590576
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 963  U=2245.052  z_cont=[3.2,21.0]
#   x: grad_norm=1.4941679239273071
#   y: grad_norm=8.16958999633789
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 964  U=2244.415  z_cont=[3.2,21.0]
#   x: grad_norm=1.8696156740188599
#   y: grad_norm=8.861000061035156
# Fine-tune at epoch 965
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 965  U=2242.815  z_cont=[3.2,21.0]
#   x: grad_norm=1.7239573001861572
#   y: grad_norm=8.876051902770996
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 966  U=2245.220  z_cont=[3.2,21.0]
#   x: grad_norm=1.3140827417373657
#   y: grad_norm=8.430146217346191
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 967  U=2244.855  z_cont=[3.2,21.0]
#   x: grad_norm=1.5064496994018555
#   y: grad_norm=8.29776382446289
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 968  U=2245.074  z_cont=[3.2,21.0]
#   x: grad_norm=1.8094699382781982
#   y: grad_norm=8.600129127502441
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 969  U=2243.561  z_cont=[3.2,21.0]
#   x: grad_norm=1.68093740940094
#   y: grad_norm=8.6521577835083
# Fine-tune at epoch 970
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 970  U=2245.323  z_cont=[3.2,21.0]
#   x: grad_norm=1.3066062927246094
#   y: grad_norm=8.400796890258789
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 971  U=2245.024  z_cont=[3.2,21.0]
#   x: grad_norm=1.5843514204025269
#   y: grad_norm=8.141879081726074
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 972  U=2245.884  z_cont=[3.2,21.0]
#   x: grad_norm=1.7338591814041138
#   y: grad_norm=8.253206253051758
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 973  U=2244.103  z_cont=[3.2,21.0]
#   x: grad_norm=1.90742826461792
#   y: grad_norm=38.63410186767578
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 974  U=2244.150  z_cont=[3.2,21.0]
#   x: grad_norm=1.3481106758117676
#   y: grad_norm=8.61426067352295
# Fine-tune at epoch 975
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 975  U=2244.221  z_cont=[3.2,21.0]
#   x: grad_norm=1.4532082080841064
#   y: grad_norm=7.380885601043701
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 976  U=2248.378  z_cont=[3.2,21.0]
#   x: grad_norm=0.9183915257453918
#   y: grad_norm=5.944965839385986
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 977  U=2247.959  z_cont=[3.2,21.0]
#   x: grad_norm=1.090836763381958
#   y: grad_norm=5.417987823486328
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 978  U=2248.783  z_cont=[3.2,21.0]
#   x: grad_norm=1.1851469278335571
#   y: grad_norm=5.6895856857299805
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 979  U=2247.216  z_cont=[3.2,21.0]
#   x: grad_norm=1.1795247793197632
#   y: grad_norm=5.869584083557129
# Fine-tune at epoch 980
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 980  U=2248.597  z_cont=[3.2,21.0]
#   x: grad_norm=0.8955764174461365
#   y: grad_norm=5.797714710235596
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 981  U=2247.787  z_cont=[3.2,21.0]
#   x: grad_norm=1.1235687732696533
#   y: grad_norm=5.556690692901611
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 982  U=2249.168  z_cont=[3.2,21.0]
#   x: grad_norm=0.825616180896759
#   y: grad_norm=5.340861797332764
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 983  U=2248.463  z_cont=[3.2,21.0]
#   x: grad_norm=1.0915237665176392
#   y: grad_norm=5.189061641693115
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 984  U=2249.406  z_cont=[3.2,21.0]
#   x: grad_norm=1.0886648893356323
#   y: grad_norm=5.23480224609375
# Fine-tune at epoch 985
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 985  U=2248.398  z_cont=[3.2,21.0]
#   x: grad_norm=1.0600517988204956
#   y: grad_norm=5.227212905883789
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 986  U=2249.510  z_cont=[3.2,21.0]
#   x: grad_norm=0.7836490273475647
#   y: grad_norm=5.092021942138672
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 987  U=2248.941  z_cont=[3.2,21.0]
#   x: grad_norm=0.9949018955230713
#   y: grad_norm=4.906343460083008
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 988  U=2249.897  z_cont=[3.2,21.0]
#   x: grad_norm=0.7316023707389832
#   y: grad_norm=4.759634494781494
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 989  U=2249.384  z_cont=[3.2,21.0]
#   x: grad_norm=0.9396275877952576
#   y: grad_norm=4.607417106628418
# Fine-tune at epoch 990
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 990  U=2250.131  z_cont=[3.2,21.0]
#   x: grad_norm=0.9568856954574585
#   y: grad_norm=4.636253356933594
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 991  U=2249.406  z_cont=[3.2,21.0]
#   x: grad_norm=0.9421189427375793
#   y: grad_norm=4.616191864013672
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 992  U=2250.225  z_cont=[3.2,21.0]
#   x: grad_norm=0.689297080039978
#   y: grad_norm=4.512113094329834
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 993  U=2249.843  z_cont=[3.2,21.0]
#   x: grad_norm=0.8840752840042114
#   y: grad_norm=4.310479164123535
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 994  U=2250.602  z_cont=[3.2,21.0]
#   x: grad_norm=0.6320232152938843
#   y: grad_norm=4.155660152435303
# Fine-tune at epoch 995
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 995  U=2250.284  z_cont=[3.2,21.0]
#   x: grad_norm=0.8223288059234619
#   y: grad_norm=3.9877967834472656
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 996  U=2250.802  z_cont=[3.2,21.0]
#   x: grad_norm=0.8275264501571655
#   y: grad_norm=4.052496910095215
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 997  U=2250.186  z_cont=[3.2,21.0]
#   x: grad_norm=0.9252104759216309
#   y: grad_norm=4.5997843742370605
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 998  U=2249.610  z_cont=[3.2,21.0]
#   x: grad_norm=1.1354498863220215
#   y: grad_norm=5.449194431304932
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# Epoch 999  U=2248.218  z_cont=[3.2,21.0]
#   x: grad_norm=1.2293206453323364
#   y: grad_norm=6.281230926513672
# Fine-tune at epoch 1000
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt
# CPU times: user 1min 3s, sys: 3.65 s, total: 1min 7s
# Wall time: 2min 36s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='1e2 U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='1e2 U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='1e8 U_E',    lw=1)
plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_35_10_shower/cashed_showers_10.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_lb.detach().cpu().max()], [0, E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
