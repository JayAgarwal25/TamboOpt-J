# %% [markdown]
# # SWGO L07 Detector Optimization — TR (Triangulated) Mountain Surface
#
# v4: detectors slide on the 3D Colca Valley mountain surface.
# Learnable parameters: `(x = North, y = Up)` in metres.
# Derived: `East = f(N, Up)` via differentiable surface map; `z_cont = (EAST_ENTRY − East) / LAYER_EAST_DX` maps to AllShowers layer index.
#
# Reuses v3 modules via sys.path injection — no verbatim copies.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch._utils  # workaround: torch 2.x lazy submodule needed by torch.save on Py3.13
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc
import functools

# Suppress noisy warnings that flood SLURM logs
warnings.filterwarnings("ignore", message="num points .* exceeds max points")
torch.set_float32_matmul_precision('highest')

# v3 modules (via sys.path injection in modules_v4/__init__.py)
import modules_v4  # triggers sys.path injection for v3
from modules.generate_showers import GenerateShowers
from modules.shower_computation import ComputeShowerDetection
from modules.detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from modules.reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from modules.layout_optimization import LearnableXY
from modules.utility_functions import reconstructability, U_PR, U_E, U_angle

# v4 new modules
from modules_v4.tr_geometry import load_tr_mountain
from modules_v4.tr_surface_map import SurfaceEastMap
from modules_v4.tr_plane_kernel import GetCounts_planeaware

output_dir = "./outputs/NN_Files_41_10_shower_mean_U_lr_1"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

#####################
#  Hyperparameters  #
#####################
generate_new_data = True
use_cache = True
training_epochs = 1250
# Out:
# device: cuda

# %% [markdown]
# ## Constants and Parameters

# %%
# Physics constants
c0 = .29979          # Speed of light [m/ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)

# Tank values (same as v3)
IntegrationWindow = 128.   # ns
sigma_time        = 10.    # ns time resolution
TankArea          = 6.859 * np.pi
TankRadius        = np.sqrt(6.859)
R_min             = 2.

# Background
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Optimization sizes
Nunits       = 90
RelResCounts = .05
NUM_FEATURES = 5#7   # [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]

# NN training sizes
Nevents     = 10 # 200000
Nvalidation = 10 # 20000
Ntest       = 10 # 3000
Nbatch      = 10 # 5000

# Geometry — v4 mountain surface
GEOMETRY_PATH = "../../TAMBOSim/resources/basic_geometry.h5"
GROUP    = "colca_valley_30000"
DET_KEY  = "detector1"
N_PLANES = 24
# AllShowers layer-East calibration (empirically derived from fixture data):
#   East at AllShowers layer k = EAST_ENTRY - k * LAYER_EAST_DX = -212 - 307k metres
#   z_cont = (EAST_ENTRY - East) / LAYER_EAST_DX  (layer 0 = entry, increases going deeper)
EAST_ENTRY    = 1500.0   # m — East at AllShowers layer 0 (shower entry, padding)
LAYER_EAST_DX =  150.0   # m — East depth per AllShowers layer (positive)

mountain = load_tr_mountain(GEOMETRY_PATH, GROUP, DET_KEY,
                            east_entry=EAST_ENTRY, layer_east_dx=LAYER_EAST_DX, n_planes=N_PLANES)
surface  = SurfaceEastMap.from_mountain(mountain, grid_h=256, grid_w=256).to(device)

print(f"Mountain: N=[{mountain.n_min:.0f}, {mountain.n_max:.0f}] m  "
      f"Up=[{mountain.u_min:.0f}, {mountain.u_max:.0f}] m  "
      f"East=[{mountain.east_lo:.0f}, {mountain.east_hi:.0f}] m")
print(f"AllShowers: EAST_ENTRY={mountain.east_entry} m  LAYER_EAST_DX={mountain.layer_east_dx} m  ")
print(f"  z_cont range on mountain surface: [0, {mountain.east_to_z_cont(mountain.east_lo):.1f}]")
print(f"  n_planes={mountain.n_planes}")

# Initial detector layout sampled on the mountain (N, Up) bounding box
N_init, U_init = mountain.sample_initial_layout(n_units=Nunits, scheme="center")
x_det = torch.as_tensor(N_init, dtype=torch.float32, device=device)
y_det = torch.as_tensor(U_init, dtype=torch.float32, device=device)

# Optimization flag
SWGOopt = False
# Out:
# Mountain: N=[-2497, 2474] m  Up=[2442, 3886] m  East=[-2019, 1182] m
# AllShowers: EAST_ENTRY=1500.0 m  LAYER_EAST_DX=150.0 m
#   z_cont range on mountain surface: [0, 23.5]
#   n_planes=24

# %% [markdown]
# ## Initialize Shower Generator

# %%
generate_showers_instance = GenerateShowers(output_dir=output_dir, device=device, batch_size=30)

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Partial-apply physics constants into v3's post-processing callables
_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                 IntegrationWindow=IntegrationWindow,
                                 sigma_time=sigma_time)

# ── Shower vertical recenter (same logic as tests/test_shower_heatmap.ipynb) ─
# AllShowers samples are centred around their own Up mean, which sits below the
# mountain face.  Shift them once so the energy-weighted Up centroid lands at
# Y_TARGET inside the mountain bbox.  The shift is computed lazily on the
# first batch and cached so detectors see a stable shower geometry.
#
# Note: ComputeShowerDetection computes X0/Y0 from samples[:, :, 0..1] BEFORE
# calling the kernel callback, so we must also patch Y0 after the call:
# since the shift is a constant added to every Up value, the energy-weighted
# Y0 just shifts by the same constant.
Y_TARGET = mountain.u_min + 0.25 * (mountain.u_max - mountain.u_min)
_y_shift_state = {"value": None}


def _apply_y_shift(samples):
    """Shift samples[:, :, 1] (Up) by a cached offset.  Compute it on first call."""
    if _y_shift_state["value"] is None:
        with torch.no_grad():
            mask = samples[..., 3] > 0
            if mask.any():
                ys = samples[..., 1][mask]
                es = samples[..., 3][mask]
                centroid = float((ys * es).sum() / es.sum())
                _y_shift_state["value"] = float(Y_TARGET) - centroid
                print(f"[generate_showers] Y_SHIFT cached: centroid={centroid:.0f} m  "
                      f"shift={_y_shift_state['value']:+.0f} m  -> target={Y_TARGET:.0f} m")
            else:
                _y_shift_state["value"] = 0.0
    shift = _y_shift_state["value"]
    if shift == 0.0:
        return samples
    samples = samples.clone()
    samples[..., 1] = samples[..., 1] + shift
    return samples


def generate_showers(x_det, y_det, z_cont, log=False, number_of_showers=1,
                     device=device, use_cache=False):
    """Generate showers and compute plane-aware detector counts.

    z_cont : (n_det,) continuous plane index derived from the mountain surface map.
             Captured by the inner closure - callers must pass the current z_cont
             so that gradients flow back through it to (x_det, y_det).

    The shower Up coordinates and Y0 are recentered by a cached y-shift so that
    the energy-weighted shower centre lands at Y_TARGET inside the mountain bbox.
    """
    def _get_counts_planeaware(samples, x_d, y_d):
        samples = _apply_y_shift(samples)
        return GetCounts_planeaware(
            samples, x_d, y_d, z_cont,
            SmearN_fn=_SmearN,
            fluxB_e=fluxB_e.to(samples.device),
            TimeAverage_vectorized_fn=_TimeAverage,
            sigma=400
        )

    out = ComputeShowerDetection(
        x_det, y_det,
        generate_showers_instance,
        _get_counts_planeaware,
        log=log,
        number_of_showers=number_of_showers,
        device=device,
        use_cache=use_cache,
        output_dir=output_dir,
        filter_plane=None,          # v4: all 24 layers reach the kernel
    )

    # ── Patch Y0 to match the y-shifted samples ─────────────────────────────
    # ComputeShowerDetection returns (N, T, X0, Y0, energies, sin_z, cos_z, sin_a, cos_a, labels).
    # X0 is unaffected (we never shift samples[..., 0]); Y0 needs the constant shift.
    shift = _y_shift_state["value"]
    if shift is not None and shift != 0.0:
        out = list(out)
        out[3] = out[3] + shift     # Y0
        out = tuple(out)
    return out

# %% [markdown]
# ## Visualize Initial Layout

# %%
# Compute initial East / z_cont for visualization
with torch.no_grad():
    east_init = surface(x_det, y_det)
    z_cont_init = (mountain.east_entry - east_init) / mountain.layer_east_dx

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Top-down (N, Up) view with mountain surface as background
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc0 = axes[0].scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.3)
plt.colorbar(sc0, ax=axes[0], label='East [m]')
axes[0].scatter(x_det.cpu(), y_det.cpu(), c='red', s=30, zorder=5, label='Detectors')
axes[0].set_xlabel("North [m]"); axes[0].set_ylabel("Up [m]")
axes[0].set_title("Initial detector layout (top-down)"); axes[0].legend()

# z_cont distribution
axes[1].hist(z_cont_init.cpu().numpy(), bins=20, color='steelblue', edgecolor='k')
axes[1].set_xlabel("z_cont (plane index)"); axes[1].set_ylabel("count")
axes[1].set_title("Initial z_cont distribution")
axes[1].axvline(20, color='red', linestyle='--', label='v3 fixed plane (20)')
axes[1].legend()

plt.tight_layout(); plt.show()
print(f"z_cont: min={z_cont_init.min():.2f}  max={z_cont_init.max():.2f}  mean={z_cont_init.mean():.2f}")
# Out:
# z_cont: min=11.16  max=12.33  mean=11.90

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, labels = generate_showers(
        x_det, y_det, _z, log=True, number_of_showers=10, use_cache=use_cache
    )
# Out:
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# [generate_showers] Y_SHIFT cached: centroid=-56 m  shift=+2860 m  -> target=2803 m

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([ 1209.3162,  -185.9382, -4770.9209, -3740.6626, -2724.5300,  6926.7793,
#         -1610.1606,   491.2737,  3148.9158, -4356.9370], device='cuda:0')
# Y0: tensor([ 5521.8242,  5838.6670,  1888.6909,  1871.6783,   482.1055,   954.0850,
#          4315.3809,  3780.6860, -1127.4365,  2013.8997], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    ax = axes[i]
    sc = ax.scatter(x_det.cpu(), y_det.cpu(), c=N[i].detach().cpu(),
                    cmap='viridis', s=60, norm=LogNorm(vmin=1e-2, vmax=1e3))
    fig.colorbar(sc, ax=ax, label='N_int')
    ax.scatter([X0[i].item()], [Y0[i].item()], c='red', marker='*', s=200, label='Core')
    ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
    ax.set_title(f"Shower {i}  E={energy[i]:.2f}  θ={th[i]*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
print(f"energy.min(): {energy.min():.3f}, energy.max(): {energy.max():.3f}")
print(f"theta.min():  {th.min()*180/np.pi:.1f}°, theta.max():  {th.max()*180/np.pi:.1f}°")
print(f"phi.min():    {ph.min()*180/np.pi:.1f}°, phi.max():    {ph.max()*180/np.pi:.1f}°")
# Out:
# energy.min(): 255442.672, energy.max(): 76481400.000
# theta.min():  65.2°, theta.max():  98.9°
# phi.min():    -138.1°, phi.max():    178.4°

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nevents, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nevents, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # 7 features: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# CPU times: user 6.5 ms, sys: 1.13 ms, total: 7.63 ms
# Wall time: 83.3 ms

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Nvalidation, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Nvalidation, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_val = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# CPU times: user 4.13 ms, sys: 1.02 ms, total: 5.15 ms
# Wall time: 58.1 ms

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    with torch.no_grad():
        _z = (mountain.east_entry - surface(x_det, y_det)) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det, y_det, _z, False, number_of_showers=Ntest, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)
    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)

    x0 = X0 / 5000
    y0 = Y0 / 5000
    z_exp   = _z.unsqueeze(0).expand(Ntest, -1)
    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    # inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
    inputs_test = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")
# Out:
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs      = torch.load(f"{output_dir}/inputs.pt")
labels      = torch.load(f"{output_dir}/labels.pt")
inputs_val  = torch.load(f"{output_dir}/inputs_val.pt")
labels_val  = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")
print("inputs:", inputs.shape, "  labels:", labels.shape)
# Out:
# inputs: torch.Size([10, 90, 5])   labels: torch.Size([10, 3])

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)
criterion = nn.MSELoss()
optimizer_nn = torch.optim.Adam(model.parameters(), lr=3e-5)
print("NN parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# NN parameters: 152579

# %%
# Per-feature normalization (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))   # (7,)
input_std  = inputs.std(dim=(0, 1))    # (7,)
input_std[input_std < 1e-8] = 1.0

inputs      = (inputs      - input_mean) / input_std
inputs_val  = (inputs_val  - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset    = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(800):
        epoch_loss = 0
        total_batch = 0

        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1
            loss.backward()
            optimizer_nn.step()
            optimizer_nn.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)
        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        model.train()

        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training {int((num_epoch + 1) / 10)}%  val_loss={val_loss:.4f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(losses,     color="blue", label="Training Loss")
    plt.plot(val_losses, color="red",  label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
    plt.title("NN Training"); plt.show()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# Training 10%  val_loss=0.0921
# Training 20%  val_loss=0.0710
# Training 30%  val_loss=0.0707
# Training 40%  val_loss=0.0707
# Training 50%  val_loss=0.0707
# Training 60%  val_loss=0.0707
# Training 70%  val_loss=0.0707
# Training 80%  val_loss=0.0707
# CPU times: user 1.4 s, sys: 87.8 ms, total: 1.49 s
# Wall time: 1.53 s

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])
E_p, E_r     = E_pred,     E_lb
Th_p, Th_r   = theta_pred, theta_lb
Ph_p, Ph_r   = phi_pred,   phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([E_r.min().cpu(), E_r.max().cpu()], [E_r.min().cpu(), E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()
axes[0].set_xscale("log"); axes[0].set_yscale("log")
axes[0].set_xlim([6e4, 3e8])
axes[0].set_ylim([6e4, 3e8])

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (initial layout)", fontsize=13)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    input_features=NUM_FEATURES,
    num_detectors=Nunits,
).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Checkpoint weights loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial NN weights loaded")
# Out:
# Initial NN weights loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

# Compute and save initial layout (3 columns: N, Up, z_cont)
with torch.no_grad():
    east_0 = surface(x_det, y_det)
    zc_0   = (mountain.east_entry - east_0) / mountain.layer_east_dx
np.savetxt(f"{output_dir}/Python_Layout/Layout_0.txt",
           np.column_stack((x_det.cpu().numpy(), y_det.cpu().numpy(), zc_0.cpu().numpy())))

# %%
# Resume from last saved layout if available
for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32, device=device)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32, device=device)
        e = i + 1

if e > 0:
    print(f"Resumed from Layout_{e}")
else:
    print("Starting from initial layout")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# Starting from initial layout

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std  = input_std.to(device)
input_mean = input_mean.to(device)

# %%
SWGOopt = True
# optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.3)
optimizer = torch.optim.Adam(                  
      xy_module.parameters(),               
      lr=1,              
      betas=(0.9, 0.999),                                                                                                                                                                                                                                                                          
      eps=1e-8,                           
  )        

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    print(f"Optimizer resumed from epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer initialized from scratch")

U_vals    = []
U_th_vals = []
U_phi_vals = []
U_e_vals  = []
U_pr_vals = []
x_det_opt: torch.Tensor = torch.tensor([])
y_det_opt: torch.Tensor = torch.tensor([])
# Out:
# Optimizer initialized from scratch

# %%
# %%time
for epoch in range(num_epoch, num_epoch + training_epochs):

    if epoch < 20:
        Nfinetune = 10 # 3000
    else:
        Nfinetune = 10 # 6000

    x_det_opt, y_det_opt = xy_module()

    # ── Mountain surface map: derive East and z_cont from learnable (N, Up) ──
    east_det = surface(x_det_opt, y_det_opt)                        # (n_det,)
    z_cont   = (mountain.east_entry - east_det) / mountain.layer_east_dx   # (n_det,)  ∈ [0, 23]

    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x_det_opt, y_det_opt, z_cont, False, number_of_showers=Nbatch, use_cache=use_cache
    )

    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000

    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    z_cont_exp    = z_cont.unsqueeze(0).repeat(Nbatch, 1)
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    # 7-feature input: [x=N, y=Up, z=z_cont, N_int, T_int, x0, y0]
    # inputs_batch = torch.stack(
    #     [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list, x0_exp, y0_exp], dim=2
    # ).float()
    inputs_batch = torch.stack(
        [x_det_opt_exp, y_det_opt_exp, z_cont_exp, N_list, T_list], dim=2
    ).float()

    # Use the FROZEN training-time normalization (computed in cell 27 over 20k
    # showers).  Updating per-batch during optimization causes a discontinuity
    # in the NN input distribution → spurious large gradient steps.
    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))
    preds_e, preds_th, preds_phi = DenormalizeLabels(
        preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2]
    )

    # N_int is at feature index 3
    r_score = reconstructability(inputs_batch[:, :, 3], reconstruct_threshold=10)
    U = (
        U_angle(preds_th,  th, r_score) +
        U_angle(preds_phi, ph, r_score) + 
        U_E(preds_e, energy, r_score)   + 0
        # 5e5 * U_PR(r_score)
    )

    U_vals.append(U.item())
    U_th_vals.append(  ( U_angle(preds_th,  th, r_score)).item() )
    U_phi_vals.append( ( U_angle(preds_phi, ph, r_score)).item() )
    U_e_vals.append(   ( U_E(preds_e, energy, r_score)).item() )
    U_pr_vals.append(  ( U_PR(r_score)).item() )

    print(f"Epoch {epoch}  U={U:.3f}  z_cont=[{z_cont.min():.1f},{z_cont.max():.1f}]")

    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        gn = p.grad.norm().item() if p.grad is not None else "None"
        print(f"  {name}: grad_norm={gn}")

    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=100.0)
    optimizer.step()
    optimizer.zero_grad()

    # ── Project detectors back onto the mountain surface ────────────────────
    # A rectangular bbox clamp would let detectors sit in bbox corners outside
    # the actual mountain footprint (where SurfaceEastMap's nearest-neighbour
    # fallback gives visually misleading East values).  Instead, snap any
    # detector whose nearest centroid is farther than max_gap to that nearest
    # centroid's (N, Up).
    with torch.no_grad():
        N_proj, U_proj = mountain.project_to_mountain(xy_module.x.data, xy_module.y.data)
        xy_module.x.data.copy_(N_proj)
        xy_module.y.data.copy_(U_proj)

    # ── NN fine-tune every 5 epochs ───────────────────────────────────────────
    if (epoch + 1) % 5 == 0:
        model.zero_grad()
        print(f"Fine-tune at epoch {epoch + 1}")

        with torch.no_grad():
            x_ft, y_ft = xy_module()
            east_ft = surface(x_ft, y_ft)
            zc_ft   = (mountain.east_entry - east_ft) / mountain.layer_east_dx

            N, T, X0_ft, Y0_ft, energy_ft, sin_z_ft, cos_z_ft, sin_a_ft, cos_a_ft, _ =                 generate_showers(x_ft, y_ft, zc_ft, False,
                                 number_of_showers=Nfinetune, use_cache=use_cache)

            theta_ft = torch.atan2(sin_z_ft, cos_z_ft)
            phi_ft   = torch.atan2(sin_a_ft, cos_a_ft)
            e_norm, th_norm, ph_norm = NormalizeLabels(energy_ft, theta_ft, phi_ft)

            X0_ft /= 5000; Y0_ft /= 5000
            labels_ft = torch.stack([e_norm, th_norm, ph_norm], dim=1).float()

            x_ft_exp  = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_ft_exp  = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            zc_ft_exp = zc_ft.unsqueeze(0).expand(Nfinetune, -1)
            x0_ft = X0_ft.unsqueeze(1).expand(-1, Nunits)
            y0_ft = Y0_ft.unsqueeze(1).expand(-1, Nunits)

            # inputs_ft = torch.stack(
            #     [x_ft_exp, y_ft_exp, zc_ft_exp, N, T, x0_ft, y0_ft], dim=2
            # ).float()
            inputs_ft = torch.stack(
                [x_ft_exp, y_ft_exp, zc_ft_exp, N, T], dim=2
            ).float()

            # Same as the main loop: keep the frozen training-time normalization.
            inputs_ft = (inputs_ft - input_mean) / input_std

        ReconstructionNN = model
        ReconstructionNN.train()
        criterion_ft = nn.MSELoss()
        optimizer_ft = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)

        ft_dataset    = TensorDataset(inputs_ft, labels_ft)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True,
                                   drop_last=False, num_workers=0)
        for j in range(5):
            for inputs_b, labels_b in ft_dataloader:
                bsz = inputs_b.size(0)
                out_ft = ReconstructionNN(inputs_b.view(bsz, -1).to(device))
                loss_ft = criterion_ft(out_ft, labels_b.view(bsz, 3).to(device))
                loss_ft.backward()
                optimizer_ft.step()
                optimizer_ft.zero_grad()

    # ── Save checkpoint and layout ────────────────────────────────────────────
    torch.save({"epoch": epoch, "loss": Loss.cpu(),
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()},
               f"{output_dir}/checkpoint.pth")

    # 3-column layout file: North, Up, z_cont
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((
                   x_det_opt.detach().cpu().numpy(),
                   y_det_opt.detach().cpu().numpy(),
                   z_cont.detach().cpu().numpy(),
               )))
    # Save utilities incrementally (survives SLURM preemption)
    # Columns: U_total, U_theta, U_phi, U_E, U_PR
    utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")
    u_row = np.array([[U_vals[-1], U_th_vals[-1], U_phi_vals[-1], U_e_vals[-1], U_pr_vals[-1]]])
    if utility_path.exists():
        u_prev = np.loadtxt(utility_path, ndmin=2)
        np.savetxt(utility_path, np.vstack([u_prev, u_row]),
                   header="U_total U_theta U_phi U_E U_PR")
    else:
        np.savetxt(utility_path, u_row,
                   header="U_total U_theta U_phi U_E U_PR")
# Out:
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 0  U=221.183  z_cont=[11.2,12.3]
#   x: grad_norm=4.847327709197998
#   y: grad_norm=11.04079532623291
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1  U=197.139  z_cont=[11.1,12.3]
#   x: grad_norm=4.367451190948486
#   y: grad_norm=9.236557006835938
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 2  U=204.338  z_cont=[11.1,12.3]
#   x: grad_norm=4.8841776847839355
#   y: grad_norm=9.612646102905273
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 3  U=316.129  z_cont=[11.2,12.3]
#   x: grad_norm=14.620368957519531
#   y: grad_norm=28.430965423583984
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 4  U=264.031  z_cont=[11.2,12.3]
#   x: grad_norm=7.955763816833496
#   y: grad_norm=24.640243530273438
# Fine-tune at epoch 5
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 5  U=269.763  z_cont=[11.2,12.3]
#   x: grad_norm=5.971367359161377
#   y: grad_norm=19.753835678100586
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 6  U=325.176  z_cont=[11.2,12.3]
#   x: grad_norm=13.128543853759766
#   y: grad_norm=41.8503532409668
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 7  U=290.733  z_cont=[11.2,12.3]
#   x: grad_norm=7.882024765014648
#   y: grad_norm=19.625118255615234
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 8  U=286.141  z_cont=[11.2,12.3]
#   x: grad_norm=4.309970378875732
#   y: grad_norm=9.876267433166504
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 9  U=294.412  z_cont=[11.2,12.3]
#   x: grad_norm=3.7554116249084473
#   y: grad_norm=8.869234085083008
# Fine-tune at epoch 10
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 10  U=306.071  z_cont=[11.2,12.3]
#   x: grad_norm=4.502765655517578
#   y: grad_norm=11.585773468017578
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 11  U=330.548  z_cont=[11.2,12.3]
#   x: grad_norm=9.566887855529785
#   y: grad_norm=25.955310821533203
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 12  U=380.580  z_cont=[11.2,12.3]
#   x: grad_norm=14.049158096313477
#   y: grad_norm=39.15256881713867
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 13  U=388.665  z_cont=[11.2,12.3]
#   x: grad_norm=12.076642990112305
#   y: grad_norm=34.48646926879883
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 14  U=355.978  z_cont=[11.2,12.3]
#   x: grad_norm=13.824565887451172
#   y: grad_norm=37.89888000488281
# Fine-tune at epoch 15
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 15  U=365.932  z_cont=[11.2,12.3]
#   x: grad_norm=14.826788902282715
#   y: grad_norm=42.365657806396484
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 16  U=398.107  z_cont=[11.2,12.3]
#   x: grad_norm=13.846146583557129
#   y: grad_norm=43.13432693481445
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 17  U=405.133  z_cont=[11.2,12.3]
#   x: grad_norm=14.218606948852539
#   y: grad_norm=43.08469772338867
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 18  U=414.256  z_cont=[11.2,12.3]
#   x: grad_norm=16.54566192626953
#   y: grad_norm=47.82941436767578
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 19  U=440.703  z_cont=[11.2,12.3]
#   x: grad_norm=9.669660568237305
#   y: grad_norm=25.584863662719727
# Fine-tune at epoch 20
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 20  U=432.565  z_cont=[11.2,12.3]
#   x: grad_norm=13.832743644714355
#   y: grad_norm=43.80061340332031
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 21  U=457.483  z_cont=[11.2,12.3]
#   x: grad_norm=8.635329246520996
#   y: grad_norm=27.38290786743164
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 22  U=436.845  z_cont=[11.2,12.3]
#   x: grad_norm=14.852663040161133
#   y: grad_norm=43.25983428955078
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 23  U=450.414  z_cont=[11.2,12.3]
#   x: grad_norm=13.104586601257324
#   y: grad_norm=39.3507194519043
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 24  U=428.478  z_cont=[11.2,12.3]
#   x: grad_norm=16.471532821655273
#   y: grad_norm=46.342750549316406
# Fine-tune at epoch 25
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 25  U=433.160  z_cont=[11.2,12.3]
#   x: grad_norm=16.47876739501953
#   y: grad_norm=46.034912109375
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 26  U=435.482  z_cont=[11.2,12.3]
#   x: grad_norm=13.255937576293945
#   y: grad_norm=41.12525939941406
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 27  U=428.914  z_cont=[11.2,12.3]
#   x: grad_norm=13.558939933776855
#   y: grad_norm=42.11840057373047
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 28  U=451.200  z_cont=[11.2,12.3]
#   x: grad_norm=6.82713508605957
#   y: grad_norm=17.183942794799805
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 29  U=439.845  z_cont=[11.2,12.3]
#   x: grad_norm=15.255712509155273
#   y: grad_norm=42.42504119873047
# Fine-tune at epoch 30
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 30  U=459.194  z_cont=[11.2,12.3]
#   x: grad_norm=4.6040425300598145
#   y: grad_norm=14.913141250610352
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 31  U=452.526  z_cont=[11.2,12.3]
#   x: grad_norm=12.400886535644531
#   y: grad_norm=36.43744659423828
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 32  U=461.858  z_cont=[11.2,12.3]
#   x: grad_norm=7.667418003082275
#   y: grad_norm=21.169673919677734
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 33  U=461.550  z_cont=[11.2,12.3]
#   x: grad_norm=8.6405668258667
#   y: grad_norm=24.455888748168945
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 34  U=458.404  z_cont=[11.2,12.3]
#   x: grad_norm=11.057190895080566
#   y: grad_norm=31.62395668029785
# Fine-tune at epoch 35
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 35  U=463.969  z_cont=[11.2,12.3]
#   x: grad_norm=1.5351523160934448
#   y: grad_norm=3.506424903869629
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 36  U=458.436  z_cont=[11.2,12.3]
#   x: grad_norm=8.986109733581543
#   y: grad_norm=25.839643478393555
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 37  U=461.511  z_cont=[11.2,12.3]
#   x: grad_norm=4.4707746505737305
#   y: grad_norm=11.313993453979492
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 38  U=460.526  z_cont=[11.2,12.3]
#   x: grad_norm=6.265894889831543
#   y: grad_norm=16.297086715698242
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 39  U=459.570  z_cont=[11.2,12.3]
#   x: grad_norm=7.58975887298584
#   y: grad_norm=22.13936996459961
# Fine-tune at epoch 40
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 40  U=462.384  z_cont=[11.2,12.3]
#   x: grad_norm=2.7433247566223145
#   y: grad_norm=8.429734230041504
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 41  U=457.568  z_cont=[11.2,12.3]
#   x: grad_norm=11.183309555053711
#   y: grad_norm=30.10956382751465
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 42  U=464.502  z_cont=[11.2,12.3]
#   x: grad_norm=4.2363057136535645
#   y: grad_norm=12.543342590332031
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 43  U=463.931  z_cont=[11.2,12.3]
#   x: grad_norm=7.002952575683594
#   y: grad_norm=20.081880569458008
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 44  U=463.107  z_cont=[11.2,12.3]
#   x: grad_norm=8.811431884765625
#   y: grad_norm=24.22996711730957
# Fine-tune at epoch 45
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 45  U=467.119  z_cont=[11.2,12.3]
#   x: grad_norm=0.2330024689435959
#   y: grad_norm=0.4852922558784485
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 46  U=463.936  z_cont=[11.2,12.3]
#   x: grad_norm=7.87471342086792
#   y: grad_norm=21.888507843017578
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 47  U=465.454  z_cont=[11.2,12.3]
#   x: grad_norm=5.025920867919922
#   y: grad_norm=14.580366134643555
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 48  U=465.758  z_cont=[11.2,12.3]
#   x: grad_norm=3.341099500656128
#   y: grad_norm=10.000483512878418
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 49  U=463.156  z_cont=[11.2,12.3]
#   x: grad_norm=7.740470886230469
#   y: grad_norm=21.456092834472656
# Fine-tune at epoch 50
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 50  U=463.758  z_cont=[11.2,12.3]
#   x: grad_norm=7.005612373352051
#   y: grad_norm=20.386695861816406
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 51  U=466.266  z_cont=[11.2,12.3]
#   x: grad_norm=2.3887815475463867
#   y: grad_norm=6.218520164489746
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 52  U=465.883  z_cont=[11.2,12.3]
#   x: grad_norm=4.696343421936035
#   y: grad_norm=12.947184562683105
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 53  U=465.480  z_cont=[11.2,12.3]
#   x: grad_norm=6.156494617462158
#   y: grad_norm=17.784513473510742
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 54  U=467.748  z_cont=[11.2,12.3]
#   x: grad_norm=1.5495737791061401
#   y: grad_norm=4.172191619873047
# Fine-tune at epoch 55
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 55  U=468.106  z_cont=[11.2,12.3]
#   x: grad_norm=1.2945924997329712
#   y: grad_norm=3.736618757247925
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 56  U=468.434  z_cont=[11.2,12.3]
#   x: grad_norm=0.3168606460094452
#   y: grad_norm=0.7279958128929138
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 57  U=468.533  z_cont=[11.2,12.3]
#   x: grad_norm=1.389972448348999
#   y: grad_norm=3.5222411155700684
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 58  U=468.673  z_cont=[11.2,12.3]
#   x: grad_norm=1.2984087467193604
#   y: grad_norm=4.079078674316406
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 59  U=468.917  z_cont=[11.2,12.3]
#   x: grad_norm=0.5996745824813843
#   y: grad_norm=1.0645784139633179
# Fine-tune at epoch 60
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 60  U=468.625  z_cont=[11.2,12.3]
#   x: grad_norm=1.0561490058898926
#   y: grad_norm=3.478335380554199
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 61  U=468.817  z_cont=[11.2,12.3]
#   x: grad_norm=2.2806453704833984
#   y: grad_norm=5.472189426422119
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 62  U=469.414  z_cont=[11.2,12.3]
#   x: grad_norm=1.4234274625778198
#   y: grad_norm=4.338567733764648
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 63  U=470.078  z_cont=[11.2,12.3]
#   x: grad_norm=0.5878044366836548
#   y: grad_norm=1.6832704544067383
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 64  U=470.569  z_cont=[11.2,12.3]
#   x: grad_norm=1.8728716373443604
#   y: grad_norm=4.601390838623047
# Fine-tune at epoch 65
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 65  U=469.654  z_cont=[11.2,12.3]
#   x: grad_norm=5.05900239944458
#   y: grad_norm=14.121787071228027
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 66  U=469.036  z_cont=[11.2,12.3]
#   x: grad_norm=7.300583362579346
#   y: grad_norm=19.45987892150879
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 67  U=471.864  z_cont=[11.2,12.3]
#   x: grad_norm=3.4354145526885986
#   y: grad_norm=9.446839332580566
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 68  U=472.807  z_cont=[11.2,12.3]
#   x: grad_norm=2.7649080753326416
#   y: grad_norm=7.43812370300293
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 69  U=471.933  z_cont=[11.2,12.3]
#   x: grad_norm=6.23778772354126
#   y: grad_norm=16.973529815673828
# Fine-tune at epoch 70
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 70  U=469.926  z_cont=[11.2,12.3]
#   x: grad_norm=9.389246940612793
#   y: grad_norm=25.40998649597168
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 71  U=471.818  z_cont=[11.2,12.3]
#   x: grad_norm=8.352324485778809
#   y: grad_norm=22.71530532836914
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 72  U=476.299  z_cont=[11.2,12.3]
#   x: grad_norm=0.6415367126464844
#   y: grad_norm=1.0108250379562378
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 73  U=474.172  z_cont=[11.2,12.3]
#   x: grad_norm=7.608272075653076
#   y: grad_norm=20.282445907592773
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 74  U=473.803  z_cont=[11.2,12.3]
#   x: grad_norm=8.456151008605957
#   y: grad_norm=23.249357223510742
# Fine-tune at epoch 75
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 75  U=475.825  z_cont=[11.2,12.3]
#   x: grad_norm=7.163173675537109
#   y: grad_norm=19.285404205322266
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 76  U=477.698  z_cont=[11.2,12.3]
#   x: grad_norm=4.642644882202148
#   y: grad_norm=12.67911434173584
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 77  U=478.933  z_cont=[11.2,12.3]
#   x: grad_norm=0.8215788006782532
#   y: grad_norm=2.3033664226531982
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 78  U=477.701  z_cont=[11.2,12.3]
#   x: grad_norm=5.288062572479248
#   y: grad_norm=14.234322547912598
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 79  U=477.235  z_cont=[11.2,12.4]
#   x: grad_norm=5.981171131134033
#   y: grad_norm=16.37095069885254
# Fine-tune at epoch 80
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 80  U=478.055  z_cont=[11.2,12.4]
#   x: grad_norm=4.156437397003174
#   y: grad_norm=11.53292465209961
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 81  U=478.672  z_cont=[11.2,12.4]
#   x: grad_norm=1.2892522811889648
#   y: grad_norm=3.2500483989715576
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 82  U=478.379  z_cont=[11.2,12.4]
#   x: grad_norm=2.170747756958008
#   y: grad_norm=5.6575846672058105
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 83  U=477.664  z_cont=[11.2,12.4]
#   x: grad_norm=4.045988082885742
#   y: grad_norm=11.198382377624512
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 84  U=477.673  z_cont=[11.2,12.4]
#   x: grad_norm=3.8747763633728027
#   y: grad_norm=10.370265007019043
# Fine-tune at epoch 85
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 85  U=475.843  z_cont=[11.2,12.4]
#   x: grad_norm=6.749897480010986
#   y: grad_norm=18.781770706176758
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 86  U=473.156  z_cont=[11.2,12.4]
#   x: grad_norm=9.796592712402344
#   y: grad_norm=26.33356285095215
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 87  U=476.753  z_cont=[11.2,12.4]
#   x: grad_norm=5.771169185638428
#   y: grad_norm=15.916754722595215
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 88  U=478.439  z_cont=[11.2,12.4]
#   x: grad_norm=1.533490538597107
#   y: grad_norm=4.216044902801514
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 89  U=475.974  z_cont=[11.2,12.4]
#   x: grad_norm=7.252924919128418
#   y: grad_norm=19.815563201904297
# Fine-tune at epoch 90
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 90  U=472.347  z_cont=[11.2,12.4]
#   x: grad_norm=10.561866760253906
#   y: grad_norm=28.919008255004883
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 91  U=475.217  z_cont=[11.2,12.4]
#   x: grad_norm=8.417984008789062
#   y: grad_norm=22.92770767211914
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 92  U=479.012  z_cont=[11.2,12.4]
#   x: grad_norm=0.5016741752624512
#   y: grad_norm=1.2381759881973267
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 93  U=476.475  z_cont=[11.2,12.4]
#   x: grad_norm=7.152043342590332
#   y: grad_norm=19.32099723815918
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 94  U=474.130  z_cont=[11.2,12.4]
#   x: grad_norm=9.447751998901367
#   y: grad_norm=25.999305725097656
# Fine-tune at epoch 95
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 95  U=479.188  z_cont=[11.2,12.4]
#   x: grad_norm=0.15748633444309235
#   y: grad_norm=0.2917442321777344
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 96  U=470.303  z_cont=[11.2,12.4]
#   x: grad_norm=12.047722816467285
#   y: grad_norm=32.65718460083008
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 97  U=470.974  z_cont=[11.2,12.4]
#   x: grad_norm=11.598663330078125
#   y: grad_norm=31.769359588623047
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 98  U=479.167  z_cont=[11.2,12.4]
#   x: grad_norm=0.33644044399261475
#   y: grad_norm=0.7606433629989624
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 99  U=472.768  z_cont=[11.2,12.4]
#   x: grad_norm=10.61507797241211
#   y: grad_norm=28.787704467773438
# Fine-tune at epoch 100
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 100  U=477.282  z_cont=[11.2,12.4]
#   x: grad_norm=5.954433441162109
#   y: grad_norm=15.956968307495117
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 101  U=475.409  z_cont=[11.2,12.4]
#   x: grad_norm=8.338665962219238
#   y: grad_norm=22.452220916748047
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 102  U=467.471  z_cont=[11.2,12.4]
#   x: grad_norm=13.013497352600098
#   y: grad_norm=35.62067794799805
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 103  U=478.241  z_cont=[11.2,12.4]
#   x: grad_norm=4.170725345611572
#   y: grad_norm=11.170374870300293
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 104  U=475.316  z_cont=[11.2,12.4]
#   x: grad_norm=8.506357192993164
#   y: grad_norm=23.051990509033203
# Fine-tune at epoch 105
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 105  U=466.476  z_cont=[11.2,12.4]
#   x: grad_norm=13.303556442260742
#   y: grad_norm=36.460025787353516
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 106  U=477.684  z_cont=[11.2,12.4]
#   x: grad_norm=5.3663716316223145
#   y: grad_norm=14.401947975158691
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 107  U=475.975  z_cont=[11.2,12.4]
#   x: grad_norm=7.858137607574463
#   y: grad_norm=21.299400329589844
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 108  U=469.272  z_cont=[11.2,12.4]
#   x: grad_norm=12.501495361328125
#   y: grad_norm=33.993133544921875
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 109  U=477.994  z_cont=[11.2,12.4]
#   x: grad_norm=4.928536415100098
#   y: grad_norm=13.519659042358398
# Fine-tune at epoch 110
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 110  U=473.760  z_cont=[11.2,12.4]
#   x: grad_norm=9.881207466125488
#   y: grad_norm=26.920799255371094
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 111  U=463.111  z_cont=[11.2,12.4]
#   x: grad_norm=14.470077514648438
#   y: grad_norm=39.235740661621094
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 112  U=479.184  z_cont=[11.2,12.4]
#   x: grad_norm=0.3217317461967468
#   y: grad_norm=0.7433636784553528
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 113  U=465.325  z_cont=[11.2,12.4]
#   x: grad_norm=13.73873519897461
#   y: grad_norm=37.494422912597656
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 114  U=474.904  z_cont=[11.2,12.4]
#   x: grad_norm=9.016409873962402
#   y: grad_norm=24.423147201538086
# Fine-tune at epoch 115
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 115  U=478.771  z_cont=[11.2,12.4]
#   x: grad_norm=3.0672285556793213
#   y: grad_norm=8.424188613891602
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 116  U=474.182  z_cont=[11.2,12.4]
#   x: grad_norm=9.61883544921875
#   y: grad_norm=26.119943618774414
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 117  U=475.928  z_cont=[11.2,12.4]
#   x: grad_norm=7.994591236114502
#   y: grad_norm=21.84535026550293
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 118  U=479.246  z_cont=[11.2,12.4]
#   x: grad_norm=0.48725777864456177
#   y: grad_norm=1.249859094619751
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 119  U=476.972  z_cont=[11.2,12.4]
#   x: grad_norm=6.7623677253723145
#   y: grad_norm=18.353187561035156
# Fine-tune at epoch 120
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 120  U=477.051  z_cont=[11.2,12.4]
#   x: grad_norm=6.515487194061279
#   y: grad_norm=17.966585159301758
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 121  U=479.223  z_cont=[11.2,12.4]
#   x: grad_norm=0.18356123566627502
#   y: grad_norm=0.33103400468826294
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 122  U=477.545  z_cont=[11.2,12.4]
#   x: grad_norm=5.904031753540039
#   y: grad_norm=15.948407173156738
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 123  U=476.274  z_cont=[11.2,12.4]
#   x: grad_norm=7.630589485168457
#   y: grad_norm=20.84250831604004
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 124  U=478.305  z_cont=[11.2,12.4]
#   x: grad_norm=4.4902191162109375
#   y: grad_norm=12.23481273651123
# Fine-tune at epoch 125
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 125  U=477.850  z_cont=[11.2,12.4]
#   x: grad_norm=5.135685443878174
#   y: grad_norm=14.24830436706543
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 126  U=475.718  z_cont=[11.2,12.4]
#   x: grad_norm=8.25720500946045
#   y: grad_norm=22.30572509765625
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 127  U=477.577  z_cont=[11.2,12.4]
#   x: grad_norm=5.858938694000244
#   y: grad_norm=16.027786254882812
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 128  U=479.291  z_cont=[11.2,12.4]
#   x: grad_norm=0.22035153210163116
#   y: grad_norm=0.6254878640174866
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 129  U=478.043  z_cont=[11.2,12.4]
#   x: grad_norm=5.014316082000732
#   y: grad_norm=13.778877258300781
# Fine-tune at epoch 130
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 130  U=478.943  z_cont=[11.2,12.4]
#   x: grad_norm=2.7440178394317627
#   y: grad_norm=7.422865390777588
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 131  U=478.215  z_cont=[11.2,12.4]
#   x: grad_norm=4.72738790512085
#   y: grad_norm=12.762704849243164
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 132  U=475.303  z_cont=[11.2,12.4]
#   x: grad_norm=8.641968727111816
#   y: grad_norm=23.684001922607422
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 133  U=476.802  z_cont=[11.2,12.4]
#   x: grad_norm=7.029764175415039
#   y: grad_norm=18.96570587158203
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 134  U=479.166  z_cont=[11.2,12.4]
#   x: grad_norm=1.4412657022476196
#   y: grad_norm=4.08458948135376
# Fine-tune at epoch 135
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 135  U=473.612  z_cont=[11.2,12.4]
#   x: grad_norm=10.143351554870605
#   y: grad_norm=27.600330352783203
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 136  U=462.615  z_cont=[11.2,12.4]
#   x: grad_norm=14.558475494384766
#   y: grad_norm=39.50722122192383
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 137  U=479.312  z_cont=[11.2,12.4]
#   x: grad_norm=0.10401923954486847
#   y: grad_norm=0.2638472616672516
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 138  U=465.465  z_cont=[11.2,12.4]
#   x: grad_norm=13.916468620300293
#   y: grad_norm=37.7528190612793
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 139  U=473.041  z_cont=[11.2,12.4]
#   x: grad_norm=10.530899047851562
#   y: grad_norm=28.71052360534668
# Fine-tune at epoch 140
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 140  U=478.854  z_cont=[11.2,12.4]
#   x: grad_norm=2.6135897636413574
#   y: grad_norm=7.396877288818359
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 141  U=471.185  z_cont=[11.2,12.4]
#   x: grad_norm=11.675779342651367
#   y: grad_norm=31.524682998657227
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 142  U=473.977  z_cont=[11.2,12.4]
#   x: grad_norm=9.779191970825195
#   y: grad_norm=26.816722869873047
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 143  U=479.283  z_cont=[11.2,12.4]
#   x: grad_norm=0.09892135858535767
#   y: grad_norm=0.2622211277484894
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 144  U=474.944  z_cont=[11.2,12.4]
#   x: grad_norm=9.060077667236328
#   y: grad_norm=24.61107063293457
# Fine-tune at epoch 145
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 145  U=470.306  z_cont=[11.2,12.4]
#   x: grad_norm=12.00888729095459
#   y: grad_norm=32.85847091674805
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 146  U=477.311  z_cont=[11.2,12.4]
#   x: grad_norm=6.323015213012695
#   y: grad_norm=17.00118064880371
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 147  U=478.436  z_cont=[11.2,12.4]
#   x: grad_norm=4.280860900878906
#   y: grad_norm=11.554001808166504
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 148  U=473.007  z_cont=[11.2,12.4]
#   x: grad_norm=10.615034103393555
#   y: grad_norm=28.798988342285156
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 149  U=475.717  z_cont=[11.2,12.4]
#   x: grad_norm=8.290887832641602
#   y: grad_norm=22.631484985351562
# Fine-tune at epoch 150
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 150  U=478.766  z_cont=[11.2,12.4]
#   x: grad_norm=3.448782444000244
#   y: grad_norm=9.371819496154785
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 151  U=468.307  z_cont=[11.2,12.4]
#   x: grad_norm=13.07807445526123
#   y: grad_norm=35.61996078491211
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 152  U=474.955  z_cont=[11.2,12.4]
#   x: grad_norm=9.058403968811035
#   y: grad_norm=24.87216567993164
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 153  U=478.890  z_cont=[11.2,12.4]
#   x: grad_norm=2.977736711502075
#   y: grad_norm=8.279224395751953
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 154  U=471.704  z_cont=[11.2,12.4]
#   x: grad_norm=11.483567237854004
#   y: grad_norm=31.2017879486084
# Fine-tune at epoch 155
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 155  U=472.811  z_cont=[11.2,12.4]
#   x: grad_norm=10.77566146850586
#   y: grad_norm=29.4196834564209
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 156  U=479.007  z_cont=[11.2,12.4]
#   x: grad_norm=2.6524081230163574
#   y: grad_norm=7.348596572875977
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 157  U=477.006  z_cont=[11.2,12.4]
#   x: grad_norm=6.840119361877441
#   y: grad_norm=18.803071975708008
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 158  U=473.165  z_cont=[11.2,12.4]
#   x: grad_norm=10.542279243469238
#   y: grad_norm=28.799087524414062
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 159  U=477.468  z_cont=[11.2,12.4]
#   x: grad_norm=6.189391136169434
#   y: grad_norm=16.9815731048584
# Fine-tune at epoch 160
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 160  U=477.803  z_cont=[11.2,12.4]
#   x: grad_norm=5.65643310546875
#   y: grad_norm=15.38570785522461
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 161  U=475.481  z_cont=[11.2,12.4]
#   x: grad_norm=8.627643585205078
#   y: grad_norm=23.662996292114258
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 162  U=477.579  z_cont=[11.2,12.4]
#   x: grad_norm=6.050937175750732
#   y: grad_norm=16.566064834594727
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 163  U=479.371  z_cont=[11.2,12.4]
#   x: grad_norm=0.1945793479681015
#   y: grad_norm=0.48634073138237
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 164  U=478.044  z_cont=[11.2,12.4]
#   x: grad_norm=5.266034126281738
#   y: grad_norm=14.362274169921875
# Fine-tune at epoch 165
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 165  U=474.967  z_cont=[11.2,12.4]
#   x: grad_norm=9.156316757202148
#   y: grad_norm=24.951248168945312
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 166  U=475.538  z_cont=[11.2,12.4]
#   x: grad_norm=8.587069511413574
#   y: grad_norm=23.5815372467041
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 167  U=479.047  z_cont=[11.2,12.4]
#   x: grad_norm=2.6855247020721436
#   y: grad_norm=7.317424297332764
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 168  U=478.518  z_cont=[11.2,12.4]
#   x: grad_norm=4.276486396789551
#   y: grad_norm=11.719663619995117
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 169  U=475.857  z_cont=[11.2,12.4]
#   x: grad_norm=8.31973648071289
#   y: grad_norm=23.196428298950195
# Fine-tune at epoch 170
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 170  U=478.421  z_cont=[11.2,12.4]
#   x: grad_norm=4.369902610778809
#   y: grad_norm=11.729930877685547
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 171  U=478.331  z_cont=[11.2,12.4]
#   x: grad_norm=4.6373772621154785
#   y: grad_norm=12.500378608703613
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 172  U=474.189  z_cont=[11.2,12.4]
#   x: grad_norm=9.770965576171875
#   y: grad_norm=26.86697769165039
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 173  U=475.959  z_cont=[11.2,12.4]
#   x: grad_norm=8.204826354980469
#   y: grad_norm=22.398723602294922
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 174  U=479.266  z_cont=[11.2,12.4]
#   x: grad_norm=1.696218729019165
#   y: grad_norm=4.638028144836426
# Fine-tune at epoch 175
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 175  U=477.386  z_cont=[11.2,12.4]
#   x: grad_norm=6.289913654327393
#   y: grad_norm=17.414363861083984
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 176  U=473.142  z_cont=[11.2,12.4]
#   x: grad_norm=10.60633659362793
#   y: grad_norm=28.901002883911133
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 177  U=476.659  z_cont=[11.2,12.4]
#   x: grad_norm=7.387274265289307
#   y: grad_norm=20.253379821777344
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 178  U=479.383  z_cont=[11.2,12.4]
#   x: grad_norm=0.1608411818742752
#   y: grad_norm=0.3855070173740387
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 179  U=477.017  z_cont=[11.2,12.4]
#   x: grad_norm=6.870294094085693
#   y: grad_norm=18.909238815307617
# Fine-tune at epoch 180
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 180  U=470.078  z_cont=[11.2,12.4]
#   x: grad_norm=12.28139591217041
#   y: grad_norm=33.74940872192383
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 181  U=473.048  z_cont=[11.2,12.4]
#   x: grad_norm=10.690962791442871
#   y: grad_norm=29.116195678710938
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 182  U=479.402  z_cont=[11.2,12.4]
#   x: grad_norm=0.33766719698905945
#   y: grad_norm=0.9917759895324707
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 183  U=474.666  z_cont=[11.2,12.4]
#   x: grad_norm=9.467020034790039
#   y: grad_norm=25.90692710876465
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 184  U=471.982  z_cont=[11.2,12.4]
#   x: grad_norm=11.32988166809082
#   y: grad_norm=31.041982650756836
# Fine-tune at epoch 185
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 185  U=479.135  z_cont=[11.2,12.4]
#   x: grad_norm=2.4541208744049072
#   y: grad_norm=6.684038162231445
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 186  U=460.982  z_cont=[11.2,12.4]
#   x: grad_norm=14.970417022705078
#   y: grad_norm=40.85264205932617
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 187  U=477.044  z_cont=[11.2,12.4]
#   x: grad_norm=6.931660175323486
#   y: grad_norm=19.00868034362793
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 188  U=475.098  z_cont=[11.2,12.4]
#   x: grad_norm=9.077141761779785
#   y: grad_norm=24.89432716369629
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 189  U=465.290  z_cont=[11.2,12.4]
#   x: grad_norm=14.102927207946777
#   y: grad_norm=38.4808235168457
# Fine-tune at epoch 190
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 190  U=477.768  z_cont=[11.2,12.4]
#   x: grad_norm=5.833166122436523
#   y: grad_norm=15.80393123626709
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 191  U=477.644  z_cont=[11.2,12.4]
#   x: grad_norm=6.052851676940918
#   y: grad_norm=16.41575050354004
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 192  U=470.974  z_cont=[11.2,12.4]
#   x: grad_norm=11.8917818069458
#   y: grad_norm=32.65163803100586
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 193  U=476.462  z_cont=[11.2,12.4]
#   x: grad_norm=7.709129333496094
#   y: grad_norm=21.015880584716797
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 194  U=479.260  z_cont=[11.2,12.4]
#   x: grad_norm=2.0004186630249023
#   y: grad_norm=5.425720691680908
# Fine-tune at epoch 195
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 195  U=477.274  z_cont=[11.2,12.4]
#   x: grad_norm=6.557875633239746
#   y: grad_norm=18.136159896850586
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 196  U=478.491  z_cont=[11.2,12.4]
#   x: grad_norm=4.483281135559082
#   y: grad_norm=12.15954303741455
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 197  U=479.441  z_cont=[11.2,12.4]
#   x: grad_norm=0.48201489448547363
#   y: grad_norm=1.3657588958740234
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 198  U=478.948  z_cont=[11.2,12.4]
#   x: grad_norm=3.313342809677124
#   y: grad_norm=9.048070907592773
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 199  U=478.082  z_cont=[11.2,12.4]
#   x: grad_norm=5.3320159912109375
#   y: grad_norm=14.690455436706543
# Fine-tune at epoch 200
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 200  U=478.066  z_cont=[11.2,12.4]
#   x: grad_norm=5.331244945526123
#   y: grad_norm=14.729023933410645
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 201  U=478.877  z_cont=[11.2,12.4]
#   x: grad_norm=3.5503718852996826
#   y: grad_norm=9.573610305786133
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 202  U=479.454  z_cont=[11.2,12.4]
#   x: grad_norm=0.5003296136856079
#   y: grad_norm=1.3914448022842407
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 203  U=479.201  z_cont=[11.2,12.4]
#   x: grad_norm=2.409400463104248
#   y: grad_norm=6.562923908233643
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 204  U=478.643  z_cont=[11.2,12.4]
#   x: grad_norm=4.162436485290527
#   y: grad_norm=11.480581283569336
# Fine-tune at epoch 205
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 205  U=477.591  z_cont=[11.2,12.4]
#   x: grad_norm=6.161065578460693
#   y: grad_norm=17.02313232421875
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 206  U=476.955  z_cont=[11.2,12.4]
#   x: grad_norm=7.184852123260498
#   y: grad_norm=19.47840118408203
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 207  U=478.351  z_cont=[11.2,12.4]
#   x: grad_norm=4.894337177276611
#   y: grad_norm=13.45594310760498
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 208  U=479.462  z_cont=[11.2,12.4]
#   x: grad_norm=0.9239687323570251
#   y: grad_norm=2.532459259033203
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 209  U=479.080  z_cont=[11.2,12.4]
#   x: grad_norm=2.997087240219116
#   y: grad_norm=8.270209312438965
# Fine-tune at epoch 210
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 210  U=477.711  z_cont=[11.2,12.4]
#   x: grad_norm=6.006733417510986
#   y: grad_norm=16.607759475708008
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 211  U=477.165  z_cont=[11.2,12.4]
#   x: grad_norm=6.922225475311279
#   y: grad_norm=18.835756301879883
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 212  U=478.363  z_cont=[11.2,12.4]
#   x: grad_norm=4.936797618865967
#   y: grad_norm=13.542274475097656
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 213  U=479.436  z_cont=[11.2,12.4]
#   x: grad_norm=1.374599814414978
#   y: grad_norm=3.801150321960449
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 214  U=479.279  z_cont=[11.2,12.4]
#   x: grad_norm=2.261897563934326
#   y: grad_norm=6.289437770843506
# Fine-tune at epoch 215
# ...
#   y: grad_norm=20.389352798461914
# Fine-tune at epoch 1180
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1180  U=536.799  z_cont=[11.1,12.4]
#   x: grad_norm=16.29263687133789
#   y: grad_norm=32.79942321777344
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1181  U=537.328  z_cont=[11.1,12.4]
#   x: grad_norm=18.42702293395996
#   y: grad_norm=30.18198013305664
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1182  U=577.370  z_cont=[11.1,12.4]
#   x: grad_norm=5.713665962219238
#   y: grad_norm=10.137150764465332
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1183  U=542.604  z_cont=[11.1,12.4]
#   x: grad_norm=20.86644744873047
#   y: grad_norm=37.23130798339844
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1184  U=534.459  z_cont=[11.1,12.4]
#   x: grad_norm=16.758817672729492
#   y: grad_norm=37.36644744873047
# Fine-tune at epoch 1185
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1185  U=567.954  z_cont=[11.1,12.4]
#   x: grad_norm=18.373586654663086
#   y: grad_norm=44.22920227050781
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1186  U=560.431  z_cont=[11.1,12.4]
#   x: grad_norm=12.87069034576416
#   y: grad_norm=38.82539749145508
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1187  U=558.257  z_cont=[11.1,12.4]
#   x: grad_norm=12.206907272338867
#   y: grad_norm=35.7302360534668
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1188  U=574.225  z_cont=[11.1,12.4]
#   x: grad_norm=15.021251678466797
#   y: grad_norm=31.50537872314453
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1189  U=561.126  z_cont=[11.1,12.4]
#   x: grad_norm=15.940495491027832
#   y: grad_norm=26.767080307006836
# Fine-tune at epoch 1190
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1190  U=565.196  z_cont=[11.1,12.4]
#   x: grad_norm=11.353431701660156
#   y: grad_norm=29.668581008911133
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1191  U=576.318  z_cont=[11.1,12.4]
#   x: grad_norm=6.156931400299072
#   y: grad_norm=13.73946475982666
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1192  U=562.166  z_cont=[11.1,12.4]
#   x: grad_norm=12.162744522094727
#   y: grad_norm=31.832672119140625
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1193  U=577.429  z_cont=[11.1,12.4]
#   x: grad_norm=4.7108845710754395
#   y: grad_norm=12.077798843383789
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1194  U=569.033  z_cont=[11.1,12.4]
#   x: grad_norm=9.86597728729248
#   y: grad_norm=27.81241798400879
# Fine-tune at epoch 1195
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1195  U=564.935  z_cont=[11.1,12.4]
#   x: grad_norm=11.129494667053223
#   y: grad_norm=32.456581115722656
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1196  U=569.952  z_cont=[11.1,12.4]
#   x: grad_norm=18.514570236206055
#   y: grad_norm=42.81229782104492
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1197  U=557.179  z_cont=[11.1,12.4]
#   x: grad_norm=18.41197395324707
#   y: grad_norm=30.141353607177734
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1198  U=568.330  z_cont=[11.1,12.4]
#   x: grad_norm=14.266365051269531
#   y: grad_norm=23.42617416381836
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1199  U=558.091  z_cont=[11.1,12.4]
#   x: grad_norm=25.52277183532715
#   y: grad_norm=51.26932144165039
# Fine-tune at epoch 1200
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1200  U=556.965  z_cont=[11.1,12.4]
#   x: grad_norm=15.3851957321167
#   y: grad_norm=43.50450897216797
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1201  U=565.815  z_cont=[11.1,12.4]
#   x: grad_norm=12.647868156433105
#   y: grad_norm=37.28071594238281
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1202  U=554.987  z_cont=[11.1,12.4]
#   x: grad_norm=26.84215545654297
#   y: grad_norm=60.0142822265625
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1203  U=557.959  z_cont=[11.1,12.4]
#   x: grad_norm=17.422767639160156
#   y: grad_norm=28.402542114257812
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1204  U=560.405  z_cont=[11.1,12.4]
#   x: grad_norm=21.683164596557617
#   y: grad_norm=39.39395523071289
# Fine-tune at epoch 1205
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1205  U=561.120  z_cont=[11.1,12.4]
#   x: grad_norm=24.67391586303711
#   y: grad_norm=50.2161865234375
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1206  U=566.985  z_cont=[11.1,12.4]
#   x: grad_norm=11.381110191345215
#   y: grad_norm=26.550167083740234
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1207  U=563.192  z_cont=[11.1,12.4]
#   x: grad_norm=22.77452278137207
#   y: grad_norm=52.206111907958984
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1208  U=555.240  z_cont=[11.1,12.4]
#   x: grad_norm=24.338760375976562
#   y: grad_norm=56.8986930847168
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1209  U=566.793  z_cont=[11.1,12.4]
#   x: grad_norm=12.238770484924316
#   y: grad_norm=25.34137725830078
# Fine-tune at epoch 1210
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1210  U=556.503  z_cont=[11.1,12.4]
#   x: grad_norm=27.01559066772461
#   y: grad_norm=56.03136444091797
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1211  U=544.857  z_cont=[11.1,12.4]
#   x: grad_norm=27.239564895629883
#   y: grad_norm=55.4620246887207
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1212  U=556.788  z_cont=[11.1,12.4]
#   x: grad_norm=15.973548889160156
#   y: grad_norm=28.580530166625977
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1213  U=550.840  z_cont=[11.1,12.4]
#   x: grad_norm=27.623462677001953
#   y: grad_norm=61.999813079833984
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1214  U=568.674  z_cont=[11.1,12.4]
#   x: grad_norm=14.756237030029297
#   y: grad_norm=39.521087646484375
# Fine-tune at epoch 1215
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1215  U=554.136  z_cont=[11.1,12.4]
#   x: grad_norm=12.48195743560791
#   y: grad_norm=36.51365661621094
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1216  U=575.359  z_cont=[11.1,12.4]
#   x: grad_norm=12.859110832214355
#   y: grad_norm=24.05649185180664
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1217  U=563.180  z_cont=[11.1,12.4]
#   x: grad_norm=13.783188819885254
#   y: grad_norm=27.137842178344727
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1218  U=566.170  z_cont=[11.1,12.4]
#   x: grad_norm=13.589934349060059
#   y: grad_norm=24.477588653564453
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1219  U=575.152  z_cont=[11.1,12.4]
#   x: grad_norm=12.166803359985352
#   y: grad_norm=21.046987533569336
# Fine-tune at epoch 1220
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1220  U=560.831  z_cont=[11.1,12.4]
#   x: grad_norm=12.635758399963379
#   y: grad_norm=31.909944534301758
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1221  U=571.296  z_cont=[11.1,12.4]
#   x: grad_norm=14.382683753967285
#   y: grad_norm=37.106666564941406
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1222  U=560.078  z_cont=[11.1,12.4]
#   x: grad_norm=18.759716033935547
#   y: grad_norm=48.19643783569336
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1223  U=560.717  z_cont=[11.1,12.4]
#   x: grad_norm=14.655933380126953
#   y: grad_norm=29.026905059814453
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1224  U=570.115  z_cont=[11.1,12.4]
#   x: grad_norm=19.46885108947754
#   y: grad_norm=40.016910552978516
# Fine-tune at epoch 1225
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1225  U=542.787  z_cont=[11.1,12.4]
#   x: grad_norm=23.197263717651367
#   y: grad_norm=43.463409423828125
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1226  U=548.870  z_cont=[11.1,12.4]
#   x: grad_norm=16.487995147705078
#   y: grad_norm=32.086544036865234
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1227  U=559.548  z_cont=[11.1,12.4]
#   x: grad_norm=24.228429794311523
#   y: grad_norm=55.65886688232422
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1228  U=561.020  z_cont=[11.1,12.4]
#   x: grad_norm=14.200162887573242
#   y: grad_norm=41.00395202636719
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1229  U=557.280  z_cont=[11.1,12.4]
#   x: grad_norm=12.464092254638672
#   y: grad_norm=37.46833419799805
# Fine-tune at epoch 1230
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1230  U=576.727  z_cont=[11.1,12.4]
#   x: grad_norm=10.510870933532715
#   y: grad_norm=20.00716209411621
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1231  U=566.845  z_cont=[11.1,12.4]
#   x: grad_norm=10.546001434326172
#   y: grad_norm=29.688920974731445
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1232  U=568.978  z_cont=[11.1,12.4]
#   x: grad_norm=14.38236141204834
#   y: grad_norm=23.71442222595215
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1233  U=576.487  z_cont=[11.1,12.4]
#   x: grad_norm=9.128116607666016
#   y: grad_norm=15.236964225769043
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1234  U=569.382  z_cont=[11.1,12.4]
#   x: grad_norm=10.138209342956543
#   y: grad_norm=24.65495491027832
# Fine-tune at epoch 1235
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1235  U=575.478  z_cont=[11.1,12.4]
#   x: grad_norm=13.275103569030762
#   y: grad_norm=27.745159149169922
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1236  U=558.855  z_cont=[11.1,12.4]
#   x: grad_norm=22.460811614990234
#   y: grad_norm=53.90947723388672
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1237  U=569.051  z_cont=[11.1,12.4]
#   x: grad_norm=16.682397842407227
#   y: grad_norm=28.5804386138916
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1238  U=578.008  z_cont=[11.1,12.4]
#   x: grad_norm=7.4648003578186035
#   y: grad_norm=17.238811492919922
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1239  U=560.009  z_cont=[11.1,12.4]
#   x: grad_norm=23.151779174804688
#   y: grad_norm=44.35475540161133
# Fine-tune at epoch 1240
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1240  U=567.312  z_cont=[11.1,12.4]
#   x: grad_norm=19.756711959838867
#   y: grad_norm=46.38601303100586
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1241  U=577.532  z_cont=[11.1,12.4]
#   x: grad_norm=8.757139205932617
#   y: grad_norm=19.63384246826172
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1242  U=577.439  z_cont=[11.1,12.4]
#   x: grad_norm=5.327598571777344
#   y: grad_norm=16.034603118896484
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1243  U=573.734  z_cont=[11.1,12.4]
#   x: grad_norm=15.662784576416016
#   y: grad_norm=31.893831253051758
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1244  U=569.242  z_cont=[11.1,12.4]
#   x: grad_norm=20.041297912597656
#   y: grad_norm=40.51115036010742
# Fine-tune at epoch 1245
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1245  U=565.227  z_cont=[11.1,12.4]
#   x: grad_norm=22.024545669555664
#   y: grad_norm=50.240478515625
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1246  U=568.466  z_cont=[11.1,12.4]
#   x: grad_norm=20.832942962646484
#   y: grad_norm=44.0772705078125
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1247  U=576.948  z_cont=[11.1,12.4]
#   x: grad_norm=10.24827766418457
#   y: grad_norm=19.54325294494629
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1248  U=578.728  z_cont=[11.1,12.4]
#   x: grad_norm=4.672662258148193
#   y: grad_norm=7.929383754730225
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# Epoch 1249  U=574.162  z_cont=[11.1,12.4]
#   x: grad_norm=15.205554962158203
#   y: grad_norm=31.603504180908203
# Fine-tune at epoch 1250
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt
# CPU times: user 29.8 s, sys: 1.46 s, total: 31.3 s
# Wall time: 3min 20s

# %%
plt.figure(figsize=(10, 4))
plt.plot(U_vals,  label='Total U', color='black', lw=1.5)
plt.plot([u for u in U_th_vals],  label='U_theta',  lw=1)
plt.plot([u for u in U_phi_vals], label='U_phi',   lw=1)
plt.plot([u for u in U_e_vals],   label='U_E',    lw=1)
# plt.plot([u for u in U_pr_vals],  label='5e5 U_PR',    lw=1)
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Utility"); plt.grid()
# plt.yscale("log")
plt.title("Optimization utility components"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Visualize Results

# %%
# Top-down (N, Up) view: mountain background + optimized detectors
fig, ax = plt.subplots(figsize=(10, 7))
N_mtn  = mountain.centroids_NUE[:, 0]
Up_mtn = mountain.centroids_NUE[:, 1]
East_mtn = mountain.centroids_NUE[:, 2]
sc_bg = ax.scatter(N_mtn, Up_mtn, c=East_mtn, s=1, cmap='terrain', alpha=0.4)
plt.colorbar(sc_bg, ax=ax, label='East [m]')

x_final = x_det_opt.detach().cpu().numpy()
y_final = y_det_opt.detach().cpu().numpy()

with torch.no_grad():
    east_final = surface(x_det_opt.detach(), y_det_opt.detach()).detach()
    zc_final   = (mountain.east_entry - east_final) / mountain.layer_east_dx

ax.scatter(N_init, U_init,          c='blue',  s=30, alpha=.6, label='Initial')
ax.scatter(x_final, y_final,        c='red',   s=30, alpha=.8, label='Final (optimized)')
ax.set_xlabel("North [m]"); ax.set_ylabel("Up [m]")
ax.set_title("Detector layout on mountain surface (top-down)")
ax.legend(); plt.tight_layout(); plt.show()

# %%
u_t = np.vstack([u_prev, u_row])
# Plot all components
mean_ut = [np.mean(u_t[max(0, i-4):i, 0]) for i in range(1, len(u_t)+1)]
plt.plot(u_t[:, 0], color="black", linestyle="none", marker="o", lw=.5, ms=3, label="U total")
plt.plot(mean_ut, color="red", lw=2, label="Rolling mean (4)")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
plt.title("Total Utility per Optimization Step"); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3D Scatter on Mountain Surface

# %%
fig = plt.figure(figsize=(12, 8))
ax3 = fig.add_subplot(111, projection='3d')

# Axes: x=North, y=East, z=Up  (Up is the vertical axis)
ax3.scatter(N_mtn, East_mtn, Up_mtn, c=East_mtn, cmap='terrain',
            s=1, alpha=0.15, depthshade=True)

sc_det = ax3.scatter(
    x_final, east_final.cpu().numpy(), y_final,
    c=zc_final.cpu().numpy(), cmap='plasma',
    vmin=0, vmax=N_PLANES - 1, s=50, zorder=5, depthshade=False
)
plt.colorbar(sc_det, ax=ax3, label='z_cont (plane index)', pad=0.1)

ax3.view_init(elev=20, azim=30)
ax3.set_xlabel("North [m]"); ax3.set_ylabel("East [m]"); ax3.set_zlabel("Up [m]")
ax3.set_title("Optimized detector positions on the Colca Valley mountain surface")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Animation: Detectors Sliding on Mountain

# %%
# %%capture
from matplotlib import animation
from IPython.display import HTML

layout_dir = Path(f"{output_dir}/Python_Layout")
layout_files = sorted(layout_dir.glob("Layout_*.txt"),
                      key=lambda p: int(p.stem.split("_")[1]))

step_sample = 5  # use every 5th saved layout
layouts = [np.loadtxt(f) for f in layout_files[::step_sample]]
print(f"Loaded {len(layouts)} layout frames")

N_mtn_a  = mountain.centroids_NUE[:, 0]
Up_mtn_a = mountain.centroids_NUE[:, 1]
East_mtn_a = mountain.centroids_NUE[:, 2]

fig_a = plt.figure(figsize=(11, 7))
ax_a  = fig_a.add_subplot(111, projection='3d')

# Static mountain background (drawn once)
ax_a.scatter(N_mtn_a, East_mtn_a, Up_mtn_a, c=East_mtn_a, cmap='terrain',
             s=1, alpha=0.15, depthshade=True)
ax_a.set_xlabel("North [m]"); ax_a.set_ylabel("East [m]"); ax_a.set_zlabel("Up [m]")
ax_a.view_init(elev=20, azim=30)


# Animated detector scatter — initialize with first frame
lay0 = layouts[0]
N_d0, Up_d0, zc_d0 = lay0[:, 0], lay0[:, 1], lay0[:, 2]
East_d0 = mountain.east_entry - zc_d0 * mountain.layer_east_dx
det_scatter = ax_a.scatter(N_d0, East_d0, Up_d0, c=zc_d0, cmap='plasma',
                           vmin=0, vmax=N_PLANES - 1, s=40, zorder=5, depthshade=False)
title_obj = ax_a.set_title("Step 0")


def _update(frame):
    lay = layouts[frame]
    N_d, Up_d, zc_d = lay[:, 0], lay[:, 1], lay[:, 2]
    East_d = mountain.east_entry - zc_d * mountain.layer_east_dx
    det_scatter._offsets3d = (N_d, East_d, Up_d)
    det_scatter.set_array(zc_d)
    title_obj.set_text(f"Step {frame * step_sample}")
    return det_scatter, title_obj


anim = animation.FuncAnimation(fig_a, _update, frames=len(layouts), interval=120, blit=False)

gif_path = Path(output_dir) / "layout_evolution_3d.gif"
anim.save(str(gif_path), writer="pillow", fps=8, dpi=100)
plt.close(fig_a)
print(f"Saved {gif_path}")

# %%
# HTML(anim.to_jshtml())

# %% [markdown]
# ## Evaluate Reconstruction (final layout)

# %%
x, y = x_det_opt, y_det_opt
with torch.no_grad():
    east_eval = surface(x, y)
    zc_eval   = (mountain.east_entry - east_eval) / mountain.layer_east_dx
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a, _ = generate_showers(
        x, y, zc_eval, False, number_of_showers=Ntest, use_cache=use_cache
    )

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)
E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000; y0 = Y0 / 5000
z_exp   = zc_eval.unsqueeze(0).expand(Ntest, -1)
x_det_exp = x.unsqueeze(0).expand(Ntest, -1)
y_det_exp = y.unsqueeze(0).expand(Ntest, -1)
x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)
# inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test_final = torch.stack([x_det_exp, y_det_exp, z_exp, N, T], dim=2).float()
labels_test_final = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_41_10_shower_mean_U_lr_1/cashed_showers_10.pt

# %%
model.eval()
with torch.no_grad():
    inputs_n = (inputs_test_final.cpu() - input_mean.cpu()) / input_std.cpu()
    outputs = model(inputs_n.view(Ntest, -1).to(device)).cpu()

E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb,  theta_lb,  phi_lb  = DenormalizeLabels(
    labels_test_final[:, 0], labels_test_final[:, 1], labels_test_final[:, 2]
)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].scatter(E_lb.cpu(), E_pred.cpu(), alpha=.5, color="r")
axes[0].plot([E_lb.detach().cpu().min(), E_lb.detach().cpu().max()], [E_lb.detach().cpu().min(), E_lb.detach().cpu().max()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()
axes[0].set_xscale("log"); axes[0].set_yscale("log")
axes[0].set_xlim([6e4, 3e8])
axes[0].set_ylim([6e4, 3e8])

axes[1].scatter(theta_lb.cpu(), theta_pred.detach().cpu(), alpha=.5, color="r")
axes[1].plot([Th_r.min().cpu(), Th_r.max().cpu()], [Th_r.min().cpu(), Th_r.max().cpu()], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(phi_lb.cpu(), phi_pred.detach().cpu(), alpha=.5, color="r")
axes[2].plot([Ph_r.min().cpu(), Ph_r.max().cpu()], [Ph_r.min().cpu(), Ph_r.max().cpu()], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.suptitle("NN Reconstruction Quality (optimized layout)", fontsize=13)
plt.tight_layout(); plt.show()
