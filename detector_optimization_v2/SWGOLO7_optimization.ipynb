# %% [markdown]
# # SWGO L07 Detector Optimization (Refactored)
#
# All utility functions have been extracted into separate Python modules.
# This notebook preserves the original optimization logic.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc

# Extracted module imports
from shower_generation import GenerateShowers
from detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from geometry import Layouts
from reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from layout_optimization import LearnableXY, push_apart, symmetry_loss
from utility_functions import reconstructability, U_PR, U_E, U_angle

output_dir = "./outputs/NN_Files_28_20k_max_n_capured"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and Parameters

# %%
# Matrices used in shower parametrization
A = torch.tensor([[1, 1, 1, 1],[1, 2, 4, 8], [1, 3, 9, 27], [1, 4, 16, 64]], dtype=torch.float32)

# Constants
c0 = .29979  # Speed of light in [m / ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)
sqrt12 = torch.tensor([np.sqrt(12)], dtype=torch.float32)

# Tank Values
IntegrationWindow = 128.  # 128 ns integration window, SWGO default
sigma_time = 10.  # Time resolution assumed for the detectors
R_min = 2.
TankArea = 6.859 * np.pi  # Area for 19 hexagonal macro unit
TankRadius = np.sqrt(6.859)  # Radius of macro unit

# Background
Bgr_mu_per_m2 = 0.000001826 * IntegrationWindow
fluxB_m = torch.tensor([TankArea * Bgr_mu_per_m2])
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Sizes
Nunits = 90 # 500
n_rings = 5 #20
RelResCounts = .05

# Debug Parameters
largenumber = 1e13
epsilon = 1 / largenumber

# NN
Nevents = 20000#200000
Nvalidation = 2000#20000
Ntest = 300#3000

# Layout
SWGOopt = False

# shower denormalization stats
STATS_PATH = '/n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/pre_processed_3rd_step/standardization_stats_train_only.pt'

x_det, y_det = Layouts(n_detectors=Nunits, n_rings=n_rings, radius=300, center=(300,0), device=device)
generate_new_data = False

# %% [markdown]
# ## Initialize Diffusion Model

# %%
from diffusion_model.tambo_3D_diffusion_generator import PlaneDiffusionEvaluator

generator = PlaneDiffusionEvaluator(
    data_dir="/n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/pre_processed_3rd_step/",
    checkpoint_path="/n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/checkpoints/tam_unet/epoch_epoch=1229-val_loss_val_loss=0.0333.ckpt",
    ddim_steps=20,
    eta=0.0,
    guidance_w=1.8,
    imports_path="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/hhanif/tambo_optimization/unet"
)
generator.load_model()
# Out:
# Initialized PlaneDiffusionEvaluator
# Device: cuda:0
# Model parameters: 12,408,387
# Loaded checkpoint: /n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/checkpoints/tam_unet/epoch_epoch=1229-val_loss_val_loss=0.0333.ckpt
# DDIM sampler built (ddim_steps=20, eta=0.0, w=1.8)
# Model loading time: 0.82s

# %%
from diffusion_model.tambo_3D_fnn_scaler import PlaneFNNGenerator

scaler = PlaneFNNGenerator(
    data_dir="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/pre_processed_3rd_step_min_50/",
    checkpoint_path="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/checkpoints/tam_fnn/last.ckpt",
    imports_path="/n/home05/zdimitrov/tambo/TambOpt/ml/scaling_NN/FNN/"
)
scaler.load_model()
# Out:
# Initialized PlaneFNNGenerator
# Device: cuda:0
# Loaded standardization stats from: /n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/pre_processed_3rd_step_min_50/global_bbox_stats.pt
#   Mean: 90.71444702148438
#   Std: 140.77218627929688
# Model parameters: 3,751,008
# Loaded checkpoint: /n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/checkpoints/tam_fnn/last.ckpt
# Using EMA weights for inference
# Model parameters: 3,751,008
# Model loading time: 0.22s

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Create wrapped versions that capture the global dependencies
import functools

_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                  IntegrationWindow=IntegrationWindow,
                                  sigma_time=sigma_time)
_GetCounts = functools.partial(GetCounts_differentiable,
                                SmearN_fn=_SmearN,
                                fluxB_e=fluxB_e,
                                TimeAverage_vectorized_fn=_TimeAverage)

def generate_showers(x_det, y_det, log=False, number_of_showers=1, device=device, use_cache=False):
    return GenerateShowers(x_det, y_det, generator, scaler, _GetCounts,
                           log=log, number_of_showers=number_of_showers, stats_path=STATS_PATH, device=device, 
                           use_cache=use_cache, output_dir=output_dir)

# %% [markdown]
# ## Visualize Initial Layout

# %%
plt.figure(figsize=[6, 6])
plt.scatter(x_det.cpu().detach(), y_det.cpu().detach(), color="red")
plt.grid()
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.title("Initial Position of the detectors")
plt.xlim((-50, 650))
plt.ylim((-350, 350))
plt.show()

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x_det, y_det, True, number_of_showers=10)
# Out:
# Processing conditions 0 to 10 / 10...

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 90])
# T: torch.Size([10, 90])
# X0: tensor([444.8161,  96.0104, 289.3977, 395.4639, 249.4876, 544.0464, 535.7203,
#         227.8309, 391.3791, 370.0404], device='cuda:0')
# Y0: tensor([25.7651,  4.7048,  8.4286, 27.9064, 10.5181, 24.4813,  8.1706, 15.5701,
#         15.7191, 13.2656], device='cuda:0')
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes  = axes.flatten()

for i in range(n_events):
    N_tmp = N[i]
    idx = torch.where(N_tmp >= 5e-2)[0]
    norm = LogNorm(vmin=5e-2, vmax=5e-1)

    scatter = axes[i].scatter(x_det[idx].detach().cpu(), y_det[idx].detach().cpu(), c=N_tmp[idx].detach().cpu(), cmap="viridis", norm=norm)
    axes[i].scatter(X0[i].item(), Y0[i].item(), c="red", marker="d")
    fig.colorbar(scatter, ax=axes[i], label='Number of detected particles')
    axes[i].set_xlabel("x [m]"); axes[i].set_ylabel("y [m]")
    axes[i].set_xlim((-50, 650)); axes[i].set_ylim((-350, 350))
    axes[i].set_title(f"Event {i}: E={energy[i].item():.3f} PeV, θ={th[i].item()*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes  = axes.flatten()

for i in range(n_events):
    N_tmp = N[i]
    T_tmp = T[i]
    idx = torch.where(N_tmp >= 5e-2)[0]
    from matplotlib.colors import SymLogNorm
    norm = SymLogNorm(linthresh=1, vmin=-1, vmax=1)


    scatter = axes[i].scatter(x_det[idx].detach().cpu(), y_det[idx].detach().cpu(), c=T_tmp[idx].detach().cpu(), cmap="twilight", norm=norm)
    
    axes[i].scatter(X0[i].item(), Y0[i].item(), c="red", marker="d")
    fig.colorbar(scatter, ax=axes[i], label='Time of Arrival [ns]')
    axes[i].set_xlabel("x [m]"); axes[i].set_ylabel("y [m]")
    axes[i].set_xlim((-50, 650)); axes[i].set_ylim((-350, 350))
    axes[i].set_title(f"Event {i}: E={energy[i].item():.3f} PeV, θ={th[i].item()*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    N_tmp = N[i]
    T_tmp = T[i]
    idx = torch.where(N_tmp >= 5e-3)[0]
    axes[i].hist(T_tmp[idx].detach().cpu().numpy(), bins=30, edgecolor='black')
    axes[i].set_xlabel("Time of Arrival [normalized]")
    axes[i].set_ylabel("Count")
    axes[i].set_title(f"Event {i}: E={energy[i].item():.3f} PeV, θ={th[i].item()*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
# %%time

if generate_new_data:
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x_det, y_det, False, number_of_showers=Nevents, use_cache=True)

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)

    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
    x0 = X0 / 5000
    y0 = Y0 / 5000

    x_det_exp = x_det.unsqueeze(0).expand(Nevents, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nevents, -1)

    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    inputs = torch.stack([x_det_exp, y_det_exp, N, T, x0_exp, y0_exp], dim=2).float()
    labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    os.makedirs(output_dir, exist_ok=True)
    torch.save(inputs, f"{output_dir}/inputs.pt")
    torch.save(labels, f"{output_dir}/labels.pt")
# Out:
# CPU times: user 4 μs, sys: 0 ns, total: 4 μs
# Wall time: 7.15 μs

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

if generate_new_data:
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x_det, y_det, False, number_of_showers=Nvalidation, use_cache=True)

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)

    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
    x0 = X0 / 5000
    y0 = Y0 / 5000

    x_det_exp = x_det.unsqueeze(0).expand(Nvalidation, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Nvalidation, -1)

    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    inputs_val = torch.stack([x_det_exp, y_det_exp, N, T, x0_exp, y0_exp], dim=2).float()
    labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
    torch.save(labels_val, f"{output_dir}/labels_val.pt")
# Out:
# CPU times: user 9 μs, sys: 1 μs, total: 10 μs
# Wall time: 16 μs

# %% [markdown]
# ## Generate Test Data

# %%
if generate_new_data:
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x_det, y_det, False, number_of_showers=Ntest, use_cache=True)

    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)

    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
    x0 = X0 / 5000
    y0 = Y0 / 5000

    x_det_exp = x_det.unsqueeze(0).expand(Ntest, -1)
    y_det_exp = y_det.unsqueeze(0).expand(Ntest, -1)


    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    inputs_test = torch.stack([x_det_exp, y_det_exp, N, T, x0_exp, y0_exp], dim=2).float()
    labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

    torch.save(inputs_test, f"{output_dir}/inputs_test.pt")
    torch.save(labels_test, f"{output_dir}/labels_test.pt")

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs = torch.load(f"{output_dir}/inputs.pt")
labels = torch.load(f"{output_dir}/labels.pt")
inputs_val = torch.load(f"{output_dir}/inputs_val.pt")
labels_val = torch.load(f"{output_dir}/labels_val.pt")
inputs_test = torch.load(f"{output_dir}/inputs_test.pt")
labels_test = torch.load(f"{output_dir}/labels_test.pt")

# %%
# # switch normaliation value

# labels_denorm = DenormalizeLabels(labels[:,0], labels[:,1], labels[:,2], theta_max = torch.pi*65/180)
# labels_renorm = NormalizeLabels(labels_denorm[0], labels_denorm[1], labels_denorm[2])
# labels_renorm = torch.stack(labels_renorm, dim=1)

# labels_val_denorm = DenormalizeLabels(labels_val[:,0], labels_val[:,1], labels_val[:,2], theta_max = torch.pi*65/180)
# labels_val_renorm = NormalizeLabels(labels_val_denorm[0], labels_val_denorm[1], labels_val_denorm[2])
# labels_val_renorm = torch.stack(labels_val_renorm, dim=1)


# labels_test_denorm = DenormalizeLabels(labels_test[:,0], labels_test[:,1], labels_test[:,2], theta_max = torch.pi*65/180)
# labels_test_renorm = NormalizeLabels(labels_test_denorm[0], labels_test_denorm[1], labels_test_denorm[2])
# labels_test_renorm = torch.stack(labels_test_renorm, dim=1)

# # labels_renorm.shape, labels_val_renorm.shape, labels_test_renorm.shape

# torch.save(labels_renorm, f"{output_dir}/labels.pt")
# torch.save(labels_val_renorm, f"{output_dir}/labels_val.pt")
# torch.save(labels_test_renorm, f"{output_dir}/labels_test.pt")

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(
    num_detectors=Nunits,
    ).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)

# %%
# Per-feature normalization stats (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))  # [6]
input_std  = inputs.std(dim=(0, 1))   # [6]
input_std[input_std < 1e-8] = 1.0

# Normalize cached datasets
inputs     = (inputs - input_mean) / input_std
inputs_val = (inputs_val - input_mean) / input_std
inputs_test = (inputs_test - input_mean) / input_std

dataset = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=0)

# %%
# %%time
if generate_new_data:
    val_losses = []
    losses = []
    early_stopper = EarlyStopping()

    for num_epoch in range(1000):
        epoch_loss = 0
        total_batch = 0
        
        for batch_inputs, batch_labels in dataloader:
            train_x = batch_inputs.flatten(start_dim=1, end_dim=2).to(device)
            train_y = batch_labels.to(device)
            
            outputs = model(train_x)
            loss = criterion(outputs, train_y)
            epoch_loss += loss.item()
            total_batch += 1

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

        val_x = inputs_val.flatten(start_dim=1, end_dim=2).to(device)
        val_y = labels_val.to(device)

        model.eval()
        with torch.no_grad():
            val_output = model(val_x)
            val_loss = criterion(val_output, val_y)
        
        val_losses.append(val_loss.item())
        early_stopper(val_loss)

        if (num_epoch + 1) % 100 == 0:
            print(f"Training is {int((num_epoch + 1) / 10)}% done, with Loss = {val_loss:.2f}")

        losses.append(epoch_loss / total_batch)

    plt.plot(np.arange(1, len(losses) + 1), losses, color="blue", label="Training Loss")
    plt.plot(np.arange(1, len(val_losses) + 1), val_losses, color="red", label="Validation Loss")
    plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()

    torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")
# Out:
# CPU times: user 4 μs, sys: 0 ns, total: 4 μs
# Wall time: 5.48 μs

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))

model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
# x_pred = outputs[:, 0]
# y_pred = outputs[:, 1]
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])
E_lb, theta_lb, phi_lb = DenormalizeLabels(labels_test[:, 0], labels_test[:, 1], labels_test[:, 2])

E_p,    E_r     =   E_pred,       E_lb
Th_p,   Th_r    =   theta_pred,   theta_lb
Ph_p,   Ph_r    =   phi_pred,     phi_lb

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([0, np.pi], [0, np.pi], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([-np.pi, np.pi], [-np.pi, np.pi], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(
    num_detectors=Nunits,
    ).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Updated Weights are loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial Weights are loaded")
# Out:
# Initial Weights are loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x_det = torch.tensor(data[:, 0], dtype=torch.float32)
        y_det = torch.tensor(data[:, 1], dtype=torch.float32)
        e = i + 1

if e > 0:
    print(f"Updated Layout {e} is initialized")
else:
    print("First Layout is initialized")

xy_module = LearnableXY(x_det, y_det, device=device)
# Out:
# First Layout is initialized

# %% [markdown]
# ## Layout Optimization Loop

# %%
input_std = input_std.to(device)
input_mean = input_mean.to(device)

# %%
# %%time

SWGOopt = True
optimizer = torch.optim.SGD(xy_module.parameters(), lr=10, momentum=.3)

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    loss = checkpoint.get("loss")
    print(f"Optimizer is initialized from the last epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer is initialized")

# max_grad = 5. #10.
Nbatch = 500#1000

if num_epoch < 20:
    Nfinetune = 1250#2500
elif num_epoch >= 20:
    Nfinetune = 2500#5000

U_vals = []
U_th_vals = []
U_phi_vals = []
U_e_vals = []
U_pr_vals = []

for epoch in range(num_epoch, num_epoch + 300):
    x_det_opt, y_det_opt = xy_module()
    
    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x_det_opt, y_det_opt, False, number_of_showers=Nbatch, use_cache=True)
    
    th = torch.atan2(sin_z, cos_z).to(device)
    ph = torch.atan2(sin_a, cos_a).to(device)

    X0 /= 5000
    Y0 /= 5000
    
    # detector locations            
    x_det_opt_exp = x_det_opt.unsqueeze(0).repeat(Nbatch, 1)
    y_det_opt_exp = y_det_opt.unsqueeze(0).repeat(Nbatch, 1)

    # shower centers    
    x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

    inputs_batch = torch.stack([x_det_opt_exp, y_det_opt_exp, N_list, T_list, x0_exp, y0_exp], dim=2).float()
    with torch.no_grad():
        input_mean[0] = inputs_batch[:, :, 0].mean()
        input_mean[1] = inputs_batch[:, :, 1].mean()
        input_std[0]  = inputs_batch[:, :, 0].std().clamp(min=1e-8)
        input_std[1]  = inputs_batch[:, :, 1].std().clamp(min=1e-8)

    inputs_batch_norm = (inputs_batch - input_mean) / input_std

    model.eval()
    preds_batch = model(inputs_batch_norm.view(Nbatch, -1))

    preds_e, preds_th, preds_phi = DenormalizeLabels(preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2])

    # compute utility 
    r_score = reconstructability(inputs_batch[:, :, 2], reconstruct_threshold=10)
    U = (
        # 1e2    *   U_angle( preds_th, th, r_score ) + 
        # 1e2    *   U_angle( preds_phi, ph, r_score ) +
        # 1e3     *   U_E( preds_e, energy, r_score ) + 
        # 1e9*N_list.mean()
        1e9*preds_e.mean()
        # 5e5     *   U_PR( r_score ) 
    ) / 1e5

    # save utlity values for logging
    U_vals.append( U.item() )
    U_th_vals.append( 1e2 * U_angle( preds_th, th, r_score ).item() )
    U_phi_vals.append( 1e2 * U_angle( preds_phi, ph, r_score ).item() )
    U_e_vals.append( 1e3 * U_E( preds_e, energy, r_score ).item() )
    U_pr_vals.append( ( 5e5 * U_PR( r_score ) ).item() )

    print(f"Utility: {U:.2f}")

    # backpropagate loss
    Loss = -U
    Loss.backward()

    for name, p in xy_module.named_parameters():
        print(f"{name}: grad norm = {p.grad.norm().item() if p.grad is not None else 'None'}")

    # torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=max_grad)
    optimizer.step()

    # with torch.no_grad():
    #     push_apart(xy_module, min_dist=2 * TankRadius)
    
    optimizer.zero_grad()
    
    # Fine-tune NN every 5 epochs
    if (epoch + 1) % 5 == 0:
        
        model.zero_grad()
        print(f"Fine Tune at epoch {epoch + 1}")
        
        # Prepare data
        with torch.no_grad():
            x_det_ft, y_det_ft = xy_module()
            x_ft = x_det_ft.detach()
            y_ft = y_det_ft.detach()

            N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x_ft, y_ft, False, number_of_showers=Nfinetune, use_cache=True)
            
            theta = torch.atan2(sin_z, cos_z)
            phi = torch.atan2(sin_a, cos_a)
            
            energy_norm, theta_norm, phi_norm = NormalizeLabels(energy, theta, phi)
            X0 /= 5000
            Y0 /= 5000
            
            # normalized labels
            labels_finetune = torch.stack([ energy_norm, theta_norm, phi_norm], dim=1).float()
            
            # detector locations
            x_det_ft_exp = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_det_ft_exp = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            
            # shower centers
            x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
            y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

            inputs_finetune = torch.stack([x_det_ft_exp, y_det_ft_exp, N, T, x0_exp, y0_exp], dim=2).float()
            
            input_mean[0] = inputs_finetune[:, :, 0].mean()
            input_mean[1] = inputs_finetune[:, :, 1].mean()
            input_std[0]  = inputs_finetune[:, :, 0].std().clamp(min=1e-8)
            input_std[1]  = inputs_finetune[:, :, 1].std().clamp(min=1e-8)

            inputs_finetune = (inputs_finetune - input_mean) / input_std

        # get model
        ReconstructionNN = model
        ReconstructionNN.train()
        criterion = nn.MSELoss()
        optimizerNN = torch.optim.Adam(ReconstructionNN.parameters(), lr=1e-6)
        
        # create training dataset
        ft_dataset = TensorDataset(inputs_finetune, labels_finetune)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True, drop_last=True, num_workers=0)

        # train NN for 5 sub-epochs
        for j in range(2):
            for inputs_ft, labels_ft in ft_dataloader:
                batch_size = inputs_ft.size(0)
                train_x = inputs_ft.view(batch_size, -1).to(device)
                train_y = labels_ft.view(batch_size, 3).to(device)
                outputs = ReconstructionNN(train_x)
                lossT = criterion(outputs, train_y)
                lossT.backward()
                optimizerNN.step()
                optimizerNN.zero_grad()

    torch.save({"epoch": epoch, "loss": Loss.cpu(), "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()}, f"{output_dir}/checkpoint.pth")
    
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((x_det_opt.detach().cpu().numpy(), y_det_opt.detach().cpu().numpy())))
# Out:
# Optimizer is initialized from the last epoch 300
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.10
# x: grad norm = 0.5439800024032593
# y: grad norm = 1.331260085105896
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.00
# x: grad norm = 1.2492533922195435
# y: grad norm = 0.8835872411727905
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.05
# x: grad norm = 0.45469236373901367
# y: grad norm = 1.8332189321517944
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.79
# x: grad norm = 0.6126623153686523
# y: grad norm = 0.8055415153503418
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.64
# x: grad norm = 0.8662103414535522
# y: grad norm = 0.7623026371002197
# Fine Tune at epoch 305
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.82
# x: grad norm = 0.9623446464538574
# y: grad norm = 0.6866954565048218
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 623.40
# x: grad norm = 1.7121000289916992
# y: grad norm = 1.2626017332077026
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 623.68
# x: grad norm = 0.8843201398849487
# y: grad norm = 0.9807828664779663
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.48
# x: grad norm = 0.8314604759216309
# y: grad norm = 0.6969365477561951
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.12
# x: grad norm = 0.5276321768760681
# y: grad norm = 0.6366326212882996
# Fine Tune at epoch 310
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.81
# x: grad norm = 4.366114139556885
# y: grad norm = 1.4840457439422607
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.02
# x: grad norm = 0.4300331473350525
# y: grad norm = 0.5974254012107849
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 622.61
# x: grad norm = 0.8221648335456848
# y: grad norm = 0.8419443368911743
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.88
# x: grad norm = 1.2351335287094116
# y: grad norm = 0.8604752421379089
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.42
# x: grad norm = 0.4012466371059418
# y: grad norm = 0.4883524179458618
# Fine Tune at epoch 315
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.11
# x: grad norm = 0.5548669695854187
# y: grad norm = 0.5883364081382751
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.65
# x: grad norm = 0.5429569482803345
# y: grad norm = 0.7183889150619507
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.33
# x: grad norm = 0.46031439304351807
# y: grad norm = 0.6765391826629639
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.47
# x: grad norm = 0.6040138602256775
# y: grad norm = 0.581456184387207
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.61
# x: grad norm = 0.39627036452293396
# y: grad norm = 0.7188006043434143
# Fine Tune at epoch 320
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.38
# x: grad norm = 0.4474394917488098
# y: grad norm = 0.5580544471740723
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.81
# x: grad norm = 0.43181246519088745
# y: grad norm = 0.6064900159835815
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.03
# x: grad norm = 0.425862580537796
# y: grad norm = 2.38063645362854
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.94
# x: grad norm = 0.4028637707233429
# y: grad norm = 0.6443679332733154
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.37
# x: grad norm = 0.3765161335468292
# y: grad norm = 0.6071720719337463
# Fine Tune at epoch 325
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.30
# x: grad norm = 0.5226942896842957
# y: grad norm = 0.30715593695640564
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.65
# x: grad norm = 0.43453797698020935
# y: grad norm = 0.2864741384983063
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.87
# x: grad norm = 0.41407114267349243
# y: grad norm = 0.45259249210357666
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.45
# x: grad norm = 0.43462133407592773
# y: grad norm = 0.4829058349132538
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.80
# x: grad norm = 0.42668068408966064
# y: grad norm = 0.43191656470298767
# Fine Tune at epoch 330
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.01
# x: grad norm = 0.41398686170578003
# y: grad norm = 0.4179171025753021
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.14
# x: grad norm = 0.4244099259376526
# y: grad norm = 0.4593515992164612
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.04
# x: grad norm = 0.4434167742729187
# y: grad norm = 0.33859139680862427
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.80
# x: grad norm = 0.46745383739471436
# y: grad norm = 0.4788801074028015
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.12
# x: grad norm = 0.6424250602722168
# y: grad norm = 1.7208415269851685
# Fine Tune at epoch 335
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.78
# x: grad norm = 0.6358691453933716
# y: grad norm = 0.9151387810707092
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.48
# x: grad norm = 0.7095434665679932
# y: grad norm = 0.4729446470737457
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.27
# x: grad norm = 1.1171972751617432
# y: grad norm = 1.0287871360778809
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.66
# x: grad norm = 0.8468077182769775
# y: grad norm = 0.4174107611179352
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.94
# x: grad norm = 1.1026215553283691
# y: grad norm = 0.4358806610107422
# Fine Tune at epoch 340
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.00
# x: grad norm = 1.4586877822875977
# y: grad norm = 0.3520534038543701
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.92
# x: grad norm = 0.41729190945625305
# y: grad norm = 0.5917763113975525
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.14
# x: grad norm = 0.3956567645072937
# y: grad norm = 0.40911707282066345
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.20
# x: grad norm = 0.40191179513931274
# y: grad norm = 0.3172227740287781
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.06
# x: grad norm = 0.385690301656723
# y: grad norm = 0.3858676850795746
# Fine Tune at epoch 345
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.73
# x: grad norm = 0.463474839925766
# y: grad norm = 0.4606013894081116
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.99
# x: grad norm = 0.5236180424690247
# y: grad norm = 0.3633699119091034
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.98
# x: grad norm = 0.46429866552352905
# y: grad norm = 0.30973443388938904
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.87
# x: grad norm = 0.39580386877059937
# y: grad norm = 0.5053630471229553
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.83
# x: grad norm = 0.471883624792099
# y: grad norm = 0.38390928506851196
# Fine Tune at epoch 350
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.01
# x: grad norm = 0.46160492300987244
# y: grad norm = 0.6368404626846313
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.71
# x: grad norm = 0.4026581346988678
# y: grad norm = 0.5559147596359253
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.83
# x: grad norm = 0.4466521441936493
# y: grad norm = 0.41851919889450073
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.41
# x: grad norm = 0.47355833649635315
# y: grad norm = 1.7536019086837769
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.08
# x: grad norm = 0.3694356381893158
# y: grad norm = 0.4046727418899536
# Fine Tune at epoch 355
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 610.53
# x: grad norm = 0.41947314143180847
# y: grad norm = 0.34202447533607483
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 610.12
# x: grad norm = 0.43538081645965576
# y: grad norm = 0.3873758614063263
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 610.56
# x: grad norm = 0.4286397099494934
# y: grad norm = 0.4307689666748047
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.46
# x: grad norm = 0.4702952802181244
# y: grad norm = 0.3355812728404999
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.02
# x: grad norm = 0.47322311997413635
# y: grad norm = 0.5161497592926025
# Fine Tune at epoch 360
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.06
# x: grad norm = 0.8284871578216553
# y: grad norm = 1.0673664808273315
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.34
# x: grad norm = 0.5012544393539429
# y: grad norm = 0.4553510844707489
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.25
# x: grad norm = 0.40752875804901123
# y: grad norm = 0.419819712638855
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.65
# x: grad norm = 0.6164393424987793
# y: grad norm = 0.7393586039543152
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.64
# x: grad norm = 0.8108068704605103
# y: grad norm = 1.7334741353988647
# Fine Tune at epoch 365
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.98
# x: grad norm = 0.4675006866455078
# y: grad norm = 0.2868495285511017
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.01
# x: grad norm = 0.4905479848384857
# y: grad norm = 0.44001099467277527
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.27
# x: grad norm = 0.3821852207183838
# y: grad norm = 0.3718402087688446
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.71
# x: grad norm = 0.7919634580612183
# y: grad norm = 0.29324427247047424
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.55
# x: grad norm = 0.9325379133224487
# y: grad norm = 0.4141327440738678
# Fine Tune at epoch 370
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.01
# x: grad norm = 0.792189359664917
# y: grad norm = 0.645339846611023
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.92
# x: grad norm = 0.44194498658180237
# y: grad norm = 0.7952001094818115
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.00
# x: grad norm = 0.8528861403465271
# y: grad norm = 1.0326006412506104
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.90
# x: grad norm = 0.5786977410316467
# y: grad norm = 0.47471511363983154
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.07
# x: grad norm = 0.4529533088207245
# y: grad norm = 0.7217869758605957
# Fine Tune at epoch 375
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.29
# x: grad norm = 0.5100381374359131
# y: grad norm = 0.3791888952255249
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.77
# x: grad norm = 0.6015574336051941
# y: grad norm = 1.0716726779937744
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.83
# x: grad norm = 0.45990392565727234
# y: grad norm = 0.5044682621955872
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.73
# x: grad norm = 0.4123688340187073
# y: grad norm = 0.5476295948028564
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.99
# x: grad norm = 0.413571834564209
# y: grad norm = 0.40693676471710205
# Fine Tune at epoch 380
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.85
# x: grad norm = 0.4724982976913452
# y: grad norm = 0.34724682569503784
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.63
# x: grad norm = 0.4265887141227722
# y: grad norm = 0.6365078091621399
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.74
# x: grad norm = 0.5435473322868347
# y: grad norm = 0.3738349974155426
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.19
# x: grad norm = 0.5073427557945251
# y: grad norm = 0.8892322182655334
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.15
# x: grad norm = 0.776652991771698
# y: grad norm = 0.46097707748413086
# Fine Tune at epoch 385
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.34
# x: grad norm = 0.4796430468559265
# y: grad norm = 0.49442481994628906
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.69
# x: grad norm = 0.5190034508705139
# y: grad norm = 0.40034738183021545
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.35
# x: grad norm = 1.1016998291015625
# y: grad norm = 0.5822980999946594
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.96
# x: grad norm = 0.5010527968406677
# y: grad norm = 0.8287732005119324
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.93
# x: grad norm = 0.4655693471431732
# y: grad norm = 0.3176167607307434
# Fine Tune at epoch 390
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.95
# x: grad norm = 0.44421783089637756
# y: grad norm = 0.4780829846858978
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.28
# x: grad norm = 0.4729728400707245
# y: grad norm = 0.401159405708313
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.04
# x: grad norm = 0.39211955666542053
# y: grad norm = 0.5927014350891113
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.30
# x: grad norm = 0.4741869866847992
# y: grad norm = 0.44881999492645264
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.14
# x: grad norm = 0.5885251760482788
# y: grad norm = 1.0397104024887085
# Fine Tune at epoch 395
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.53
# x: grad norm = 0.45304936170578003
# y: grad norm = 0.46862685680389404
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.59
# x: grad norm = 0.4589897692203522
# y: grad norm = 0.8200629353523254
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.68
# x: grad norm = 0.757191002368927
# y: grad norm = 0.647188663482666
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.47
# x: grad norm = 0.4085995852947235
# y: grad norm = 0.7232096195220947
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.03
# x: grad norm = 0.8725360035896301
# y: grad norm = 0.6488516926765442
# Fine Tune at epoch 400
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.74
# x: grad norm = 0.6571887135505676
# y: grad norm = 0.34146150946617126
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.15
# x: grad norm = 1.0624096393585205
# y: grad norm = 0.5357651710510254
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.40
# x: grad norm = 1.550559639930725
# y: grad norm = 1.0152766704559326
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.41
# x: grad norm = 0.5565536022186279
# y: grad norm = 0.8353815674781799
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.67
# x: grad norm = 0.9608244299888611
# y: grad norm = 0.7277843356132507
# Fine Tune at epoch 405
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.62
# x: grad norm = 0.7637007236480713
# y: grad norm = 1.4212729930877686
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.76
# x: grad norm = 0.5535701513290405
# y: grad norm = 1.2148936986923218
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.48
# x: grad norm = 0.8771488070487976
# y: grad norm = 0.4676208794116974
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.09
# x: grad norm = 0.4928223192691803
# y: grad norm = 0.4785842299461365
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.37
# x: grad norm = 0.7929436564445496
# y: grad norm = 1.4055981636047363
# Fine Tune at epoch 410
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.82
# x: grad norm = 0.5303800106048584
# y: grad norm = 1.2405211925506592
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.33
# x: grad norm = 0.45977750420570374
# y: grad norm = 0.317682683467865
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.69
# x: grad norm = 0.46076712012290955
# y: grad norm = 0.33869487047195435
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.81
# x: grad norm = 0.4374955892562866
# y: grad norm = 1.2069578170776367
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.66
# x: grad norm = 0.6215674877166748
# y: grad norm = 1.0853484869003296
# Fine Tune at epoch 415
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.39
# x: grad norm = 0.9138441681861877
# y: grad norm = 0.7213398814201355
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.20
# x: grad norm = 0.7983105182647705
# y: grad norm = 1.0744589567184448
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.96
# x: grad norm = 0.992433488368988
# y: grad norm = 0.5362207889556885
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.74
# x: grad norm = 0.9738571643829346
# y: grad norm = 1.1273258924484253
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.91
# x: grad norm = 0.7028659582138062
# y: grad norm = 0.9128046035766602
# Fine Tune at epoch 420
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.93
# x: grad norm = 0.4541560709476471
# y: grad norm = 0.43074965476989746
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.75
# x: grad norm = 0.45134222507476807
# y: grad norm = 1.275378942489624
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.10
# x: grad norm = 0.515069305896759
# y: grad norm = 1.2830148935317993
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.48
# x: grad norm = 0.4851081669330597
# y: grad norm = 0.7349638938903809
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.24
# x: grad norm = 0.4364469349384308
# y: grad norm = 0.4764877259731293
# Fine Tune at epoch 425
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.37
# x: grad norm = 0.3760581612586975
# y: grad norm = 0.5625818371772766
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.61
# x: grad norm = 0.4147774875164032
# y: grad norm = 1.1784285306930542
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.59
# x: grad norm = 0.48862016201019287
# y: grad norm = 0.9108383655548096
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.29
# x: grad norm = 0.8050202131271362
# y: grad norm = 1.3012418746948242
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.04
# x: grad norm = 0.33532077074050903
# y: grad norm = 0.5200816988945007
# Fine Tune at epoch 430
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.58
# x: grad norm = 0.4338114559650421
# y: grad norm = 0.8201451301574707
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.97
# x: grad norm = 0.3946666717529297
# y: grad norm = 0.7395260334014893
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.73
# x: grad norm = 0.41912057995796204
# y: grad norm = 0.3988918364048004
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.00
# x: grad norm = 0.4439733624458313
# y: grad norm = 0.5019068717956543
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.56
# x: grad norm = 0.4239564836025238
# y: grad norm = 1.327658772468567
# Fine Tune at epoch 435
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.63
# x: grad norm = 0.47681641578674316
# y: grad norm = 0.5735521912574768
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.08
# x: grad norm = 0.48178669810295105
# y: grad norm = 0.4852489233016968
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.99
# x: grad norm = 0.3963530659675598
# y: grad norm = 0.5291529893875122
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.96
# x: grad norm = 0.43248093128204346
# y: grad norm = 0.7131344676017761
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.09
# x: grad norm = 0.5015122294425964
# y: grad norm = 0.48108038306236267
# Fine Tune at epoch 440
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.42
# x: grad norm = 0.47621411085128784
# y: grad norm = 0.6303800344467163
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.50
# x: grad norm = 0.4091365337371826
# y: grad norm = 0.4737606644630432
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.85
# x: grad norm = 0.4361247420310974
# y: grad norm = 0.5716373920440674
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.79
# x: grad norm = 0.4450668394565582
# y: grad norm = 0.5718998908996582
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.90
# x: grad norm = 0.3873480558395386
# y: grad norm = 0.3526016175746918
# Fine Tune at epoch 445
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.95
# x: grad norm = 0.41051286458969116
# y: grad norm = 0.440813809633255
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.58
# x: grad norm = 0.41605496406555176
# y: grad norm = 0.5753995180130005
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.42
# x: grad norm = 0.4686330556869507
# y: grad norm = 0.40918055176734924
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.85
# x: grad norm = 0.5055989623069763
# y: grad norm = 0.6993246674537659
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.75
# x: grad norm = 0.5298948884010315
# y: grad norm = 0.5415462851524353
# Fine Tune at epoch 450
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.41
# x: grad norm = 0.3815765380859375
# y: grad norm = 1.0798115730285645
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.57
# x: grad norm = 0.5452058911323547
# y: grad norm = 0.39208799600601196
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.65
# x: grad norm = 0.861008882522583
# y: grad norm = 0.4597817063331604
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 622.73
# x: grad norm = 1.0545614957809448
# y: grad norm = 1.4296245574951172
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.81
# x: grad norm = 0.5392557382583618
# y: grad norm = 0.4137985408306122
# Fine Tune at epoch 455
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.06
# x: grad norm = 0.5744006037712097
# y: grad norm = 0.4249981641769409
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.48
# x: grad norm = 0.9657272100448608
# y: grad norm = 0.6155563592910767
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.57
# x: grad norm = 0.48709380626678467
# y: grad norm = 1.1390972137451172
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 624.18
# x: grad norm = 1.4162051677703857
# y: grad norm = 0.8821297883987427
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.02
# x: grad norm = 1.1356396675109863
# y: grad norm = 0.7468997240066528
# Fine Tune at epoch 460
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 630.95
# x: grad norm = 1.080802321434021
# y: grad norm = 2.15613055229187
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.79
# x: grad norm = 0.529897153377533
# y: grad norm = 0.3779902756214142
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.63
# x: grad norm = 0.42653119564056396
# y: grad norm = 0.45011135935783386
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.93
# x: grad norm = 0.4492127001285553
# y: grad norm = 0.5681694149971008
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.73
# x: grad norm = 0.45931291580200195
# y: grad norm = 0.48799723386764526
# Fine Tune at epoch 465
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.06
# x: grad norm = 0.6252788305282593
# y: grad norm = 0.3780063986778259
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.96
# x: grad norm = 0.6601480841636658
# y: grad norm = 0.9881268739700317
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.76
# x: grad norm = 0.9890234470367432
# y: grad norm = 0.500806450843811
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.06
# x: grad norm = 0.8339430689811707
# y: grad norm = 0.417623907327652
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.34
# x: grad norm = 1.0985138416290283
# y: grad norm = 0.394355833530426
# Fine Tune at epoch 470
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.23
# x: grad norm = 0.9399452805519104
# y: grad norm = 0.5622057318687439
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.89
# x: grad norm = 1.1381666660308838
# y: grad norm = 0.4365527331829071
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.97
# x: grad norm = 0.5477062463760376
# y: grad norm = 0.36586010456085205
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.18
# x: grad norm = 0.5593270063400269
# y: grad norm = 0.4420391321182251
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.57
# x: grad norm = 0.9123049974441528
# y: grad norm = 0.3369150757789612
# Fine Tune at epoch 475
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.01
# x: grad norm = 1.061002254486084
# y: grad norm = 0.41842812299728394
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.59
# x: grad norm = 0.7418270111083984
# y: grad norm = 0.5666928291320801
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.11
# x: grad norm = 0.7362716794013977
# y: grad norm = 0.41527682542800903
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.19
# x: grad norm = 0.9469696879386902
# y: grad norm = 0.3372761905193329
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.44
# x: grad norm = 0.8751088976860046
# y: grad norm = 0.8199653029441833
# Fine Tune at epoch 480
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.44
# x: grad norm = 0.43843308091163635
# y: grad norm = 0.42983004450798035
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.11
# x: grad norm = 0.49914059042930603
# y: grad norm = 0.4451696276664734
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.07
# x: grad norm = 0.7636473178863525
# y: grad norm = 0.35045677423477173
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.72
# x: grad norm = 1.0477267503738403
# y: grad norm = 0.594465434551239
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.97
# x: grad norm = 0.6581421494483948
# y: grad norm = 1.006106972694397
# Fine Tune at epoch 485
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.60
# x: grad norm = 0.6383602023124695
# y: grad norm = 0.4947360157966614
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.04
# x: grad norm = 0.5667722821235657
# y: grad norm = 0.45838987827301025
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.01
# x: grad norm = 1.3697487115859985
# y: grad norm = 1.0505058765411377
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.45
# x: grad norm = 0.4098098874092102
# y: grad norm = 0.573435366153717
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.50
# x: grad norm = 0.4190542995929718
# y: grad norm = 0.39174526929855347
# Fine Tune at epoch 490
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.10
# x: grad norm = 0.4467811584472656
# y: grad norm = 0.6540043354034424
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.42
# x: grad norm = 0.47427526116371155
# y: grad norm = 0.4036179780960083
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.67
# x: grad norm = 0.4200631380081177
# y: grad norm = 0.7017449140548706
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.96
# x: grad norm = 0.4040001928806305
# y: grad norm = 0.6405401825904846
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.59
# x: grad norm = 0.4271678626537323
# y: grad norm = 0.654280960559845
# Fine Tune at epoch 495
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.19
# x: grad norm = 0.4537663459777832
# y: grad norm = 0.424733430147171
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.69
# x: grad norm = 0.4192166030406952
# y: grad norm = 0.5434277057647705
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.60
# x: grad norm = 0.48186323046684265
# y: grad norm = 0.4227384328842163
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.01
# x: grad norm = 0.47389790415763855
# y: grad norm = 0.2631329298019409
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.99
# x: grad norm = 0.44562655687332153
# y: grad norm = 0.48283636569976807
# Fine Tune at epoch 500
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.92
# x: grad norm = 0.40348634123802185
# y: grad norm = 0.45756715536117554
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.56
# x: grad norm = 0.4120545983314514
# y: grad norm = 0.4647153615951538
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.99
# x: grad norm = 0.4568985104560852
# y: grad norm = 0.445568323135376
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.24
# x: grad norm = 0.4622678756713867
# y: grad norm = 0.477509081363678
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.76
# x: grad norm = 0.41105225682258606
# y: grad norm = 0.711912214756012
# Fine Tune at epoch 505
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.41
# x: grad norm = 0.3735765218734741
# y: grad norm = 0.5306089520454407
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.46
# x: grad norm = 0.3979518413543701
# y: grad norm = 0.32570308446884155
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.86
# x: grad norm = 0.42529988288879395
# y: grad norm = 0.42622843384742737
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.78
# x: grad norm = 0.4423096179962158
# y: grad norm = 0.42877545952796936
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.61
# x: grad norm = 0.5376767516136169
# y: grad norm = 0.3585067391395569
# Fine Tune at epoch 510
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.02
# x: grad norm = 0.5251767039299011
# y: grad norm = 0.6293052434921265
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.09
# x: grad norm = 0.5307108163833618
# y: grad norm = 0.5147968530654907
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.03
# x: grad norm = 0.41409942507743835
# y: grad norm = 0.7649625539779663
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.63
# x: grad norm = 0.9406279921531677
# y: grad norm = 0.5570743680000305
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.37
# x: grad norm = 0.8569037914276123
# y: grad norm = 0.39085376262664795
# Fine Tune at epoch 515
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.35
# x: grad norm = 0.8528949618339539
# y: grad norm = 0.34619155526161194
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.63
# x: grad norm = 1.0220327377319336
# y: grad norm = 0.8595752716064453
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.19
# x: grad norm = 0.8908430337905884
# y: grad norm = 0.8404105305671692
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.88
# x: grad norm = 1.0576436519622803
# y: grad norm = 0.39977627992630005
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.27
# x: grad norm = 0.7584187388420105
# y: grad norm = 0.4106646776199341
# Fine Tune at epoch 520
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.18
# x: grad norm = 1.2472003698349
# y: grad norm = 0.8280171751976013
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.22
# x: grad norm = 0.5193589925765991
# y: grad norm = 0.46229684352874756
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.18
# x: grad norm = 0.898351788520813
# y: grad norm = 0.5064533948898315
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.11
# x: grad norm = 0.9798061847686768
# y: grad norm = 0.584423303604126
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.93
# x: grad norm = 0.9226844310760498
# y: grad norm = 0.5414098501205444
# Fine Tune at epoch 525
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.26
# x: grad norm = 0.5663850903511047
# y: grad norm = 0.8634002804756165
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.73
# x: grad norm = 0.45901742577552795
# y: grad norm = 0.40490105748176575
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.02
# x: grad norm = 0.4723548889160156
# y: grad norm = 0.38631388545036316
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.40
# x: grad norm = 0.42773038148880005
# y: grad norm = 0.5866453647613525
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.29
# x: grad norm = 0.5254104733467102
# y: grad norm = 0.42766475677490234
# Fine Tune at epoch 530
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.19
# x: grad norm = 0.6437711715698242
# y: grad norm = 0.40019404888153076
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.89
# x: grad norm = 0.8136265277862549
# y: grad norm = 1.4844341278076172
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.36
# x: grad norm = 1.0003196001052856
# y: grad norm = 0.6239879727363586
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.72
# x: grad norm = 0.9643862247467041
# y: grad norm = 0.5947526693344116
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 619.31
# x: grad norm = 0.973901629447937
# y: grad norm = 0.8452665209770203
# Fine Tune at epoch 535
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.71
# x: grad norm = 0.8430905938148499
# y: grad norm = 0.3767490088939667
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.29
# x: grad norm = 1.166396141052246
# y: grad norm = 1.0659973621368408
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 642.49
# x: grad norm = 3.9468605518341064
# y: grad norm = 3.227367639541626
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.90
# x: grad norm = 1.148647427558899
# y: grad norm = 0.33717313408851624
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 607.70
# x: grad norm = 0.5469905734062195
# y: grad norm = 0.4308220446109772
# Fine Tune at epoch 540
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 607.22
# x: grad norm = 0.44972988963127136
# y: grad norm = 0.5761329531669617
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 607.99
# x: grad norm = 0.5312643647193909
# y: grad norm = 0.45543384552001953
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 608.98
# x: grad norm = 0.5074731707572937
# y: grad norm = 0.45432570576667786
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.71
# x: grad norm = 0.9051275253295898
# y: grad norm = 0.41476309299468994
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.61
# x: grad norm = 1.0950978994369507
# y: grad norm = 0.5576624274253845
# Fine Tune at epoch 545
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 611.91
# x: grad norm = 0.668655514717102
# y: grad norm = 0.5983272194862366
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.28
# x: grad norm = 0.8976231217384338
# y: grad norm = 0.7012701034545898
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 608.33
# x: grad norm = 1.0668681859970093
# y: grad norm = 0.8407573103904724
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.43
# x: grad norm = 1.1200963258743286
# y: grad norm = 0.5308858156204224
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 608.34
# x: grad norm = 0.4932650625705719
# y: grad norm = 0.6003378033638
# Fine Tune at epoch 550
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 608.90
# x: grad norm = 0.45518800616264343
# y: grad norm = 0.36784628033638
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 609.57
# x: grad norm = 0.45570677518844604
# y: grad norm = 0.8725739121437073
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 610.28
# x: grad norm = 0.8970654010772705
# y: grad norm = 0.2985386550426483
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.47
# x: grad norm = 1.1143383979797363
# y: grad norm = 0.6220906376838684
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.33
# x: grad norm = 0.9802442193031311
# y: grad norm = 0.860317051410675
# Fine Tune at epoch 555
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.27
# x: grad norm = 0.8396111726760864
# y: grad norm = 0.9425176978111267
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 608.80
# x: grad norm = 0.5103178024291992
# y: grad norm = 0.7201867699623108
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 610.58
# x: grad norm = 0.42041701078414917
# y: grad norm = 0.29146984219551086
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.49
# x: grad norm = 0.3837038576602936
# y: grad norm = 1.4338834285736084
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 623.18
# x: grad norm = 1.267858624458313
# y: grad norm = 1.0489561557769775
# Fine Tune at epoch 560
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.99
# x: grad norm = 0.5903860926628113
# y: grad norm = 0.6776249408721924
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.76
# x: grad norm = 0.5701421499252319
# y: grad norm = 0.40902045369148254
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.83
# x: grad norm = 0.5727071762084961
# y: grad norm = 0.78929603099823
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 628.31
# x: grad norm = 1.422752857208252
# y: grad norm = 1.1799943447113037
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.32
# x: grad norm = 0.4921369254589081
# y: grad norm = 1.507704734802246
# Fine Tune at epoch 565
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 621.65
# x: grad norm = 1.664288878440857
# y: grad norm = 1.6280020475387573
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.28
# x: grad norm = 2.1367850303649902
# y: grad norm = 1.357696771621704
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 630.09
# x: grad norm = 2.8020215034484863
# y: grad norm = 1.841848611831665
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.92
# x: grad norm = 0.4938763380050659
# y: grad norm = 0.8330912590026855
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.63
# x: grad norm = 0.4548293948173523
# y: grad norm = 0.5083724856376648
# Fine Tune at epoch 570
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.28
# x: grad norm = 0.47568610310554504
# y: grad norm = 0.4921239912509918
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.73
# x: grad norm = 0.49605563282966614
# y: grad norm = 0.6550443768501282
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.86
# x: grad norm = 0.39429277181625366
# y: grad norm = 1.3018542528152466
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.61
# x: grad norm = 0.49412092566490173
# y: grad norm = 0.3989418148994446
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.91
# x: grad norm = 0.46053358912467957
# y: grad norm = 1.3563557863235474
# Fine Tune at epoch 575
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.20
# x: grad norm = 0.4088708162307739
# y: grad norm = 0.5628838539123535
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 612.55
# x: grad norm = 0.5995572805404663
# y: grad norm = 0.4874156713485718
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.07
# x: grad norm = 0.44845080375671387
# y: grad norm = 0.5107782483100891
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.22
# x: grad norm = 0.4993537664413452
# y: grad norm = 0.5075044631958008
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.82
# x: grad norm = 0.7544722557067871
# y: grad norm = 0.36949649453163147
# Fine Tune at epoch 580
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.70
# x: grad norm = 0.610758364200592
# y: grad norm = 0.6761882305145264
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.49
# x: grad norm = 1.0132765769958496
# y: grad norm = 0.6277635097503662
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 620.05
# x: grad norm = 0.8588168621063232
# y: grad norm = 0.8322177529335022
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.82
# x: grad norm = 1.2282851934432983
# y: grad norm = 0.9832398891448975
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 618.69
# x: grad norm = 0.9158117771148682
# y: grad norm = 0.3618822395801544
# Fine Tune at epoch 585
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 622.74
# x: grad norm = 1.1499425172805786
# y: grad norm = 0.7030141353607178
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.03
# x: grad norm = 0.7072249054908752
# y: grad norm = 0.3380544185638428
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.18
# x: grad norm = 0.7692434787750244
# y: grad norm = 0.8473599553108215
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 614.56
# x: grad norm = 0.3699074685573578
# y: grad norm = 1.0667983293533325
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.77
# x: grad norm = 1.669359564781189
# y: grad norm = 0.8812692165374756
# Fine Tune at epoch 590
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.59
# x: grad norm = 0.5207459330558777
# y: grad norm = 0.5335281491279602
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.22
# x: grad norm = 0.5825284123420715
# y: grad norm = 0.8366763591766357
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.03
# x: grad norm = 0.7180905342102051
# y: grad norm = 1.1311672925949097
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 615.20
# x: grad norm = 0.494308739900589
# y: grad norm = 0.3561256527900696
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 616.78
# x: grad norm = 1.2933704853057861
# y: grad norm = 1.3349658250808716
# Fine Tune at epoch 595
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 617.02
# x: grad norm = 1.0899479389190674
# y: grad norm = 0.6343687772750854
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.12
# x: grad norm = 0.45418599247932434
# y: grad norm = 0.7100914716720581
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.61
# x: grad norm = 0.5573033094406128
# y: grad norm = 0.6064381003379822
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.12
# x: grad norm = 0.4852261245250702
# y: grad norm = 0.6074658036231995
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_500.pt
# Utility: 613.36
# x: grad norm = 0.5780057907104492
# y: grad norm = 0.5950192809104919
# Fine Tune at epoch 600
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_2500.pt
# CPU times: user 48.2 s, sys: 2.49 s, total: 50.7 s
# Wall time: 1min 4s

# %%
plt.plot(U_vals, label='U_vals')
plt.plot([1000*u for u in U_th_vals], label='U_th_vals')
plt.plot([1000*u for u in U_phi_vals], label='U_phi_vals')
plt.plot(U_e_vals, label='U_e_vals')
plt.plot([100*u for u in U_pr_vals], label='U_pr_vals')
plt.legend()

# %% [markdown]
# ## Visualize Results

# %%
a, b = Layouts(n_detectors=Nunits, n_rings=n_rings, radius=300)

plt.figure(figsize=[12, 12])
plt.scatter(
    x_det_opt.detach().cpu(), 
    y_det_opt.detach().cpu(), 
    color="red", alpha=.8, label="Final Layout"
    )
plt.scatter(a, b, color="blue", alpha=.3, label="Initial Layout")
plt.grid(); plt.xlabel("x [m]"); plt.ylabel("y [m]")
plt.title("Position of the detectors"); plt.legend()
plt.show()

# %%
utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")

if utility_path.exists():
    u_t = np.loadtxt(utility_path)
    u_t = np.append(u_t, np.array(U_vals).ravel())
    np.savetxt(utility_path, u_t)
else:
    u_t = U_vals
    np.savetxt(utility_path, u_t)

# %%
mean_ut = [np.mean(u_t[i - 4: i]) for i in range(4, len(u_t))]

plt.plot(u_t, color="black", linestyle="none", marker="o", linewidth=.5, label="Total Utility")
plt.plot(np.arange(4, len(u_t)), mean_ut, linestyle="-", linewidth=2, label="Mean Utility")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
# plt.ylim((-0.1, 1000.2))
plt.title("Utility Values per Optimization Step")
plt.show()

# %% [markdown]
# ## Evaluate Reconstruction (end)

# %%
x,y = x_det_opt,y_det_opt
with torch.no_grad():
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x, y, False, number_of_showers=Ntest, use_cache=True)

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000
y0 = Y0 / 5000

x_exp = x.unsqueeze(0).expand(Ntest, -1)
y_exp = y.unsqueeze(0).expand(Ntest, -1)

x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

inputs_test = torch.stack([x_exp, y_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test = (inputs_test - input_mean) / input_std  # add this line
labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Loading cached showers from ./outputs/NN_Files_28_20k_max_n_capured/cached_showers_300.pt

# %%
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])

E_p, E_r = E_pred.cpu(), energy.cpu()
Th_r, Th_p = th.cpu(), theta_pred.cpu()
Ph_r, Ph_p = ph.cpu(), phi_pred.cpu()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].scatter(E_r.cpu(), E_p.cpu(), alpha=.5, color="r")
axes[0].plot([0, E_r.max().cpu()], [0, E_r.max().cpu()], "k-", lw=2)
axes[0].set_xlabel("True E"); axes[0].set_ylabel("Predicted E"); axes[0].grid()

axes[1].scatter(Th_r.cpu(), Th_p.detach().cpu(), alpha=.5, color="r")
axes[1].plot([0, np.pi], [0, np.pi], "k-", lw=2)
axes[1].set_xlabel("True Theta"); axes[1].set_ylabel("Predicted Theta"); axes[1].grid()

axes[2].scatter(Ph_r.cpu(), Ph_p.detach().cpu(), alpha=.5, color="r")
axes[2].plot([-np.pi, np.pi], [-np.pi, np.pi], "k-", lw=2)
axes[2].set_xlabel("True Phi"); axes[2].set_ylabel("Predicted Phi"); axes[2].grid()

plt.tight_layout(); plt.show()

# %% [markdown]
# TAMBO KPI
# - efficiency, fraction of particles detected,
# - they don't care about Energy
# - direction of the primary particle
