# %% [markdown]
# # SWGO L07 Detector Optimization (Refactored)
#
# All utility functions have been extracted into separate Python modules.
# This notebook preserves the original optimization logic.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import copy
import warnings
import matplotlib.patches as patches
from pathlib import Path
from matplotlib import colors
from matplotlib.colors import LogNorm, Normalize
from torch.utils.data import TensorDataset, DataLoader
import os
import gc

# Extracted module imports
from shower_generation import GenerateShowers
from detector_response import GetCounts_differentiable, SmearN, TimeAverage_vectorized
from geometry import Layouts
from reconstruction import Reconstruction, NormalizeLabels, DenormalizeLabels, EarlyStopping
from layout_optimization import LearnableXY, push_apart, symmetry_loss
from utility_functions import reconstructability, U_PR, U_E, U_TH

output_dir = "./outputs/NN_Files_21_20k_update_coeff"
os.makedirs(output_dir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Constants and Parameters

# %%
# Matrices used in shower parametrization
A = torch.tensor([[1, 1, 1, 1],[1, 2, 4, 8], [1, 3, 9, 27], [1, 4, 16, 64]], dtype=torch.float32)

# Constants
c0 = .29979  # Speed of light in [m / ns]
theta_max = np.pi * 65 / 180
log_01 = torch.tensor([np.log(.1)], dtype=torch.float32)
log_10 = torch.tensor([np.log(10)], dtype=torch.float32)
sqrt12 = torch.tensor([np.sqrt(12)], dtype=torch.float32)

# Tank Values
IntegrationWindow = 128.  # 128 ns integration window, SWGO default
sigma_time = 10.  # Time resolution assumed for the detectors
R_min = 2.
TankArea = 6.859 * np.pi  # Area for 19 hexagonal macro unit
TankRadius = np.sqrt(6.859)  # Radius of macro unit

# Background
Bgr_mu_per_m2 = 0.000001826 * IntegrationWindow
fluxB_m = torch.tensor([TankArea * Bgr_mu_per_m2])
Bgr_e_per_m2 = 0.000000200 * IntegrationWindow
fluxB_e = torch.tensor([TankArea * Bgr_e_per_m2])

# Sizes
Nunits = 500
RelResCounts = .05

# Debug Parameters
largenumber = 1e13
epsilon = 1 / largenumber

# NN
Nevents = 20000#0
Nvalidation = 2000#0

# Layout
SWGOopt = False
x, y = Layouts(n_detectors=Nunits, n_rings=20, radius=300, center=(300,0))
x = torch.tensor(x, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)

# shower denormalization stats
STATS_PATH = '/n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/pre_processed_3rd_step/standardization_stats_train_only.pt'

# %% [markdown]
# ## Initialize Diffusion Model

# %%
from diffusion_model.tambo_3D_diffusion_generator import PlaneDiffusionEvaluator

generator = PlaneDiffusionEvaluator(
    data_dir="/n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/pre_processed_3rd_step/",
    checkpoint_path="/n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/checkpoints/tam_unet/epoch_epoch=1229-val_loss_val_loss=0.0333.ckpt",
    ddim_steps=20,
    eta=0.0,
    guidance_w=1.8,
    imports_path="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/hhanif/tambo_optimization/unet"
)
generator.load_model()
# Out:
# Initialized PlaneDiffusionEvaluator
# Device: cuda:0
# Model parameters: 12,408,387
# Loaded checkpoint: /n/netscratch/arguelles_delgado_lab/Everyone/hhanif/tambo_simulation_nov_25/checkpoints/tam_unet/epoch_epoch=1229-val_loss_val_loss=0.0333.ckpt
# DDIM sampler built (ddim_steps=20, eta=0.0, w=1.8)
# Model loading time: 0.73s

# %%
from diffusion_model.tambo_3D_fnn_scaler import PlaneFNNGenerator

scaler = PlaneFNNGenerator(
    data_dir="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/pre_processed_3rd_step_min_50/",
    checkpoint_path="/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/checkpoints/tam_fnn/last.ckpt",
    imports_path="/n/home05/zdimitrov/tambo/TambOpt/ml/scaling_NN/FNN/"
)
scaler.load_model()
# Out:
# Initialized PlaneFNNGenerator
# Device: cuda:0
# Loaded standardization stats from: /n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/pre_processed_3rd_step_min_50/global_bbox_stats.pt
#   Mean: 90.71444702148438
#   Std: 140.77218627929688
# Model parameters: 3,751,008
# Loaded checkpoint: /n/holylfs05/LABS/arguelles_delgado_lab/Everyone/zdimitrov/tambo_simulations/checkpoints/tam_fnn/last.ckpt
# Using EMA weights for inference
# Model parameters: 3,751,008
# Model loading time: 0.23s

# %% [markdown]
# ## Helper: Wrap GenerateShowers with module dependencies

# %%
# Create wrapped versions that capture the global dependencies
import functools

_SmearN = functools.partial(SmearN, RelResCounts=RelResCounts)
_TimeAverage = functools.partial(TimeAverage_vectorized,
                                  IntegrationWindow=IntegrationWindow,
                                  sigma_time=sigma_time)
_GetCounts = functools.partial(GetCounts_differentiable,
                                SmearN_fn=_SmearN,
                                fluxB_e=fluxB_e,
                                TimeAverage_vectorized_fn=_TimeAverage)

def generate_showers(x, y, log=False, number_of_showers=1):
    return GenerateShowers(x, y, generator, scaler, _GetCounts, _SmearN, fluxB_e,
                           log=log, number_of_showers=number_of_showers, stats_path=STATS_PATH)

# %% [markdown]
# ## Visualize Initial Layout

# %%
plt.figure(figsize=[6, 6])
plt.scatter(x.detach(), y.detach(), color="red")
plt.grid()
plt.xlabel("x [m]")
plt.ylabel("y [m]")
plt.title("Initial Position of the detectors")
plt.xlim((-50, 650))
plt.ylim((-350, 350))
plt.show()

# %% [markdown]
# ## Generate and Visualize a Single Shower

# %%
SWGOopt = False
with torch.no_grad():
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x, y, True, number_of_showers=10)
# Out:
# Processing conditions 0 to 10 / 10...

# %%
print("N:", N.shape)
print("T:", T.shape)
print("X0:", X0)
print("Y0:", Y0)
print("E:", energy.shape)
# Out:
# N: torch.Size([10, 500])
# T: torch.Size([10, 500])
# X0: tensor([547.6106, 124.7832, 208.0513, 350.0125, 165.3190, 309.7203,  52.3268,
#         391.4519, 329.5145, 159.0684])
# Y0: tensor([17.3914,  6.0429, 11.5481, 28.0173,  8.3201, -5.8066,  5.1656,  9.6067,
#          8.9330,  6.8256])
# E: torch.Size([10])

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes  = axes.flatten()

for i in range(n_events):
    N_tmp = N[i]
    idx = torch.where(N_tmp >= 5e-1)[0]
    norm = LogNorm(vmin=0.1, vmax=1)

    scatter = axes[i].scatter(x[idx].detach(), y[idx].detach(), c=N_tmp[idx].detach(), cmap="viridis", norm=norm)
    axes[i].scatter(X0[i].item(), Y0[i].item(), c="red", marker="d")
    fig.colorbar(scatter, ax=axes[i], label='Number of detected particles')
    axes[i].set_xlabel("x [m]"); axes[i].set_ylabel("y [m]")
    axes[i].set_xlim((-50, 650)); axes[i].set_ylim((-350, 350))
    axes[i].set_title(f"Event {i}: E={energy[i].item():.3f} PeV, θ={th[i].item()*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# x = torch.linspace(0, 2, 100)
# plt.plot(x, torch.sigmoid(2 * (x -0.1)))

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes  = axes.flatten()

for i in range(n_events):
    N_tmp = N[i]
    T_tmp = T[i]
    idx = torch.where(N_tmp >= 5e-1)[0]
    from matplotlib.colors import SymLogNorm
    norm = SymLogNorm(linthresh=1, vmin=-200, vmax=200)


    scatter = axes[i].scatter(x[idx].detach(), y[idx].detach(), c=T_tmp[idx].detach(), cmap="twilight", norm=norm)
    
    axes[i].scatter(X0[i].item(), Y0[i].item(), c="red", marker="d")
    fig.colorbar(scatter, ax=axes[i], label='Time of Arrival [ns]')
    axes[i].set_xlabel("x [m]"); axes[i].set_ylabel("y [m]")
    axes[i].set_xlim((-50, 650)); axes[i].set_ylim((-350, 350))
    axes[i].set_title(f"Event {i}: E={energy[i].item():.3f} PeV, θ={th[i].item()*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %%
th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

n_events = N.shape[0]
ncols = 5
nrows = (n_events + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
axes = axes.flatten()

for i in range(n_events):
    N_tmp = N[i]
    T_tmp = T[i]
    idx = torch.where(N_tmp >= 1e-2)[0]
    axes[i].hist(T_tmp[idx].detach().cpu().numpy(), bins=30, edgecolor='black')
    axes[i].set_xlabel("Time of Arrival [ns]")
    axes[i].set_ylabel("Count")
    axes[i].set_title(f"Event {i}: E={energy[i].item():.3f} PeV, θ={th[i].item()*180/np.pi:.1f}°")

for i in range(n_events, len(axes)):
    axes[i].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Generate Training Data

# %%
# %%time

# N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x, y, False, number_of_showers=Nevents)

# th = torch.atan2(sin_z, cos_z)
# ph = torch.atan2(sin_a, cos_a)

# E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
# x0 = X0 / 5000
# y0 = Y0 / 5000

# x_exp = x.unsqueeze(0).expand(Nevents, -1)
# y_exp = y.unsqueeze(0).expand(Nevents, -1)

# x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
# y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

# inputs = torch.stack([x_exp, y_exp, N, T, x0_exp, y0_exp], dim=2).float()
# labels = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

# %%
# os.makedirs(output_dir, exist_ok=True)
# torch.save(inputs, f"{output_dir}/inputs.pt")
# torch.save(labels, f"{output_dir}/labels.pt")

# %% [markdown]
# ## Generate Validation Data

# %%
# %%time

# N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x, y, False, number_of_showers=Nvalidation)

# th = torch.atan2(sin_z, cos_z)
# ph = torch.atan2(sin_a, cos_a)

# E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
# x0 = X0 / 5000
# y0 = Y0 / 5000

# x_exp = x.unsqueeze(0).expand(Nvalidation, -1)
# y_exp = y.unsqueeze(0).expand(Nvalidation, -1)

# x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
# y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

# inputs_val = torch.stack([x_exp, y_exp, N, T, x0_exp, y0_exp], dim=2).float()
# labels_val = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()

# %%
# torch.save(inputs_val, f"{output_dir}/inputs_val.pt")
# torch.save(labels_val, f"{output_dir}/labels_val.pt")

# %% [markdown]
# ## Load Cached Data (optional)

# %%
inputs = torch.load(f"{output_dir}/inputs.pt")
labels = torch.load(f"{output_dir}/labels.pt")
inputs_val = torch.load(f"{output_dir}/inputs_val.pt")
labels_val = torch.load(f"{output_dir}/labels_val.pt")

# %%
labels.shape
# Out:
# torch.Size([20000, 3])

# %%
# # EDA
# import seaborn as sns
# # Particle count (N) summaries per event
# N_total  = inputs[:, :, 2].sum(dim=1)
# N_mean   = inputs[:, :, 2].mean(dim=1)
# N_median = inputs[:, :, 2].median(dim=1).values
# N_max    = inputs[:, :, 2].max(dim=1).values
# N_std    = inputs[:, :, 2].std(dim=1)

# # Arrival time (T) summaries per event
# T_mean   = inputs[:, :, 3].mean(dim=1)
# T_median = inputs[:, :, 3].median(dim=1).values
# T_max    = inputs[:, :, 3].max(dim=1).values
# T_min    = inputs[:, :, 3].min(dim=1).values
# T_std    = inputs[:, :, 3].std(dim=1)

# df = pd.DataFrame({
#     'N_total':  N_total.cpu().numpy(),
#     'N_mean':   N_mean.cpu().numpy(),
#     'N_median': N_median.cpu().numpy(),
#     'N_max':    N_max.cpu().numpy(),
#     'N_std':    N_std.cpu().numpy(),
#     'T_mean':   T_mean.cpu().numpy(),
#     'T_median': T_median.cpu().numpy(),
#     'T_max':    T_max.cpu().numpy(),
#     'T_min':    T_min.cpu().numpy(),
#     'T_std':    T_std.cpu().numpy(),
#     'x0':       labels[:, 0].cpu().numpy(),
#     'y0':       labels[:, 1].cpu().numpy(),
#     'E_norm':   labels[:, 2].cpu().numpy(),
#     'theta':    labels[:, 3].cpu().numpy(),
#     'phi':      labels[:, 4].cpu().numpy(),
# })

# sns.pairplot(df.sample(2000))

# %% [markdown]
# ## Train Reconstruction NN

# %%
model = Reconstruction(num_detectors=Nunits).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)

# %%
# Per-feature normalization stats (computed from training data only)
input_mean = inputs.mean(dim=(0, 1))  # [6]
input_std  = inputs.std(dim=(0, 1))   # [6]
input_std[input_std < 1e-8] = 1.0

# Normalize cached datasets
inputs     = (inputs - input_mean) / input_std
inputs_val = (inputs_val - input_mean) / input_std

dataset = TensorDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=256, shuffle=True, drop_last=False, num_workers=4)

# %%
# %%time

val_losses = []
losses = []
early_stopper = EarlyStopping()

for num_epoch in range(1000):
    epoch_loss = 0
    total_batch = 0
    
    for batch_inputs, batch_labels in dataloader:
        batch_size = batch_inputs.size(0)
        train_x = batch_inputs.view(batch_size, -1).to(device)
        train_y = batch_labels.view(batch_size, -1).to(device)
        
        outputs = model(train_x)
        loss = criterion(outputs, train_y)
        epoch_loss += loss.item()
        total_batch += 1

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    val_size = inputs_val.size(0)
    val_x = inputs_val.view(val_size, -1).to(device)
    val_y = labels_val.view(val_size, -1).to(device)

    model.eval()
    with torch.no_grad():
        val_output = model(val_x)
        val_loss = criterion(val_output, val_y)
    
    val_losses.append(val_loss.item())
    early_stopper(val_loss)

    if (num_epoch + 1) % 100 == 0:
        print(f"Training is {int((num_epoch + 1) / 10)}% done, with Loss = {val_loss:.2f}")

    losses.append(epoch_loss / total_batch)

plt.plot(np.arange(1, len(losses) + 1), losses, color="blue", label="Training Loss")
plt.plot(np.arange(1, len(val_losses) + 1), val_losses, color="red", label="Validation Loss")
plt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()
# Out:
# Training is 10% done, with Loss = 0.98
# CPU times: user 15.9 s, sys: 9.59 s, total: 25.5 s
# Wall time: 32.3 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\nval_losses = []\nlosses = []\nearly_stopper = EarlyStopping()\n\nfor num_epoch in range(1000):\n    epoch_loss = 0\n    total_batch = 0\n\n    for batch_inputs, batch_labels in dataloader:\n        batch_size = batch_inputs.size(0)\n        train_x = batch_inputs.view(batch_size, -1).to(device)\n        train_y = batch_labels.view(batch_size, -1).to(device)\n\n        outputs = model(train_x)\n        loss = criterion(outputs, train_y)\n        epoch_loss += loss.item()\n        total_batch += 1\n\n        loss.backward()\n        optimizer.step()\n        optimizer.zero_grad()\n\n    val_size = inputs_val.size(0)\n    val_x = inputs_val.view(val_size, -1).to(device)\n    val_y = labels_val.view(val_size, -1).to(device)\n\n    model.eval()\n    with torch.no_grad():\n        val_output = model(val_x)\n        val_loss = criterion(val_output, val_y)\n\n    val_losses.append(val_loss.item())\n    early_stopper(val_loss)\n\n    if (num_epoch + 1) % 100 == 0:\n        print(f"Training is {int((num_epoch + 1) / 10)}% done, with Loss = {val_loss:.2f}")\n\n    losses.append(epoch_loss / total_batch)\n\nplt.plot(np.arange(1, len(losses) + 1), losses, color="blue", label="Training Loss")\nplt.plot(np.arange(1, len(val_losses) + 1), val_losses, color="red", label="Validation Loss")\nplt.legend(); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.grid()\n')
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1470, in ExecutionMagics.time(self, line, cell, local_ns)
#    1468 if interrupt_occured:
#    1469     if exit_on_interrupt and captured_exception:
# -> 1470         raise captured_exception
#    1471     return
#    1472 return out
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1434, in ExecutionMagics.time(self, line, cell, local_ns)
#    1432 st = clock2()
#    1433 try:
# -> 1434     exec(code, glob, local_ns)
#    1435     out = None
#    1436     # multi-line %%time case
#
# File <timed exec>:20
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/optim/optimizer.py:82, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      80     torch.set_grad_enabled(self.defaults["differentiable"])
#      81     torch._dynamo.graph_break()
# ---> 82     ret = func(*args, **kwargs)
#      83 finally:
#      84     torch._dynamo.graph_break()
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/optim/adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)    244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/optim/optimizer.py:150, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     148     return disabled_func(*args, **kwargs)
#     149 else:
# --> 150     return func(*args, **kwargs)
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/optim/adam.py:953, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     950 else:
#     951     func = _single_tensor_adam
# --> 953 func(
#     954     params,
#     955     grads,
#     956     exp_avgs,
#     957     exp_avg_sqs,
#     958     max_exp_avg_sqs,
#     959     state_steps,
#     960     amsgrad=amsgrad,
#     961     has_complex=has_complex,
#     962     beta1=beta1,
#     963     beta2=beta2,
#     964     lr=lr,
#     965     weight_decay=weight_decay,
#     966     eps=eps,
#     967     maximize=maximize,
#     968     capturable=capturable,
#     969     differentiable=differentiable,
#     970     grad_scale=grad_scale,
#     971     found_inf=found_inf,
#     972     decoupled_weight_decay=decoupled_weight_decay,
#     973 )
#
# File ~/.conda/envs/multiproc_env/lib/python3.13/site-packages/torch/optim/adam.py:777, in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     775     exp_avg_sq_sqrt = torch._foreach_sqrt(device_max_exp_avg_sqs)
#     776 else:
# --> 777     exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
#     779 torch._foreach_div_(exp_avg_sq_sqrt, bias_correction2_sqrt)
#     780 torch._foreach_add_(exp_avg_sq_sqrt, eps)
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

# %% [markdown]
# ## Evaluate Reconstruction

# %%
model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
# x,y = x1,y1
Ntest = 300#0
with torch.no_grad():
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x, y, False, number_of_showers=Ntest)

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000
y0 = Y0 / 5000

x_exp = x.unsqueeze(0).expand(Ntest, -1)
y_exp = y.unsqueeze(0).expand(Ntest, -1)


x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

inputs_test = torch.stack([x_exp, y_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test = (inputs_test - input_mean) / input_std
labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Processing conditions 0 to 300 / 300...

# %%
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
# x_pred = outputs[:, 0]
# y_pred = outputs[:, 1]
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])

E_p, E_r = E_pred, energy
# X_r, X_p = X0, x_pred * 5000
# Y_r, Y_p = Y0, y_pred * 5000
Th_r, Th_p = th, theta_pred
Ph_r, Ph_p = ph, phi_pred

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

axes[0, 0].scatter(E_r, E_p, alpha=.5, color="r")
axes[0, 0].plot([0, E_r.max()], [0, E_r.max()], "k-", lw=2)
axes[0, 0].set_xlabel("True E"); axes[0, 0].set_ylabel("Predicted E"); axes[0, 0].grid()

# axes[0, 1].scatter(X_r, X_p.detach(), alpha=.5, color="r")
# axes[0, 1].set_xlabel("True X"); axes[0, 1].set_ylabel("Predicted X"); axes[0, 1].grid()

# axes[0, 2].scatter(Y_r, Y_p.detach(), alpha=.5, color="r")
# axes[0, 2].set_xlabel("True Y"); axes[0, 2].set_ylabel("Predicted Y"); axes[0, 2].grid()

axes[1, 0].scatter(Th_r, Th_p.detach(), alpha=.5, color="r")
axes[1, 0].plot([0, np.pi*65/180], [0, np.pi*65/180], "k-", lw=2)
axes[1, 0].set_xlabel("True Theta"); axes[1, 0].set_ylabel("Predicted Theta"); axes[1, 0].grid()

axes[1, 1].scatter(Ph_r, Ph_p.detach(), alpha=.5, color="r")
axes[1, 1].plot([-np.pi, np.pi], [-np.pi, np.pi], "k-", lw=2)
axes[1, 1].set_xlabel("True Phi"); axes[1, 1].set_ylabel("Predicted Phi"); axes[1, 1].grid()

axes[1, 2].axis("off")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Load/Initialize Model for Optimization

# %%
torch.save(model.state_dict(), f"{output_dir}/model_weights.pth")

model = Reconstruction(num_detectors=Nunits).to(device)

path = Path(f"{output_dir}/checkpoint.pth")
if path.exists():
    checkpoint = torch.load(f"{output_dir}/checkpoint.pth")
    model.load_state_dict(checkpoint['model_state_dict'])
    print("Updated Weights are loaded")
else:
    model.load_state_dict(torch.load(f"{output_dir}/model_weights.pth"))
    print("Initial Weights are loaded")
# Out:
# Initial Weights are loaded

# %% [markdown]
# ## Initialize Learnable Layout

# %%
e = 0
os.makedirs(f"{output_dir}/Python_Layout", exist_ok=True)

for i in range(1000):
    p_layout = Path(f"{output_dir}/Python_Layout/Layout_{i + 1}.txt")
    if p_layout.exists():
        data = np.loadtxt(p_layout)
        x = torch.tensor(data[:, 0], dtype=torch.float32)
        y = torch.tensor(data[:, 1], dtype=torch.float32)
        e = i + 1

if e > 0:
    print(f"Updated Layout {e} is initialized")
else:
    print("First Layout is initialized")

xy_module = LearnableXY(x, y)
# Out:
# First Layout is initialized

# %% [markdown]
# ## Layout Optimization Loop

# %%
# %%time

SWGOopt = True
optimizer = torch.optim.SGD(xy_module.parameters(), lr=5, momentum=.9)

if path.exists():
    checkpoint = torch.load(path)
    optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
    num_epoch = checkpoint.get("epoch") + 1
    loss = checkpoint.get("loss")
    print(f"Optimizer is initialized from the last epoch {num_epoch}")
else:
    num_epoch = 0
    print("Optimizer is initialized")

max_grad = 10.
Nbatch = 100#0

if num_epoch < 20:
    Nfinetune = 250#0
elif num_epoch >= 20:
    Nfinetune = 500#0

U_vals = []
U_pr_vals = []
U_e_vals = []
U_th_vals = []

for epoch in range(num_epoch, num_epoch + 50):
    x1, y1 = xy_module()
    
    N_list, T_list, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x1, y1, False, number_of_showers=Nbatch)
    
    th = torch.atan2(sin_z, cos_z)
    ph = torch.atan2(sin_a, cos_a)

    E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
    x0 = X0 / 5000
    y0 = Y0 / 5000

    x = x1.unsqueeze(0).repeat(Nbatch, 1)
    y = y1.unsqueeze(0).repeat(Nbatch, 1)
    
    x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
    y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

    labels_batch = torch.stack([ E_norm, theta_norm, phi_norm], dim=1).float().to(device)
    events_batch = torch.stack([x, y, N_list, T_list, x0_exp, y0_exp], dim=2).float()
    events_batch_norm = (events_batch - input_mean) / input_std
    
    model.eval()
    preds_batch = model(events_batch_norm.view(Nbatch, -1).to(device))

    # preds_x = preds_batch[:, 0] * 5000
    # preds_y = preds_batch[:, 1] * 5000
    preds_e, preds_th, preds_phi = DenormalizeLabels(preds_batch[:, 0], preds_batch[:, 1], preds_batch[:, 2])

    r_score = reconstructability(events_batch[:, :, 2]).to(device)
    # density = Nbatch / ((events_batch[:, 4].max() - events_batch[:, 4].min()) * 
    #                     (events_batch[:, 5].max() - events_batch[:, 5].min()))
    

    U = 1e-1 * U_TH(preds_th, labels_batch[:, 1], r_score) + 1e3*U_E(preds_e, labels_batch[:, 0], r_score) + 5e3*U_PR(r_score)

    U_vals.append(U.item())
    U_pr_vals.append((5e3*U_PR(r_score)).item())
    U_e_vals.append(1e3*U_E(preds_e, labels_batch[:, 0], r_score).item())
    U_th_vals.append(1e-1 * U_TH(preds_th, labels_batch[:, 1], r_score).item())

    print(f"Utility: {U:.2f}")

    Loss = -U
    Loss.backward()
    for name, p in xy_module.named_parameters():
        print(f"{name}: grad norm = {p.grad.norm().item() if p.grad is not None else 'None'}")


    torch.nn.utils.clip_grad_norm_(xy_module.parameters(), max_norm=max_grad)
    optimizer.step()

    with torch.no_grad():
        push_apart(xy_module, min_dist=2 * TankRadius)

    optimizer.zero_grad()

    # Fine-tune NN every 5 epochs
    if (epoch + 1) % 5 == 0:
        print(f"Fine Tune at epoch {epoch + 1}")
        
        with torch.no_grad():
            x2, y2 = xy_module()
            x_ft = x2.detach()
            y_ft = y2.detach()

            N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x_ft, y_ft, False, number_of_showers=Nfinetune)
            
            theta = torch.atan2(sin_z, cos_z)
            phi = torch.atan2(sin_a, cos_a)
            energy, theta, phi = NormalizeLabels(energy, theta, phi)
            X0 /= 5000
            Y0 /= 5000
            
            finetune_trues = torch.stack([ energy, theta, phi], dim=1).float()
            
            x_exp = x_ft.unsqueeze(0).expand(Nfinetune, -1)
            y_exp = y_ft.unsqueeze(0).expand(Nfinetune, -1)
            
            x0_exp = X0.unsqueeze(1).expand(-1, Nunits)
            y0_exp = Y0.unsqueeze(1).expand(-1, Nunits)

            finetune_events = torch.stack([x_exp, y_exp, N, T, x0_exp, y0_exp], dim=2).float()
            finetune_events = (finetune_events - input_mean) / input_std  # add this line



        ReconstructionNN = model
        ReconstructionNN.train()
        criterion = nn.MSELoss()
        optimizerNN = torch.optim.Adam(ReconstructionNN.parameters(), lr=5e-5)

        ft_dataset = TensorDataset(finetune_events, finetune_trues)
        ft_dataloader = DataLoader(ft_dataset, batch_size=32, shuffle=True, drop_last=True, num_workers=4)

        for j in range(5):
            for ft_batch, ft_trues in ft_dataloader:
                batch_size = ft_batch.size(0)
                train_x = ft_batch.view(batch_size, -1).to(device)
                train_y = ft_trues.view(batch_size, 3).to(device)
                outputs = ReconstructionNN(train_x)
                lossT = criterion(outputs, train_y)
                lossT.backward()
                optimizerNN.step()
                optimizerNN.zero_grad()
                # after fine-tuning loop ends
        
        # model.zero_grad()
        # optimizer.zero_grad()  # clear xy_module grads
        # for param in xy_module.parameters():
        #     if param in optimizer.state:
        #         optimizer.state[param]['momentum_buffer'] = torch.zeros_like(param)



    torch.save({"epoch": epoch, "loss": Loss.cpu(), "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict()}, f"{output_dir}/checkpoint.pth")
    
    np.savetxt(f"{output_dir}/Python_Layout/Layout_{epoch + 1}.txt",
               np.column_stack((x1.detach().numpy(), y1.detach().numpy())))
# Out:
# Optimizer is initialized
# Processing conditions 0 to 100 / 100...
# Utility: 68397.28
# x: grad norm = 1438.9637451171875
# y: grad norm = 177.97506713867188
# Processing conditions 0 to 100 / 100...
# Utility: 69474.05
# x: grad norm = 429.0885925292969
# y: grad norm = 921.5631713867188
# Processing conditions 0 to 100 / 100...
# Utility: 72623.77
# x: grad norm = 2267.312744140625
# y: grad norm = 2028.4373779296875
# Processing conditions 0 to 100 / 100...
# Utility: 74577.22
# x: grad norm = 816.3388671875
# y: grad norm = 2095.671630859375
# Processing conditions 0 to 100 / 100...
# Utility: 73841.77
# x: grad norm = 920.9091186523438
# y: grad norm = 1271.6207275390625
# Fine Tune at epoch 5
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 76731.36
# x: grad norm = 1220.9002685546875
# y: grad norm = 1162.001953125
# Processing conditions 0 to 100 / 100...
# Utility: 74775.26
# x: grad norm = 3225.440185546875
# y: grad norm = 11444.0869140625
# Processing conditions 0 to 100 / 100...
# Utility: 63397.23
# x: grad norm = 1742.589599609375
# y: grad norm = 2149.297119140625
# Processing conditions 0 to 100 / 100...
# Utility: 78718.75
# x: grad norm = 2563.8974609375
# y: grad norm = 2215.587646484375
# Processing conditions 0 to 100 / 100...
# Utility: 78128.75
# x: grad norm = 677.2317504882812
# y: grad norm = 14141.9951171875
# Fine Tune at epoch 10
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 76124.53
# x: grad norm = 11701.8603515625
# y: grad norm = 19335.30078125
# Processing conditions 0 to 100 / 100...
# Utility: 67512.00
# x: grad norm = 61.75908279418945
# y: grad norm = 74.32452392578125
# Processing conditions 0 to 100 / 100...
# Utility: 69296.02
# x: grad norm = 11669.076171875
# y: grad norm = 2345.660888671875
# Processing conditions 0 to 100 / 100...
# Utility: 59796.64
# x: grad norm = 1648.96044921875
# y: grad norm = 2239.568603515625
# Processing conditions 0 to 100 / 100...
# Utility: 66946.10
# x: grad norm = 213.27798461914062
# y: grad norm = 102.69610595703125
# Fine Tune at epoch 15
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 55346.78
# x: grad norm = 1248.9884033203125
# y: grad norm = 3525.402099609375
# Processing conditions 0 to 100 / 100...
# Utility: 69145.56
# x: grad norm = 2278.371337890625
# y: grad norm = 2456.652587890625
# Processing conditions 0 to 100 / 100...
# Utility: 68112.95
# x: grad norm = 741.2265014648438
# y: grad norm = 671.6669311523438
# Processing conditions 0 to 100 / 100...
# Utility: 67583.09
# x: grad norm = 139.02406311035156
# y: grad norm = 417.74310302734375
# Processing conditions 0 to 100 / 100...
# Utility: 60793.65
# x: grad norm = 757.180419921875
# y: grad norm = 396.9645080566406
# Fine Tune at epoch 20
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 70964.33
# x: grad norm = 109.13450622558594
# y: grad norm = 52.5568733215332
# Processing conditions 0 to 100 / 100...
# Utility: 61497.77
# x: grad norm = 238.98727416992188
# y: grad norm = 242.73069763183594
# Processing conditions 0 to 100 / 100...
# Utility: 64835.05
# x: grad norm = 262.4641418457031
# y: grad norm = 290.9610595703125
# Processing conditions 0 to 100 / 100...
# Utility: 54194.84
# x: grad norm = 279.9499206542969
# y: grad norm = 167.3428497314453
# Processing conditions 0 to 100 / 100...
# Utility: 61504.37
# x: grad norm = 2460.153076171875
# y: grad norm = 4770.26318359375
# Fine Tune at epoch 25
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 55697.16
# x: grad norm = 204.11749267578125
# y: grad norm = 153.76039123535156
# Processing conditions 0 to 100 / 100...
# Utility: 57785.17
# x: grad norm = 95.51998901367188
# y: grad norm = 314.6643371582031
# Processing conditions 0 to 100 / 100...
# Utility: 57640.87
# x: grad norm = 1173.38330078125
# y: grad norm = 1019.7128295898438
# Processing conditions 0 to 100 / 100...
# Utility: 61039.32
# x: grad norm = 2098.1494140625
# y: grad norm = 1971.3018798828125
# Processing conditions 0 to 100 / 100...
# Utility: 52600.84
# x: grad norm = 1201.46826171875
# y: grad norm = 733.3567504882812
# Fine Tune at epoch 30
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 64683.65
# x: grad norm = 1127.015625
# y: grad norm = 619.0281372070312
# Processing conditions 0 to 100 / 100...
# Utility: 60688.16
# x: grad norm = 224.89996337890625
# y: grad norm = 45.325313568115234
# Processing conditions 0 to 100 / 100...
# Utility: 60789.38
# x: grad norm = 130.33505249023438
# y: grad norm = 58.78396987915039
# Processing conditions 0 to 100 / 100...
# Utility: 57039.12
# x: grad norm = 88.69081115722656
# y: grad norm = 24.738380432128906
# Processing conditions 0 to 100 / 100...
# Utility: 55641.36
# x: grad norm = 409.6418151855469
# y: grad norm = 180.6623077392578
# Fine Tune at epoch 35
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 54406.12
# x: grad norm = 1219.5826416015625
# y: grad norm = 988.1245727539062
# Processing conditions 0 to 100 / 100...
# Utility: 62519.59
# x: grad norm = 2098.682373046875
# y: grad norm = 1568.981689453125
# Processing conditions 0 to 100 / 100...
# Utility: 58698.66
# x: grad norm = 474.9097900390625
# y: grad norm = 247.5580596923828
# Processing conditions 0 to 100 / 100...
# Utility: 48892.67
# x: grad norm = 106.66387939453125
# y: grad norm = 166.9689483642578
# Processing conditions 0 to 100 / 100...
# Utility: 60255.69
# x: grad norm = 744.9799194335938
# y: grad norm = 638.9331665039062
# Fine Tune at epoch 40
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 59951.93
# x: grad norm = 891.4960327148438
# y: grad norm = 801.8577880859375
# Processing conditions 0 to 100 / 100...
# Utility: 64594.25
# x: grad norm = 1376.5767822265625
# y: grad norm = 709.9553833007812
# Processing conditions 0 to 100 / 100...
# Utility: 75615.37
# x: grad norm = 6991.37939453125
# y: grad norm = 5561.2265625
# Processing conditions 0 to 100 / 100...
# Utility: 55934.09
# x: grad norm = 776.6390991210938
# y: grad norm = 1030.6683349609375
# Processing conditions 0 to 100 / 100...
# Utility: 62132.25
# x: grad norm = 1679.2119140625
# y: grad norm = 1527.9835205078125
# Fine Tune at epoch 45
# Processing conditions 0 to 250 / 250...
# Processing conditions 0 to 100 / 100...
# Utility: 53208.59
# x: grad norm = 593.6553955078125
# y: grad norm = 659.7123413085938
# Processing conditions 0 to 100 / 100...
# Utility: 61306.38
# x: grad norm = 379.7630920410156
# y: grad norm = 217.0524444580078
# Processing conditions 0 to 100 / 100...
# Utility: 67073.64
# x: grad norm = 19108.7890625
# y: grad norm = 24970.0625
# Processing conditions 0 to 100 / 100...
# Utility: 50940.31
# x: grad norm = 965.4332275390625
# y: grad norm = 1034.936767578125
# Processing conditions 0 to 100 / 100...
# Utility: 59681.55
# x: grad norm = 688.607177734375
# y: grad norm = 586.1917114257812
# Fine Tune at epoch 50
# Processing conditions 0 to 250 / 250...
# CPU times: user 11min 37s, sys: 2min 29s, total: 14min 6s
# Wall time: 14min 15s

# %%
plt.plot(U_vals, label='U_vals')
plt.plot(U_pr_vals, label='U_pr_vals')
plt.plot(np.array(U_e_vals), label='U_e_vals (x100)')
plt.plot(np.array(U_th_vals), label='U_th_vals (x10)')
plt.legend()

# %% [markdown]
# ## Visualize Results

# %%
a, b = Layouts(n_detectors=Nunits, n_rings=20, radius=300)

plt.figure(figsize=[12, 12])
plt.scatter(x1.detach() if 'x1' in dir() else x.detach(), 
            y1.detach() if 'y1' in dir() else y.detach(), color="red", alpha=.8, label="Final Layout")
plt.scatter(a, b, color="blue", alpha=.3, label="Initial Layout")
plt.grid(); plt.xlabel("x [m]"); plt.ylabel("y [m]")
plt.title("Position of the detectors"); plt.legend()
plt.show()

# %%
utility_path = Path(f"{output_dir}/Python_Layout/Utilities.txt")

if utility_path.exists():
    u_t = np.loadtxt(utility_path)
    u_t = np.append(u_t, np.array(U_vals).ravel())
    np.savetxt(utility_path, u_t)
else:
    u_t = U_vals
    np.savetxt(utility_path, u_t)

# %%
mean_ut = [np.mean(u_t[i - 4: i]) for i in range(4, len(u_t))]

plt.plot(u_t, color="black", linestyle="none", marker="o", linewidth=.5, label="Total Utility")
plt.plot(np.arange(4, len(u_t)), mean_ut, linestyle="-", linewidth=2, label="Mean Utility")
plt.legend(); plt.grid()
plt.xlabel("Epoch"); plt.ylabel("Utility Score")
# plt.ylim((-0.1, 1000.2))
plt.title("Utility Values per Optimization Step")
plt.show()

# %% [markdown]
# ## Evaluate Reconstruction (end)

# %%
x,y = x1,y1
Ntest = 300#0
with torch.no_grad():
    N, T, X0, Y0, energy, sin_z, cos_z, sin_a, cos_a = generate_showers(x, y, False, number_of_showers=Ntest)

th = torch.atan2(sin_z, cos_z)
ph = torch.atan2(sin_a, cos_a)

E_norm, theta_norm, phi_norm = NormalizeLabels(energy, th, ph)
x0 = X0 / 5000
y0 = Y0 / 5000

x_exp = x.unsqueeze(0).expand(Ntest, -1)
y_exp = y.unsqueeze(0).expand(Ntest, -1)


x0_exp = x0.unsqueeze(1).expand(-1, Nunits)
y0_exp = y0.unsqueeze(1).expand(-1, Nunits)

inputs_test = torch.stack([x_exp, y_exp, N, T, x0_exp, y0_exp], dim=2).float()
inputs_test = (inputs_test - input_mean) / input_std  # add this line
labels_test = torch.stack([E_norm, theta_norm, phi_norm], dim=1).float()
# Out:
# Processing conditions 0 to 300 / 300...

# %%
model.eval()
with torch.no_grad():
    outputs = model(inputs_test.view(Ntest, -1).to(device)).cpu()

# %%
# x_pred = outputs[:, 0]
# y_pred = outputs[:, 1]
E_pred, theta_pred, phi_pred = DenormalizeLabels(outputs[:, 0], outputs[:, 1], outputs[:, 2])

E_p, E_r = E_pred, energy
# X_r, X_p = X0, x_pred * 5000
# Y_r, Y_p = Y0, y_pred * 5000
Th_r, Th_p = th, theta_pred
Ph_r, Ph_p = ph, phi_pred

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

axes[0, 0].scatter(E_r, E_p, alpha=.5, color="r")
axes[0, 0].plot([0, E_r.max()], [0, E_r.max()], "k-", lw=2)
axes[0, 0].set_xlabel("True E"); axes[0, 0].set_ylabel("Predicted E"); axes[0, 0].grid()

# axes[0, 1].scatter(X_r, X_p.detach(), alpha=.5, color="r")
# axes[0, 1].set_xlabel("True X"); axes[0, 1].set_ylabel("Predicted X"); axes[0, 1].grid()

# axes[0, 2].scatter(Y_r, Y_p.detach(), alpha=.5, color="r")
# axes[0, 2].set_xlabel("True Y"); axes[0, 2].set_ylabel("Predicted Y"); axes[0, 2].grid()

axes[1, 0].scatter(Th_r, Th_p.detach(), alpha=.5, color="r")
axes[1, 0].plot([0, np.pi*65/180], [0, np.pi*65/180], "k-", lw=2)
axes[1, 0].set_xlabel("True Theta"); axes[1, 0].set_ylabel("Predicted Theta"); axes[1, 0].grid()

axes[1, 1].scatter(Ph_r, Ph_p.detach(), alpha=.5, color="r")
axes[1, 1].plot([-np.pi, np.pi], [-np.pi, np.pi], "k-", lw=2)
axes[1, 1].set_xlabel("True Phi"); axes[1, 1].set_ylabel("Predicted Phi"); axes[1, 1].grid()

axes[1, 2].axis("off")
plt.tight_layout(); plt.show()
